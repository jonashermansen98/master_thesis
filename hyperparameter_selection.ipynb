# %% [markdown]
# # Upload data and embeddings

# %%
import pandas as pd
df_2024 = pd.read_csv('~/Library/Mobile Documents/com~apple~CloudDocs/UNI-kopi 2/Kandidat/virtual_environments/data/short.csv')
df_2023 = pd.read_csv('~/Library/Mobile Documents/com~apple~CloudDocs/UNI-kopi 2/Kandidat/virtual_environments/data/short_2023.csv')

# Combine datasets
df_combined = pd.concat([df_2024, df_2023], ignore_index=True)

documents = df_combined["translated_Comment"].tolist()

# %%
import numpy as np

embeddings = np.load("embeddings.npy")

# %%
del keybert_model
del mmr_model
del representation_model

# %% [markdown]
# # Reload definitions

# %% [markdown]
# Redefine definitions needed to upload the models later, so I don't need to run the grid searches again

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
import spacy
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.model_selection import ParameterGrid
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance
from octis.evaluation_metrics.coherence_metrics import Coherence
from umap import UMAP
from hdbscan import HDBSCAN
import spacy


# Prepare Tokenizer model
# Load spaCy English model
nlp = spacy.load("en_core_web_sm")
nlp.max_length = 1520000

# Define custom tokenizer function with lemmatization for topic representations
def spacy_tokenizer(doc):
    spacy_doc = nlp(doc)
    # Lemmatize, lowercase, remove stopwords & punctuation
    return [token.lemma_.lower() for token in spacy_doc if not token.is_stop and not token.is_punct] #

base_vectorizer = CountVectorizer(tokenizer=spacy_tokenizer, min_df=5) # remove words that appear in less than 5 documents
base_vectorizer.fit(documents) # fit the vectorizer to the documents, to find the vocabulary for topic representations
filtered_vocab = set(base_vectorizer.get_feature_names_out()) # # get the vocabulary of the filtered vectorizer

def filtered_tokenizer(doc): # Now create a custom tokenizer that only keeps words in the filtered vocabulary, which will be passed to the CountVectorizer for topic representations
    tokens = spacy_tokenizer(doc)
    return [t for t in tokens if t in filtered_vocab]

# Create CountVectorizer with custom tokenizer
vectorizer_model = CountVectorizer(tokenizer=filtered_tokenizer, # use the custom tokenizer
                                   #stop_words="english", # already done in the tokenizer, but countvectorizer might have other stop words
                                   lowercase = False, # lowercase is already done in the tokenizer
                                   min_df = 1, #  Excludes words that appear in only one document.
                                   ngram_range=(1, 2)) # consider topic representations that are made up of one or two words

def coherence_tokenizer(doc): # The tokenizer for the coherence score. This is a standard tokenizer that does not filter out words, but lemmatizes and lowercases them.
    spacy_doc = nlp(doc)
    return [
        token.lemma_.lower()
        for token in spacy_doc
        if not token.is_punct  # keep stopwords as I want to calculate the coherence score based on all words
    ]

tokens_for_coherence = [coherence_tokenizer(doc) for doc in documents]

# %% [markdown]
# # The first grid

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
import spacy
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.model_selection import ParameterGrid
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance
from octis.evaluation_metrics.coherence_metrics import Coherence
from umap import UMAP
from hdbscan import HDBSCAN
import spacy

# Load your data
#df = pd.read_csv('~/Library/Mobile Documents/com~apple~CloudDocs/UNI-kopi 2/Kandidat/virtual_environments/data/short.csv')
#documents = df["translated_Comment"].tolist() # Convert to list of strings


# Define the hyperparameter grid
param_grid = {
    # BERTOPIC parameters
    #"min_topic_size": [50,70,90], # Minimum size of a topic. Should be higher than min_cluster_size
    #"top_n_words": [10],
    #"nr_topics": ["none","auto"], # None means no reduction

    #UMAP parameters
    "n_components": [2,5], # Number of dimensions to reduce to
    "n_neighbors": [10,15,20], # Number of neighbors to consider for UMAP 

    #HDBSCAN parameters
    "min_cluster_size": [50,70,90,110], # Min cluster size for HDBSCAN # Min cluster size for HDBSCAN. 
    "min_samples": [50,70,90,110] # Minimum number of samples in a cluster
}
#Create all possible combinations of the hyperparameter grid
grid = list(ParameterGrid(param_grid))


# Filter: only keep combinations where min_cluster_size <= min_topic_size
valid_grid = [
    params for params in grid
    if params["min_samples"] <= params["min_cluster_size"]
]

# Total number combinations. Used later in the print statement to show progress
total = len(valid_grid)

#total = len(grid)


# Embedding model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
#Compute embeddings
#embeddings = embedding_model.encode(documents, show_progress_bar=True)


# Prepare Tokenizer model
# Load spaCy English model
nlp = spacy.load("en_core_web_sm")
nlp.max_length = 1520000

# Define custom tokenizer function with lemmatization for topic representations
def spacy_tokenizer(doc):
    spacy_doc = nlp(doc)
    # Lemmatize, lowercase, remove stopwords & punctuation
    return [token.lemma_.lower() for token in spacy_doc if not token.is_stop and not token.is_punct] #

base_vectorizer = CountVectorizer(tokenizer=spacy_tokenizer, min_df=5) # remove words that appear in less than 5 documents
base_vectorizer.fit(documents) # fit the vectorizer to the documents, to find the vocabulary for topic representations
filtered_vocab = set(base_vectorizer.get_feature_names_out()) # # get the vocabulary of the filtered vectorizer

def filtered_tokenizer(doc): # Now create a custom tokenizer that only keeps words in the filtered vocabulary, which will be passed to the CountVectorizer for topic representations
    tokens = spacy_tokenizer(doc)
    return [t for t in tokens if t in filtered_vocab]

# Create CountVectorizer with custom tokenizer
vectorizer_model = CountVectorizer(tokenizer=filtered_tokenizer, # use the custom tokenizer
                                   #stop_words="english", # already done in the tokenizer, but countvectorizer might have other stop words
                                   lowercase = False, # lowercase is already done in the tokenizer
                                   min_df = 1, #  Excludes words that appear in only one document.
                                   ngram_range=(1, 2)) # consider topic representations that are made up of one or two words

def coherence_tokenizer(doc): # The tokenizer for the coherence score. This is a standard tokenizer that does not filter out words, but lemmatizes and lowercases them.
    spacy_doc = nlp(doc)
    return [
        token.lemma_.lower()
        for token in spacy_doc
        if not token.is_punct  # keep stopwords as I want to calculate the coherence score based on all words
    ]

tokens_for_coherence = [coherence_tokenizer(doc) for doc in documents] 


# Fine-tune representations 
#keybert_model = KeyBERTInspired()
#mmr_model = MaximalMarginalRelevance(diversity=0.2) #0.2 is used in the book.

#representation_model = {
    #"KeyBERT": keybert_model,
    #"MMR": mmr_model
#}


# Function to calculate Topic Diversity as the proportion of unique words across all top-k topic words (PUW)
def topic_diversity(topics, topk):
    all_words = [word for topic in topics for word in topic[:topk]]
    unique_words = set(all_words)
    return len(unique_words) / len(all_words)


# Defintions to later being able to track best model. 
best_model = None #no best model from the start
best_score = -1 # the first model with a score better than -1 will the current best. Just a placeholder make npmi_score > best_score work.
best_params = None #no best parameters from the start


# Results storage. A list that sores the coherence and diversty score of each model
results = []
# A list which saves all the models, so each model can be easily retrieved by typing its corresponding parameters
saved_models = {}  



#### THE LOOP ####
# Grid search
for i, params in enumerate(valid_grid, 1):#change to valid_grid as the parameter grid to iterate over if min_topic_size is used
    print(f"[{i}/{total}] Running with params: {params}") #print the current parameter combination being evaluated for each iteration 

    # UMAP
    umap_model = UMAP(n_neighbors=params["n_neighbors"],
                      n_components=params["n_components"], 
                      min_dist=0.0, 
                      metric='cosine', 
                      random_state=42)

    # HDBSCAN  
    hdbscan_model = HDBSCAN(min_cluster_size=params["min_cluster_size"], 
                            min_samples=params["min_samples"], 
                            metric='euclidean', 
                            cluster_selection_method='eom',
                            prediction_data=True
                            )

    # BERTopic model
    topic_model = BERTopic(
        #nr_topics=params["nr_topics"],
        #min_topic_size=params["min_topic_size"]
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        #representation_model=representation_model,
        vectorizer_model=vectorizer_model, #this makes some models not able to calculate NPMI
        #ctfidf_model=ctfidf_model,
        top_n_words=10,   
    )

    # Fit model
    topics, _ = topic_model.fit_transform(documents, embeddings)

    # Save meach model in the Saved_models list
    param_key = tuple(sorted(params.items()))  # extracting the parameters for the each model and creates a unique key for every model combination
    saved_models[param_key] = topic_model # save the each model in the saved_models list by its unique key 


    # Get top `top_n_words` words per topic (excluding outlier topic -1)
    topic_words = [] #an empty list that will be used to store the top words of every topic found for each model. So a list (topics) of lists (top words for each topic).
    
    for topic in topic_model.get_topic_freq().Topic: # grabs the topics from the topic_model
        if topic != -1: #skips the outlier topic -1
            topic_content = topic_model.get_topic(topic) #get the top words and scores for the topics.
            if isinstance(topic_content, list) and len(topic_content) > 0: # checks if the topic_content (top words) is a list and has more than 0 elements. To check if there actually is extracted topic words
                if isinstance(topic_content[0], tuple) and len(topic_content[0]) == 2: # checks if the first element of topic_content is a tuple and has two elements (word and score)
                    words = [word for word, _ in topic_content[:topic_model.top_n_words]] #if so, it extracts the words (but not the scores) in a variable called "words"
                else:
                    words = topic_content[:topic_model.top_n_words] #if there is only top words but no scores, extracts the top words in a variabkle called "words"
                topic_words.append(words) #append the topic words (defined in the variable "words") to the topic_words list for the model.

    if topic_words:
        
        # Calculate NPMI
        coherence_model = Coherence(texts=tokens_for_coherence, # reference corpus. Here it's all documents in the dataset
                                    topk=10, #specifies the number of top words to consider for NPMI calculation
                                    measure="c_npmi")
        npmi_score = coherence_model.score({"topics": topic_words}) # average

        # Calculate Topic Diversity
            # the topic_diversity command was defned before the loop. This is not a standard command, so I defined how it works earlier.
        diversity_score = topic_diversity(topics=topic_words, topk=10)

        # Calculate Topic Quality by multiplying NPMI score and Topic Diversity
        topic_quality = npmi_score * diversity_score 


        # Print the number of topics
        num_topics = len(topic_words) #number of topics is the length of the topic_words list
        num_outliers = sum(1 for topic in topics if topic == -1) #number of outliers is the number of topics that are equal to -1
        print(f"Number of Topics: {num_topics} | TC: {npmi_score:.3f} | TD: {diversity_score:.3f} | TQ: {topic_quality:.3f} | num_outliers: {num_outliers}") #4f = 4 decimals 

        # Track best model
        if npmi_score > best_score:
            best_score = npmi_score
            best_model = topic_model
            best_params = params

        # store the params, npmi, diversy, and num_topcis for each model in the results list
        results.append({
            "params": params,
            "num_topics": num_topics,
            "npmi_score": npmi_score,
            "topic_diversity": diversity_score,
            "topic_quality": topic_quality,
            "num_outliers": num_outliers
        })

    else:
        print("No valid topics were generated.")

#####

import csv

# Save the all the models' information to a CSV file

model_info = [] # an empty list to store model information. This is the dataframe that will be saved in the CSV file in the end 

# Loop through the models saved from the loop above and save the information to the model_info dataframe
for param_key, model in saved_models.items(): #activates a loop that goes through all the models (identified by their unique key).
    # Convert the tuple of params back to a dictionary (a formal step)
    params_dict = dict(param_key)
    
    # Get topic information
    #topics_freq = model.get_topic_freq() #retrives the number of topics and documents in each topic
    #num_topics = len(topics_freq[topics_freq.Topic != -1]) #retrives the number of topics (length) and exlcudes the outlier topic -1
    
    ## Get performance metrics if available
    # Matches the models with parameters saved in the loop with the parameters of models saved in the CVS file
    matching_result = next((r for r in results if all(r["params"][k] == v for k, v in params_dict.items())), None)
    
    if matching_result: 
        num_topics =matching_result.get("num_topics", 0) #extract the number of topics for the models
        num_outliers = matching_result.get("num_outliers", 0) #extract the number of outliers for the models
        npmi_score = matching_result.get("npmi_score", 0) #extract the NPMI score for the models
        diversity_score = matching_result.get("topic_diversity", 0) #extract the topic diversity score for the models
        topic_quality = matching_result.get("topic_quality", 0) #extract the topic quality score for the models
        
        model_info.append({  #assigns the number of topics and scores to the differnt models in the model_info list. This is the dataframe that will be saved in the CSV file.
            **params_dict,  
            "num_topics": num_topics,
            "npmi_score": npmi_score,
            "topic_diversity": diversity_score,
            "topic_quality": topic_quality,
            "num_outliers" : num_outliers   
        })

# Now we retrived all the information to the model_info dataframe, 
# Saves it to CSV file
with open('very_first_model.csv', 'w', newline='') as csvfile:
    fieldnames = list(model_info[0].keys()) if model_info else []
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    for info in model_info:
        writer.writerow(info)


# Sort the results by NPMI score in descending order
top_20_npmi = sorted(results, key=lambda x: x["npmi_score"], reverse=True)[:10]

# Sort the results by Topic Diversity score in descending order
top_20_diversity = sorted(results, key=lambda x: x["topic_diversity"], reverse=True)[:10]

# Sort the results by both NPMI and Topic Diversity score in descending order
top_20_quality = sorted(results, key=lambda x: (x["topic_quality"]), reverse=True)[:10]

# Print the top 20 based on NPMI
print("\nTop 20 Best Performing Models (Based on NPMI):\n")
for i, result in enumerate(top_20_npmi, start=1):
    print(f"Rank {i}: num_topics: {result['num_topics']} | {result['params']} | TC: {result['npmi_score']:.3f} | TD: {result['topic_diversity']:.3f} | TQ: {result['topic_quality']:.3f} | num_outliers: {result['num_outliers']})")

# Print the top 20 based on Topic Diversity
print("\nTop 20 Best Performing Models (Based on Topic Diversity):\n")
for i, result in enumerate(top_20_diversity, start=1):
    print(f"Rank {i}: num_topics: {result['num_topics']} | {result['params']} | TC: {result['npmi_score']:.3f} | TD: {result['topic_diversity']:.3f} | TQ: {result['topic_quality']:.3f} | num_outliers: {result['num_outliers']})")

# Print the top 20 based on topic quality
print("\nTop 20 Best Performing Models (Based on topic quality):\n")
for i, result in enumerate(top_20_quality, start=1):
    print(f"Rank {i}: num_topics: {result['num_topics']} | {result['params']} | TC: {result['npmi_score']:.3f} | TD: {result['topic_diversity']:.3f} | TQ: {result['topic_quality']:.3f} | num_outliers: {result['num_outliers']})")
# Out:
# [1/60] Running with params: {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 36 | TC: 0.058 | TD: 0.683 | TQ: 0.039 | num_outliers: 4382
# [2/60] Running with params: {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 38 | TC: 0.059 | TD: 0.682 | TQ: 0.040 | num_outliers: 3848
# [3/60] Running with params: {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 36 | TC: 0.073 | TD: 0.700 | TQ: 0.051 | num_outliers: 4106
# [4/60] Running with params: {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 2 | TC: 0.102 | TD: 0.950 | TQ: 0.097 | num_outliers: 330
# [5/60] Running with params: {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 33 | TC: 0.084 | TD: 0.718 | TQ: 0.060 | num_outliers: 4335
# [6/60] Running with params: {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 28 | TC: 0.072 | TD: 0.732 | TQ: 0.053 | num_outliers: 3886
# [7/60] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 24 | TC: 0.069 | TD: 0.667 | TQ: 0.046 | num_outliers: 3831
# [8/60] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 28 | TC: 0.080 | TD: 0.675 | TQ: 0.054 | num_outliers: 3628
# [9/60] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 25 | TC: 0.078 | TD: 0.668 | TQ: 0.052 | num_outliers: 3604
# [10/60] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 27 | TC: 0.081 | TD: 0.711 | TQ: 0.058 | num_outliers: 3917
# [11/60] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 26 | TC: 0.095 | TD: 0.708 | TQ: 0.067 | num_outliers: 4109
# [12/60] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 22 | TC: 0.053 | TD: 0.705 | TQ: 0.037 | num_outliers: 3375
# [13/60] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 23 | TC: 0.062 | TD: 0.691 | TQ: 0.043 | num_outliers: 4286
# [14/60] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 26 | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059
# [15/60] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 22 | TC: 0.095 | TD: 0.677 | TQ: 0.064 | num_outliers: 3968
# [16/60] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 22 | TC: 0.060 | TD: 0.709 | TQ: 0.043 | num_outliers: 4154
# [17/60] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 21 | TC: 0.078 | TD: 0.705 | TQ: 0.055 | num_outliers: 3781
# [18/60] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 20 | TC: 0.075 | TD: 0.710 | TQ: 0.053 | num_outliers: 3697
# [19/60] Running with params: {'min_cluster_size': 90, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 21 | TC: 0.046 | TD: 0.638 | TQ: 0.029 | num_outliers: 3604
# [20/60] Running with params: {'min_cluster_size': 90, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 20 | TC: 0.059 | TD: 0.655 | TQ: 0.039 | num_outliers: 3754
# [21/60] Running with params: {'min_cluster_size': 90, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 21 | TC: 0.048 | TD: 0.643 | TQ: 0.031 | num_outliers: 3579
# [22/60] Running with params: {'min_cluster_size': 90, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 15 | TC: 0.055 | TD: 0.660 | TQ: 0.037 | num_outliers: 2681
# [23/60] Running with params: {'min_cluster_size': 90, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 22 | TC: 0.056 | TD: 0.686 | TQ: 0.038 | num_outliers: 3676
# [24/60] Running with params: {'min_cluster_size': 90, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 19 | TC: 0.053 | TD: 0.695 | TQ: 0.037 | num_outliers: 3600
# [25/60] Running with params: {'min_cluster_size': 90, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 19 | TC: 0.070 | TD: 0.695 | TQ: 0.049 | num_outliers: 3880
# [26/60] Running with params: {'min_cluster_size': 90, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 20 | TC: 0.068 | TD: 0.695 | TQ: 0.047 | num_outliers: 4057
# [27/60] Running with params: {'min_cluster_size': 90, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 19 | TC: 0.056 | TD: 0.658 | TQ: 0.037 | num_outliers: 3578
# [28/60] Running with params: {'min_cluster_size': 90, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 15 | TC: 0.055 | TD: 0.700 | TQ: 0.039 | num_outliers: 3122
# [29/60] Running with params: {'min_cluster_size': 90, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 14 | TC: 0.045 | TD: 0.707 | TQ: 0.032 | num_outliers: 2635
# [30/60] Running with params: {'min_cluster_size': 90, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 18 | TC: 0.058 | TD: 0.700 | TQ: 0.041 | num_outliers: 3851
# [31/60] Running with params: {'min_cluster_size': 90, 'min_samples': 90, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 14 | TC: 0.045 | TD: 0.650 | TQ: 0.029 | num_outliers: 3220
# [32/60] Running with params: {'min_cluster_size': 90, 'min_samples': 90, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 18 | TC: 0.065 | TD: 0.683 | TQ: 0.044 | num_outliers: 4458
# [33/60] Running with params: {'min_cluster_size': 90, 'min_samples': 90, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 17 | TC: 0.055 | TD: 0.671 | TQ: 0.037 | num_outliers: 4227
# [34/60] Running with params: {'min_cluster_size': 90, 'min_samples': 90, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 16 | TC: 0.063 | TD: 0.681 | TQ: 0.043 | num_outliers: 3821
# [35/60] Running with params: {'min_cluster_size': 90, 'min_samples': 90, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 14 | TC: 0.056 | TD: 0.729 | TQ: 0.041 | num_outliers: 2931
# [36/60] Running with params: {'min_cluster_size': 90, 'min_samples': 90, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 18 | TC: 0.055 | TD: 0.689 | TQ: 0.038 | num_outliers: 4132
# [37/60] Running with params: {'min_cluster_size': 110, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 19 | TC: 0.048 | TD: 0.679 | TQ: 0.033 | num_outliers: 3570
# [38/60] Running with params: {'min_cluster_size': 110, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 19 | TC: 0.060 | TD: 0.668 | TQ: 0.040 | num_outliers: 3337
# [39/60] Running with params: {'min_cluster_size': 110, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 20 | TC: 0.051 | TD: 0.630 | TQ: 0.032 | num_outliers: 3569
# [40/60] Running with params: {'min_cluster_size': 110, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 15 | TC: 0.055 | TD: 0.660 | TQ: 0.037 | num_outliers: 2681
# [41/60] Running with params: {'min_cluster_size': 110, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 19 | TC: 0.067 | TD: 0.705 | TQ: 0.047 | num_outliers: 3662
# [42/60] Running with params: {'min_cluster_size': 110, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 19 | TC: 0.053 | TD: 0.695 | TQ: 0.037 | num_outliers: 3967
# [43/60] Running with params: {'min_cluster_size': 110, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 14 | TC: 0.061 | TD: 0.671 | TQ: 0.041 | num_outliers: 3093
# [44/60] Running with params: {'min_cluster_size': 110, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 16 | TC: 0.064 | TD: 0.681 | TQ: 0.043 | num_outliers: 3727
# [45/60] Running with params: {'min_cluster_size': 110, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 13 | TC: 0.067 | TD: 0.708 | TQ: 0.047 | num_outliers: 2608
# [46/60] Running with params: {'min_cluster_size': 110, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 14 | TC: 0.050 | TD: 0.693 | TQ: 0.034 | num_outliers: 2747
# [47/60] Running with params: {'min_cluster_size': 110, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 11 | TC: 0.047 | TD: 0.700 | TQ: 0.033 | num_outliers: 2491
# [48/60] Running with params: {'min_cluster_size': 110, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 16 | TC: 0.070 | TD: 0.688 | TQ: 0.048 | num_outliers: 3902
# [49/60] Running with params: {'min_cluster_size': 110, 'min_samples': 90, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 14 | TC: 0.045 | TD: 0.650 | TQ: 0.029 | num_outliers: 3220
# [50/60] Running with params: {'min_cluster_size': 110, 'min_samples': 90, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 18 | TC: 0.065 | TD: 0.683 | TQ: 0.044 | num_outliers: 4458
# [51/60] Running with params: {'min_cluster_size': 110, 'min_samples': 90, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 17 | TC: 0.055 | TD: 0.671 | TQ: 0.037 | num_outliers: 4227
# [52/60] Running with params: {'min_cluster_size': 110, 'min_samples': 90, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 16 | TC: 0.063 | TD: 0.681 | TQ: 0.043 | num_outliers: 3821
# [53/60] Running with params: {'min_cluster_size': 110, 'min_samples': 90, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 12 | TC: 0.064 | TD: 0.750 | TQ: 0.048 | num_outliers: 3126
# [54/60] Running with params: {'min_cluster_size': 110, 'min_samples': 90, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 16 | TC: 0.069 | TD: 0.681 | TQ: 0.047 | num_outliers: 4216
# [55/60] Running with params: {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 2, 'n_neighbors': 10}
# Number of Topics: 12 | TC: 0.078 | TD: 0.708 | TQ: 0.055 | num_outliers: 3814
# [56/60] Running with params: {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 15 | TC: 0.064 | TD: 0.680 | TQ: 0.043 | num_outliers: 4448
# [57/60] Running with params: {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 2, 'n_neighbors': 20}
# Number of Topics: 12 | TC: 0.074 | TD: 0.717 | TQ: 0.053 | num_outliers: 3150
# [58/60] Running with params: {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 5, 'n_neighbors': 10}
# Number of Topics: 11 | TC: 0.060 | TD: 0.700 | TQ: 0.042 | num_outliers: 2836
# [59/60] Running with params: {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 15 | TC: 0.067 | TD: 0.720 | TQ: 0.048 | num_outliers: 4325
# [60/60] Running with params: {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 5, 'n_neighbors': 20}
# Number of Topics: 15 | TC: 0.075 | TD: 0.667 | TQ: 0.050 | num_outliers: 4184
#
# Top 20 Best Performing Models (Based on NPMI):
#
# Rank 1: num_topics: 2 | {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10} | TC: 0.102 | TD: 0.950 | TQ: 0.097 | num_outliers: 330)
# Rank 2: num_topics: 26 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15} | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059)
# Rank 3: num_topics: 26 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15} | TC: 0.095 | TD: 0.708 | TQ: 0.067 | num_outliers: 4109)
# Rank 4: num_topics: 22 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 20} | TC: 0.095 | TD: 0.677 | TQ: 0.064 | num_outliers: 3968)
# Rank 5: num_topics: 33 | {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15} | TC: 0.084 | TD: 0.718 | TQ: 0.060 | num_outliers: 4335)
# Rank 6: num_topics: 27 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10} | TC: 0.081 | TD: 0.711 | TQ: 0.058 | num_outliers: 3917)
# Rank 7: num_topics: 28 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 15} | TC: 0.080 | TD: 0.675 | TQ: 0.054 | num_outliers: 3628)
# Rank 8: num_topics: 25 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 20} | TC: 0.078 | TD: 0.668 | TQ: 0.052 | num_outliers: 3604)
# Rank 9: num_topics: 12 | {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 2, 'n_neighbors': 10} | TC: 0.078 | TD: 0.708 | TQ: 0.055 | num_outliers: 3814)
# Rank 10: num_topics: 21 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 15} | TC: 0.078 | TD: 0.705 | TQ: 0.055 | num_outliers: 3781)
#
# Top 20 Best Performing Models (Based on Topic Diversity):
#
# Rank 1: num_topics: 2 | {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10} | TC: 0.102 | TD: 0.950 | TQ: 0.097 | num_outliers: 330)
# Rank 2: num_topics: 12 | {'min_cluster_size': 110, 'min_samples': 90, 'n_components': 5, 'n_neighbors': 15} | TC: 0.064 | TD: 0.750 | TQ: 0.048 | num_outliers: 3126)
# Rank 3: num_topics: 28 | {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 20} | TC: 0.072 | TD: 0.732 | TQ: 0.053 | num_outliers: 3886)
# Rank 4: num_topics: 14 | {'min_cluster_size': 90, 'min_samples': 90, 'n_components': 5, 'n_neighbors': 15} | TC: 0.056 | TD: 0.729 | TQ: 0.041 | num_outliers: 2931)
# Rank 5: num_topics: 15 | {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 5, 'n_neighbors': 15} | TC: 0.067 | TD: 0.720 | TQ: 0.048 | num_outliers: 4325)
# Rank 6: num_topics: 33 | {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15} | TC: 0.084 | TD: 0.718 | TQ: 0.060 | num_outliers: 4335)
# Rank 7: num_topics: 12 | {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 2, 'n_neighbors': 20} | TC: 0.074 | TD: 0.717 | TQ: 0.053 | num_outliers: 3150)
# Rank 8: num_topics: 27 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10} | TC: 0.081 | TD: 0.711 | TQ: 0.058 | num_outliers: 3917)
# Rank 9: num_topics: 20 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 20} | TC: 0.075 | TD: 0.710 | TQ: 0.053 | num_outliers: 3697)
# Rank 10: num_topics: 22 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 10} | TC: 0.060 | TD: 0.709 | TQ: 0.043 | num_outliers: 4154)
#
# Top 20 Best Performing Models (Based on topic quality):
#
# Rank 1: num_topics: 2 | {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10} | TC: 0.102 | TD: 0.950 | TQ: 0.097 | num_outliers: 330)
# Rank 2: num_topics: 26 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15} | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059)
# Rank 3: num_topics: 26 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15} | TC: 0.095 | TD: 0.708 | TQ: 0.067 | num_outliers: 4109)
# Rank 4: num_topics: 22 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 20} | TC: 0.095 | TD: 0.677 | TQ: 0.064 | num_outliers: 3968)
# Rank 5: num_topics: 33 | {'min_cluster_size': 50, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15} | TC: 0.084 | TD: 0.718 | TQ: 0.060 | num_outliers: 4335)
# Rank 6: num_topics: 27 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 10} | TC: 0.081 | TD: 0.711 | TQ: 0.058 | num_outliers: 3917)
# Rank 7: num_topics: 12 | {'min_cluster_size': 110, 'min_samples': 110, 'n_components': 2, 'n_neighbors': 10} | TC: 0.078 | TD: 0.708 | TQ: 0.055 | num_outliers: 3814)
# Rank 8: num_topics: 21 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 15} | TC: 0.078 | TD: 0.705 | TQ: 0.055 | num_outliers: 3781)
# Rank 9: num_topics: 28 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 15} | TC: 0.080 | TD: 0.675 | TQ: 0.054 | num_outliers: 3628)
# Rank 10: num_topics: 20 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 20} | TC: 0.075 | TD: 0.710 | TQ: 0.053 | num_outliers: 3697)

# %% [markdown]
# # Create models with final grid

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
import spacy
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.model_selection import ParameterGrid
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance
from octis.evaluation_metrics.coherence_metrics import Coherence
from umap import UMAP
from hdbscan import HDBSCAN
import spacy

# Load your data
#df = pd.read_csv('~/Library/Mobile Documents/com~apple~CloudDocs/UNI-kopi 2/Kandidat/virtual_environments/data/short.csv')
#documents = df["translated_Comment"].tolist() # Convert to list of strings


# Define the hyperparameter grid
param_grid = {
    # BERTOPIC parameters
    #"min_topic_size": [50,70,90], # Minimum size of a topic. Should be higher than min_cluster_size
    #"top_n_words": [10],
    # "nr_topics": ["auto",10,15,20], # None means no reduction

    #UMAP parameters
    "n_components": [2,5], # Number of dimensions to reduce to
    "n_neighbors": [14,15,16], # Number of neighbors to consider for UMAP 

    #HDBSCAN parameters
    "min_cluster_size": [60,70,80], # Min cluster size for HDBSCAN # Min cluster size for HDBSCAN. 
    "min_samples": [30,40,50,60,70,80] # Minimum number of samples in a cluster
}
#Create all possible combinations of the hyperparameter grid
grid = list(ParameterGrid(param_grid))


# Filter: only keep combinations where min_cluster_size <= min_topic_size
valid_grid = [
    params for params in grid
    if params["min_samples"] <= params["min_cluster_size"]
]

# Total number combinations. Used later in the print statement to show progress
total = len(valid_grid)

#total = len(grid)



# Embedding model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
#Compute embeddings
#embeddings = embedding_model.encode(documents, show_progress_bar=True)



# Prepare Tokenizer model
# Load spaCy English model
nlp = spacy.load("en_core_web_sm")
nlp.max_length = 1520000

# Define custom tokenizer function with lemmatization for topic representations
def spacy_tokenizer(doc):
    spacy_doc = nlp(doc)
    # Lemmatize, lowercase, remove stopwords & punctuation
    return [token.lemma_.lower() for token in spacy_doc if not token.is_stop and not token.is_punct] #

base_vectorizer = CountVectorizer(tokenizer=spacy_tokenizer, min_df=5) # remove words that appear in less than 5 documents
base_vectorizer.fit(documents) # fit the vectorizer to the documents, to find the vocabulary for topic representations
filtered_vocab = set(base_vectorizer.get_feature_names_out()) # # get the vocabulary of the filtered vectorizer

def filtered_tokenizer(doc): # Now create a custom tokenizer that only keeps words in the filtered vocabulary, which will be passed to the CountVectorizer for topic representations
    tokens = spacy_tokenizer(doc)
    return [t for t in tokens if t in filtered_vocab]

# Create CountVectorizer with custom tokenizer
vectorizer_model = CountVectorizer(tokenizer=filtered_tokenizer, # use the custom tokenizer
                                   #stop_words="english", # already done in the tokenizer, but countvectorizer might have other stop words
                                   lowercase = False, # lowercase is already done in the tokenizer
                                   min_df = 1, #  Excludes words that appear in only one document.
                                   ngram_range=(1, 2)) # consider topic representations that are made up of one or two words

def coherence_tokenizer(doc): # The tokenizer for the coherence score. This is a standard tokenizer that does not filter out words, but lemmatizes and lowercases them.
    spacy_doc = nlp(doc)
    return [
        token.lemma_.lower()
        for token in spacy_doc
        if not token.is_punct  # keep stopwords as I want to calculate the coherence score based on all words
    ]

tokens_for_coherence = [coherence_tokenizer(doc) for doc in documents] 


# Fine-tune representations 
#keybert_model = KeyBERTInspired()
#mmr_model = MaximalMarginalRelevance(diversity=0.2) #0.2 is used in the book.

#representation_model = {
    #"KeyBERT": keybert_model,
    #"MMR": mmr_model
#}


# Function to calculate Topic Diversity as the proportion of unique words across all top-k topic words (PUW)
def topic_diversity(topics, topk):
    all_words = [word for topic in topics for word in topic[:topk]]
    unique_words = set(all_words)
    return len(unique_words) / len(all_words)


# Defintions to later being able to track best model. 
best_model = None #no best model from the start
best_score = -1 # the first model with a score better than -1 will the current best. Just a placeholder make npmi_score > best_score work.
best_params = None #no best parameters from the start


# Results storage. A list that sores the coherence and diversty score of each model
results = []
# A list which saves all the models, so each model can be easily retrieved by typing its corresponding parameters
saved_models = {}  



#### THE LOOP ####
# Grid search
for i, params in enumerate(valid_grid, 1):#change to valid_grid as the parameter grid to iterate over if min_topic_size is used
    print(f"[{i}/{total}] Running with params: {params}") #print the current parameter combination being evaluated for each iteration 

    # UMAP
    umap_model = UMAP(n_neighbors=params["n_neighbors"],
                      n_components=params["n_components"], 
                      min_dist=0.0, 
                      metric='cosine', 
                      random_state=42)

    # HDBSCAN  
    hdbscan_model = HDBSCAN(min_cluster_size=params["min_cluster_size"], 
                            min_samples=params["min_samples"], 
                            metric='euclidean', 
                            cluster_selection_method='eom',
                            prediction_data=True
                            )

    # BERTopic model
    topic_model = BERTopic(
        #nr_topics=params["nr_topics"],
        #min_topic_size=params["min_topic_size"]
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        #representation_model=representation_model,
        vectorizer_model=vectorizer_model, #this makes some models not able to calculate NPMI
        #ctfidf_model=ctfidf_model,
        top_n_words=10,   
    )

    # Fit model
    topics, _ = topic_model.fit_transform(documents, embeddings)

    # Save meach model in the Saved_models list
    param_key = tuple(sorted(params.items()))  # extracting the parameters for the each model and creates a unique key for every model combination
    saved_models[param_key] = topic_model # save the each model in the saved_models list by its unique key 


    # Get top `top_n_words` words per topic (excluding outlier topic -1)
    topic_words = [] #an empty list that will be used to store the top words of every topic found for each model. So a list (topics) of lists (top words for each topic).
    
    for topic in topic_model.get_topic_freq().Topic: # grabs the topics from the topic_model
        if topic != -1: #skips the outlier topic -1
            topic_content = topic_model.get_topic(topic) #get the top words and scores for the topics.
            if isinstance(topic_content, list) and len(topic_content) > 0: # checks if the topic_content (top words) is a list and has more than 0 elements. To check if there actually is extracted topic words
                if isinstance(topic_content[0], tuple) and len(topic_content[0]) == 2: # checks if the first element of topic_content is a tuple and has two elements (word and score)
                    words = [word for word, _ in topic_content[:topic_model.top_n_words]] #if so, it extracts the words (but not the scores) in a variable called "words"
                else:
                    words = topic_content[:topic_model.top_n_words] #if there is only top words but no scores, extracts the top words in a variabkle called "words"
                topic_words.append(words) #append the topic words (defined in the variable "words") to the topic_words list for the model.

    if topic_words:
        
        # Calculate NPMI
        coherence_model = Coherence(texts=tokens_for_coherence, # reference corpus. Here it's all documents in the dataset
                                    topk=10, #specifies the number of top words to consider for NPMI calculation
                                    measure="c_npmi")
        npmi_score = coherence_model.score({"topics": topic_words}) # average

        # Calculate Topic Diversity
            # the topic_diversity command was defned before the loop. This is not a standard command, so I defined how it works earlier.
        diversity_score = topic_diversity(topics=topic_words, topk=10)

        # Calculate Topic Quality by multiplying NPMI score and Topic Diversity
        topic_quality = npmi_score * diversity_score 


        # Print the number of topics
        num_topics = len(topic_words) #number of topics is the length of the topic_words list
        num_outliers = sum(1 for topic in topics if topic == -1) #number of outliers is the number of topics that are equal to -1
        print(f"Number of Topics: {num_topics} | TC: {npmi_score:.3f} | TD: {diversity_score:.3f} | TQ: {topic_quality:.3f} | num_outliers: {num_outliers}") #4f = 4 decimals 

        # Track best model
        if npmi_score > best_score:
            best_score = npmi_score
            best_model = topic_model
            best_params = params

        # store the params, npmi, diversy, and num_topcis for each model in the results list
        results.append({
            "params": params,
            "num_topics": num_topics,
            "npmi_score": npmi_score,
            "topic_diversity": diversity_score,
            "topic_quality": topic_quality,
            "num_outliers": num_outliers
        })

    else:
        print("No valid topics were generated.")

#####

import csv

# Save the all the models' information to a CSV file

model_info = [] # an empty list to store model information. This is the dataframe that will be saved in the CSV file in the end 

# Loop through the models saved from the loop above and save the information to the model_info dataframe
for param_key, model in saved_models.items(): #activates a loop that goes through all the models (identified by their unique key).
    # Convert the tuple of params back to a dictionary (a formal step)
    params_dict = dict(param_key)
    
    # Get topic information
    #topics_freq = model.get_topic_freq() #retrives the number of topics and documents in each topic
    #num_topics = len(topics_freq[topics_freq.Topic != -1]) #retrives the number of topics (length) and exlcudes the outlier topic -1
    
    ## Get performance metrics if available
    # Matches the models with parameters saved in the loop with the parameters of models saved in the CVS file
    matching_result = next((r for r in results if all(r["params"][k] == v for k, v in params_dict.items())), None)
    
    if matching_result: 
        num_topics =matching_result.get("num_topics", 0) #extract the number of topics for the models
        num_outliers = matching_result.get("num_outliers", 0) #extract the number of outliers for the models
        npmi_score = matching_result.get("npmi_score", 0) #extract the NPMI score for the models
        diversity_score = matching_result.get("topic_diversity", 0) #extract the topic diversity score for the models
        topic_quality = matching_result.get("topic_quality", 0) #extract the topic quality score for the models
        
        model_info.append({  #assigns the number of topics and scores to the differnt models in the model_info list. This is the dataframe that will be saved in the CSV file.
            **params_dict,  
            "num_topics": num_topics,
            "npmi_score": npmi_score,
            "topic_diversity": diversity_score,
            "topic_quality": topic_quality,
            "num_outliers" : num_outliers   
        })

# Now we retrived all the information to the model_info dataframe, 
# Saves it to CSV file
with open('simple_model1.csv', 'w', newline='') as csvfile:
    fieldnames = list(model_info[0].keys()) if model_info else []
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    for info in model_info:
        writer.writerow(info)

print(f"Model information saved to bertopic_models_info_preprocessing.csv with combined score column")



# Sort the results by NPMI score in descending order
top_20_npmi = sorted(results, key=lambda x: x["npmi_score"], reverse=True)[:10]

# Sort the results by Topic Diversity score in descending order
top_20_diversity = sorted(results, key=lambda x: x["topic_diversity"], reverse=True)[:10]

# Sort the results by both NPMI and Topic Diversity score in descending order
top_20_quality = sorted(results, key=lambda x: (x["topic_quality"]), reverse=True)[:10]

# Print the top 20 based on NPMI
print("\nTop 20 Best Performing Models (Based on NPMI):\n")
for i, result in enumerate(top_20_npmi, start=1):
    print(f"Rank {i}: num_topics: {result['num_topics']} | {result['params']} | TC: {result['npmi_score']:.3f} | TD: {result['topic_diversity']:.3f} | TQ: {result['topic_quality']:.3f} | num_outliers: {result['num_outliers']})")

# Print the top 20 based on Topic Diversity
print("\nTop 20 Best Performing Models (Based on Topic Diversity):\n")
for i, result in enumerate(top_20_diversity, start=1):
    print(f"Rank {i}: num_topics: {result['num_topics']} | {result['params']} | TC: {result['npmi_score']:.3f} | TD: {result['topic_diversity']:.3f} | TQ: {result['topic_quality']:.3f} | num_outliers: {result['num_outliers']})")

# Print the top 20 based on topic quality
print("\nTop 20 Best Performing Models (Based on topic quality):\n")
for i, result in enumerate(top_20_quality, start=1):
    print(f"Rank {i}: num_topics: {result['num_topics']} | {result['params']} | TC: {result['npmi_score']:.3f} | TD: {result['topic_diversity']:.3f} | TQ: {result['topic_quality']:.3f} | num_outliers: {result['num_outliers']})")
# Out:
# [1/90] Running with params: {'min_cluster_size': 60, 'min_samples': 30, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 33 | TC: 0.073 | TD: 0.682 | TQ: 0.050 | num_outliers: 3231
# [2/90] Running with params: {'min_cluster_size': 60, 'min_samples': 30, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 33 | TC: 0.069 | TD: 0.655 | TQ: 0.045 | num_outliers: 3258
# [3/90] Running with params: {'min_cluster_size': 60, 'min_samples': 30, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 37 | TC: 0.075 | TD: 0.697 | TQ: 0.052 | num_outliers: 3656
# [4/90] Running with params: {'min_cluster_size': 60, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 29 | TC: 0.078 | TD: 0.748 | TQ: 0.058 | num_outliers: 3900
# [5/90] Running with params: {'min_cluster_size': 60, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 28 | TC: 0.079 | TD: 0.711 | TQ: 0.056 | num_outliers: 3511
# [6/90] Running with params: {'min_cluster_size': 60, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 27 | TC: 0.079 | TD: 0.722 | TQ: 0.057 | num_outliers: 3389
# [7/90] Running with params: {'min_cluster_size': 60, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 30 | TC: 0.070 | TD: 0.707 | TQ: 0.050 | num_outliers: 3660
# [8/90] Running with params: {'min_cluster_size': 60, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 33 | TC: 0.074 | TD: 0.676 | TQ: 0.050 | num_outliers: 3335
# [9/90] Running with params: {'min_cluster_size': 60, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 30 | TC: 0.093 | TD: 0.717 | TQ: 0.067 | num_outliers: 3805
# [10/90] Running with params: {'min_cluster_size': 60, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 29 | TC: 0.082 | TD: 0.721 | TQ: 0.059 | num_outliers: 4077
# [11/90] Running with params: {'min_cluster_size': 60, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 29 | TC: 0.080 | TD: 0.728 | TQ: 0.058 | num_outliers: 3898
# [12/90] Running with params: {'min_cluster_size': 60, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 27 | TC: 0.073 | TD: 0.730 | TQ: 0.053 | num_outliers: 3698
# [13/90] Running with params: {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 30 | TC: 0.075 | TD: 0.703 | TQ: 0.053 | num_outliers: 3969
# [14/90] Running with params: {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 31 | TC: 0.074 | TD: 0.681 | TQ: 0.050 | num_outliers: 3508
# [15/90] Running with params: {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 29 | TC: 0.095 | TD: 0.734 | TQ: 0.070 | num_outliers: 3987
# [16/90] Running with params: {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 26 | TC: 0.080 | TD: 0.696 | TQ: 0.056 | num_outliers: 4009
# [17/90] Running with params: {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 28 | TC: 0.096 | TD: 0.729 | TQ: 0.070 | num_outliers: 4090
# [18/90] Running with params: {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 27 | TC: 0.081 | TD: 0.730 | TQ: 0.059 | num_outliers: 3929
# [19/90] Running with params: {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 28 | TC: 0.076 | TD: 0.711 | TQ: 0.054 | num_outliers: 4043
# [20/90] Running with params: {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 28 | TC: 0.084 | TD: 0.689 | TQ: 0.058 | num_outliers: 3826
# [21/90] Running with params: {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 27 | TC: 0.102 | TD: 0.733 | TQ: 0.075 | num_outliers: 4118
# [22/90] Running with params: {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 26 | TC: 0.083 | TD: 0.692 | TQ: 0.057 | num_outliers: 4309
# [23/90] Running with params: {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 25 | TC: 0.103 | TD: 0.712 | TQ: 0.073 | num_outliers: 4111
# [24/90] Running with params: {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 26 | TC: 0.095 | TD: 0.723 | TQ: 0.068 | num_outliers: 4275
# [25/90] Running with params: {'min_cluster_size': 70, 'min_samples': 30, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 28 | TC: 0.068 | TD: 0.671 | TQ: 0.046 | num_outliers: 3242
# [26/90] Running with params: {'min_cluster_size': 70, 'min_samples': 30, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 29 | TC: 0.079 | TD: 0.669 | TQ: 0.053 | num_outliers: 3393
# [27/90] Running with params: {'min_cluster_size': 70, 'min_samples': 30, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 35 | TC: 0.075 | TD: 0.709 | TQ: 0.053 | num_outliers: 3784
# [28/90] Running with params: {'min_cluster_size': 70, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 24 | TC: 0.058 | TD: 0.692 | TQ: 0.040 | num_outliers: 3382
# [29/90] Running with params: {'min_cluster_size': 70, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 27 | TC: 0.078 | TD: 0.704 | TQ: 0.055 | num_outliers: 3579
# [30/90] Running with params: {'min_cluster_size': 70, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 24 | TC: 0.049 | TD: 0.696 | TQ: 0.034 | num_outliers: 2906
# [31/90] Running with params: {'min_cluster_size': 70, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 26 | TC: 0.077 | TD: 0.677 | TQ: 0.052 | num_outliers: 3190
# [32/90] Running with params: {'min_cluster_size': 70, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 28 | TC: 0.081 | TD: 0.671 | TQ: 0.055 | num_outliers: 3278
# [33/90] Running with params: {'min_cluster_size': 70, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 27 | TC: 0.095 | TD: 0.711 | TQ: 0.068 | num_outliers: 3665
# [34/90] Running with params: {'min_cluster_size': 70, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 24 | TC: 0.061 | TD: 0.679 | TQ: 0.041 | num_outliers: 3476
# [35/90] Running with params: {'min_cluster_size': 70, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 27 | TC: 0.084 | TD: 0.700 | TQ: 0.059 | num_outliers: 3957
# [36/90] Running with params: {'min_cluster_size': 70, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 26 | TC: 0.071 | TD: 0.723 | TQ: 0.051 | num_outliers: 3684
# [37/90] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 27 | TC: 0.070 | TD: 0.674 | TQ: 0.047 | num_outliers: 3817
# [38/90] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 28 | TC: 0.080 | TD: 0.675 | TQ: 0.054 | num_outliers: 3628
# [39/90] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 27 | TC: 0.093 | TD: 0.722 | TQ: 0.067 | num_outliers: 3933
# [40/90] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 23 | TC: 0.067 | TD: 0.687 | TQ: 0.046 | num_outliers: 3607
# [41/90] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 26 | TC: 0.095 | TD: 0.708 | TQ: 0.067 | num_outliers: 4109
# [42/90] Running with params: {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 19 | TC: 0.116 | TD: 0.705 | TQ: 0.082 | num_outliers: 3027
# [43/90] Running with params: {'min_cluster_size': 70, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 26 | TC: 0.076 | TD: 0.704 | TQ: 0.054 | num_outliers: 3903
# [44/90] Running with params: {'min_cluster_size': 70, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 25 | TC: 0.090 | TD: 0.704 | TQ: 0.063 | num_outliers: 3511
# [45/90] Running with params: {'min_cluster_size': 70, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 24 | TC: 0.092 | TD: 0.696 | TQ: 0.064 | num_outliers: 3965
# [46/90] Running with params: {'min_cluster_size': 70, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 21 | TC: 0.063 | TD: 0.681 | TQ: 0.043 | num_outliers: 3785
# [47/90] Running with params: {'min_cluster_size': 70, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 21 | TC: 0.075 | TD: 0.714 | TQ: 0.054 | num_outliers: 3578
# [48/90] Running with params: {'min_cluster_size': 70, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 25 | TC: 0.092 | TD: 0.716 | TQ: 0.066 | num_outliers: 4226
# [49/90] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 25 | TC: 0.081 | TD: 0.692 | TQ: 0.056 | num_outliers: 4277
# [50/90] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 26 | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059
# [51/90] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 23 | TC: 0.093 | TD: 0.700 | TQ: 0.065 | num_outliers: 4179
# [52/90] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 19 | TC: 0.058 | TD: 0.684 | TQ: 0.039 | num_outliers: 3884
# [53/90] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 21 | TC: 0.078 | TD: 0.705 | TQ: 0.055 | num_outliers: 3781
# [54/90] Running with params: {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 22 | TC: 0.070 | TD: 0.700 | TQ: 0.049 | num_outliers: 3878
# [55/90] Running with params: {'min_cluster_size': 80, 'min_samples': 30, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 24 | TC: 0.062 | TD: 0.642 | TQ: 0.040 | num_outliers: 3164
# [56/90] Running with params: {'min_cluster_size': 80, 'min_samples': 30, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 25 | TC: 0.067 | TD: 0.680 | TQ: 0.046 | num_outliers: 3334
# [57/90] Running with params: {'min_cluster_size': 80, 'min_samples': 30, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 26 | TC: 0.082 | TD: 0.669 | TQ: 0.055 | num_outliers: 3280
# [58/90] Running with params: {'min_cluster_size': 80, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 21 | TC: 0.057 | TD: 0.681 | TQ: 0.039 | num_outliers: 3273
# [59/90] Running with params: {'min_cluster_size': 80, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 22 | TC: 0.063 | TD: 0.673 | TQ: 0.042 | num_outliers: 3253
# [60/90] Running with params: {'min_cluster_size': 80, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 22 | TC: 0.044 | TD: 0.659 | TQ: 0.029 | num_outliers: 3056
# [61/90] Running with params: {'min_cluster_size': 80, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 23 | TC: 0.063 | TD: 0.643 | TQ: 0.041 | num_outliers: 3412
# [62/90] Running with params: {'min_cluster_size': 80, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 26 | TC: 0.071 | TD: 0.669 | TQ: 0.048 | num_outliers: 3433
# [63/90] Running with params: {'min_cluster_size': 80, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 25 | TC: 0.095 | TD: 0.700 | TQ: 0.066 | num_outliers: 3544
# [64/90] Running with params: {'min_cluster_size': 80, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 21 | TC: 0.057 | TD: 0.662 | TQ: 0.038 | num_outliers: 3405
# [65/90] Running with params: {'min_cluster_size': 80, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 24 | TC: 0.054 | TD: 0.671 | TQ: 0.036 | num_outliers: 3564
# [66/90] Running with params: {'min_cluster_size': 80, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 22 | TC: 0.044 | TD: 0.686 | TQ: 0.030 | num_outliers: 3445
# [67/90] Running with params: {'min_cluster_size': 80, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 23 | TC: 0.062 | TD: 0.639 | TQ: 0.040 | num_outliers: 3813
# [68/90] Running with params: {'min_cluster_size': 80, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 23 | TC: 0.080 | TD: 0.678 | TQ: 0.054 | num_outliers: 3504
# [69/90] Running with params: {'min_cluster_size': 80, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 25 | TC: 0.099 | TD: 0.708 | TQ: 0.070 | num_outliers: 3791
# [70/90] Running with params: {'min_cluster_size': 80, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 20 | TC: 0.053 | TD: 0.665 | TQ: 0.035 | num_outliers: 3480
# [71/90] Running with params: {'min_cluster_size': 80, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 23 | TC: 0.060 | TD: 0.691 | TQ: 0.042 | num_outliers: 3727
# [72/90] Running with params: {'min_cluster_size': 80, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 16 | TC: 0.079 | TD: 0.700 | TQ: 0.055 | num_outliers: 2791
# [73/90] Running with params: {'min_cluster_size': 80, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 22 | TC: 0.062 | TD: 0.673 | TQ: 0.041 | num_outliers: 4208
# [74/90] Running with params: {'min_cluster_size': 80, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 22 | TC: 0.079 | TD: 0.714 | TQ: 0.057 | num_outliers: 3547
# [75/90] Running with params: {'min_cluster_size': 80, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 24 | TC: 0.092 | TD: 0.696 | TQ: 0.064 | num_outliers: 3965
# [76/90] Running with params: {'min_cluster_size': 80, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 20 | TC: 0.057 | TD: 0.675 | TQ: 0.038 | num_outliers: 3859
# [77/90] Running with params: {'min_cluster_size': 80, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 19 | TC: 0.059 | TD: 0.700 | TQ: 0.042 | num_outliers: 3535
# [78/90] Running with params: {'min_cluster_size': 80, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 22 | TC: 0.060 | TD: 0.695 | TQ: 0.042 | num_outliers: 3896
# [79/90] Running with params: {'min_cluster_size': 80, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 22 | TC: 0.072 | TD: 0.691 | TQ: 0.050 | num_outliers: 4427
# [80/90] Running with params: {'min_cluster_size': 80, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 24 | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4112
# [81/90] Running with params: {'min_cluster_size': 80, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 22 | TC: 0.093 | TD: 0.686 | TQ: 0.064 | num_outliers: 4042
# [82/90] Running with params: {'min_cluster_size': 80, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 18 | TC: 0.054 | TD: 0.683 | TQ: 0.037 | num_outliers: 3785
# [83/90] Running with params: {'min_cluster_size': 80, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 14 | TC: 0.045 | TD: 0.707 | TQ: 0.032 | num_outliers: 2635
# [84/90] Running with params: {'min_cluster_size': 80, 'min_samples': 70, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 20 | TC: 0.067 | TD: 0.695 | TQ: 0.047 | num_outliers: 4024
# [85/90] Running with params: {'min_cluster_size': 80, 'min_samples': 80, 'n_components': 2, 'n_neighbors': 14}
# Number of Topics: 20 | TC: 0.078 | TD: 0.670 | TQ: 0.052 | num_outliers: 4694
# [86/90] Running with params: {'min_cluster_size': 80, 'min_samples': 80, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 22 | TC: 0.087 | TD: 0.682 | TQ: 0.059 | num_outliers: 4686
# [87/90] Running with params: {'min_cluster_size': 80, 'min_samples': 80, 'n_components': 2, 'n_neighbors': 16}
# Number of Topics: 23 | TC: 0.092 | TD: 0.696 | TQ: 0.064 | num_outliers: 4458
# [88/90] Running with params: {'min_cluster_size': 80, 'min_samples': 80, 'n_components': 5, 'n_neighbors': 14}
# Number of Topics: 17 | TC: 0.053 | TD: 0.688 | TQ: 0.037 | num_outliers: 3721
# [89/90] Running with params: {'min_cluster_size': 80, 'min_samples': 80, 'n_components': 5, 'n_neighbors': 15}
# Number of Topics: 18 | TC: 0.067 | TD: 0.700 | TQ: 0.047 | num_outliers: 3852
# [90/90] Running with params: {'min_cluster_size': 80, 'min_samples': 80, 'n_components': 5, 'n_neighbors': 16}
# Number of Topics: 19 | TC: 0.061 | TD: 0.711 | TQ: 0.043 | num_outliers: 4232
# Model information saved to bertopic_models_info_preprocessing.csv with combined score column
#
# Top 20 Best Performing Models (Based on NPMI):
#
# Rank 1: num_topics: 19 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 16} | TC: 0.116 | TD: 0.705 | TQ: 0.082 | num_outliers: 3027)
# Rank 2: num_topics: 25 | {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 15} | TC: 0.103 | TD: 0.712 | TQ: 0.073 | num_outliers: 4111)
# Rank 3: num_topics: 27 | {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 16} | TC: 0.102 | TD: 0.733 | TQ: 0.075 | num_outliers: 4118)
# Rank 4: num_topics: 26 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15} | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059)
# Rank 5: num_topics: 24 | {'min_cluster_size': 80, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15} | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4112)
# Rank 6: num_topics: 25 | {'min_cluster_size': 80, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 16} | TC: 0.099 | TD: 0.708 | TQ: 0.070 | num_outliers: 3791)
# Rank 7: num_topics: 28 | {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15} | TC: 0.096 | TD: 0.729 | TQ: 0.070 | num_outliers: 4090)
# Rank 8: num_topics: 29 | {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 16} | TC: 0.095 | TD: 0.734 | TQ: 0.070 | num_outliers: 3987)
# Rank 9: num_topics: 27 | {'min_cluster_size': 70, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 16} | TC: 0.095 | TD: 0.711 | TQ: 0.068 | num_outliers: 3665)
# Rank 10: num_topics: 25 | {'min_cluster_size': 80, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 16} | TC: 0.095 | TD: 0.700 | TQ: 0.066 | num_outliers: 3544)
#
# Top 20 Best Performing Models (Based on Topic Diversity):
#
# Rank 1: num_topics: 29 | {'min_cluster_size': 60, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 14} | TC: 0.078 | TD: 0.748 | TQ: 0.058 | num_outliers: 3900)
# Rank 2: num_topics: 29 | {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 16} | TC: 0.095 | TD: 0.734 | TQ: 0.070 | num_outliers: 3987)
# Rank 3: num_topics: 27 | {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 16} | TC: 0.102 | TD: 0.733 | TQ: 0.075 | num_outliers: 4118)
# Rank 4: num_topics: 27 | {'min_cluster_size': 60, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 16} | TC: 0.073 | TD: 0.730 | TQ: 0.053 | num_outliers: 3698)
# Rank 5: num_topics: 27 | {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 16} | TC: 0.081 | TD: 0.730 | TQ: 0.059 | num_outliers: 3929)
# Rank 6: num_topics: 28 | {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15} | TC: 0.096 | TD: 0.729 | TQ: 0.070 | num_outliers: 4090)
# Rank 7: num_topics: 29 | {'min_cluster_size': 60, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 15} | TC: 0.080 | TD: 0.728 | TQ: 0.058 | num_outliers: 3898)
# Rank 8: num_topics: 26 | {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 16} | TC: 0.095 | TD: 0.723 | TQ: 0.068 | num_outliers: 4275)
# Rank 9: num_topics: 26 | {'min_cluster_size': 70, 'min_samples': 40, 'n_components': 5, 'n_neighbors': 16} | TC: 0.071 | TD: 0.723 | TQ: 0.051 | num_outliers: 3684)
# Rank 10: num_topics: 27 | {'min_cluster_size': 60, 'min_samples': 30, 'n_components': 5, 'n_neighbors': 16} | TC: 0.079 | TD: 0.722 | TQ: 0.057 | num_outliers: 3389)
#
# Top 20 Best Performing Models (Based on topic quality):
#
# Rank 1: num_topics: 19 | {'min_cluster_size': 70, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 16} | TC: 0.116 | TD: 0.705 | TQ: 0.082 | num_outliers: 3027)
# Rank 2: num_topics: 27 | {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 2, 'n_neighbors': 16} | TC: 0.102 | TD: 0.733 | TQ: 0.075 | num_outliers: 4118)
# Rank 3: num_topics: 25 | {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 15} | TC: 0.103 | TD: 0.712 | TQ: 0.073 | num_outliers: 4111)
# Rank 4: num_topics: 29 | {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 16} | TC: 0.095 | TD: 0.734 | TQ: 0.070 | num_outliers: 3987)
# Rank 5: num_topics: 25 | {'min_cluster_size': 80, 'min_samples': 50, 'n_components': 2, 'n_neighbors': 16} | TC: 0.099 | TD: 0.708 | TQ: 0.070 | num_outliers: 3791)
# Rank 6: num_topics: 28 | {'min_cluster_size': 60, 'min_samples': 50, 'n_components': 5, 'n_neighbors': 15} | TC: 0.096 | TD: 0.729 | TQ: 0.070 | num_outliers: 4090)
# Rank 7: num_topics: 26 | {'min_cluster_size': 70, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15} | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059)
# Rank 8: num_topics: 24 | {'min_cluster_size': 80, 'min_samples': 70, 'n_components': 2, 'n_neighbors': 15} | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4112)
# Rank 9: num_topics: 26 | {'min_cluster_size': 60, 'min_samples': 60, 'n_components': 5, 'n_neighbors': 16} | TC: 0.095 | TD: 0.723 | TQ: 0.068 | num_outliers: 4275)
# Rank 10: num_topics: 27 | {'min_cluster_size': 70, 'min_samples': 40, 'n_components': 2, 'n_neighbors': 16} | TC: 0.095 | TD: 0.711 | TQ: 0.068 | num_outliers: 3665)

# %% [markdown]
# # Model 1

# %%
from bertopic import BERTopic

loaded_model = BERTopic.load("simple_model1")
print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %% [markdown]
# ## Inspection

# %%
loaded_model.get_topic_info()
# Out:
#     Topic  Count                                       Name  \
# 0      -1   3027                     -1_order_time_app_wolt
# 1       0   2492                   0_pay_wolt_order_payment
# 2       1    965                    1_good_happy_wolt_thank
# 3       2    430               2_ready_restaurant_food_wait
# 4       3    429         3_support_wolt support_system_chat
# 5       4    373            4_courier_new courier_new_order
# 6       5    366            5_mcdonald_wait_order_mcdonalds
# 7       6    355                   6_map_address_google_gps
# 8       7    298        7_order_home_order order_home order
# 9       8    268                   8_app_app work_work_time
# 10      9    241                       9_bag_drink_pack_cup
# 11     10    223                10_app_order_order app_time
# 12     11    216                       11_order_hour_wait_2
# 13     12    181  12_burger_king_burger king_burger concept
# 14     13    146            13_task_task task_time_new task
# 15     14    131           14_bundle_bundle order_order_pay
# 16     15     98              15_support_order_deliver_tell
# 17     16     80        16_wolt happy_happy wolt_happy_wolt
# 18     17     75           17_dkk_hour_dkk hour_hour online
# 19     18     70    18_mile_mile offer_drive mile_let drive
#
#                                        Representation  \
# 0   [order, time, app, wolt, work, customer, deliv...
# 1   [pay, wolt, order, payment, low, work, money, ...
# 2   [good, happy, wolt, thank, work, day, job, lov...
# 3   [ready, restaurant, food, wait, time, food rea...
# 4   [support, wolt support, system, chat, team, ne...
# 5   [courier, new courier, new, order, order couri...
# 6   [mcdonald, wait, order, mcdonalds, ready, mc, ...
# 7   [map, address, google, gps, location, app, map...
# 8   [order, home, order order, home order, order h...
# 9   [app, app work, work, time, update, time app, ...
# 10  [bag, drink, pack, cup, food, paper, spill, so...
# 11  [app, order, order app, time, error, accept, g...
# 12  [order, hour, wait, 2, minute, order hour, min...
# 13  [burger, king, burger king, burger concept, co...
# 14  [task, task task, time, new task, accept task,...
# 15  [bundle, bundle order, order, pay, task, syste...
# 16  [support, order, deliver, tell, mistake, deduc...
# 17  [wolt happy, happy wolt, happy, wolt, love wol...
# 18  [dkk, hour, dkk hour, hour online, online, 3 h...
# 19  [mile, mile offer, drive mile, let drive, clos...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [The pay per order is too low., Lots of discre...
# 2   [wolt is the best i am very happy with wolt, w...
# 3   [Marking the food ready before it's…, More tha...
# 4   [Wolt support not good.verybad, Leaf -tender s...
# 5   [few orders too many couriers, No orders!!! To...
# 6   [Hi! Today started great but the few times I’v...
# 7   [Addresses were misleading, Please make it pos...
# 8   [There are not enough amount of orders, There ...
# 9   [The app was down for me, MOST RIGGED MANIPULA...
# 10  [Please do something about the bags. Big proce...
# 11  [Uphill…. Began as courier 5 months ago (it ma...
# 12  [No order in 2 hours., only 1 order for 2 hour...
# 13  [Burger King and The Burger Concept is almost ...
# 14  [Because i always get less task, It's Sku Slay...
# 15  [Why the system give bundles when there are no...
# 16  [I am charged with some of 90 kroner for a res...
# 17  [i am very happy with wolt, i am very happy wi...
# 18  [Almost 2 hours online, 2 orders, 110 dkk, Thi...
# 19  [App lets me drive for miles, then offers almo...

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = loaded_model.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = loaded_model.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: pay, wolt, order, payment, low, work, money, distance, hour, km
# Topic 1: good, happy, wolt, thank, work, day, job, love, great, work wolt
# Topic 2: ready, restaurant, food, wait, time, food ready, mark, order, minute, order ready
# Topic 3: support, wolt support, system, chat, team, new, bad, help, good, wolt
# Topic 4: courier, new courier, new, order, order courier, hour, hire, stop, work, courier order
# Topic 5: mcdonald, wait, order, mcdonalds, ready, mc, minute, time, donald, mc donald
# Topic 6: map, address, google, gps, location, app, maps, wrong, google map, google maps
# Topic 7: order, home, order order, home order, order home, go home, work late, work, get, get order
# Topic 8: app, app work, work, time, update, time app, freeze, phone, slow, crash
# Topic 9: bag, drink, pack, cup, food, paper, spill, soda, paper bag, need
# Topic 10: app, order, order app, time, error, accept, get, support, work, app work
# Topic 11: order, hour, wait, 2, minute, order hour, min, hour order, wait order, time
# Topic 12: burger, king, burger king, burger concept, concept, wait, minute, time, order, delay
# Topic 13: task, task task, time, new task, accept task, accept, new, disappear, hour, receive
# Topic 14: bundle, bundle order, order, pay, task, system, payment, new, order bundle, accept
# Topic 15: support, order, deliver, tell, mistake, deduct, compensation, time, wrong, customer
# Topic 16: wolt happy, happy wolt, happy, wolt, love wolt, love, wolt love, wolt yes, yes happy, thank wolt
# Topic 17: dkk, hour, dkk hour, hour online, online, 3 hour, dkk bad, 3, 2, 100 dkk
# Topic 18: mile, mile offer, drive mile, let drive, close venue, app let, offer ready, order close, ready order, offer

# %% [markdown]
# - Topic 0: en blanding af indtjening, og distance. Ved inspektion ligner det, at det er 50% indtjening 50% andre ting.
# - Topic 1: glad for at arbejde som courier
# - Topic 2: Noget omkring at restauranterne ikke er klar med maden, og de markerer ordren klar før den er det
# - Topic 3: Wolt support
# - Topic 4: Noget omkring nye kurerer, måske at de ansættes for mange nye
# - Topic 5: McDonalds (måske noget med at vente?)
# - Topic 6: Google maps, lokation og adresser.
# - Topic 7: Noget omkring orderer? Og hjem? Når jeg kigger i dokumenterne kan jeg se det handler om ikke nok ordrer.
# - Topic 8: Appen der ikke virker optimalt
# - Topic 9: Udstyr såsom taske, kopholder, evt. hvordan venues forsejler ordrer
# - Topic 10: Måske noget omkring at accepterer ordre, og fejl når man skal acceptere ordre?
# - Topic 11: Man venter lang tid på ordre
# - Topic 12: Burker king og andre restauranter med navnet ”burger” i
# - Topic 13: Noget omkring opgaven eller få /acceptere opgaver? Ved inspektion ser det ud til at nogle handler om dette.
# - Topic 14:  bundle orders
# - Topic 15: blurry. Men i hvert fald noget omkring kompensation og blive trukket i løn
# - Topic 16: Glad for wolt
# - Topic 17: hvor dkk og tal er nævnt. Nok noget omkring indtjening
# - Topic 18: noget omkring distance. Ved inspektion ligner det, at det omhandler problemer med at appen giver ordrer som er -1 min, eller steder man lige har været.

# %% [markdown]
# ### Inspect documents in topics

# %% [markdown]
# I inspect the documents in the topics, to see if they seem coherent and belong to the right topic.
# The idea is that feedback in the topics should quite similar.
# Moreover for at topic to make sense, we should be able to tell what the topic is about without seeing the topic representations

# %%
# Retrieve the topic assignments for each document
topics, _ = loaded_model.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Iterate over sorted topic IDs
for topic_id in sorted(topic_to_docs.keys()):
    docs = topic_to_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))  # Randomly select up to 10 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
# Out:
# === Topic -1 (3027 documents) ===
# 1. restaurant Kostadious Burger Joint Trøjborg always late. And today I was waiting 15 minutes for nothing - someone else took the order. But they give the orders to the couriers. Totaly dissapointed from thos restaurant. Plese contact them if possible.
# 2. Everything goes ok and happy but when you pick up food from MacDonald, the wait is very long
# 3. Bad Service Bad Support
# 4. Jagger frederiksberg is more than 10 mins behind the time. Please ask them to keep it on time or adjust time accordingly
# 5. Really bad treatment of the courses in the city's café and pizzaria waited 40 minutes on the order as they kept saying just about every time you asked when the food was ready. Their attitude towards me and other couriers were condescending hope it is taken seriously
# 6. Durum Bar Frederiksberg Smallegade 56, 2000 Frederiksberg The restaurant is always cheating. They mark the food ready, but they start to make it only when we show up. They do they ask wolt for double pay for the remake orders, but they never make the orders, they start making after we show up only. I have never seen the order ready in the restaurant. Even if they make an order for the first time, they don't give it to us until they get a response for double pay from wolt. I got an order today. It was marked ready. 3 minutes late. I asked them where the food is. They asked me to wait 5 minutes to make it, but they never make it in 5 minutes. I removed the order. One of my friends received the same order after 7 minutes. He arrived at the venue, and they said they have to remake it cause its late. He asked to show the food of remake, and they had nothing to show. Please investigate the restaurant, cause they stealing money from wolt and time from drivers
# 7. Customers will have to understand that the green location marking is what we Wolt Bude is running for. It is very important that it is precise and put precisely on their front door
# 8. Hello with you "Wolt" You talk about listening to us cures and fairly done the app. First you have set our starting fee down from 45,- to 35,- earlier it was a bird spacing of 450 meters when the reality was 2 km and now even you have fixed the app in favor of Wolt and take the ass on us cures that made you rich. In the video on YouTube, the guy says you have listened to us where we were important per piece for distance. Now you have changed it even to you benefit so that there is a distance from each other and not distance from retrieval to delivery per piece PS. I'm super disappointed with your behavior toward us
# 9. Silent notification no vibration when food is ready
# 10. Navigation extremely slow
#
# === Topic 0 (3379 documents) ===
# 1. Sometimes there is a bug with the application. It doesn't calculate pickup distance properly.
# 2. Earnings are getting lower than 200 per hour during peak hours. When the client makes you lose time because he doesn't answer none compensates you :(
# 3. Why the just order pickup is 2/2.5 km away..I ride bicycle
# 4. Seems Wage should rise up a little
# 5. 16:30 is too early to start the he bonus as there aren't enough jobs to do even 3 deliveries per hour at that time..... This makes the bonus unreachable and lowering our earnings as there are too many hopefuls and not enough ready orders!!!!! 11 orders from 17 until 20 is the realistic bonus
# 6. Not like the old system of double oodre for the same money or the distances
# 7. Seems it is better than at Foodora misses your post also was in Danish
# 8. I got less per kilometer than usual ￼
# 9. A little sorry to be online so long and no order:/
# 10. will they have orders or?
#
# === Topic 1 (1045 documents) ===
# 1. Easy and smart to use
# 2. Though it was my first day, I enjoyed a lot.
# 3. You are lort and trash
# 4. Soups Lovely Working
# 5. Very happy,this is my job and my job is my life
# 6. if the world depended on you, it would be gone
# 7. Luxury is happy for you
# 8. I really very happy with wolt
# 9. Its really a enjoyably job.
# 10. Basic workers rights like sick leave would be nice
#
# === Topic 2 (977 documents) ===
# 1. McDonald's Valby (Gammel Køge Landevej, has a special place for handing over takeaway orders. Unfortunately, it is not staffed, which can be extremely frustrating when waiting to get an order that is either marked ready, or should be marked ready. And it is an obvious priority of, for example, Wolt's customers, with the physical customers who can turn to a manner of a manner ...
# 2. Some restaurants you have to wait a long time, while they say that the food is ready
# 3. One of the restaurants had wrong order but or very good
# 4. McDonald's Gladsaxe writes the order is ready even when it is not.
# 5. I am still unhappy with MCD on Østerbrogade. Contact me on phone 42 92 81 73 if you want it elaborated.
# 6. La Pizza Varde Every time I pick up it, it says the "order is ready" in the app, but then I have waited 5-10 min for them to finish. Wolt I took 3 orders at once and the order I picked up first I had to hand over as the last. It meant that the food had become cool and somewhat boring, which I had a shit with
# 7. The restaurant Nudel Biksen is very slow, i hat to wait 20 minutes as always, its not worth it to accept orders from them
# 8. Papa cucina very bad cpmmunication about delayed order McDonald’s very bad communication also about delated order
# 9. Since last week, a lot of restaurants say the order is ready, but when you arrive they take at least 10 more mins until it is actually ready
# 10. Frustrating that restaurants mark the order ready when it is not ready but in return is delayed
#
# === Topic 3 (527 documents) ===
# 1. Can't say anything good for those support who gave me 4 orders in the peak hours. Of course those bad people deserve only bad and worst wishes.
# 2. Cool support is quick
# 3. When I had delivered the first donut's delivery there was nothing if there was a more so agree with her from the laundry that they both 2 were to her then it seemed your system that made a mistake and not me made a mistake Then your support writes to me that they are drawing all my income today so all in all bad system as I could not see it should be delivered somewhere else.
# 4. it needs improvement very urgent system is very bad right now
# 5. Impossible to contact support
# 6. Just in the busy time it happen two time that when I was about to slide for accept an order was not happening and a note pop up that an error occurred and I couldn’t slide to pick up that order…. I got anyway the next one
# 7. Racism is bad and hopefully all these racists in support end soon.
# 8. Not fair your system
# 9. I am sorry I have same problem I come back to online
# 10. The new system is sailing
#
# === Topic 4 (491 documents) ===
# 1. The app is still working on H to - Are there others who have reported problems with this?
# 2. Could't contact the support due to app bug, it was unavailable today.
# 3. The app is sick: sometimes has to be restarted because the menu disappears. Sometimes I can’t mark a task as picked up. Sometimes I drive for say 2 km with no orders and the when I am near a venue I am offered an order that is 3 minutes late already..
# 4. The app works very badly. Often gets error messages when I have to enter "Items picked up". It causes i have to restart the app, which is very stressful when i'm busy
# 5. Mainly some minor lags of app but the main issue is the restaurant nudel biksen in roskilde and their preparation time, its is almost every time there when I have to wait 10-15 minutes for order and sometimes even longer, I think they need to change their preparation time or something... and wolt support was Great as always
# 6. App has Ben bugging like crazy, freezes alot. Sometimes can't accept or reject orders. Also get orders that are very far away and keeps repeating no matter how many times I reject
# 7. The app isn't working good
# 8. App is slow responding
# 9. The app is very slow about responding.
# 10. 00000000000000 points for support and app wolt big
#
# === Topic 5 (355 documents) ===
# 1. I don't like the locations I get when I started working was much better
# 2. I don't understand why it non-stop gives me addresses that are many kilometers away from me and doesn't give me an address in the area I'm in
# 3. App unable to locate me for half an hour, then not working at all.
# 4. GPS tracking could be more accurate, and it would be nice to have a route to your destination. Otherwise great really, I'm reaching for critiques here
# 5. Seems it works really well. However, I wish I can click on every order in my history to see where I was driving from time to time.
# 6. The map should be like Google maps to make the job esier
# 7. CHANGE ADDRESS NUMS. The app has done it several times on delivery.
# 8. In the future, it would be nice if changes in location were also changed in the app, rather than only coming as a message. This would make it easier to change the location in Maps so that you do not have to enter the new address yourself, but could just press the button in the upper right again.
# 9. The app will not react if I have zoomed in and out on the map… So I have to close and open the app again before it will answer
# 10. Waze had a very misleading location and to add there was also construction work in very same block which had most of entrances locked so I couldn't get to the right place. Then switched to Maps which showed right adress.
#
# === Topic 6 (241 documents) ===
# 1. The drinks holder can be more effective. It would be easier with an attached holder to the outside of the bag.
# 2. Negative: Make payment, no compensation for errors, approve all bags by split order. Positive: Can work whenever you want.
# 3. McDonald’s City slower to pack orders with the new bag system, bags take up more space.
# 4. App: there is a bug, When I have to pick two bags from Wolt market (this is the second time happening) it doesn’t allow me to mark the order as taken from store if I have both bags ticked, only if only one of them is ticked I can continue Support: I will like to not have to collaborate with Sebastian if that is possible Venues:
# 5. Simply too weird that burger concept does not wrap drinks in this case milkshake. It is really difficult to make sure the item emerges undamaged.
# 6. Please KFC, Mac Donald's need make Stickers as burger king to put in the cover because the soft drink alway come out please
# 7. Just the review of order doesn't make sense because all packages are sealed by restaurant
# 8. McDonalds City putting orders in big bags is a disaster. They put drink in one separate bag and food in one separate bag then put those bags together in a big bag. We have no control of the drinks. It’s a mess. And it takes up so much space. Bundles of 3 are not possible anymore. Don’t get me started on how much extra time it takes for them to pack the bags like this
# 9. Tell restaurants not to pack drinks inside the same bag as food, wnd to make sure lid is on properly
# 10. Menu didn't know there were price rackets for heavier stuff, I just wrote many liters of water and other stuff for halfassed payment. Defo not satisfied with menu.
#
# === Topic 7 (146 documents) ===
# 1. I could not delete task for 1 hour.
# 2. The only failure that I can find is that I have to wait too much time to receive tasks. I would like to be more busy doing tasks and I want to work without stoping. I hope you can put me with priority and thank you very much.
# 3. Too many bugs, useless and retarded support, few tasks
# 4. Often gets a task…. Which disappears again after 5-7 seconds.
# 5. You give me task in other zones, fuck off
# 6. After 17:00 ,only a task at 30 minutes,I have a few days the same sistem and I do t understand why....
# 7. Too much waitig for next task
# 8. 8 hours only 4 tasks
# 9. Can be optimized better during busy times!
# 10. I am not receiving task
#
# === Topic 8 (131 documents) ===
# 1. Bundle order should be same side same way and pay must pick point!
# 2. 1) too low pay for bundle orders. The have been lowered since the new payment system in feb/march. 2) fix the “DRIVE” orders in which the couriers can’t check the items and the venue can’t mark it as ready.
# 3. If it is quiet and there is no orders for everyone you should give bundles to others couriers. It is selfish and unfair
# 4. Today was a rather difficult day. I took 2 rather heavy bundle orders from the Wolt Market which I had to carry in my backpack. The first order was delivered which I received Dkr 60, but my second order which was equally heavy and 300 meters from the first order and I was only paid Dkr 30. I carried that heavy load 1.6km on my back and I was only paid 30 for carrying 300 meters. I understand there's a new bundle payment system. I can understand getting an extra 30 for carrying another McDonald's order 300 meters farther than the first order. But a heavy wolt market shopping list. You need to look over the bundle payment agreement. There's something seriously wrong there. Until the bundle payment is correctly adjusted, I think I'll avoid it cause personally, it feels like we are being taken advantage off. And I had a cancelled order by McDonald's at Kongens Nytorv. I arrived and they said my order was being made. I waited 30 minutes and they cancelled my order saying it was too busy. I was only compensated 30 for waiting 30 minutes through no fault of mine or Wolts. Compensation agreement should also be reviewed. Other than that. The app was working great and the Wolt support team was amazing. Especially Elena who helped me out.
# 5. The new bundle system needs you to shape way up in the restaurants delays, because otherwise it’s a useless new feature!!! Or add more info on minutes! Plus ready orders should also have minutes added!
# 6. Totally messed up. Orders super delayed.. The algorithm sending totally opposite way for bundles because it was crazy delayed everywhere so, one task at a time because of this and also because the bundles are payed totally unfair, 25, 23, 22kr for a bundle... Have you asked yourself why is it like this? Nobody wants to go in the rain for 30kr for a task... It's even summer.. Have you planned winter??? There's gonna be a huge problem as I see. Get back to old payment method
# 7. It's not ok that I am now constantly being disturbed, with the need to reject bundles, when I generally only whant single orders, also the payment seem to go down, and lacks transparency even more for every change that is made
# 8. Still hope bundles, especially the heavy ones, will be rewarded better. Hope you share some of your profits with the couriers..
# 9. Too much emphasis on bundles. Instead of having single orders delivered on time there are bundles with late drop offs. This needs to be fixed, reverted to the older system!!!
# 10. U should increase the price for bundles
#
# === Topic 9 (75 documents) ===
# 1. Almost 5 hours online,380 dkk Bad weather, Saturday, still low earnings!!! The position is updated at large time intervals, and then it shows you where you were 5 minutes before (the problem was many months ago)
# 2. About 580 in 3 hours is okay but only thanks to that 100 dkk bonus. Otherwise the fees are currently lowest ever since I started working with Wolt
# 3. Orders for 35 dkk or less on a Friday supposedly on peak hours (7pm) sounds wrong... I feel like the pricing has got quite off sometimes.
# 4. I made 600 dkk for 10h of working was very bad day... another people got orders but from 20 00 until 22 00 I didn't get any.. or maybe just one
# 5. 2 hours online,145dkk,
# 6. 26 dkk is too low for a normal order….
# 7. This afternoon, 2 and a half hours online, 2 orders, 140 dkk, less than 60 dkk per hour, wasting time and gas!
# 8. 8 hours 570dkk, this should be illegal
# 9. 90 mins no tasks Wolt per hr is 160 dkk in Dk ..now my per hr is 20 -30 dkk .l lost 50 % payments per hr in Dk ..I can't earn 100 dkk per hr anymore?
# 10. Let 45 dkk base payment during week please in Lyngby
#
# === Topic 10 (70 documents) ===
# 1. 5 of 7 orders offered late. SO SAD AND WRONG..App lets me drive for miles, then offers almost ready order when I’m close to the venue
# 2. App lets me drive for miles, then offers late or almost ready order when I’m close to the venue. Almost six orders like this today !!!
# 3. App lets me drive for miles, then offers almost ready order when I’m close to the venue. ABSOLUTE JOKE TODAY. THE LEVEL OF MANIPULATION IS BEYOND BELIEF.
# 4. App lets me drive for miles, then offers almost ready order when I’m close to the venue. JUST AN ABSOLUTE EMBARRASSMENT!!!! Most orders are to top floors, 5th, 4th but I don’t see it reflected in the pay?
# 5. App lets me drive for miles, then offers almost ready order when I’m close to the venue. PLEASE PLEASE STOP DOING THIS. WOULD YOU LIKE TO BE MANIPULATED THIS WAY ?
# 6. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Biiig joke
# 7. App lets me drive for miles, then offers almost ready order when I’m close to the venue. PLEASE PLEASE change the programming of the app, so it offer us orders BEFORE we cross a big intersection, or turn a corner. It is super annoying and somewhat dangerous to have to do all these U-turns.. Also my app doesn’t really register how many miles I drive, I estimate less than 20 % is registered this month
# 8. App lets me drive for miles, then offers order when I’m close to the venue, and as an extra bonus, the order is quite late because you wait to offer it…
# 9. App crashes. App lets me drive for miles, then offers almost ready order when I’m close to the venue Miles driven exploded
# 10. App lets me drive for miles, then offers almost ready order when I’m close to the venue. DONT YOU FEEL ASHAMED TREATING US LIKE THAT??

# %%
from collections import defaultdict
import random

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = -1
docs = topic_to_docs.get(topic_id, [])

# Filter documents with max length of 50 characters
filtered_docs = [doc for doc in docs if len(doc) <= 140]

if filtered_docs:
    sampled_docs = random.sample(filtered_docs, min(15, len(filtered_docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic -1 (3027 documents) ===
# 1. App unresponsive at times forcing me to restart the app many times Wolt market was very far behind schedule
# 2. About half an hour delay at Frankies in spite of having marked the order ready
# 3. Let's keep wolt as it is now . Let's gooooo
# 4. Could well wish that extra is given when sent out to an area where there is no possibility of taking some orders with returns
# 5. J3G thinks there is a problem as I have not received any odre
# 6. Have an excellent week
# 7. WTF ? WHERE IS ORDERS ???
# 8. Disgusting thieves in support
# 9. The swiping at the resturant doesn’t work
# 10. Have needed to focus a little on the study, but have been actively watching if there is a busy
# 11. Worst app after update. Horrible keeps crashing
# 12. are we going to work ?? no orders .. it's very weak .. what happened to this area ?
# 13. Larger range for order
# 14. App still really bad -Offering task 40 minutes ahead…
# 15. The worst company in the world by a long mile

# %% [markdown]
# 1. Skulle være endt i app topic (8). Men måske fordi vedkommende også brokker sig over Wolt market, så skaber det støj --> problem ved to topics
# 2. skulle være endt i topic 2, omkring venues er forsinket
# 5. måske for dårligt formuleret, ellers skulle den være måske være endt i topic (11)
# 7. skulle være endt i

# %% [markdown]
# ## Merge topics

# %% [markdown]
# Based on the inspection of topics, it looks like the following topics can be merged
#
#
# - 4 + 7 + 11 (lack of orders)
#
# - 2 + 5 + 12 (venues being late)
# - 1 + 16 (sentiment)

# %% [markdown]
# Now a create a dendogram which clusters the algorithm find the closest

# %%
loaded_model.visualize_hierarchy(custom_labels=True)

# %% [markdown]
# - confirms 7 + 11 are related (4 could be merged as well)
# - comnfirms 2+5+12 are related
# - confirms 1 + 16 are related
#
# Suggest
# - 8 + 10 could be merged (and 6)
# - 3 + 15 could be merged
# - 0 + 4 could be merged

# %%
# Createas a identical model called reduced_model, which is a copy of the loaded_model
# I'll use this to reduce the number of topics in the model, while keeping the original model intact
import copy

reduced_model = copy.deepcopy(loaded_model)

# %%
topics_to_merge = [[7, 11, 4],
                   [1, 16],
                   [2, 5, 12],
                   [8, 10],
                   [3, 15]
]

reduced_model.merge_topics(documents, topics_to_merge)

# %%
reduced_model.get_topic_info()
# Out:
#     Topic  Count                                     Name  \
# 0      -1   3027                   -1_order_time_app_wolt
# 1       0   2492                 0_pay_order_wolt_payment
# 2       1   1045                  1_happy_wolt_good_thank
# 3       2    977            2_ready_wait_order_restaurant
# 4       3    887                 3_courier_order_hour_new
# 5       4    527      4_support_order_system_wolt support
# 6       5    491                5_app_order_app work_work
# 7       6    355                 6_map_address_google_gps
# 8       7    241                    7_bag_drink_pack_food
# 9       8    146           8_task_task task_time_new task
# 10      9    131          9_bundle_order_bundle order_pay
# 11     10     75         10_dkk_hour_dkk hour_hour online
# 12     11     70  11_mile_drive mile_mile offer_let drive
#
#                                        Representation  \
# 0   [order, time, app, wolt, work, customer, deliv...
# 1   [pay, order, wolt, payment, work, low, money, ...
# 2   [happy, wolt, good, thank, work, happy wolt, d...
# 3   [ready, wait, order, restaurant, time, food, b...
# 4   [courier, order, hour, new, new courier, order...
# 5   [support, order, system, wolt support, team, c...
# 6   [app, order, app work, work, time, error, supp...
# 7   [map, address, google, gps, app, location, map...
# 8   [bag, drink, pack, food, cup, paper, spill, so...
# 9   [task, task task, time, new task, accept, acce...
# 10  [bundle, order, bundle order, pay, task, payme...
# 11  [dkk, hour, dkk hour, hour online, online, 3 h...
# 12  [mile, drive mile, mile offer, let drive, clos...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [The pay per order is too low., Lots of discre...
# 2   [wolt is the best i am very happy with wolt, w...
# 3   [some of the restaurant marked food as ready w...
# 4   [Didn't get some order, There are No orders at...
# 5   [Wolt support not good.verybad, Support always...
# 6   [The app works really well, The app was down f...
# 7   [Addresses were misleading, Please don’t pley ...
# 8   [Please do something about the bags. Big proce...
# 9   [I didn't get any task, I don't get as many ta...
# 10  [Why the system give bundles when there are no...
# 11  [It is disastrous, yesterday after 7 hours on ...
# 12  [App lets me drive for miles, then offers almo...

# %%
reduced_model.visualize_hierarchy(custom_labels=True)

# %%
topics_to_merge1 = [[0,3]]
                   

reduced_model.merge_topics(documents, topics_to_merge1)

# %%
reduced_model.get_topic_info()
# Out:
#     Topic  Count                                     Name  \
# 0      -1   3027                   -1_order_time_app_wolt
# 1       0   3379                 0_order_pay_courier_hour
# 2       1   1045                  1_happy_wolt_good_thank
# 3       2    977            2_ready_wait_order_restaurant
# 4       3    527      3_support_order_system_wolt support
# 5       4    491                4_app_order_app work_work
# 6       5    355                 5_map_address_google_app
# 7       6    241                    6_bag_drink_pack_food
# 8       7    146           7_task_task task_time_new task
# 9       8    131          8_bundle_order_bundle order_pay
# 10      9     75          9_dkk_hour_dkk hour_hour online
# 11     10     70  10_mile_drive mile_mile offer_let drive
#
#                                        Representation  \
# 0   [order, time, app, wolt, work, customer, deliv...
# 1   [order, pay, courier, hour, wolt, work, paymen...
# 2   [happy, wolt, good, thank, work, happy wolt, d...
# 3   [ready, wait, order, restaurant, time, food, b...
# 4   [support, order, system, wolt support, team, c...
# 5   [app, order, app work, work, time, support, er...
# 6   [map, address, google, app, gps, location, map...
# 7   [bag, drink, pack, food, cup, paper, spill, so...
# 8   [task, task task, time, new task, accept, acce...
# 9   [bundle, order, bundle order, pay, task, payme...
# 10  [dkk, hour, dkk hour, hour online, online, 3 h...
# 11  [mile, drive mile, mile offer, let drive, clos...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [I didn’t get that much order., Didn’t get any...
# 2   [wolt is the best i am happy with wolt, wolt i...
# 3   [I had an unacceptable experience at McDonald'...
# 4   [Wolt support not good.verybad, Leaf -tender s...
# 5   [The app works really well, The app was down f...
# 6   [Addresses were misleading, Please make it pos...
# 7   [Please do something about the bags. Big proce...
# 8   [Because i always get less task, Then we are t...
# 9   [Why the system give bundles when there are no...
# 10  [It is disastrous, yesterday after 7 hours on ...
# 11  [App lets me drive for miles, then offers almo...

# %% [markdown]
# Now there are 19 topics.
#
# From inspecting the topic representations and documents in each topic (see further down), I have made the following assessment
#
# Topic 0: Problems with restaturants (especially being late) = cooperation with venues
#
# Topic 1: Satisfaction of working with Wolt (also a few negative)
#
# Topic 2: Order and salary (two different things, but closely connected)
#
# Topic 3: App functionality
#
# Topic 4: Something about distances in relation to earnings and vehicle
#
# Topic 5: Too many couriers (and hiring new couriers), but some more express they don't care about courier or bad earnings. Too many couriers can also easily be linked to low earnings or too few orders
#
# Topic 6: Wolt support
#
# Topic 7: GPS tracking, google maps, and addresses
#
# Topic 8: Wolt bag, and how restaurant pack/seal the food
#
# Topic 9: Bad earnings
#
# Topic 10: mixed in relation to taks (too few tasks, some where task is just mentioned but about specific problems or frustrations).
#
# Topic 11: Random topics, where city names are included.
#
# Topic 12: Bundle orders
#
# Topic 13: Low prices (some about new payment model). Prices is related to earnings.
#
# Topic 14: Bonuses (either in relation to pay or schedule)
#
# Topic 15: Lidt rodet topic. Men handler bl.a. om a acceptere / annullere ordre samt unfair penalties og mangel på kompensation når der er sket fejl
#
# Topic 16: Low paypment + some comments about a new / old payment system
#
# Topic 17: Happy with Wolt
#
# Topic 18: No orders (couriers go home)
#
# --------------------------------------------
#
# The folliwing would logically make sense to merge
#
#  1+17: satisfaction with Wolt
#
#  2+5+9+13+17+18: earnings / too many couriers / orders / prices / pay

# %% [markdown]
# I inspect the documents

# %%
# Get topic assignments for each document
topics, _ = reduced_model.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Iterate over sorted topic IDs
for topic_id in sorted(topic_to_docs.keys()):
    docs = topic_to_docs[topic_id]
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 10 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
# Out:
# === Topic -1 (3027 documents) ===
# 1. This update is very bad, for large and double orders it is no longer worth going to deliver them, you earn far too little on them, others receive more, others less, for the same distance, this update is very bad
# 2. I am really happy when there are tasks but there may be a little quiet when i am online
# 3. Staff at Otto Frederiksberg gave bad estimate and took no responsibility for the 15 minute delay they caused to my customers
# 4. I couldn't reach the customer for 20 minutes and delivered it to her boyfriend. Again a problem at rush hour. That's too bad.
# 5. I took an order from a place, and when I arrived, they told me that the order was to pick in an hour from that time. If wolt allowes to the people to order on a specific time, they should write somewhere in the task so the courier can know and reject it if it’s not useful, or they should send the task to the courier when is going to be ready, not one hour before, because I lost time going to the venue and also I got no compensation for it. For that time wolt support was really slow and took 15 minutes to unassign the task. Really disappointed today
# 6. Wolt app turns down the volume of other apps… please fix it (on iPhone)
# 7. I had an order from mc donalds frederiksberg, it was marked ready, i waited there 20 min, after they said to me they have problem with the program, so i had to remove the order..and i just didn’t get any recompesation..the support just did’t take care of this issue..shame!!
# 8. Original pita always late even when not busy
# 9. Lolo vu7vu77.æmo9 Jjjj5nnujb4brm
# 10. The algorithm is shit,
# 11. There was very quiet with orders
# 12. wolt has become a waste of time if you have nothing to do in your life and want to work for free then do it Wolt fuck you !!
# 13. Waited 30min for an order 160kr in an hour not gonna happen. U need to pay more guys. No way around it.
# 14. Today, I had to cancel an order after traveling a long way because the venue said it will take too long. It would be great if the Wolt could improve order preparation estimates or consider a compensation. Thanks.
# 15. The application completed a task without me being close to the address, it must be a bug in the system or something. Please check how could this be possible. It caused a delay for the customer to receive the food, and if the support person does not contact me I would have not been able to deliver the task.
# 16. Plzzzzz gi me something to make plzzzzzzzxxxxxxxxxxx
# 17. Very bad experience today 2 people get same order support doesn’t help and waste 1 hour and in peak hours you said 25% extra but nothing was added
# 18. Less rides, less money made a day, not as good as before
# 19. The mobileholder that I bought from you broke. It couldn't take a small bump in the road
# 20. Suggestion for when we press decline order, there should be two options "yes" and "no" instead of "decline" and "take order", so when we press "no" we can go back to the previous screen.
#
# === Topic 0 (3379 documents) ===
# 1. Waiting time was horrible today
# 2. Miles driven look to increase dramatically. What would you do if it was you?
# 3. Get back to old payment system and stop stealing our money please
# 4. It would be great to work when there is bonus during rain..
# 5. We should know about the bonus schedule if it is different...
# 6. Fuck everything about Wolt and Their new shitty payment system… and thanks for giring every single bum you could find. So there is no Work for the rest of us… 3.5 km for 48kr and I had to wait 35min for this shitty support to respond and help me out. Seems fair! I’ve could collect recycling cans and made more, u aholes
# 7. Two orders in one hour
# 8. Increase pay for long distances
# 9. Is it just me you are scamming or is it all couriers?
# 10. I didnt get my pay from august
# 11. I get no order in Kalundborg can not be increased in marketing here so people know it is here, via social media or via flyers in town :-)
# 12. Impossible to make any money due to ur overhiring issues 60min no orders in peak times nah
# 13. Very poor amount offered
# 14. Super good could have used a little more orders
# 15. Many orders, congratulations on that. Miles driven to make money obviously up a lot because you have once again reduced the pay especially for longer pick ups. So so sad. But I feel sorry for you, because I imagine it is the same for the administration. Must be so hard to have to work weekends, and no holiday. Please accept my condolences.
# 16. Sorry. My scooter don't start.
# 17. Dear Wolt, I am really worried about availability of tasks besides the fact that current pricing model is different substantially at least from the one when I was starting delivering in 2020. Hoping that it will not get worse and fingers crossed for getting better.
# 18. if you won't place orders i'll shut down....then you'll be looking for couriers for the evening...when everyone leaves? I was thinking of working late... but if there are no orders, I'll go home
# 19. For this payment per task you have to move your asses and go deliver yourself!!!!!
# 20. The price for orders keeps dropping instead of improving and when the system makes a mistake calculating the distance we're told it can't be fixed
#
# === Topic 1 (1045 documents) ===
# 1. It’s my first day and was quite challenging but I’m hopeful
# 2. Things went wrong but I’m too tired to tell and it wasn’t my fault
# 3. Super good thanks for evening
# 4. Much better than yesterday
# 5. Can work when I feel like and earn a little extra on the page. Also really good payment, up to 320kr per hour by car I have experienced
# 6. But time, it is like charm. You never have as much as you think.
# 7. It was my first day really nice and learned a lot today
# 8. Fk all you, wolt suck
# 9. Love Wolt, could need a little more stability in the amount of work, but when there is something it is completely impeccable!
# 10. I’m very happy! I love Wolt
# 11. Pretty happy, they’re good to me
# 12. I very Happy, I like this job. Thanks for all
# 13. 1st day and I love it
# 14. LOVE TO RUN WITH WOLT - it's all timeers
# 15. Thank you for your help and support
# 16. It still has super cool with the work and hope you are happy to have me on board too.
# 17. I love my work :) Like the customers love that we deliver ♡
# 18. It was a short but good, effective and lovely Monday :)
# 19. Great day plz More of Demaeder
# 20. So far it seems like a great job for me
#
# === Topic 2 (977 documents) ===
# 1. The collaboration with McDonald's is bad. Long queues for delivery.
# 2. Would be nice to get compensated for when restaurants are late. Burger Concept is constantly late 15-20 minutes, so no one wants to accept orders from there. Couriers are just wasting time
# 3. Once you have taken an order and it is ready at 6pm and you know in advance you come 10 min late, then it is not smart that you can only report 10min delayed when the food is already ready. You must have a function where you can report delayed immediately so that the arrival and the end time of the food fit and it is picked up warm.
# 4. Mc Donald’s frederiksberg just make us to wait there outside even if food is ready and available.
# 5. It makes no sense to collect two orders where the first is ice cream, after which you have to wait +10 minutes on another order to come. Get the timing control!
# 6. Have experienced several times now that Burger King is extremely slow and disorganized. It takes too long for them to make the order ready, even small and simple orders have been extremely delayed.
# 7. Berlin Döner on Nørrebrogade Marker Ordering as ready and when I come in and have to take it then she says they have started right now. I thought it is totally bad and disrespect where I have to wait 10min to order even though on the app this is ready. I have experienced from them several times the same mistake and thought it is not going.
# 8. Special thanks for McDonalds Fisketorvet- amazing work!!!
# 9. At Burger King Køge the estimated time is everytime overpassed with about 10 minutes beacause of the venue not being able to finish the order in time.
# 10. O snacks Falkoner alle mark food as ready without being ready and then long wait time for couriers. It happens multiple times but no action or improvement
# 11. Often i need to wait extra time in Halifax. Today it was really long time. About 20 minutes extra.
# 12. Sivas pizza marked the orders ready even if it is not ready yet!
# 13. Orders coming too far, fees too low The order seems ready, but when I come to the restaurant, it is not ready. I am given 5-6 minutes. Can you contact the restaurants so that they do not mark the orders as ready if they are not ready? Distance charges are decreasing day by da
# 14. McDonald's in Frederiksberg wasted not only my time, but other drivers time. They weren't that busy, I saw t least 5 personal there just standing around and having fun with each other, they didn't respond with I tried getting their attention, which is why I cancelled the order (and declined the two subsequent orders that came) - resulting in me having an extremely slow hour between 22.00 and 23.00. A competing delivery service driver told me I was the third to cancel the order and leave, because the workers at this McDonald's apparently weren't working very fast (if at all)
# 15. New design is kinda weird, every tome I GoT new order I never knew what restaurant it was from
# 16. Time estimate at McDonald's Nørreport does not fit. A repeated problem I often experience.
# 17. Mc Donald’s Frederiksberg always mark food as ready without being ready. It creates lots of uncertainty and confusion. Could you please ask staff to mark food as ready when it is actually ready
# 18. Huge delays in the burger concept in Aalborg and Catch Sushi doesn't mark when order is ready, resulted in huge delay of delivery. App crashed all of a sudden
# 19. McDonald's Fisketorvet packs their orders really bad ..
# 20. Had to wait 15-20 min for an order at McDonald's, and then they told me sorry someone took the order earlier. And generally big delays at McDonald's near Frederiksberg Station today. Wolt chat support was great.
#
# === Topic 3 (527 documents) ===
# 1. Good & helping Team Wolt
# 2. Today wolt support was very bad
# 3. No contact to support
# 4. Haven't used support today.
# 5. My account is dysfunctional still. I can’t work
# 6. Terrible update you want us all broke?
# 7. Sorry come back 30 minutes (((LAUNCH)))
# 8. Our support is became a copy paste and does not take into account individual inquiries anymore ...
# 9. The new support section is too fiddly, slow!!!
# 10. Sorry had some issues tonight and had to end, will try again tomorrow.
# 11. I had to write 4 times to wolt support before someone reluctantly helped me
# 12. There could well be a feature where you could undo an order after accepting. If, for example, there is an order in a store where they are behind with many orders
# 13. In general, the support seems to be extremely helpful and quick to return. Today, however, I had a tremendously unfortunate experience that was the mix of pure accidents and slow support. The order I was going to pick up (which was marked ready), there was someone who had snapped, and so I contacted the support. At first I was distributed and then I was asked whether I will wait for a remake or not (this went okay strong). To this, I replied that probably had to wait for the remake. It went over 10 minutes before the support started the remake. This meant I spent over 20 minutes on McDonald's on an order already marked ready. I had probably expected some kind of compensation, which I have received for much less things in the past. So all in all super sorry situation :(.
# 14. Shitty disrespectful platform
# 15. Wolt support was super slow and unresponsive. I did not get any conclusion from the conversation about me or the customer.
# 16. Gastronomia Italia order 268. I arrived. Confirmed my order number is 2 6 8. They confirm and ask multiple times if it's 2 6 8. After I get it, I swipe. But they say I didn't swipe. I show them the order on my phone. They show me the order on their tablet, saying the order is 2 6 9.... I say mine is 2 6 8. They don't understand why 2 6 8 is my order, and not 2 6 9... They insist they gave me order 2 6 9, even though we agreed multiple times that I came for order 2 6 8.. I should receive compensation on behalf of their mistake.
# 17. So bad people in support
# 18. The new update (multideliveries)is horrible
# 19. The new app update it's not good at all ,the old style it's the best
# 20. Anachi very bad support team
#
# === Topic 4 (491 documents) ===
# 1. There are still some features of the app
# 2. The app still doesn't work.
# 3. who messed around with the app's UI? the name of the restaurant when receiving orders is now blue but smaller, which makes it harder to see. and the chepoints sizes...man don't even get me started on that. the visibility is almost terrible
# 4. The app is working slow
# 5. Sometime app hangs otherwise its good
# 6. App is super glitchy, a lot of the times I can’t accept or decline tasks and I keep getting pop ups for orders that are like 30min+ remaining on them..
# 7. The app works terribly
# 8. Your application keeps crashing and it doesn't work in background!!!!!!
# 9. App is broken AGAIN!!!
# 10. App doesn't work, doest shoe drmand
# 11. App works like shit...
# 12. App stops working for 5-15 minutes. Nothing fixes it. Frequent issue.
# 13. The recent update sucks... The app get freeze everytime
# 14. Horrible app bugs preventing us from getting orders getting stuck on high demand
# 15. The app was down for me
# 16. Faulty app, useless support
# 17. Freezing, could not scroll up for details or to check items, very annoying!
# 18. When I deliver to Ørestad Boulevard 34A, I often lose connection to the app. Maybe because I try to swipe in while driving down with the elevator. When I get down the street again I try to swipe many times. But it will not be registered. Then I restart the app and then it says I am offline. It has happened some times now
# 19. THE APP IS BROKEN. It stops working for 5-10 minutes. Yes, I restart and it's updated. It has happened like 20 times in a month. FIX IT ALREADY, THIS IS INCOMPETENCE.
# 20. Even though the app said the demand was normal, the first hour or so, I waited for an order about 60% of the time
#
# === Topic 5 (355 documents) ===
# 1. The application should have navigation mode. I cannot use Google Maps application with WOLT Simultaneous...This causes trouble.
# 2. The new app doesn't have a good map, it's not cluttered, it's harder to handle
# 3. The location system is full of shit
# 4. The adress on google had the wrong number. Every time. All day. Right street, two numbers or so off
# 5. Please change the green circle for Strandvejen 5. The position is wrong. Thank you Dirk
# 6. Good , sometimes Google map is disturbing
# 7. Sometimes the address does not fit when pressing maps from within your app of Men or Fino
# 8. Add copy of addresses
# 9. There were problems with GPS but support was quick and good at correcting the error
# 10. The app shows incorrect addresses every now and then
# 11. I miss a function to enlargen streetnames on map.
# 12. A lot of inaccuracies with their dropped pins ￼on the map
# 13. The map needs real time follow
# 14. It could well become very vedre
# 15. The apps shows wrong delivery address before pick up
# 16. Could be nice with GPS
# 17. Wolt App and Google Maps mostly well together. But there is often collaboration problems on the top. Sometimes 300m next door, sometimes neighboring the street. The most violent I've experienced is 2 km wrong. I have been doing wolt for 2 years 8 months so now double I always check
# 18. Some locations of apartments in the inner city are inaccurate and hard to find, taking precious minutes from the delivery time.
# 19. When copying an address also to Appel mapped, it does not show the exact address just nearby
# 20. Some problems with address finding on 2 .. where GPS does not work properly in relation to app
#
# === Topic 6 (241 documents) ===
# 1. Actually I start to like the new algorithm a lot. I even think about to invest in a e bike this month to be more efficient ;) Please just remind the restaurant (Pizza Top) please to pack the food in a extra paper bag, cause it is not hygienic to transport Pommes in a Styrofoam bag, where the ketchup or mayonnaise can run out and the couriers have to clean than the bag again and again - which takes a lot of time. It would also look better for the customer to get the food in a paper bag.
# 2. hello It is necessary to say two things here. 1- On rainy and cold days and after sunset the stated prices for delivery do not differ from hot summer days, which is very problematic considering that under heavy rain, the delivery work is really difficult, especially with a motorcycle that is directly exposed to the rain and we spray water from the side of the cars, it will be very difficult so we have to reject some orders. 2- Burger King Vanløse has a problem with the beverage package, and almost all orders including the drinks have waste or leaks that need to be warned because it is us who are questioned when the food is delivered.
# 3. Joe & The Juice gives us coffee in cups with a hole in the lid that they have not covered. There is not much bump in the road until there is coffee throughout the bag/bag.
# 4. Milkshake packed with hot food. Had to apologize to the customer.
# 5. I broke food, don't know or it is my mistake or food was packed not well
# 6. Burger King packs their food so badly so it's hard to handle. McDonald's, on the other hand, packs their food well in large bags, however, they put very little in the big bags, so you end up with 3 large bags for an order. Since I have to pick up three orders at once away, they can't be in my bag at once.
# 7. Wolt market w/ bike was not a good experience. Way too heavy and not enough space in the bag. Luckily I had a basket on the bike. Is it possible to give heavy and big Wolt market orders to car couriers only?
# 8. MacDo gives you closed bags, impossible to check what they contain! I take them for good!
# 9. Tell MacDonalds to stop putting the drinks in bags where they fall over and keep them separate so I can put them in our supplied cup holder. I am really getting tired of this stupidity on their part.
# 10. Would suggest that McDonald's by Vejlevej gets a bench until you can sell your bag on when you pop in it instead of putting one on the floor as I mean this is quite unhygienic and McDonald's on the flow baker has such a bench so it can be done
# 11. Some bend, I should ask for bags for the orders. When the customer pays for it, they must also give one.
# 12. I recommend that you include ‘fragile’ category marked with a sticker or marker pen to each order that contains anything fragile, ranging from eggs through fruits and liquids like drinks in plastic cups and soups to improve awareness, safety of a delivery, and overall quality and satisfaction of a customer and partner rating. Especially in the Wolt Market where products can be damaged easily. Some venues inform me about such contents but some don’t and it is not alright because I most often I don’t see the contents through the bag and I cannot ensure the quality of delivered. That way I would be able to take double the care about such orders. Moreover, the design of bags should have some straps inside to secure bags from moving that happens a lot when riding over cobblestone roads and uneven surfaces and turns. Again, improving safety standards of goods delivered.
# 13. Hi, I bealive that there should be possibility to check where the order will be delivered and to check how bug the order is in termes of itemy and size so partner can imagine how bug the order is and He/she knows if it can be fit inside the bag when there are multiplex orders. Other than that it is Great
# 14. Carls JR gives drinking products without the bag, how is it possible to deliver it without anything happening to it unless you hold in hand
# 15. McDonald’s City slower to pack orders with the new bag system, bags take up more space.
# 16. Some fast food joints should start packing drinks better, it’s not a big issue, but the drinks are dripping, and the acid from the soda damages the bag, which we have to pay ourselves. Also, customers might think the drink is spilled if they see some drops running down the cups. Burger King, Carl Jr’s and a few other ones. In other countries a layer of plastic is put on the drinks. Also. It’s been pretty quiet. Please don’t hire too many couriers.
# 17. The bags in the Wolt Supermarket were crowded. All the bags couldn't be in the bag despite pressing as much as possible in it. The last bag broke under the weight and the contents which were many small soda bottles overturned over Nørrebrogade. It's too stupid not to think about how much there can be in the bag when you have shared one out and know how much space everyone has. Put a Limit on item or give the big orders to people in cars if needed
# 18. Burger king has to stop giving drinks in cups. They spill every time, and the canned drinks stay cool much better!!
# 19. A comment for Wok in Vesterbro. I delivered two orders and the bags both broke due to leaking packing. 1st orders bag broke directly as I handed to the customer, the second i had to arrange the mess into something deliverable. I would advise they look at their packaging to make it less leaky as the deliverable product doesn’t look pretty for me or the customer.
# 20. Sandwich kompagniet venue serves juices in the soft plastic cup with a plastic wrap that doesn’t stick and with plastic cover that does not match the bottom therefore couldn’t even be closed. It would be hard to carry it in hands not to mention a bag or backpack
#
# === Topic 7 (146 documents) ===
# 1. Often gives 'unknown' mistakes when I have to accept task. Cannot do anything while the mistake stands on
# 2. It takes time to get a task when you have finished it as you had, you get upset
# 3. Something was modified with the distance of tasks. Now I receive too long tasks, after a survey you sent asking about the vehicle type
# 4. Why the same cures that get the whole timennnn
# 5. Will be cool if new tasks first came up on screen when you finish another task
# 6. Hi, I’ve experienced some trouble with the duration of the display of a new task. Whenever I mark a task as dropped off or picked up and there is a new pickup lined up, the new pick up is displayed for 1-2 seconds and then disappears, which means I don’t even have time to read it before it’s gone. This is a consistent problem.
# 7. 5 hours, 3 tasks, less than 200 DKK, pure conditions
# 8. 45 minutes without a task on high demand
# 9. multitasking sucks. if we aren't employees as you say we should have the freedom to choose if we want to work on a single order or multitask. put the option to activate or deactivate multitasking. useless
# 10. Don't send out the tasks when they have 20,30,40,50 minutes of waiting time! Nobody accepts this...
# 11. Don't solve my problem
# 12. Allocating was too early today I had a few jobs with a ready time of 20!!
# 13. Many many duties accepted just to disappear immediately afterwards.. but it was the only issue
# 14. Gets the message unknown error when I will accept a task
# 15. Hestitant to go back online because I’m worried whether there’ll be enough to do… lately there’s been a lot of waiting between tasks even when the status is “busy”
# 16. No task for over an hour from 18:45 to 19:00, while others were getting tasks in bundle!!!!!
# 17. I don't get as many tasks
# 18. Was online for 20min and didn't get one task...........
# 19. All tasks with +15, 20, 30, 40 minutes waiting time.. Really bad
# 20. 4 hour yesterday one task???
#
# === Topic 8 (131 documents) ===
# 1. Miss the old bundle order system
# 2. Look at Bundles: Seems better pay is needed, you seem to just reward for extra distance, but in reality the orders can be very heavy, you have to go a long way with heavy order for pick up 2, which can be up to 10 stairs that may be delays and risk of delays
# 3. With this new bundle system, you took the chance to get any tips. The food will be cold and it will take more time to deliver. More unsatisfied customers.. less will order in the long run... for example, I am getting comments like .. what took u so long.. and did you find the way finally?ect...and I did as fast i could.. and I think as fast as possible with a car. It's stressing, and I am not used to meeting unhappy and angry customers
# 4. I do not always like the way your bundles are administered: Today I got an order at Max Burgers at Gammeltorv, Copenhagen. It was to be handed over at Nørregade 36a. But when I marked the order as picked up, I was offered a bundle/new order at Sushi Lovers in Torvehallerne. The order was to be delivered Nørregade 40. I accepted the assignment, but was surprised I first had to pick up order two in the Torvehallerne, rather than delivering orders one at Nørregade 36 which was on the road to the Torvehallerne…
# 5. It's not ok that I am now constantly being disturbed, with the need to reject bundles, when I generally only whant single orders, also the payment seem to go down, and lacks transparency even more for every change that is made
# 6. Be transparent on payment!! Stop tricking us! Bundle orders should pay the same as first ones!!
# 7. The new system of bundled orders has generally not worked very well. It is as if the system just collects the trips that no courier wants to drive, either because the service at that restaurant is too bad or because it is not a legal stop at that restaurant.
# 8. Very unhappy.. decreased the price per km. bundle order calculate from drop of not from shop. Worst management ever.
# 9. System has had major issue since you change system yet its not been fixed, at this point i think it's intentional. Also bundles is really not worth it, i drive more km and getting paid less compared to before you change system, it stuns me you haven't YET made a km deduction system, at least you can do that. Benzin is not free.
# 10. Still hope bundles, especially the heavy ones, will be rewarded better. Hope you share some of your profits with the couriers..
# 11. Bundle orders are a joke now. By no means profitable as in the past
# 12. Make bundle orders profitable again. In the second order, the full distance should be paid (pick up & drop off) that was the beauty of boundle orders. Now even on bonus weekend it's not much difference we are making with earnings.
# 13. Every day I earn less.. nobody cares about us. The bundles aren't a good business for the couriers. There are few orders
# 14. Make bundle orders worth taking!
# 15. Quiet, now? We are not doing economic difference with bad days. The bundles not add money for us anymore
# 16. Long distance deliveries and bundle packs are much less profitable...
# 17. Some of the bundle pays are down, less than 25 kr. Please reconsider this, often short deliveries are to top floors with no elevator, and can be heavy, and the orders are also subject to delays, just like other orders…
# 18. It is a big difference now taking bundles, we get paid so much less than before, and the same with long distance deliveries.
# 19. No hollyday payment, bundles are too low 35KR
# 20. The new pay system is unfavorable and unreasonable to couriers. This is especially with services provided by couriers during bundle deliveries…in my opinion that’s not fair …we should get our full fee for services whether bundle or single delivery.
#
# === Topic 9 (75 documents) ===
# 1. I decide for myself when and how long I want to work. If I work Friday to Sunday from 17 to 20 I am guaranteed DKK 110 per hour. If you have more orders and constantly orders are your hourly wage 150+
# 2. I think there should be a no lower than 35 Dkk for all deliveries between 0-500
# 3. Orders for 35 dkk or less on a Friday supposedly on peak hours (7pm) sounds wrong... I feel like the pricing has got quite off sometimes.
# 4. I just spend more than 2:30 for 70 dkk îs this oke ?
# 5. After 2 hours online I won 70 dkk, after paying taxes and gas I don't have enough money to buy a sandwich to eat for lunch, it's very, very bad
# 6. In the last 6 hours in Copenhagen area I got 1 single delivery in the value of 93 DKK before tax. It is about 15 DKK/h before tax and 9 DKK/h after tax.
# 7. Now it’s very bad, at winter I could earn 180dkk per hour and now it’s often to be lower than 100dkk per hour
# 8. It's disastrous, 3 hours online, 2 orders, 30 km, 50 dkk per hour!!!
# 9. 55 DKK per hour is too low
# 10. 7 hors on the street,120 km,8 orders,540dkk
# 11. In 5h of working I got 230dkk...
# 12. Almost 2 hours online, 2 orders, 110 dkk
# 13. More than 2 and a half hours online, 70 dkk, what do you think? For me it is disastrous!
# 14. More than 3 hours online,2 oreders,160dk The vacation period has passed but the situation is not going well, the average between earnings and km traveled remains below 10 dkk before taxes and other expenses, which is very low!!!
# 15. Stop accepting people!!! 130 per hour this is a pittance!! Orders of 26 dkk??? Why don't you pay more?
# 16. I’ve got 280 dkk for 3 hours of work. Not even a 100/hour. This is criminal!
# 17. You are paying me 405 DKK for four hours of work on a Friday at peak hours. This is ridiculous, I cannot support myself with this.This should be illegal.
# 18. 40 DKK per hour is great record, so I will be very thankful if you not try improve it
# 19. I’m hearing 100dkk for 1 hours, and some times delivery fee is very low like 25 Dkk . So I spending more time and get less regard .
# 20. 3 and half hours online,2 orders,110 dkk!!!!! it can be worse than that, probably yes
#
# === Topic 10 (70 documents) ===
# 1. App lets me drive for miles, then offers almost ready order when I’m close to the venue. JUST AN UNBELIEVABLE JOKE
# 2. There was a fire in the stock exchange today and the app kept sending trips from the inner city, even if you were far away and by car, and it was completely impossible to arrive in the inner city. Police had closed bridges and made barriers so that traffic was totally impassable. I am surprised that you have no monitoring on, so you can prevent cars from getting trips to areas where traffic is totally quiet due to an accident. The restaurants elsewhere in the city wondered that they were not serviced faster, but it is clear if a lot of Wolt is curing by car is stuck in the inner city because the app has lured them to take a trip in there.
# 3. App lets me drive for miles, then offers almost ready order when I’m close to the venue. JUST AN ABSOLUTE JOKE. DONT YOU HAVE ANY SELF RESPECT?
# 4. Time estimates just tight enough for car driving with parking options. Could wish for a feature that could go directly from the address over to the navigation app on the phone. More restaurants clips the bags, so it is not possible to check the order.
# 5. App lets me drive for miles, then offers almost ready order when I’m close to the venue. DONT YOU FEEL ASHAMED TREATING US LIKE THAT??
# 6. Please please please stop the manipulation. App lets me drive for miles, then offers almost ready order when I’m close to the venue. It’s super annoying in itself but even more annoying to have just crossed a big street only to be offered an order right behind you where you just came from
# 7. 5 of 7 orders offered late. SO SAD AND WRONG..App lets me drive for miles, then offers almost ready order when I’m close to the venue
# 8. App lets me drive for miles, then offers almost ready order when I’m close to the venue. PLEASE PLEASE change the programming of the app, so it offer us orders BEFORE we cross a big intersection, or turn a corner. It is super annoying and somewhat dangerous to have to do all these U-turns.. Also my app doesn’t really register how many miles I drive, I estimate less than 20 % is registered this month
# 9. 1- Some orders with many items ( over 15~20 positions ) and also heavy enough, from Wolt markets, are not marked as "large order", even if you are asking the support for that, and the bonus is not paid, wich i consider is not right. The algorythm for that calculations made failures. 2- i'm experimenting 6~10 times/hour hard lagging in app, aprox. 30 sec you can't mark the items from an order and you can't swap the button for picking up; or you push the button but the google map is not starting, for driving toward to customer. That situation is happening on 2 phones of mine, with 2 different mobile networks. And i asked anothers couriers and they reported the same to me. Do you know about that situation?
# 10. It is suspicious that when I'm further out of the city. I won't get an order. But when I'm cycling towards the city and pass a pizzeria the order is already ready and it pop up on my app. In that case I don't get paid for my travelling
# 11. Horrible hourly pay. Horrible miles. Horrible manipulation by the app: App lets me drive for miles, then offers almost ready order when I’m close to the venue
# 12. App lets me drive for miles, then offers almost ready order when I’m close to the venue
# 13. Today I had 3 occasions in which I waited more than 25 minutes for an order to be removed, the longest one was approximately 15 minutes the other 2 times. I also had problems with the GPS, it said that the pickup distance was less than where I was... my location was not updated in the application... and it was not a problem with my GPS... I did a huge amount of kilometers for so little money that I was able to raise. What a shame.
# 14. App lets me drive for miles, then offers almost ready order when I’m close to the venue. HAHAHHAHAHAHAH
# 15. I wish the Partner app had an in-built route. To pick up and deliver is virtually impossible to do on time, as traffic lights are a thing. I even cycle at 30 km/h, yet I still get 10-15 minutes late...
# 16. App lets me drive for miles, then offers almost ready order when I’m close to the venue. I already know that when I approach Valby city from West or South, orders are not offered before I Enter the magic 500 meter to venue zone. I could be wrong but the statistics are overwhelming…
# 17. App lets me drive for miles, then offers almost ready order when I’m close to the venue
# 18. App lets me drive for miles, then offers almost ready order when I’m close to the venue Disaster stats: Miles driven increased 20-30 % absurd.
# 19. App , I've got one task with wrong distance, so Venues mark the order ad ready but it is not it's totally not acceptable. Support my problem still after convention
# 20. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Big joke. Miles driven for same money exploding, but I understand it is the same for you. If your partner and/or friends and family don’t appreciate that your workload has increased some 30-50 percent, just tell them that you love WOLT and everything else comes second. They will then leave you (alone) and then you will have lots of time to do the extra work. It’s really smart :-)

# %% [markdown]
# ## Reduce outliers

# %% [markdown]
# Outliers must be reduced after topics have been merged. It cannot technically work the other way around

# %%
import copy

reduced_outlier_model = copy.deepcopy(reduced_model)

# %% [markdown]
# I'll now look at some outliers to get an idea what proportion of outliers should be in one of the topics, and what proportion are actual outliers (noise) not belonging to any of the topics.

# %% [markdown]
# I'll now try different approaches to outlier reduction. that is techniques and thresholds

# %%
import copy

# Define the strategy-threshold combinations
combinations = [
    ("c-tf-idf", 0.085),
    ("c-tf-idf", 0.09),
    ("c-tf-idf", 0.095),

]

# Store results
results = {}

# Loop through each combination
for strategy, threshold in combinations:
    print(f"Running: strategy = {strategy}, threshold = {threshold}")
    
    # Deep copy the original reduced model
    model_copy = copy.deepcopy(reduced_model)

    # Reduce outliers using specified strategy and threshold
    new_topics = model_copy.reduce_outliers(
        documents=documents,
        topics=topics,
        strategy=strategy,
        threshold=threshold
    )

    # Update topic representations
    model_copy.update_topics(
        docs=documents,  # <-- FIXED HERE
        topics=new_topics,
        vectorizer_model=vectorizer_model,
        #representation_model=representation_model
    )

    # Count number of outliers
    outlier_count = sum(1 for t in new_topics if t == -1)

    # Store results
    results[(strategy, threshold)] = {
        "model": model_copy,
        "topics": new_topics,
        "outlier_count": outlier_count
    }

# Optional: print summary of outlier counts
print("\nSummary of Outlier Counts:")
for (strategy, threshold), res in results.items():
    print(f"{strategy}, threshold={threshold}: {res['outlier_count']} outliers")
# Out:
# Running: strategy = c-tf-idf, threshold = 0.085
# 2025-05-25 23:41:05,030 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# Running: strategy = c-tf-idf, threshold = 0.09
# 2025-05-25 23:42:12,035 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# Running: strategy = c-tf-idf, threshold = 0.095
# 2025-05-25 23:43:14,858 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# Summary of Outlier Counts:
# c-tf-idf, threshold=0.085: 1467 outliers
# c-tf-idf, threshold=0.09: 1564 outliers
# c-tf-idf, threshold=0.095: 1664 outliers

# %% [markdown]
# first run
#
# - c-tf-idf, threshold=0.07: 1115 outliers
#
# - c-tf-idf, threshold=0.075: 1226 outliers
# - c-tf-idf, threshold=0.08: 1348 outliers
# - c-tf-idf, threshold=0.085: 1467 outliers
# - c-tf-idf, threshold=0.09: 1564 outliers
#
# ------------------------
# Second run
# - c-tf-idf, threshold=0.1: 1786 outliers
#
# - c-tf-idf, threshold=0.105: 1953 outliers
# - c-tf-idf, threshold=0.11: 2056 outliers
#
# ------------------------
# third run
#
# - c-tf-idf, threshold=0.085: 1467 outliers
#
# - c-tf-idf, threshold=0.09: 1564 outliers
# - c-tf-idf, threshold=0.095: 1664 outliers

# %% [markdown]
# Now I inspect the outliers being reassigned to the different topcis

# %%
from collections import defaultdict
import random

# Step 2: Get new topics (after outlier reduction using embedding + 0.25 threshold)
topics_c_tf_idf_085 = results[("c-tf-idf", 0.085)]["topics"]

# Step 1: Find reassigned outliers (originally -1, now assigned to a topic)
reassigned_outliers = [
    (i, doc, new_topic)
    for i, (doc, old_topic, new_topic) in enumerate(zip(documents, topics, topics_c_tf_idf_085))
    if old_topic == -1 and new_topic != -1
]

# Step 2: Group reassigned outliers by new topic
topic_to_outlier_docs = defaultdict(list)
for i, doc, new_topic in reassigned_outliers:
    topic_to_outlier_docs[new_topic].append(doc)

# Step 3: Print sampled outlier docs with ORIGINAL top words (from reduced_model2)
for topic_id in sorted(topic_to_outlier_docs.keys()):
    docs = topic_to_outlier_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))

    # Get original top words from reduced_model_manual
    original_topic_words = reduced_model.get_topic(topic_id)
    if original_topic_words:
        top_words = ", ".join([word for word, _ in original_topic_words])
    else:
        top_words = "(No original top words)"

    print(f"Reassigned Outliers → Topic {topic_id} ({len(docs)} docs) | Original top words: {top_words}")
    for j, doc in enumerate(sampled_docs):  
        print(f"{j+1}. {doc}")
    print()
# Out:
# Reassigned Outliers → Topic 0 (357 docs) | Original top words: order, pay, courier, hour, wolt, work, payment, low, money, time
# 1. No work, low pay, bad restaurants, bad customers
# 2. So, finally i can give the feedback.. Im very disappointed. 1. I dont know what happened, but since beginning of february (after big freezing days) it feels like you hired 2x more couriers than needed and now I literally drive in the city center near the lakes in peak hours (17-19:30) on friday / saturday and I see area demand: Normal.... and whole day till 17:00 its Quiet... and for 5-10mins I have no order (which before i had like 3 orders pre minute) 2. Im getting those annoying and not true push notifications (which arent even messages i can respond to) saying that "We missed you on friday and saturday so go and earn today" .. i was literally working (freezing outside waiting 5mins for order) both days so why am I receiving these fake untrue messages and why are you trying to motivate me to go to work when then im freezing and feeling like you dont have work for me? 3. I was checking on AppStore app updates messages and your developers use just general text "we are working hard on improving the app..", but I dont see or feel any improvement, all things which annoy me from begining of using the app are still there, literally nothing changed.. there is many things which could be improved or added/removed which would make our lives easier.. in app feedback after finishing the shift I already wrote about it and that im former programmer and ux designer and that i could give more detailed feedback but it was ignored .. PS now in this freezing/windy/rainy weather its very hard to work and earn enough money to survive the month in general and with that change which happened since beginning of this february I no longer feel this work will secure me to survive the next months when I literally can work only between 17 and 19:45 cos whole day is quiet and no orders at all, and in peak hours we barely have enough orders ..but thats not enough to sirvive from it.. if i spend 20-30min in restaurant sometimes cos they are busy or dont have som ingredients, its literally 20% of whole my "productive workday" time when i can work and it hurts my earnings so much and I cant avoid it to happen time to time cos they say "it will be in few minutes.." so i wait and wait and when i ask they say ye its getting ready.. and usually they dont admit its their fault.. etc.. Simply: I wana go at 11, 13, 15, 16 and have enough orders to work for 4-8hours a day and earn enough money as in regular job again. :( Im guessing you probably hired too many people cos when was very freezing nobody wanted to work, but now is the problem that we go work and have not enough orders.. so please fix it somehow, ..and please stop sending those untrue push notifications saying that you missed me previous days when I literally was driving and freezing in city centre during weekend and peek hours and had to wait 5mins for the order ... Thanks and wish you to have a beautiful day :)
# 3. Absolutely disappointed of the prices and calculations in tooo “busy” time. Very angry clients of the delayd its impossible to follow like this WOLT menagment should think something ! The demand is , the money is … but nobody of my colleagues take orders for 24kr for example… Im tired to give my feedbacks to the support . But looks like Wolt not invest in the ppl ; riders actually who really makes the money and xist this company… from January every each months it’s get worse and worse the work .
# 4. please, do not enable more partner. There are very few orders and many new people continue to be added, which makes work very difficult because our income is decreasing considerably. This added to the fact that many partners are on vacation but will soon return and the situation will be even worse. Thank you
# 5. Should we work or ??? If he doesn't want to give me an order to go home ... I'm off to work ... but?
# 6. all day I am 400 kr... if there is no work I will go home?? today is friday but no have orders? for me
# 7. picking up an order that is just 5 min late from Amager going into the city about 4 km should maybe take 7-8 min But smokes into a queue with road work and traffic accidents 2 km further ahead, my GPS now says that the last 3km takes about 43 minutes, writes to support if you can give my task to a scooter, and I can hand it over to him where I am, despite having been called by Wolt if I could help a car. 6-7 min and my GPS said 50 min, wrote that I would not deliver french fries and an icy order that would be 1 hour delayed, but they could not help, then I had to write they had to pull me and make sure to make the order for a moped/scooter when the order would have been over 1 hour in my car, so they drew 175 kr. Just seemed too poor that you can't make that system in case of such a thing that someone else comes and takes over, so I chose to pay $ 175 alone for the customer's sake, so he would get fresh food and stopped and drove home with a deficit instead
# 8. Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you have set our starting fee down from 45,- to 35,- earlier it was a bird spacing of 450 meters when the reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km can give 22.50,- as it is a delivery close to the previous one and not as before, both order from start to finish. Personally I reject all order to less than 35,- That is, even one of 34.95,- will be rejected I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped and it can be clearly felt how busy it has become. Many orders are thrown out, I have experienced that the food has been made again, up to 3 times as us cures who are left cannot reach and pick up in time as you replace/pay. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !! It will probably not last long until I do the same
# 9. Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you put our starting fee down from 45,- to 35,- earlier it was a bird spacing, such as praying at Islands Brygge, birds distance of 450 meters above the water when reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km can give 21.50,- as it is a delivery close to the previous one and not as before, both order from start to finish. Which is some hell of a swine, personally I reject all orders for less than 40,- That is, even one of 39.95,- will be rejected I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped and it can be clearly felt how busy it has become. Many orders are thrown out and made up to 3 times I have experienced, as us cures who are left can not reach and pick up in time as you replace/pay. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !!
# 10. Hi wolt #1 We are delivering under bad weather with traffic and we need all of our attention in the road as if you did a slight mistake you might loose your life. We need the cancel order as a swipe or one touch button. Need to spend as little time as possible. How is cancel order so big that we have to touch our screen twice to cancel it. #2 when we heading home we would like to have order along our way there should be an option where it only show you if their toward that place or might give you a priority too so you won't ride all this way empty handed at the same time you take the load of wolt too
#
# Reassigned Outliers → Topic 1 (130 docs) | Original top words: happy, wolt, good, thank, work, happy wolt, day, love, wolt happy, job
# 1. Perfect always good good service
# 2. I’m earming way less than i used to the same day og the week and time of day where i feel like i had the same amount to do. Good day
# 3. I wish the team a good weekend
# 4. There is not much work
# 5. Is very happy with it but too little boost is being sent in for the time being
# 6. I am tired on Wolt. Looking for another job because not enough earning to do this
# 7. are we working today? no ordes
# 8. i am very happy with wolt wolt is the best app
# 9. are happy to run wolt
# 10. Happy weekend to all of you
#
# Reassigned Outliers → Topic 2 (355 docs) | Original top words: ready, wait, order, restaurant, time, food, burger, minute, mcdonald, mark
# 1. Silent notification when food is ready. No sound, vibration and no longer pushing to Apple Watch :’( - Very consistent issue, actually it’s not working like it should 100% of the time.
# 2. Huge waiting time at the venues. This is the first time im writing a feedback after the shift. It was just so bad, wasted around 30min just on waiting during the whole working time…
# 3. I think million times before and it is going to be on top of million today, wolt market telefonvej ( soborg) treat us couriers like piece of useless cakes, all the time these people will stay packing the food right in front of us and will entertain you after letting us wait for really long time, so you guys really think our time doesn't matters or its DISRESPECT TOWARDS US the solution is simple, tell them one person must handover the food to us in the right and quick time and not just they keep doing their work and we are waiting on the door like dogs. Please act! Thank you!
# 4. Hi Wolt I write as I notice that an order ordered at Wolt has not been delivered or picked up by a courier when you have returned to the Rasstuan. My idea with the problem as a solution is to get the tasks popped up after. 2-3 minutes again if the food has not been picked up by another curl. We find that we received a task from Burger King at 3 o'clock at night approx. We drive out to Burger King and Burger King was closed at the time. An addition to the app could be smart if you have more orders on the trip that you can sort who you first run out to the direction on the road. (Unless it's hot food so it's first priority) I was thinking about whether you could raise delivery the price a little? For example, to drive about 15 minutes away and get approx. 80 kr but nothing to drive back to the next task Hope my message made sense if not then ask finally
# 5. Order was delayed up to 20 minutes .. not fat
# 6. One of the stores had a note that said you had to come in without the order was marked as clear. So I waited like a clown outside and afterwards inside when I thought it couldn't be real that it was so delayed for over 20 min
# 7. Had to wait 20+ min by Mexihagen… and they kept saying it was clear in 5 min It wasn't a bold experience
# 8. Resturant Antwerp Chicken Nørrebrogade refused to hand over me the order when it was done when he obviously got mad that I had rang on a bell he had standing which I have fully right to do when I had waited about 20 minutes on the order was made. Due to I called was because he had been out in the kitchen for just over 5 min without getting out to the front, so I called to hear how far the order had come. I just wanted to give it feedback as I think his behavior and temperament were right over the top. Good evening
# 9. The venue Al Ryes pizza had the order maked as ready -2min , I walked in and I been assaulted for asking for the order . The cook got phishycaly aggressive and pushed me out of the shop . The support didn't do much I didn't get compensated for time and fuel consumed and lost an hour and my appetite for driving . All I can say is Thank you
# 10. Hi guys need to tell few things from the last few fays . Some of the restaurants in Svendborg they moving slow when is busy hours for us waiting like for mc donals arouns 20 min. Second thing is in the last few days I was staying in a one place like right now waiting for orders , near by restaurants and ,after 10 minutes other colleague comes and is taking the order . How is posible ? Not last sometimes is ringing the phone and the wolt app to get a new order and when want to press the buton is just disappear. Hope is a heads up and the orders here for us will improve and get a better income than now in the future . All the best !
#
# Reassigned Outliers → Topic 3 (142 docs) | Original top words: support, order, system, wolt support, team, chat, wolt, help, good, bad
# 1. I did not get £ 45 on order which I have handed in and support will not understand
# 2. What Wolt is doing to its couriers is modern day slavery. Its completely mind boggling that a company can treat its employees like complete utter shit and we have nobody to talk to about this. Support is completely useless, an AI can easily do what they are doing and the email support always just says they will do something, but it never happens. We need a forum where couriers and representatives can sit down and discuss problems with each other. Until this happens Wolt will be nothing more than a capitalistic slaveowner.
# 3. Im not happy at all , we dont get orders to make money and the support somethimes they just dont care and they close the conversation without to give You an answer or to help You ...
# 4. if the Client does not get in touch and does not respond, the support service takes a very long time to make a decision or respond to a message, which really spoils the work with your application and I and the next clients have to wait for half an hour if I have several orders with me
# 5. So many times I have to face error And everytime I have to talk with customer support
# 6. In support are real thieves stealing 80 pct of the money. Nothing good to them, only bad and worst and fast end. Without thieves is better.
# 7. 3 cancels per month is pointless as 60% of the vendors are late so most drivers will try to cancel it I know some that does it more then 5 times a day ro avoid wasting their time for a delivery that's 20min late so I would suggest unlimited cancels otherwise they will proberly continue to write to the support to do so
# 8. So I asked Wolt support (Marta) to tell me whether or not the restaurant I was going to was busy. The person misinterpreted my message and cancelled my order for no reason, the order for which I DROVE from one end of the city to the other, just for it to get cancelled. The weather conditions are already bad enough to discourage me from taking orders that are far away, but when I actually do it and it gets cancelled when I am already at a restaurant, it is unfair, as I have literally wasted my trip and energy for nothing.
# 9. Disgusting thieves in support
# 10. If the operation team would be in communication with me re handling the flubs they made with moms on my paychecks . I would be very happy. I find it inefficient both for support & me when it hadød to be VIA support. Kh
#
# Reassigned Outliers → Topic 4 (295 docs) | Original top words: app, order, app work, work, time, support, error, order app, get, restart
# 1. Everything is working great, support is great etc. Although sometimes it seems the tasks are not pinging me in the app, it happens ocassionally, but luckily not often. It helps to restart the phone and app, but would be nice if it was just fixed. Another thing is the volume of other apps is turned down to half volume when a task has pinged us. We’re only able to turn it back up by closing the app and opening it again, or opening the camera on video mode and then closing the camera app.
# 2. Jagger is late the packing is a lot of times bad and there is problem in the app. Also Otto
# 3. App crashes frequently
# 4. The app is easy to use - Now it's also the first time I use it, but so far it's perfect
# 5. The app doesn't work well. It gives you the orders that someone rejected again and again
# 6. Check all the drivers couriers with selfie photos when open the app Wolt, thanks
# 7. Can't call costumers. App calls wrong numbers all the time
# 8. The app kept coming up with the same deliveries twice each time I rejected one
# 9. App crashes when sending text to customer
# 10. Hello with you "Wolt" You talk about listening to us cures and fairly done the app. First you have set our starting fee down from 45,- to 35,- earlier it was a bird spacing of 450 meters when the reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells you that you have listened to us where we were paid per piece at full distance. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km, can give 31,- as it is a delivery close to the previous one and not as before, both order from start to finish PS. I am super disappointed with your behavior against us. I have also spoken to some colleagues who say they will soon stop
#
# Reassigned Outliers → Topic 5 (39 docs) | Original top words: map, address, google, app, gps, location, maps, wrong, google map, google maps
# 1. It is necessary and urgent that Wolt comes with a sound in the application that informs the client when we are at his address and Yankee door, many times the addresses are not written correctly and we waste a lot of time delaying subsequent deliveries. Please, the same sound that we hear when we leave an order that is to the customer and they know that we were arriving and paying attention and pending to open the door as we keep ringing on the clock and they don't even open, so they should improve it It is necessary and urgent that wolt make a sound in the application that informs the client when we are at his address and yankee door, many times the addresses are not written correctly and we waste a lot of time delaying subsequent deliveries. Please, The Same Sound That We Hear When Leave An Order That Is For The Client And They Know That We Arrived and Be ATTENTIVE AND PENDING TO OPEN THE DOOR SINCE WE KEEP RINGING THE BELL AND They don't even Open please they should improve that
# 2. I had a bad experience today with a customer who gave the wrong address. He wasn’t able to communicate clearly the correct address so I asked him to write it. I called again and he said he’d written it in a text but it never got to me. Nino from Wolt was very service minded towards the customer and sent me the address and photos but I still got there and had no floor and apt no… He offered me a 7,5kr compensation and told me the correct address was close by and he couldn’t give me anything more. Then he ended our conversation abruptly. I think it’s unprofessional and rude. If this is how he was trained, it also shows me that Wolt only cares about customers but not couriers. It’s not about the distance, but the hassle, the time wasted, the countless confusing and confused phone calls and messages, the effort and stress, the apology I had to give to the other customer who’s food I had in the car and I was very late with. Please send me a proper feedback and a proper compensation so I can regain my trust, enthusiasm and simply the will to work with Wolt.
# 3. 5 second countdown before starting delivery is unnecessary and a bit of a hassle tbh. The location is often entered incorrectly, into apple maps when pressing the GPS button in the wolt app.
# 4. Anna has to write her address better the wild biscuit
# 5. If you could see Customer's address from the start then you can be used to be asked upon pick -up
# 6. Complain about 11 november, i had a problem with my delivery: The address was wrong, it was the backdoor of the hotel, and I find on the door the address of the main door. At the reception they reject me because the address was different and they don t have a name of the customer. I call the customer but they didn t answer me. I was outside with 2 packages, their one was like 10kg and started to rain, heavy rain... and i put the package inside the box again. I contacted the support but with all the water and the time i lose 40 minutes. Later the support give me a correct number, a third one. And they confirm that the hotel was correct. So I lose time, energy and make problems with 2 deliveries. I just want to ask you to do two things. Make a blacklist and check the number of the customers or force them to put the name of the hotel and the relative name of the booking in that hotel. So if the customer is from an hotel I can easily pass the reception with correct data. And the customer after 3 hours, while I was sleeping they call me. So i would like to propose a black list for the hotel and these couple of customers. The hotel was Axel guldsmeden hotels, they have 2 address front and back door. They weren t collaborative. Even if I show them the address of the backdoor they insist that the name of the customer was the hotel, another place. Secondly the customer, i don t care if they were tired or lazy, they used the wrong name in the hotel, they didn t give me the name pf the hotel, they give me the backdoor, the phone was wrong. And they call me during the night. I SPENT 1 hour in the night, under rain for some banana and idk. So please make a black list or make a procedure to force the customer to don t be retarded. Next time I will spend 10 or 15 minuts after this I will consider lose the delivery. No one pay me if I get sick or If the customer don t answer. I am trying to be professional but I don t like to lose my energy and time. So I repeat put the hotel on a black list because they werent collaborative. If they were more open I can save 20 minutes and avoid to stay under a heavy rain with an heavy bag.
# 7. At the beginning the app had lags: didnt show the the client on the map, cracked(log out) several times
# 8. Add a heat map showing where most orders can be picked up
# 9. Not all stores were in the exact location as shown on the map.
# 10. I got 3 tasks at the same time today. Along the way, the app showed delivery to a customer, but the address showed another address where I was already because I had a pickup at Homeburger Østerbro. Later, according to the app, I also had to pick up an order at Ciao Pasta, which is right next to Homeburger, but that was not what the app showed. It seemed as if the customer's name was set in, but the address pointed to where I had to pick up an order for Ciao Pasta. It also seemed mysterious that I had to pick up an order with Homeburger, which was my collection # 2, even though the customer was on the way to Homeburger - why not deliver to this customer first, and then make the next 2 collections, which were right next to each other, and then deliver to the last 2 customers? The support was also not for much help in this situation, and it took too long to move forward. The employee at Ciao Pasta was also not happy with the time it took before I could be back to pick up the order, which I can easily understand.
#
# Reassigned Outliers → Topic 6 (58 docs) | Original top words: bag, drink, pack, food, cup, paper, spill, soda, order, need
# 1. Stefanos large pizza boxes don't fit in the bag. It's really silly. When I asked them to put it in two normal boxes, they were rude about it. Not going back there.
# 2. Can't see drinks for menus
# 3. Restaurant Halifax forgot to give me a lemon soda in one of their orders today. Burger King gave me a wrong order and told me that they could not see my order number in their system. Only thing I could correct was the beverage, as I could see it was wrong compared to the order in the app, which I pointed out. Generally I cannot always, as a courier, check the food, because often times it’s placed in a sealed food bag by the restaurant. So out of respect for the customers, I don’t break the seal to check what’s inside. So I have to trust the restaurant staff when receiving an order. I would recommend Wolt to make the restaurants either always tape the receipt of the food content on the bags or hand the receipt over to the courier to be sure the food is correct. There are many young service employees in this area who works in restaurants, and they are not always that observant and precise with the orders. Would be great if you could encourage them to double check the orders and consistently use receipts on the bags. Because it’s us as couriers that has to deal with upset customers when we drive a far distance to deliver a wrong order. Thanks in advance for understanding.
# 4. Some of workers from BGing Kolding Syd are very unclear on communication..One of them today give 2 orders and the drinks but he look on me without sayng anything. He didn't say haw many drinks are in each order, is nut my duty to ask
# 5. I think the app is great. I would like an option to just push orders back into the line instead of outright refusing to do it. Just a preference really as I often refuse when I can't have a third order in the bag.
# 6. Long wait in between, ended up in a colony garden area and had to spend time driving back to the center with an empty bag, 2 orders had been optimal, out and back again ...
# 7. I got an order I couldn’t fit in my bag
# 8. I work with a bike, I have a bicycle bag. Even twice today I received an order from Express pizza, which did not fit into my backpack. Pizzas were too big
# 9. Had a pick up at Boen's ask a employer is I was really just one bag, which he confirmed. After delivery the customer call me said there Was some of the food missing. I call Boen's that sad the employer was new and had mad a mistake and she was in contact with you (support). We decided that I should just come and pick up the missing bag. Which I did and costumer got the missing part/bag In short time Had a good conversation with Boen's . They are doing very well
# 10. There’s a new cashier at On The Dot Aalborg. She has been working there about 2 months and she is painfully slow and unfocused. Oftentimes I have to remind her not to forget packing the soda as well. When I’m not there to see her packing the order, the drink is often missing. It is extremely embarrassing to deliver an incomplete order and I hate when the support is reaching out to me about something that is not my fault or responsibility. Please let the venue know that their worker should be more focused. Thank you.
#
# Reassigned Outliers → Topic 7 (81 docs) | Original top words: task, task task, time, new task, accept, accept task, new, hour, disappear, receive
# 1. One improvement would be to make bundled tasks be shown more clearly in the app. Sometimes if I already have a task, and a new task is available, the app zooms out the map to make it look like the second task is right next to the first task but when in reality it is in the opposite part of town. Maybe it would be possible to also show the drop off of a second task in a different colour than green? That way we will know immediately where it is before we accept it. Thanks
# 2. All tasks with +20, 30, 40 minutes of waiting time from the app when you send out a task, I get back home my friends, it's rainy and you still pay less and less for the tasks
# 3. I took an order from a place, and when I arrived, they told me that the order was to pick in an hour from that time. If wolt allowes to the people to order on a specific time, they should write somewhere in the task so the courier can know and reject it if it’s not useful, or they should send the task to the courier when is going to be ready, not one hour before, because I lost time going to the venue and also I got no compensation for it. For that time wolt support was really slow and took 15 minutes to unassign the task. Really disappointed today
# 4. Every time an task rings it mutes the music by 50% requiering to close and re-open the music app for it to be back to normal
# 5. App didnt function at all Had several problems with clicking start and finishing tasks
# 6. ATTENTION PLEASE: Ok so it happened now for the second time that I accept a task, bike all the way to the venue and once there I don't have the task anymore. The first time I contacted support but they couldn't (or wouldn't) help me. This time I understood what happens in these cases: by the time I accepted the task and arrived there to the venue the order got canceled. This last time the venue itself canceled by mistake (they wanted the reject a later order that they couldn't make in time and not my order that they have made already). The first time I don't know who canceled it (venue or customer). The point is when this happend you cannot just take the task away without some sort of notification (possibly with sound too or something). What if I biked 15 or 20 minutes all the way to the venue for nothing? I understand the customer or venue can decide to reject the task but the courier needs to be notified right away. The app right now basically just goes back to "waiting for tasks" silently with the courier still thinking that he's biking/driving to pick up a task. What makes it even worse is that when I contacted support they "don't know what I'm talking about cause they cannot see I took any task". The app needs to be amended. (This last time I got at least my 35 kr for having biked all the way to the venue but the first time I got nothing.
# 7. There seems to be a delay in the cancel task proces? It takes more than 3 minutes, and information does not seem to be updated live?
# 8. Seems to be an issue sometimes where tasks are not showing, especially when just going online, but it can also happen after being online for a while. The app is trying to give us a task offer, but it’s not showing on our phones. For me it helps to shut down the app and force restart my iPhone. I’ve seen this as an issue on other couriers iPhones as well. This causes couriers to miss tasks, and therefore decreasing the efficiency for Wolt as a business as a whole.
# 9. App very slow missing tasks due too
# 10. Once again the app is offering a good, far distance task and doesn't let you accept it. It is extremely frustrating. Please fix it.
#
# Reassigned Outliers → Topic 8 (21 docs) | Original top words: bundle, order, bundle order, pay, task, payment, system, new, accept, like
# 1. Heads up: Had a delivery from Burger King Rådhuspladsen to cbs near Forum. Price just under 30 kr. While it was a bundle, I find the price too low: the customer had asked to have the order delivered to the 5th floor… apparently there is an elevator in the building, but one needs a special card to ride the elevator..So as it is a tall building, getting to the fifth floor, is quite hard.. if all the students/customers start asking for 5th floor delivery for that price, I will stay away from those orders..
# 2. Why I can't reject the order?
# 3. I am so disappointed with your new pricing model. I drove 4km for 35kr because you are not allowed to make money on bundles anymore.
# 4. Better pay for donkey orders: I was dumb enough to accept a task from a supermarket. The order distance was short, the pay was low, but the order was heavy and had to be delivered to the fifth floor no elevator. I feel such orders should pay better. What do you think? Have you ever tried carrying a heavy bag of groceries to the fifth floor?
# 5. When bad weather will happen on a weekend, payday, your small 100kr bonuses will not be enough to get couriers out. Bring back the base fees like we used to have. And properly paid bundles... Otherwise enjoy paying for remakes and losing customers, good couriers
# 6. Deapite the heavy rain and wind and cold I was willing to drive and deliver , but the app was a total disaster!! Receiving pick ups far away from me and bundled deliveries in opposite direction. I went offline because of that
# 7. I’ve had bad experience, picking up food from potato potato. The owner of the restaurant was aggressive to me because I was waiting for my bundle task. She said that I should go deliver first one and then come for the second one at the end of this she stole my order ￼
# 8. Two things Some venues keep forgetting the extra soda. Also, when I want to stop working I have to hear that annoying ringing sound and wait 60 seconds. When those seconds are over I tried to go offline, but I immediately got another task. (In bundle )
# 9. It would be really cool if it could be made so you could see if you were on a bundle order and had to pick up two orders from the same store, because it would be much easier for everyone if you could say to the staff from the beginning of May to pick up two, rather than getting the first one, packing it, and then having to grab the staff again to get the next order
# 10. 29kr for most of the task in a super windy and rainy day, busy and all orders delayed.. Bundles of course even less.. What do you expect? How much more are you gonna push the prices down? Until nobody works anymore?
#
# Reassigned Outliers → Topic 9 (61 docs) | Original top words: dkk, hour, dkk hour, hour online, online, 3 hour, 3, order, 2, dkk bad
# 1. From more than one hour online 0 ORDER!!!!!!!
# 2. you made me drive for nothing, you have to assure the delivery people who are online at least a minimum per hour today in two hours I made 70 crowns and another 40 crowns you are some lying garbage
# 3. Barely any orders Earning 700 DKK in six hours of work Problems with the app either not letting to accept a task, or suddenly cancelling the one you had before. Being a Wolt partner is so just worse than last year, I can't even compare it
# 4. Online at noon and got only one trip of 1 1/2 hours
# 5. 1 hour online without orders
# 6. 7 hours only 5 orders
# 7. this is the money you gave me in 3 hours, 40 crowns per hour
# 8. Kasai Sushi on Hillerødgade had delays over a whole hour !! Too bad
# 9. From 18 to 19 is according to you peak hours but I didn't receive any orders, how is that peak hours
# 10. 3 hours online,3 orders!!!! Very very bad.
#
# Reassigned Outliers → Topic 10 (21 docs) | Original top words: mile, drive mile, mile offer, let drive, close venue, app let, order close, offer ready, ready order, offer
# 1. I shouldn't be the one that call the venue.
# 2. Venues are very late!
# 3. Some venues were quite late
# 4. Often get orders that are close to having to be picked up, but only after driving a longer stretch without orders. Is it due to the pick up place or programs in the algorithm to wait to offer the order….? Hope really in comments on this
# 5. I have drove one delivery from Mina Kebab Albertslund, the way to the delivery address was closed permanently onve I followed the navigation , I called the customer and he asked me to drive all the way around which put me to drive extra miles to drive, I asked the wolt support to post me the adjustment for same as it was not my fault if the road is closed but they denied, is this the way Wolt treat the drivers? Was it my fault? Wouldnt I be given compensation? Please respond
# 6. Same pattern, you drive miles without an order and suddenly when you are close to a pick up place you are offered an order that is close to being ready/ ie it must have been offered long…
# 7. Yeah screw u and your payment and the shitty app that never let's me swipe so I have to call support everytime
# 8. Very very quiet day… without order closest
# 9. App fubar. And so many miles extra since your last attack on the pay system ….
# 10. Order level quiet, yet I drive around with no orders only to get offered ready or late orders once I am near the place of pick up ??!

# %% [markdown]
# Now I inspect the outliers which are still left

# %%
from collections import defaultdict
import random


# Organize documents by new topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics_c_tf_idf_085):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = -1
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic -1 (1467 documents) ===
# 1. There are quite a few errors in the system
# 2. You keep log me out for no reason
# 3. Doesn't seem to be okay to be drawn so much for an error in the order as I had the opportunity to come Back with the right one.
# 4. Some venues were late, and for other the other was postponed by the customer
# 5. Have a great weekend
# 6. Would be nice with a function where you stay online but don't get orders. SKAT said the km report from Wolt should be enough proof for the transport tax deduction. So for example if going with a bike in the train towards a hotspot, and don't want to start before reaching the hotspot, there could be a transportation mode where the Wolt app keep the km counter ticking for going away and back to home.
# 7. Why isn't possible to talk directly with decisional staff, what are you afraid?!
# 8. I would like to be able to log in soon
# 9. Do we have to climb stairs to deliver food, like 3rd or 4th floor?
# 10. Hello, I work in the Vestegnen Vallensbæk and ishøj , where customer orders are fewer compared to other places; for instance, we receive two or three offers per hour. It is crucial for me to contribute to wolt's success, and I'm pleased with my role in this group. While I'm generally satisfied, I've observed a recent decrease in the number of fare offers. I kindly request a reconsideration of the fare amount to boost activity and engagement in this area, benefiting both the employees and your company. Im waiting for your response. Thanks in advance and best regards
# 11. Parking is the only thing that is irritating.
# 12. several orders delivered are missing
# 13. We need instructions for barsara sushi, it’s located on 4th in Illum
# 14. A little quiet guard
# 15. Have an excellent week
# 16. "area demand"... That thing is a joke
# 17. Total fat system! Wow.
# 18. Cow well use some more odre
# 19. Unfortunately very few orders
# 20. Still fond of work but seems the amount of effective work one has has fallen too much

# %%
reduced_outlier_model.update_topics(documents, topics = topics_c_tf_idf_085, vectorizer_model= vectorizer_model)
# Out:
# 2025-05-25 23:52:09,585 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
reduced_outlier_model.get_topic_info()
# Out:
#     Topic  Count                                  Name  \
# 0      -1   1467      -1_order_excellent_customer_time
# 1       0   3736              0_order_pay_wolt_courier
# 2       1   1175                 1_happy_wolt_good_day
# 3       2   1332               2_ready_wait_order_time
# 4       3    669  3_support_order_wolt support_contact
# 5       4    786             4_app_order_app work_work
# 6       5    394              5_address_map_google_app
# 7       6    299                 6_bag_drink_food_pack
# 8       7    227        7_task_accept_time_accept task
# 9       8    152       8_bundle_order_bundle order_pay
# 10      9    136         9_dkk_hour_online_hour online
# 11     10     91  10_mile_offer_order close_drive mile
#
#                                        Representation  \
# 0   [order, excellent, customer, time, delivery, w...
# 1   [order, pay, wolt, courier, hour, work, time, ...
# 2   [happy, wolt, good, day, thank, work, happy wo...
# 3   [ready, wait, order, time, food, restaurant, m...
# 4   [support, order, wolt support, contact, time, ...
# 5   [app, order, app work, work, time, support, er...
# 6   [address, map, google, app, location, gps, wro...
# 7   [bag, drink, food, pack, order, cup, soda, pap...
# 8   [task, accept, time, accept task, task task, s...
# 9   [bundle, order, bundle order, pay, task, payme...
# 10  [dkk, hour, online, hour online, 3 hour, order...
# 11  [mile, offer, order close, drive mile, drive, ...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [I didn’t get that much order., Didn’t get any...
# 2   [wolt is the best i am happy with wolt, wolt i...
# 3   [I had an unacceptable experience at McDonald'...
# 4   [Wolt support not good.verybad, Leaf -tender s...
# 5   [The app works really well, The app was down f...
# 6   [Addresses were misleading, Please make it pos...
# 7   [Please do something about the bags. Big proce...
# 8   [Because i always get less task, Then we are t...
# 9   [Why the system give bundles when there are no...
# 10  [It is disastrous, yesterday after 7 hours on ...
# 11  [App lets me drive for miles, then offers almo...

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = reduced_outlier_model.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = reduced_outlier_model.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: order, pay, wolt, courier, hour, work, time, payment, money, low
# Topic 1: happy, wolt, good, day, thank, work, happy wolt, job, love, wolt happy
# Topic 2: ready, wait, order, time, food, restaurant, minute, burger, mark, mcdonald
# Topic 3: support, order, wolt support, contact, time, wolt, system, bad, help, chat
# Topic 4: app, order, app work, work, time, support, error, accept, order app, crash
# Topic 5: address, map, google, app, location, gps, wrong, maps, google map, customer
# Topic 6: bag, drink, food, pack, order, cup, soda, paper, spill, need
# Topic 7: task, accept, time, accept task, task task, second, app, minute, new task, new
# Topic 8: bundle, order, bundle order, pay, task, payment, new, system, courier, customer
# Topic 9: dkk, hour, online, hour online, 3 hour, order, 3, dkk hour, 2, 2 hour
# Topic 10: mile, offer, order close, drive mile, drive, offer ready, mile offer, close venue, app let, let drive

# %% [markdown]
# ## Fine-tune topic representations

# %%
import copy

reduced_outlier_model_topics = copy.deepcopy(reduced_outlier_model)

# %%
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance

keybert_model = KeyBERTInspired()
mmr_model = MaximalMarginalRelevance(diversity=0.4)  # 0.2 is used in the book

representation_model = {
    "Main": mmr_model,
    "KeyBERT": keybert_model,
}

# %%
reduced_outlier_model_topics.update_topics(documents, topics = topics_c_tf_idf_085, vectorizer_model= vectorizer_model, representation_model=representation_model)
# Out:
# 2025-05-25 23:55:32,817 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = reduced_outlier_model_topics.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = reduced_outlier_model_topics.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: courier, payment, delivery, km, bad, kr, earn, bonus, car, go
# Topic 1: happy, day, happy wolt, excellent day, work wolt, perfect, partner, happy work, support, help
# Topic 2: restaurant, mcdonald, order ready, min, food ready, delay, customer, burger king, pick, venue
# Topic 3: order, wolt support, system, deliver, cancel, customer, support team, problem, message, contact support
# Topic 4: app work, work, error, order app, restart, delivery, app crash, bug, problem, freeze
# Topic 5: map, location, gps, google maps, wrong address, problem, wolt app, copy address, card, house
# Topic 6: food, cup, soda, spill, paper bag, mcdonald, lid, delivery, seal, wolt market
# Topic 7: accept task, app, hour, receive, time task, venue, receive task, busy, cancel, error
# Topic 8: bundle, payment, courier, customer, order bundle, bundle task, delivery, reject, bundle pay, km
# Topic 9: hour online, dkk hour, bad, average, friday, hour order, online 2, peak hour, 70 dkk, hour street
# Topic 10: order close, drive mile, mile offer, close venue, close, let, joke app, venue app, offer order, km

# %%
reduced_outlier_model_topics.get_topic_info()
# Out:
#     Topic  Count                                              Name  \
# 0      -1   1467                       -1_order_customer_week_busy
# 1       0   3736                     0_courier_payment_delivery_km
# 2       1   1175              1_happy_day_happy wolt_excellent day
# 3       2   1332             2_restaurant_mcdonald_order ready_min
# 4       3    669               3_order_wolt support_system_deliver
# 5       4    786                   4_app work_work_error_order app
# 6       5    394                    5_map_location_gps_google maps
# 7       6    299                             6_food_cup_soda_spill
# 8       7    227                    7_accept task_app_hour_receive
# 9       8    152                 8_bundle_payment_courier_customer
# 10      9    136                9_hour online_dkk hour_bad_average
# 11     10     91  10_order close_drive mile_mile offer_close venue
#
#                                        Representation  \
# 0   [order, customer, week, busy, deliver, tip, fl...
# 1   [courier, payment, delivery, km, bad, kr, earn...
# 2   [happy, day, happy wolt, excellent day, work w...
# 3   [restaurant, mcdonald, order ready, min, food ...
# 4   [order, wolt support, system, deliver, cancel,...
# 5   [app work, work, error, order app, restart, de...
# 6   [map, location, gps, google maps, wrong addres...
# 7   [food, cup, soda, spill, paper bag, mcdonald, ...
# 8   [accept task, app, hour, receive, time task, v...
# 9   [bundle, payment, courier, customer, order bun...
# 10  [hour online, dkk hour, bad, average, friday, ...
# 11  [order close, drive mile, mile offer, close ve...
#
#                                               KeyBERT  \
# 0   [week excellent, excellent week, weekend excel...
# 1   [order order, order, delivery, wolt market, de...
# 2   [love wolt, wolt happy, wolt wolt, wolt, happy...
# 3   [order ready, food ready, delay, waiting, rest...
# 4   [support help, support, contact support, suppo...
# 5   [app work, app app, app, fix app, app say, pro...
# 6   [google maps, google map, wrong address, addre...
# 7   [bag order, use bag, bag food, food bag, bag b...
# 8   [task wait, task, task come, single task, task...
# 9   [order bundle, bundle payment, pay bundle, bun...
# 10  [dkk hour, hour dkk, online dkk, order dkk, dk...
# 11  [venue app, order app, venue order, app, venue...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [I didn’t get that much order., Didn’t get any...
# 2   [wolt is the best i am happy with wolt, wolt i...
# 3   [I had an unacceptable experience at McDonald'...
# 4   [Wolt support not good.verybad, Leaf -tender s...
# 5   [The app works really well, The app was down f...
# 6   [Addresses were misleading, Please make it pos...
# 7   [Please do something about the bags. Big proce...
# 8   [Because i always get less task, Then we are t...
# 9   [Why the system give bundles when there are no...
# 10  [It is disastrous, yesterday after 7 hours on ...
# 11  [App lets me drive for miles, then offers almo...

# %%
topics, _ = reduced_outlier_model_topics.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Iterate over sorted topic IDs
for topic_id in sorted(topic_to_docs.keys()):
    docs = topic_to_docs[topic_id]
    
    # Filter to only include feedback with length ≤ 150
    short_docs = [doc for doc in docs if len(doc) <= 4000]
    sampled_docs = random.sample(short_docs, min(20, len(short_docs)))  # Randomly select up to 10 docs
    
    print(f"\n -- Topic {topic_id} -- ")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
# Out:
#  -- Topic -1 --
# 1. Im happy but im not a fan when i get a High value order (above 60kr)and i accept it and then it disappears and is replaced with a low value order (below 30kr)
# 2. Same bs: You have programmed the algorithm to wait with offering tasks until one is around 500 meter away from the venue, probably only when order level is quiet/order is not too late…
# 3. No tasks being sent through. Then taking offline as I wasn’t accepting tasks. Something wrong with app today.
# 4. Will the app not come soon in Apple CarPlay
# 5. Hello with you "Wolt" You talk about listening to us cures and fairly done the app. First you have set our starting fee down from 45,- to 35,- earlier it was a bird spacing of 450 meters when the reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells you that you have listened to us where we used to get payment per piece for full distance. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km, can give 24,- as it is a delivery close to the previous one and not as before, both order from start to finish. Personally I reject all order to less than 35,- That is, even one of 34.95,- will be rejected PS. I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped. It will probably not last long until I do the same
# 6. I was not paid the promised compensation?
# 7. I work on a bike, pizza up to 32 cm in my bag, but from Express pizza I often get orders with larger pizzas that do not fit into my backpack.
# 8. When the customer has chosen contact-free delivery, it says in app that I need to wait until the customer opens the door, but some customers don't know that the courier needs to wait for them to open the door, so sometimes (not so often though) it takes a long time for that to happen. Maybe it could be made clearer to the customers?
# 9. Time estimates were way off sometimes
# 10. Many of us are upset about the incentive they give to inactive accounts. They are motivated to give them an extra 500dkk for making 40 orders in a week, when we were motivated with a bonus of half that amount for making 50 orders in 2 and a half days. I think they are handling this situation in the wrong way. Motivate the riders who dedicate their time full time to Wolt and you will see the results.
# 11. It was really awful, the performance of the program and the distribution of orders. I was active for more than 10 hours today, and I moved to many places in the city center and order centers, but I got the least amount of orders.
# 12. Seems it takes too long before you get your salary paid. Still wonders me about how -sdor The WoltApe turns down for what you hear from the phone. This means that you have to restart the app every time you have been given a task.
# 13. The app doesn't seem to work when I swipe it.
# 14. Lolo vu7vu77.æmo9 Jjjj5nnujb4brm
# 15. Seems several of the orders were low paid if you take conditions for where the weather has been. Voting rights to drive around than yesterday. And distance from venue to the customer seems not to have worked? Or succeeded all and the day has been good
# 16. How is it possible to accept an order, see details about it, go to pick it up and on the way it simply disappears from the screen? This is unacceptable
# 17. That fat. Just a job for me
# 18. Brakes, utilization, 40 to 100 kr per hour.
# 19. Still no notification when the food is rready on iOS iPhone 14 Pro Max
# 20. I don't receive orders, and when I receive I have already left area of restaurant
#
#  -- Topic 0 --
# 1. There is very little I get a couple of turns it was already a little but tonight it was in now less I hope you look at if there were errors in the system because if it continues on those prices I think I keep up and find something else to do.
# 2. Please pay out on time, it’s very unpredictable when I’m gonna get my money that I worked for.
# 3. When I heard we got pay from a-b-c am really happy, but when I was dilevered order I was shock the price more worst than before! very unsatisfied like there is no more future in wolt job
# 4. 3 HOURS WAITING WITHOUT ORDER. W T F WOLT ???
# 5. The information for the bonus was from 11:00 am to 1:30 pm, and I got the notification at 3:30 pm.
# 6. few orders. long waiting times. on a friday evening. is wolt coming back to normal?
# 7. Hi, I dont know why i am getting less deliveries. When i see other people doing wolt, they have much deliveries.
# 8. Really happy about everything related to Wolt and most partners. However there is a general problem with some of the larger and smaller restaurants pushing the “order is ready”, while in reality we end up waiting 5-15 minutes for the order. Especially Hubbs Kitchen, both Frederiksberg and Nordvestare some of the biggest ones in this. As couriers we miss out reaching boost goals, when we are kept waiting, two Hubbs orders can destroy the tarvet of reaching 12 orders before 20.00.
# 9. Good, the pay could be a bit higher though
# 10. I am happy with wolt but not with restaurant.. few restaurant like o snacks Frederiksberg, they will just make us to wait for long after marking food as ready
# 11. 8 hours 870 with bonus. Wolt is not worth any more.
# 12. Time estimates and the average salary on weekdays are not 170 kr. (At least not close to in slice outside peak hours and even many times in peak hours)
# 13. There is not enough work what we have to make money
# 14. There are very few orders.
# 15. À big shame on … by making this worthless decision about the printing model . You’re abusing us
# 16. Bring back fair salaries!
# 17. Waiting time for new order more than one hour is not good in my opinion and my colleagues after 10 minutes sitting next to me has
# 18. Shit, shit and more shit, all orderes with less than 1 km, i have a car!!!!!!!!!!!sendme long distances, i have a car!!!!!!!!!!!!!!!!!!!!!!!
# 19. Cheating and exploitation 100-150 kr per hour on purpose whole fucking evening on night. Delivers completely t f. Edge com completely free back .. that it is called for something no .. We have to work. F. FREE .. Good curse who this system, life's bread destroys .. 100- 150- per hour intentional .. never randomly .. What the hell is it going to, tax, gasoline expenses What f is left? All Venue are good busy so what's out on ?? 50-150 in shit hour ..?
# 20. for Chikii i Aarhus C
#
#  -- Topic 1 --
# 1. Super that you have control yourself when to work
# 2. I love it really. I am very happy working for Wolt.
# 3. Good help from support
# 4. I am being pissed on
# 5. It was good today good evening
# 6. I am very happy to work with Wolt
# 7. I am very happy, you do a great job.
# 8. I'm very happy to work with wolt. I love it.
# 9. I am very happy and satisfied, just on holidays at the moment……. The best thing is I can start anytime
# 10. i am very happy with wolt
# 11. It goes wonderful: D
# 12. Everything is new for me so not much to say but I am happy with the work.
# 13. Ok thank you nice evenings
# 14. Fantastic, very happy with the collaboration
# 15. Much better than yesterday
# 16. Have always been very fond of Wolt. The problem is just that you say you listen but do not, so the very job 5*
# 17. good performance today
# 18. That’s the way I love it. Working like a Swiss watch
# 19. First day, so I haven't formed me a man yet
# 20. Great start and good tasks
#
#  -- Topic 2 --
# 1. Problems with spar and mcd Valby
# 2. Not nice to ride all the way to a restaurant, to pick up an order in “ready” status just to get the message that it will take 10+min before it’s ready… in that case you should put a charge on the venue and compensate the rider…
# 3. There’s always problems with McDonalds they marked the orders like ready but almost every time I have to wait 10 or 15 minutes until I get my order
# 4. There is often a long wait for McDonald's. Both because they are delayed, but also sometimes because they just are not aware of us Bude coming in and orders that are ready. So you almost have to shout them up for them to find that there is one to take the order that is ready.
# 5. A trouble waited over 40 min because “café tidlōs” gave the order to Just Eat
# 6. Have had problems today and yesterday that I came out to the restaurant where it was -10 min, but the order was not ready, it was not in the system. So the restaurant should see the order on my phone and then make it first .. It's a little tricky to waste time and lose other orders on
# 7. I used to decline orders from mc Donald’s. They treat Wolt employees very disrespectful. This happened again for me to night. I’m not going to take orders from Mc Donald’s anymore until they begin to respect me.
# 8. Long time delay for orders at Golden Burger
# 9. I don't have problems with the patnership, everything is going ok. My only problem is that some restaurants take to much time with the orders or they put it ready but it's not. If that issue could be improved, it will be perfect
# 10. Symphony and Berlin Döner have the orders standing as ready for pickup but when you arrive they must first start on them. I can understand that they are in a hurry and therefore give the customers who are food, but the customers who order online are also waiting. It also makes my salary much lower. It's not okay and they have to put the food aside when the customers ordering online is the next order to be made
# 11. O'snack is terrible, they treat courriers like dogs waiting for very long while 20 bags are on a table, on display for the long line of tortured Wolt courriers waiting, only to be teased for all of eternity
# 12. Less payment. Long wait to get ready food
# 13. Today both La Pizza and Kylling Co, both in Varde, had late deliveries. They marked it as “order ready” but in fact, nothing was ready. So I would like to ask them to only inform “order ready” when the order is actually ready. Kind regards, Bianca.
# 14. Hope you can do something with all that wait at Macd .. It's an hour for me every day ..
# 15. Green Mango order was cancelled. I arrived. Said it wasn't supposed to be ready for another 15 minutes. On my display it was ready, and I arrived 2 minutes after it was supposed to be ready. Not cool that there's no compensation for waiting extra 10-15 minutes during dinner rush. And certainly not cool that there's no compensation for driving all the way to the venue for nothing. Find the faulty person and shake your head, whilst staring at them with huge disappointment, please!
# 16. McDonald's has an excessive waiting time
# 17. McDonald's Valby (Gammel Køge Landevej, has a special place for handing over takeaway orders. Unfortunately, it is not staffed, which can be extremely frustrating when waiting to get an order that is either marked ready, or should be marked ready. And it is an obvious priority of, for example, Wolt's customers, with the physical customers who can turn to a manner of a manner ...
# 18. Waiting too long for the food to get done
# 19. Kebab Palace is really slow every single time I have to pick up from there which makes a desire not to pick up from there
# 20. McDonalds branches has to improve their take out attention to Wolt partners
#
#  -- Topic 3 --
# 1. Unable to reach support
# 2. Don't remember the name, nine. She was way too slow with her answers, about 10 min for each response in our chat
# 3. I had a case where I was not able to pick up the items because another courier already tool them, and I wrote to support and had the order made and I delivered it. My complaint is I lost 25 minutes of time to a mistake someone else made and did not get compensated for it, I would like to ask for this to be changed, cause I lost out on an entire orders worth of time
# 4. I will be back soon !!!
# 5. I can't turn off after I have chatted a lot of times
# 6. It passed about 40 minutes before I got help from support
# 7. It passed 15 min before support replied
# 8. With the quick response from support team it makes task easier
# 9. It’s really infuriating that support is built to make sure Wolt pats as as little as possible . What’s the point of giving extra effort if we get penalised for it and our time is wasted
# 10. My account is dysfunctional still. I can’t work
# 11. Great with the new customer chat feature!
# 12. MacD had some issues with the IT. Took a lot of time in peak hours. Strange normally they are some of the best. WOLT support was absolutely world-class today
# 13. Please operation team contact with me asap. Otherwise I can not start working.
# 14. Please make it possible to cancel an order instead of contacting support. Unfortunately, experience a wait of +5 min at Venues. And understandingly they are busy, but who bring out is time = money
# 15. Stupid new system I'm stopping working with you
# 16. Support is very friendly ording, however, I would like it so that I can go offline myself without trouble supporting it
# 17. Wolt support too bad, very slow
# 18. They deducted money from me for a mistake I did not do, and I was also unable to complete my work for this reason It’s not an acceptable, sorry. Why should I pay for the resturant mistake?! I received the order from the resturant after I let them control my mobile (they saw it), then I delivered it. How can I know the in package details?!
# 19. You have the best system it runs smoothly everytime, no problems whatsoever, I dont think you have change anything, and your support is also the best they always have a solution for everything, you should give them a raise especially the ones i have been in contact with today
# 20. No work, terrible support
#
#  -- Topic 4 --
# 1. It’s fine. Could be some small tweaks to the app, such as when opening the app from lock screen it jumps to the chat so I have to close it down. Sometimes when the app gives me bundles, if the first order is finished early or sometimes even just finished on time, the next order will maybe have 10+ minute wait and not so high pay, so it rarely makes sense to accept those.
# 2. I had problems with the app
# 3. The app is very buggy sluggish crashes a lot frezez 20.30 seconds at a time ,
# 4. The app really teases a lot
# 5. The app has been freezing
# 6. I cant write to suport and i dont know why , the app dont let me to write.
# 7. The app is working really bad!!!!!
# 8. App has been completely miserable tonight
# 9. Hi Wolt team, the app sats it is busy. But ut looks quit to me.Ni orders
# 10. It doesn't work properly
# 11. Work to fix your app
# 12. App does NOT reject delivery automatically after a certain time like the old version
# 13. Very few orders a the moment, less transparent algorithm now, app is more buggy than ever
# 14. Couldn’t deliver the orders because of App
# 15. Useless app useless support
# 16. App has many issues. Please fix
# 17. This is like the 50th time in a couple months, that the app stops working for 5+ minutes. I reported this like 15 times. FIX IT ALREADY!!!!!!!!
# 18. More error messages in the app Ifm Pick -up and Delivery ...
# 19. You have to fix that app, waisting my time and money with daily errors an-mass, today I almost went home after my first order, just in frustration, it's not good enough, steals my profit, and have done so for a long time. No dispensation for the trouble either.
# 20. Half an hour waiting time before getting a new order despite the app saying "busy, expect orders very soon"
#
#  -- Topic 5 --
# 1. Often it does not add house number when it transferring the address to Google Maps, it leads to more wait for the customer and more exercise for me haha
# 2. Add a button where you can specify where one is going
# 3. The apps shows wrong delivery address before pick up
# 4. The app its working bad, It doesn't show where the location actually is, and it doesn't update if it's on the second screen.
# 5. Please tell me my location is visible because I have been sitting without work for an hour and a half, but the rating indicates that there should be work
# 6. There is no connection to google maps
# 7. I have some observation: 1. Sometimes not indicate actual address in Google map. Suppose House no 20 it should be indicate 20. But it sometimes show 10 -20 like that. 2.Another issues sometimes restaurant food not ready 5-20 min waiting when wolt should add Money for waiting. ( MacDonald is big example) 3. Distance kilometres is not accurate sometimes also show example 67kk but paid 52dkk. This is not complaint. 4. Pick time I accept a order so far from restaurant. There is no restaurant there so need again come back otherwise no order so like this area should add money. So this is not complaint. Just my observation.
# 8. Will be nice if the map in the Wolt App could set up until Nord is always up as in Google Maps.
# 9. Gps house number not precise
# 10. Hotspots in Kbh are good! I've also tried other cities but it wasn't so good.
# 11. Incredible that the app can't deliver the right house numbers to Maps.
# 12. Worst app ever. GPS doesn't work properly
# 13. Hi! Could you possibly add address numbers into the Wolt map? Some other maps have this and it really helps to see where the odd street numbers are and the uneven, just a suggestion to help improve the delivery work, thanks!
# 14. Thx to Ana for the help. But some areas have very bad estimates on the addresses. Especially my last order from Royal Indian
# 15. Addresses don't always fit
# 16. GPS cheats with house no. When pressing Android
# 17. Please make a navigator so I don't need to open Google maps
# 18. I had an order earlier today where the app showed the customer's address in the wrong place. The address was Baunehøjvej 35, Kongens Lyngby, but the app knew to just at No. 12 an approx. 200 meters away
# 19. You give navigation to irrelevant places and you pay less money!!!
# 20. The markers for customer address are not always well placed. It could be really cool if it got better.
#
#  -- Topic 6 --
# 1. There was a restaurant DL Fried Chicken der Silver 33cl soda in the beaker. Then I had to run out with 10 pieces with them. And some McDonalds putting soda cups down in the food bags.
# 2. Restaurants should be more aware of telling you what soda/drink to include on the order. Besides this, some of the restaurants' recycling bags are impractical and cause leakage/waste if one is not really careful
# 3. Last order was 5 bags that is way to heavy for 1 person
# 4. I forgot to come with feedback after my guard so here it is. I once again had 2 bad experiences with packaging that were not close. This provides an extremely bad experience for the customer. As a bid, this is clearly what I see as the biggest problem and I would advise you to go in and make demands on the restaurants regarding the packaging. You could even make your own packaging that the restaurants can buy. It is alpha-omega that all containers are hamitically closed and can withstand tilt or even stand upside down if it ends like that. If it makes the packaging more expensive then it is good that there is a statutory charge and the restaurants can even make a mortgage system so that customers can come back with the packaging and get money back (when they have to pick up food Aha, win win). Of course, it will require the packaging to be reusable, but it is just positive for the environment and the business.
# 5. McDonald put the drinks not steady it breaks in the bag
# 6. Sandwich kompagniet venue serves juices in the soft plastic cup with a plastic wrap that doesn’t stick and with plastic cover that does not match the bottom therefore couldn’t even be closed. It would be hard to carry it in hands not to mention a bag or backpack
# 7. Wish there was an accessory to hold 2 large sodas (1.5 liters). They may like to sail around inside the bag.
# 8. I had to wait 10mn at mcdonals, and they give out drinks in cups that spill over if not held perfectly upright
# 9. MacDonald's peat brew says that they are the ones who have to swipe the goods even on our rider tel and that is before you put the goods into the bag :) ♡
# 10. A bag broke from wokshop because they had made the food leaking
# 11. Burger concept didnt closet the milkshake coreectly do it spillede in my bag
# 12. The tables are not courier responsibility to take drinks from the fridge in an order. I can understand on support that there are no rules about this, it is a shame. As courier we get paid to pick up and deliver, not to pack an order and pick up drinks in is a refrigerator at the back of the restaurant. This is a problem especially at Berlin Døns on Nørrebrogade. It creates delay and bad energy when there are plenty of employees in the restaurant who can easily make sure that drinks are handed out with the order.
# 13. Espresso House, their wrapping is so poor/defective that it makes it impossible to deliver their order without a waste. My customer came to the same conclusion. I'm not going to deliver more orders from them. Before they fix up their wrapping.
# 14. A comment for Wok in Vesterbro. I delivered two orders and the bags both broke due to leaking packing. 1st orders bag broke directly as I handed to the customer, the second i had to arrange the mess into something deliverable. I would advise they look at their packaging to make it less leaky as the deliverable product doesn’t look pretty for me or the customer.
# 15. Simply too weird that burger concept does not wrap drinks in this case milkshake. It is really difficult to make sure the item emerges undamaged.
# 16. MC. D and Burger King simply have to learn to wrap their bags properly. Tape is so weak…
# 17. I had a problem with the delivery of drinks from FFOOD. Even though I secured the drinks well in the bag, its still spilled inside the bag. I am very uncomfortable with this situation. This is completely my fault, but I would like to contact this cafe through you with a request to think about a more reliable form of glasses so that customers are satisfied. For example, McDonald's and Burger King glasses are always delivered without spilling.
# 18. Kebabistqn told me wrong number of soda
# 19. The Restaurant Grød has extremely bad cups for their lemonade. Doesn't hold tight, cycled with it in hand, and still couldn't avoid waste.
# 20. McDonalds City putting orders in big bags is a disaster. They put drink in one separate bag and food in one separate bag then put those bags together in a big bag. We have no control of the drinks. It’s a mess. And it takes up so much space. Bundles of 3 are not possible anymore. Don’t get me started on how much extra time it takes for them to pack the bags like this
#
#  -- Topic 7 --
# 1. I DIDN'T GET ANY TASK... ON A FRIDAY!!!!
# 2. please increase task rate.
# 3. I have got two tasks in two hours on a Friday!?
# 4. There too few tasks for the time being
# 5. 45 minutes without a task on high demand
# 6. The text when receiving new tasks is very small compared to before, so it's hard to read in motion. I suggest returning to the previous design
# 7. I didn't get a task directly after i finish the previous task though it was busy, 30 min waiting, When quite it's ok,
# 8. It fine but wants more tasks
# 9. This is rather a problem I had yesterday, but forgot about it. Two times when I received a new order I clicked the accept task button, but insted of starting, I got an error message that the task is failed. On both occasions I had to ride around without a task for 15-20 minutes, which considering my average salary, costed me 70kr.
# 10. Hello. We get first turn tasks, but 80% of the time we don't get other '2' round tasks. Why are you fixing the second round? Start from at least DKK 50. Your job will be easier. You don't understand words you "know" just
# 11. It's Sku Slay with Tasks
# 12. I wrote it before and I'm writing it again. Not being able to do 13 tasks from 16:30 to 20:00 on a Friday in Østerbro/Triangel doesn't make any sense. And I'm not a slow courier either. No tasks at all from 16:30 to 17:10?! Please fix your algorithm.
# 13. Not a fan of the new algorithm to distribute tasks - it takes a long time between the tasks and you get out of your flow….
# 14. With 100kr/h, i dont think so...long time between tasks
# 15. Not enough tasks despite being faster
# 16. today i started work morning 7 i get all task 4 floor 4 floor
# 17. Sometimes I have to log out and in to get more tasks
# 18. multitasking sucks. if we aren't employees as you say we should have the freedom to choose if we want to work on a single order or multitask. put the option to activate or deactivate multitasking. useless
# 19. I could not delete task for 1 hour.
# 20. There have been technical errors and I have earned very little on some tasks. Think it has something with the mistake to do
#
#  -- Topic 8 --
# 1. Why the system give bundles when there are not enough orders?
# 2. I think Bundle could be rewarded better. The weight is often heavy, which lowers the speed and increases the risk of accidents, and often the extra delivery must not only be delivered “200 meters away” but to 4 floor without elevator etc
# 3. Payment for bundle orders are very low
# 4. Hi. I am writing you because there are so many orders lying in shops, many delays.Bonus money was better this weekend than previous ,biggest thing I think bundle order money for through out day and evening.please if you will resume bundle money again as it was before will make better flow in orders till customers.Please it will be very good if you give bundle money as it was before 1 march.It will make order till customer fast because couriers leave second order when it is less money. I will always give my feedback to support.Hope you will really look in my comment.Believe me you will see the difference how is the flow of orders n Denmark . App works so slow sometimes .please resume bundle order money as it was before.It will make long distance orders move fast . Kind regards Vishal
# 5. Pay full distance for bundle orders!!!!!
# 6. Bundle order should be same side same way and pay must pick point!
# 7. Get back to old payment method! It's more clear! Now we don't know, you just se the price that you like for the tasks, really unfair. Km deduction!!!! It doesn't worth it anymore to deliver over 3km. We have to pay 100% of our expenses and the prices are super low. Let the bundles be the full price as before! 35kr for a bundle task over 4km??? When we actually have to drive 1-2-3 km from first drop of to the second??? This is insane
# 8. I had a bundle. But it wasn't a good deal. 34kr for 2km with extra weight, 4th by stairs and a lot of time picking it up. I hope you change it
# 9. Make bundle orders worth taking!
# 10. 26kr for a bundle in the “weekend boost”, which should have been taken 600 meters more…not correct at all!! Please do something, or just be correct! I don’t want more money, i just want justice!! That’s all, thanks
# 11. The bundle task is not worthy the new pricing model fail with this too
# 12. We want old system, stop forcing bundle orders down our throat when you made bundle orders alot less rewarding. Stop calling us Partners when we get zero information about anything
# 13. The bundles should not have been perma-activated ... this causes issues within the app when trying to start deliveries, you are unable to since orders keep popping up over the confirmation. Additionally, when you decline the orders that pop up there several steps to declining that order. It makes no sense to have this activated forcefully as someone who'd prefer doing an order-per-order basis. Thank you
# 14. Happy overall, but make bundle orders profitable again please! It's double the effort, more weight more time, more energy! For example for the first Wolt market order the total paid is 74kr. (Very heavy) then a second bundle order comes, very heavy too, and the extra paid is 25kr!!! No way I'm taking it!
# 15. With the new model, bundle deliveries are poorly paid.
# 16. Bundle orders is a scam
# 17. Many hills that take a lot of extra time I don't feel counting in earnings versus the orders that are very close to the extradition sites
# 18. Screw you operations team. Car salary and bundle orders suck!
# 19. Timing was off for deliveries on bundles.
# 20. When pick up bundle, the second customer drop point was not correct
#
#  -- Topic 9 --
# 1. I just spend more than 2:30 for 70 dkk îs this oke ?
# 2. What's going on there . today I worked in 8 hrs 500 dkk .if u pay tax? Kind regards
# 3. Disgusting support who is stealing the orders from other to Make someone 200 dkk per hour at low demand . No other Reason for 6 orders for 5 hours and 20 orders for same time
# 4. An hour online,0 order,in the morning 2 hours 70 dkk
# 5. Orders for 35 dkk or less on a Friday supposedly on peak hours (7pm) sounds wrong... I feel like the pricing has got quite off sometimes.
# 6. Stop accepting people!!! 130 per hour this is a pittance!! Orders of 26 dkk??? Why don't you pay more?
# 7. You are paying me 405 DKK for four hours of work on a Friday at peak hours. This is ridiculous, I cannot support myself with this.This should be illegal.
# 8. It's disastrous, 3 hours online, 2 orders, 30 km, 50 dkk per hour!!!
# 9. 26 dkk is too low for a normal order….
# 10. 3 and half hours online,2 orders,110 dkk!!!!! it can be worse than that, probably yes
# 11. I decide for myself when and how long I want to work. If I work Friday to Sunday from 17 to 20 I am guaranteed DKK 110 per hour. If you have more orders and constantly orders are your hourly wage 150+
# 12. Can't you choose one of two tasks Nàr they pop up? Otherwise I don't think it's sarish smartly made actually because I can see that it is a high amount but in theory it is just two orders of DKK 50 worth or DKK 60 worth
# 13. Two hours online, 0 orders, very interesting, this is a compensation with yesterday, which was a good day (120 dkk per hour), in the end it should be normal, under 100 dkk per hour!!!
# 14. 6 hours online,60 km,4 orders,270dkk is disastrous!
# 15. you also removed the bonus of 10 dkk and the XXL one is not ok
# 16. I made 600 dkk for 10h of working was very bad day... another people got orders but from 20 00 until 22 00 I didn't get any.. or maybe just one
# 17. Another very bad evening, 70 dkk per hour before taxes and expenses. There are a few good days per month, the rest are very bad, the average is below 100 dkk per hour before taxes and expenses Feedback Alții caută și
# 18. 55 DKK per hour is too low
# 19. I’ve got 280 dkk for 3 hours of work. Not even a 100/hour. This is criminal!
# 20. More than 2 and a half hours online, 70 dkk, what do you think? For me it is disastrous!
#
#  -- Topic 10 --
# 1. The application did not work well - the location update was done at long intervals, for this reason you had to wait 4-5 minutes before you could swipe the received order -with normal and busy status, in 1 hour and 30 minutes I received 3 orders - after long periods of waiting, I received the orders ready and delayed - a second order is pending and by the time you reach the location to pick up the first one it disappears, it is pointless to be displayed until you drive 2-3 km and then disappear - I received the order for a new customer, ready and delayed, to travel to the venue 6 km, after picking up the estimated time for delivery 3 min. for 4.5 km, driving safely is a priority
# 2. App lets me drive for miles, then offers almost ready order when I’m close to the venue Insane miles
# 3. In my opinion we could have integration with smartwatch for confirming the orders and especially an app designed for Android auto, it would be a plus not having to touch the mobile phone while driving
# 4. 5 last orders the app waits with offering task until I’m near pickup even if tasks are due or overdue for pickup, so I drive long distances for noting. Big joke
# 5. App lets me drive for miles, then offers almost ready order when I’m close to the venue. ABSOLUTE JOKE TODAY. THE LEVEL OF MANIPULATION IS BEYOND BELIEF.
# 6. Horrible hourly pay. Horrible miles. Horrible manipulation by the app: App lets me drive for miles, then offers almost ready order when I’m close to the venue
# 7. I miss a cancellation order button when you have taken the order but not picked it up and do not want it anyway. I would like to be able to make a list of places I do not want to pick up from (because it is not possible by car) You send too many indifferent messages from the app. Ex that you missed me yesterday (even though I was at work) I miss indicating where I should drive for my next job in the app. I'm tired of making driving accounts. Why don't you pay driving allowance with wages? It wears on the car to drive a lot and I do not get full compensation for the loss of value.
# 8. App lets me drive for miles, then offers almost ready order when I’m close to the venue
# 9. App lets me drive for miles, then offers almost ready order when I’m close to the venue. BIG JOKE. SSAM at Fisketorvet take more than 15 minutes to toast two buns, and it looked like the only orders they had. BIG JOKE.
# 10. App lets me drive for miles, then offers almost ready order when I’m close to the venue. ABSOLUTE JOKE!!!!!!! I hope you understand I often reject orders when the manipulation is too much.
# 11. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Biiig joke
# 12. App lets me drive for miles, then offers almost ready order when I’m close to the venue Disaster stats: Miles driven increased 20-30 % absurd.
# 13. App lets me drive for miles, then offers late or almost ready order when I’m close to the venue. Almost six orders like this today !!!
# 14. Insane mile’s increase. App lets me drive for miles, then offers almost ready order when I’m close to the venue
# 15. Delays again. App lets me drive for miles, then offers almost ready order when I’m close to the venue
# 16. Waiting for car phone holder and start by tomorrow
# 17. App lets me drive for miles, then offers almost ready order when I’m close to the venue. DONT YOU FEEL ASHAMED TREATING US LIKE THAT??
# 18. Time estimates just tight enough for car driving with parking options. Could wish for a feature that could go directly from the address over to the navigation app on the phone. More restaurants clips the bags, so it is not possible to check the order.
# 19. App lets me drive for miles, then offers almost ready order when I’m close to the venue Insane Miles driven
# 20. App can’t always mark order ready. App lets me drive for miles, then offers almost ready order when I’m close to the venue. APPALLING!!!!

# %% [markdown]
# # Model 2

# %%
from bertopic import BERTopic

loaded_model2 = BERTopic.load("simple_model2")
print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %% [markdown]
# ## Inspection

# %%
loaded_model2.get_topic_info()
# Out:
#     Topic  Count                                          Name  \
# 0      -1   4118                        -1_order_time_wolt_app
# 1       0    915                       0_happy_good_thank_work
# 2       1    521                  1_restaurant_ready_food_wait
# 3       2    490                    2_order_hour_order order_2
# 4       3    435                    3_km_distance_delivery_pay
# 5       4    372               4_mcdonald_wait_order_mcdonalds
# 6       5    371               5_courier_new courier_new_order
# 7       6    331              6_support_wolt support_chat_team
# 8       7    322                      7_map_address_google_gps
# 9       8    311                         8_app_order_task_time
# 10      9    284                      9_earning_salary_pay_low
# 11     10    269                         10_bag_drink_pack_cup
# 12     11    171     11_burger_king_burger king_burger concept
# 13     12    158                          12_wolt_hour_kr_work
# 14     13    146        13_task_task task_new task_accept task
# 15     14    138     14_wolt_market vanløse_wolt market_market
# 16     15    134                    15_app_app work_work_error
# 17     16    122              16_bundle_bundle order_order_pay
# 18     17    114            17_price_low_low price_price order
# 19     18    100                18_pay_order_pay order_payment
# 20     19     95  19_bonus_weekend bonus_weekend_bonus weekend
# 21     20     94       20_mile offer_drive mile_mile_let drive
# 22     21     90               21_support_order_deliver_cancel
# 23     22     83     22_payment_new payment_payment system_new
# 24     23     82           23_wolt happy_happy wolt_happy_wolt
# 25     24     68                24_app_freeze_app slow_restart
# 26     25     66         25_home_home order_order home_go home
# 27     26     64                   26_dkk_hour_dkk hour_3 hour
#
#                                        Representation  \
# 0   [order, time, wolt, app, work, delivery, pay, ...
# 1   [happy, good, thank, work, wolt, day, job, lov...
# 2   [restaurant, ready, food, wait, time, food rea...
# 3   [order, hour, order order, 2, wait, 1, receive...
# 4   [km, distance, delivery, pay, driver, drive, c...
# 5   [mcdonald, wait, order, mcdonalds, ready, minu...
# 6   [courier, new courier, new, order, order couri...
# 7   [support, wolt support, chat, team, help, bad,...
# 8   [map, address, google, gps, location, app, map...
# 9   [app, order, task, time, error, work, app work...
# 10  [earning, salary, pay, low, wage, bad, get bad...
# 11  [bag, drink, pack, cup, food, paper, spill, so...
# 12  [burger, king, burger king, burger concept, co...
# 13  [wolt, hour, kr, work, pay, money, day, kroner...
# 14  [task, task task, new task, accept task, time,...
# 15  [wolt, market vanløse, wolt market, market, va...
# 16  [app, app work, work, error, work properly, wo...
# 17  [bundle, bundle order, order, pay, task, order...
# 18  [price, low, low price, price order, order pri...
# 19  [pay, order, pay order, payment, order pay, lo...
# 20  [bonus, weekend bonus, weekend, bonus weekend,...
# 21  [mile offer, drive mile, mile, let drive, clos...
# 22  [support, order, deliver, cancel, deduct, cust...
# 23  [payment, new payment, payment system, new, sy...
# 24  [wolt happy, happy wolt, happy, wolt, love wol...
# 25  [app, freeze, app slow, restart, slow, update,...
# 26  [home, home order, order home, go home, order,...
# 27  [dkk, hour, dkk hour, 3 hour, hour online, onl...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [i am very very happy with, I am very happy to...
# 2   [Some restaurants you have to wait a long time...
# 3   [Nothing ?? No orders in, I don't have an orde...
# 4   [The adress of one of my delivery's today was ...
# 5   [Hi! Today started great but the few times I’v...
# 6   [Too few orders or too many courier, No orders...
# 7   [Wolt support not good.verybad, Leaf -tender s...
# 8   [No integrated route on in-app map, or easy wa...
# 9   [Uphill…. Began as courier 5 months ago (it ma...
# 10  [Salary gets worse and worse, Drastic deterior...
# 11  [McDonalds City putting orders in big bags is ...
# 12  [Burger King and The Burger Concept is almost ...
# 13  [I remember when Wolt gave you the backpack, a...
# 14  [I don't get as many tasks, No tasks in aabenr...
# 15  [I also want to order Wolt Market in Vanløse o...
# 16  [The app was down for me, The app still doesn'...
# 17  [Why the system give bundles when there are no...
# 18  [The price is too low sometimes, Really low pr...
# 19  [They are paying less and less for orders, Pay...
# 20  [You should put a bonus for weekends 23to02am,...
# 21  [App lets me drive for miles, then offers almo...
# 22  [The support is the WORST. I think I will find...
# 23  [More openness about the new payment model, Th...
# 24  [i am very happy with wolt, i am happy with wo...
# 25  [App functionallity is not well,freezing,bloki...
# 26  [going home.. no orders for me, I'm going home...
# 27  [This afternoon, 2 and a half hours online, 2 ...

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = loaded_model2.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = loaded_model2.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: happy, good, thank, work, wolt, day, job, love, great, work wolt
# Topic 1: restaurant, ready, food, wait, time, food ready, minute, mark, order, order ready
# Topic 2: order, hour, order order, 2, wait, 1, receive, receive order, get, time
# Topic 3: km, distance, delivery, pay, driver, drive, car, money, payment, bike
# Topic 4: mcdonald, wait, order, mcdonalds, ready, minute, mc, time, donald, ignore
# Topic 5: courier, new courier, new, order, order courier, hire, hour, courier order, money, stop
# Topic 6: support, wolt support, chat, team, help, bad, support team, wolt, contact, support good
# Topic 7: map, address, google, gps, location, app, maps, wrong, google map, google maps
# Topic 8: app, order, task, time, error, work, app work, accept, support, order app
# Topic 9: earning, salary, pay, low, wage, bad, get bad, hour, get, money
# Topic 10: bag, drink, pack, cup, food, paper, spill, soda, customer, menu
# Topic 11: burger, king, burger king, burger concept, concept, wait, minute, delay, min, order
# Topic 12: wolt, hour, kr, work, pay, money, day, kroner, night supplement, low
# Topic 13: task, task task, new task, accept task, time, accept, new, disappear, task hour, task receive
# Topic 14: wolt, market vanløse, wolt market, market, vanløse, danish, copenhagen, order, denmark, order wolt
# Topic 15: app, app work, work, error, work properly, work app, properly, problem app, bug, bad
# Topic 16: bundle, bundle order, order, pay, task, order bundle, accept, payment, new, system
# Topic 17: price, low, low price, price order, order price, price low, double order, double, order, rate
# Topic 18: pay, order, pay order, payment, order pay, low, year, payment order, kr, order payment
# Topic 19: bonus, weekend bonus, weekend, bonus weekend, order, bonus time, 17, remove, year, today
# Topic 20: mile offer, drive mile, mile, let drive, close venue, app let, offer ready, order close, offer, ready order
# Topic 21: support, order, deliver, cancel, deduct, customer, ask, tell, mistake, say
# Topic 22: payment, new payment, payment system, new, system, old payment, model, payment model, old, transparency
# Topic 23: wolt happy, happy wolt, happy, wolt, love wolt, wolt love, love, yes happy, wolt yes, thank wolt
# Topic 24: app, freeze, app slow, restart, slow, update, app freeze, crash, app crash, close
# Topic 25: home, home order, order home, go home, order, work late, order go, go, order order, think work
# Topic 26: dkk, hour, dkk hour, 3 hour, hour online, online, 3, average, 70 dkk, dkk bad

# %% [markdown]
# ### Inspect documents in topics

# %% [markdown]
# I inspect the documents in the topics, to see if they seem coherent and belong to the right topic.
# The idea is that feedback in the topics should quite similar.
# Moreover for at topic to make sense, we should be able to tell what the topic is about without seeing the topic representations

# %% [markdown]
# Some topics seems to be adresseing the same themes, and could be merged.

# %%
# Retrieve the topic assignments for each document
topics, _ = loaded_model2.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Iterate over sorted topic IDs
for topic_id in sorted(topic_to_docs.keys()):
    docs = topic_to_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))  # Randomly select up to 10 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
# Out:
# === Topic -1 (4118 documents) ===
# 1. ATTENTION PLEASE: Ok so it happened now for the second time that I accept a task, bike all the way to the venue and once there I don't have the task anymore. The first time I contacted support but they couldn't (or wouldn't) help me. This time I understood what happens in these cases: by the time I accepted the task and arrived there to the venue the order got canceled. This last time the venue itself canceled by mistake (they wanted the reject a later order that they couldn't make in time and not my order that they have made already). The first time I don't know who canceled it (venue or customer). The point is when this happend you cannot just take the task away without some sort of notification (possibly with sound too or something). What if I biked 15 or 20 minutes all the way to the venue for nothing? I understand the customer or venue can decide to reject the task but the courier needs to be notified right away. The app right now basically just goes back to "waiting for tasks" silently with the courier still thinking that he's biking/driving to pick up a task. What makes it even worse is that when I contacted support they "don't know what I'm talking about cause they cannot see I took any task". The app needs to be amended. (This last time I got at least my 35 kr for having biked all the way to the venue but the first time I got nothing.
# 2. Payment is Getting low everyday
# 3. Wolt = shit = toilet
# 4. Mc Donald, is extremely virtually to and comply with the time frames and shows us Kure great disrespect. Everyone else comes first
# 5. Don’t bother offering me add on tasks for 22kr they will never be accepted
# 6. Really happy about everything related to Wolt and most partners. However there is a general problem with some of the larger and smaller restaurants pushing the “order is ready”, while in reality we end up waiting 5-15 minutes for the order. Especially Hubbs Kitchen, both Frederiksberg and Nordvestare some of the biggest ones in this. As couriers we miss out reaching boost goals, when we are kept waiting, two Hubbs orders can destroy the tarvet of reaching 12 orders before 20.00.
# 7. If I could use the app without power saving mode, I would do it. I can’t. The pop up all the time asking to turn off the power saving mode ruin my day.
# 8. When work is this bad don't send fake messages saying there is work.
# 9. Ghost order. Hachi sushi 621
# 10. There is a glitch where if you pick up an order and then turn off your device the *ding* sound will repeatedly play until you open the app again, it can be a little obnoxious
#
# === Topic 0 (915 documents) ===
# 1. I think Wolt is good, but it is in Frederikshavn Little City and many people who work in Wolt so that it is not enough work.
# 2. I consider that the freedom of hours that we can work is important.
# 3. I am having a great experience
# 4. Thanks for giving me to take this opportunity
# 5. Suitable for me perfect! The days that are high load I try to run for a few hours!
# 6. always best wishes & i like this
# 7. Have always been very fond of Wolt. The problem is just that you say you listen but do not, so the very job 5*
# 8. Lovely experience, maybe a little few tasks, but otherwise good
# 9. Waiting for the 1st of March. Read the newsletter and I'm very glad for the changes.
# 10. Everything was sooooooo goood today
#
# === Topic 1 (521 documents) ===
# 1. When you receive an order and have to pick up the food, the dot is not over the same with the real distinction where the food is to be delivered it is very much next to 500 meters and it is very much inside the middle of the city it must definitely be fixed as it only creates problems I suggest you allow us to see the address of it where the food is to be delivered while we are in the process of collecting the food on it can both save time so you do not have to spend 1 to 2 minutes to find out where it is and how to get there and it can be done while the food is finalized but overall it is good
# 2. Sivas pizza marked the orders ready even if it is not ready yet!
# 3. Too many delays: Help restaurants to recognize that they are busy at the expected delivery time. It doesn't have to be spot on, they may just be allowed to press a button indicating they are in a hurry.
# 4. I stayed in front of a restaurant for 45 minutes!! for another colleague to come and take an order from there!!! I don't think it's normal!!!
# 5. Some restaurants need to be more responsible with the time...
# 6. Venuew marking food ready when its not, and also not marking food ready when it actually is, is a serious problem!
# 7. Antwerp fried chicken is always getting late never made the order on time and marked ready when food is not ready
# 8. Bites in Ankersgade were -20 min delayed today. They first said 5 min and then 5 min again. Just stood and waited and when the order was in -12 min they marked it as ready. They were kind and lamented the wait but they just should have said from the start it was –20 min delayed
# 9. Pretty much waiting in the restaurants today
# 10. The food is always too late here where there is busy
#
# === Topic 2 (490 documents) ===
# 1. Bad amount of orders
# 2. I serve too little a day ￼
# 3. Mega waiting times so the order ready time was completely off ..
# 4. So I never managed to get an order, so it wasn't the coolest one can say. But I still have a walk and will grind on tomorrow :)
# 5. Today I got only 5 orders in 4 hours, it wasnt that funny to work, im little sad
# 6. One hour standing without orders !
# 7. Unfortunately very few orders
# 8. One order in one hour
# 9. Giv me task not fucking message about all the orders all day. 3 h online 1 fucking task..so sup
# 10. Very bad more than 2 hours doesn’t have any orders
#
# === Topic 3 (435 documents) ===
# 1. An adjustment must be made between distance and prices
# 2. Share more profit. My miles driven are up more than 30 % just from last month
# 3. Last order wrong adresse 2 km more i was promised to the distance diffrence and compensation before I deliver it and i got only 25kr
# 4. Important feedback Hello Wolt This message must reach management department. I would like you to notice that you care about the customers and the restaurants that's good but please you have to give an eye to your Drivers which they are the real Wolt they are your team (your right and left hands) I feel you are working against them by bringing all the time more new partners, by this method you simply take tasks from your old and senior drivers which they have experience and give them to a new unknown driver, and nobody do this thing you have to PROTECT your old people because they are tested and deserve to be respected. you with this way forcing them to find another job because you are making the work not worthy. And did you do simple you change your good drivers with new ones not sure about them. I heard from many old colleagues Wolt is dying wolt becoming not worthy. Example 2021 old parenter average 10 tasks 2022 New driver average 5 tasks old partner average 5 tasks 2023 ? You have to stop this bleeding and no accept new drivers without needing them. Protect your team Protect your drivers income. Thank you I will repeat sending this feedback again.
# 5. Payment for heavy orders is not correct and I have an example: the payment for a normal order,distance of 4.08 km, was 67.60 dkk for a very heavy order (40 kg or more) 4.16 km-74.88 dkk, this means 7 dkk extra to carry 40 kg!!!!! So the supplement for heavy orders does not exist!!!!
# 6. There should be a minimum of 35 or 45kr per delivery as it used to be. It's insulting to get 20kr offers for a delivery
# 7. A lot of new drivers suddenly
# 8. To less money per delivery compared with the last 3 months (since the 14.11 the income per task is min to 10kr to low)
# 9. Shame on you. High demand was a lie. You didn't give order to the bikes.
# 10. Really really disappointing. Having wasted 30 minutes cycling to two orders and there being errors. Then support not compensating the fee. Really shitty!!!
#
# === Topic 4 (372 documents) ===
# 1. The waiting time on McDonalds Holstedvej in Næstved DK is to long! I have contacted one of your support member to remove my task after a period of 57 minutes waiting and it was still not ready yet (the command, I have picture, I send it to your colegue)…. It is absurd, both of us are losing money! In that time I could deliver other tasks from other restaurants more serious then McDonalds…. It is very frustrating for both our time and money…. Please, if you can, contact the manager of the restaurant (McDonalds Holstedvej)….. the parking lot was almost empty and in interior very few people…. But to wait one hour and still not be ready it’s beyond common sense! I’m very disappointed about this experience but I finally get the courage to write to you and it’s not the first one! I like your app and I intend to work for you more time from now one! Sorry for the long message! Thank you! We meet on the streets!
# 2. People working at McDonald’s Frederiksberg don’t answer when we ask for the food. And when they do, they treated me disrespectfully
# 3. For an hour it doesn't give me an order It only gives me from McDonald's which I don't collect from,yesterday it was the same should I go home and today I don't know how to work or I don't know what to do
# 4. McDonald’s need work on a lot and Us couriers having to wait 30 min that’s not nice . It’s bad for us and business
# 5. Mac Donalds were really slow. Clean chaos. Otherwise a fat day
# 6. I have a complaint about McDonald's Herlev, they don't attend wolt couriers seriously. I have been there many times. The orders were lying ready in front of us on tables, but nobody give them to us. Orders are late, marked ready from many minutes ago. Yesterday i waited 15 minutes for my order, which was lying in front of me since i went their. I asked them, he told me to get back and wait. It's very annoying. Bundle delivery picking and delivery gets late by hours. Please do Something about it. Thank you.
# 7. Often i need to wait extra time in Halifax. Today it was really long time. About 20 minutes extra.
# 8. McDonald’s horrible waiting times
# 9. Help McDonalds adjust the expected Pick up time..
# 10. Mcdonalds employees just ignores us. Even if the orders are ready
#
# === Topic 5 (371 documents) ===
# 1. It’s an absolute joke. Before the payment model got changed, I used to make between 250-800kr an hour, but now I’m lucky to make 120kr an hour. Something needs to be done about this, otherwise you’ll have no couriers left to deliver the orders, I know for a fact that I’m not the only one compalining about this, since I hear other couriers talk about the same EVERY day. Do something before you lose your slaves “wolt couriers” because it’s unprofessional and absolutely unaaceptable.
# 2. Stop Stop bringing new couriers use us your old and faithful partners with experience ,we need to have orders why you are pushing us out and give the orders to new couriers ?half of our orders are going now to the new couriers ,our hour will reach 70 kr and become not worthy .
# 3. Not possible to wait 2.5h for 1 task. You allowed too many couriers in Ringsted.
# 4. you only have orders for couriers, the new ones, the experienced ones these days we don't take anything
# 5. At split orders, would it be possible to add "new" order numbers to the "new" orders? Ex. 1. A courier rejects a big order with order number 222 because he will not carry it. 2. The order is being split, so two new couriers can pick it up. 3. The next courier arrives, but in this case he is being provided with order number 222A, and takes the first part of the order. Meanwhile the next courier is already on his way, and it would be a waste of his time and money if he should not pick up anything. 4. The next courier arrives and he is being provided with the order number 222B, and picks up the second half of the order. The only thing the staff have to do is add an A and a B to the order numbers on the bags in for example the supermarket Meny. Just something like this so we don't have to waste a lot of time talking with staff and support about what happened because a courier picked up all items in a split order, which made everyone confused about what really happened, and why the last courier is there with an order number, but seemingly nothing to pick up.
# 6. Love my work .... but hate the lack of ethics and morals from couriers, as well as wolt
# 7. I appreciate that you realized that there was a problem that we suddenly had very little orders and that you care about us and try to mhelp is asap and fix the problem by giving us extra boosts, slowing down hiring new couriers and also by finding more custommers to bring more orders. And also thank you for informing us about it and communicating with us. Thank you, I appreciate that :)
# 8. Week by week there is less and less orders and beside evening Wolt is a waste of time. There is now days when an hour passes with out a order. This was the situation before Covid 3 years ago and now we back. I mean 400-500 CPs on the street in the day time. Guys is there some one even paying attention to this. Where ever I go there are groups of 5-10 Romanians already there. It’s not the fact that it’s Romanians it the fact that threat apparently way more people here then ever before. I can go in to MC Frb to buy a coffee as theres 15 CP parking. I see people who were fired from Wolt 2 time already because they were molesting people and now working under a fleet who flooding the streets with workers. I know you need workers but this making 100kr/h is not an appealing opportunity.
# 9. It was good, however, it has become somewhat worse root how poor food delivery is accepted. Overfilling courier destroys income potential, and the company arrogant approach to the same problem
# 10. Was that the goal? Let's get a lot of new couriers, so that we wait like idiots in the cold for one order per hour!? Well, I'm not an idiot, nor am I your slave. You're not worth anything in our eyes anymore.
#
# === Topic 6 (331 documents) ===
# 1. Disgusting support but they're wrong if thinking that this unprovoked negative attitude touches me only. The sooner they finish, the better for all??
# 2. Wolt support not good.verybad
# 3. I really don't like how difficult it has become to unassign a task with the new support interface - when my fingers are wet from the rain, and it’s busy and I have a combo, I don’t like having to explain why I want to unassign a task. Sometimes I get follow-up questions from support, instead of them just unassigning, and this kills my flow and delays other orders. Please look at this and make it more streamlined to unassign like before - I don’t do it often, but when I need it, I don’t want the added frustration of language barriers and having to explain myself.
# 4. Unable to reach support
# 5. Masho, close every time the chat until you finish what you need to say!
# 6. Just wanted to overall…..that’s literally the best support in the world . They are fast, they are professional and they always are ready to handle situations. Except that, they feel like friends, we chat with
# 7. Wolt support team need to change
# 8. I got screwed on a already that was already picked up. Support refused to compensate me. 0/10. Fire those support members.
# 9. Support is very slow, it takes a long time to answer
# 10. Coming back soon! Have been busy with school, but back!
#
# === Topic 7 (322 documents) ===
# 1. There is no connection to google maps
# 2. The app has problems with GPS, tested on 2 mobiles, gets error notification that GPS is not updated to server
# 3. Apple maps and google maps is really bad at navigating
# 4. Get messages that there is no GPS tracking - even though I'm online.
# 5. App works very. Bad .always GPS problem .I follow the steps to correct as support told me but still my location many times does not move as i moves .
# 6. Often lose signal to maps cards
# 7. I think the swipint is very slow and dosent work good. It gets me stressed and frustursted. Also your map has not a line to help you reach my destination so therefore i have to use google maps
# 8. Your app is the worst application when we want to move towards the client, unfortunately the application does not transfer the client's address to the exact Google Map. This has been a problem that has not been corrected even after a year.
# 9. There was a continous issue of gps, me logging off and app getting closed automatically
# 10. The GPS could be better. More accurate in relation to where you are when you are a place. I often drove too far because it took it some time to update. But when I used the Google Maps app it worked really well. Almost immediately it showed where I was.
#
# === Topic 8 (311 documents) ===
# 1. I don't know if your app or McDonald's locations are the guilt, but 10-15 orders are sitting on the table to be picked up, and the app keeps giving me/us the order that are not ready yet. I reassigned it, boom, another unfinished order. This happened today, 1st January , but also happening in the rest of the time. Have a look on that please!
# 2. The problem with the app when asking for a "Task Removed" to continue. :-(
# 3. Hi .. the app can get much better eg when you are done and have to go home the trip can stay in that direction.
# 4. Very bad app . 1 hours online doesn’t have any orders just showing I am online??? Fuck
# 5. sometimes the app doesn't work properly,has errors,delayed to response,waiting time for order is too large(more then one hour)even if the status are normal
# 6. App is buggy. Sometimes it rings too late when the time for accepting the task already has expired. Sometimes tasks show up without ringing.
# 7. It's a shame how the app is working, I don't know what you changed but it works very badly, the worst thing is that it harms the company, the delivery people and the customers. It works so badly that there are always problems receiving orders, checking off items, delivering orders, it doesn't allow orders to be accepted, I've been working on wolt for almost two years and it's the worst moment of the app, it's a shame, you also make modifications and you never inform us, for this reason one does not make observations or comments, but the app is working so badly that it is inevitable to comment, A SHAME!!!
# 8. The app is currently very unreliable. Getting errors every time I try to pick up an order or complete one.
# 9. Great order volume! App still fails to show price 10-15 % of the time.
# 10. It takes too long Sometimes 10 minutes from I in the app reports "Tasks on the way" and until the order comes, you can't make an indication on the card where about the order starts? I don't know if I'm driving toward the order or the exact opposite direction, or should I keep boom still ??
#
# === Topic 9 (284 documents) ===
# 1. It is not the same wolt like before. Nothing change in our benefits. Payment is lower than ever and lot of the tasks are heavy and to the 4-5 floor and payed 25-30 kr.
# 2. I am deeply disappointed and upset over so little I earn. You have really cut down on my earnings. What's going on?
# 3. There is not enough work what we have to make money
# 4. Can you explain to wolt pay more and more and more please
# 5. By default fine, but revenue options today, is quite good night. That part has in destroyed
# 6. Salary has really gotten bad We should get 10 kr more per order
# 7. The pay should be little bit higher in the normal time.
# 8. Stop to say to everyone to go online !!! Because how you see it not was busy… then good earnings is not !!
# 9. low demand - low payout
# 10. Nice with the flexibility, but rather bad salary. I might be making 220kr an hor, but only in the afternnon and withouy holdiday money/Pension
#
# === Topic 10 (269 documents) ===
# 1. Poor Equipment Support When the Wolt Bag has broken after a short time
# 2. Negative: Make payment, no compensation for errors, approve all bags by split order. Positive: Can work whenever you want.
# 3. Can't you talk to McDonald's and Burger Kong about how to pack soda in the cardboard cups. Today when I had to pick up some food with a cardboard soda in. There it is put in a small paper bag without a cardboard holder in so it overturns during transport, even though I drove quietly. Customers were not happy and my bag got wet and it ran through and out onto the seat in the car. So now my car is going to clean, for a trip to little money.
# 4. McDonalds City putting orders in big bags is a disaster. They put drink in one separate bag and food in one separate bag then put those bags together in a big bag. We have no control of the drinks. It’s a mess. And it takes up so much space. Bundles of 3 are not possible anymore. Don’t get me started on how much extra time it takes for them to pack the bags like this
# 5. McDonald put the drinks not steady it breaks in the bag
# 6. MacDonals'd soda wasting too much
# 7. Besides that one place who forgot to put the drinks in i am very happy with how the shift was. Thank you!
# 8. Esaan taste of thailand packages food very poorly, it leaked all over. And the app breaks every single day, for up to 10 minutes at a time.
# 9. I need to be able to see how many kg. And how many bags a Wolt Market order is on… It's super annoying to get up to the Woltmarket to discover that the order consists of 3 bags, which is why there is no room for them in the bag with other orders. - Kg it is nice to be able to see how much to cycle with, as it can be crucial for whether the bike can hold the extra kilos.
# 10. Chicken and CO would again pack cold and hot things together. I didn't have to get the cold drink for himself until I was very assertive. Second delivery they did it again. I opened the bag and took out the drink so it could be transported properly. Annoying that the address of people disappears from the app when I'm right at their address. This happened when I received a combination delivery.
#
# === Topic 11 (171 documents) ===
# 1. The Burger Concept took too long
# 2. Burger King at Vesterbrogade 2 delivered 20 min after they report the order finished
# 3. Once again, major delays in the burger bandit where the food stands for a long time because they forget parts of the order.
# 4. Burger King continues to take extremely long to prepare orders, even outside of rush hours. And they refuse to package drinks properly, they always have refused.
# 5. Burger king drinks, remains disgraceful.
# 6. Burger Concept I stood for approx. 25 minutes and waited for an order…
# 7. Tim from Burger King in Fredericia was super
# 8. Burger venues are absolute worst. It is almost like there is competition between them who will have more nervous and disorganised shift managers.
# 9. Too much waiting at restaurants (Burger Concept, Butger King, Wok this Way)
# 10. Louis burger cheats every single time marking the order as ready a lot in advance, and we just have to wait linger there
#
# === Topic 12 (158 documents) ===
# 1. 150 per hour. Decent but we need to improve more cause for a Sunday night I'd expect more. The guys in Kashmire Østerbro didn't take heed of my advice for the packing. They didn't wrap the boxes in transparent film before putting in place the cover. It's a mistake. Those boxes leak without the transparent film in between box and cover. Today nothing happened simply cause delivery was across the street.
# 2. i feel robbed. not so long time ago in the weekends, from 17h to 20h, when wolt gave us boost, it was cleary 10kr per order, and now, its looking like it has been dropped to 5kr per hour. absurd. everything prices just go up but seens like our salary just go down. absurd, its just absurd and i have never wrote nothing bad about wolt but now its an absurd (again), the time we should get good money, very busy time, and they cut our boost, there is no incentive to work in the busy time no more, its just an absurd.
# 3. 1100 kr I start to 9-20 in the morning very worst days with wolt
# 4. I remember when Wolt gave you the backpack, also the clothes, I remember when Wolt paid a minimum of 35 crowns per order, I remember when there was real work, when it was profitable, now it is a capitalist company exploiting the poor people who have to provide their own vehicle , go through cold,wind and rain, they manage not to pay for vacations, let me tell you that ambition takes man to a dark place..
# 5. Earning with wolt is getting better and more trustable these day.
# 6. 4 hours 253 kr per hour 63 kr miss your weekend plus no money
# 7. Impossible to make any money due to ur overhiring issues 60min no orders in peak times nah
# 8. I have long since given up The new price system is only in favor of Wolt. It can no longer pay off to spend time on it
# 9. Low low morning 100 kr x hs low low
# 10. Too many wolt-pad to earn enough in the hour
#
# === Topic 13 (146 documents) ===
# 1. Good with multi -lectures
# 2. Finding tasks take time :(
# 3. Don't have task.low earned
# 4. Allocating was too early today I had a few jobs with a ready time of 20!!
# 5. Right now I am rested. I can Lie to myself i can tolerate 3/4/5th floor. But we all know im only human in some point I will brake appart. Whos fault was that me or algorythem or ur programmer? But who gives a shit im nobody we/im just means to an end to u.
# 6. Why the same cures that get the whole timennnn
# 7. No tasks of 1 hour and 40min
# 8. The folder shows no tasks and with a try again later message
# 9. I don't get a lot of tasks
# 10. Sometimes it seems difficult to get tasks when there is demand
#
# === Topic 14 (138 documents) ===
# 1. Too many couriers for current state, 10 bike couriers at one place (in the city center) is absolutely too much for Sønderborgs customer activity and amount. Please do something with it, otherwise we will be earning less that 100 kr/hour in peak hours! There are a lot of people working for Students Grant (SU).
# 2. Dear Wolt. Now I have to write to you. There have been far between the orders here in Hillerød. Most recently yesterday, there were a few times when it was over 1 hour between the orders. Today I got from 1 p.m. 13-17 KNND3 order and noticed new couriers in the street scene. It is my impression that we have become too many couriers in Hillerød. There is really mega a lot of waste every day. It's really a pity, while the revenue for one day has gone down. My hourly wage in the last few days has just dragged you over 100 kr. That's practice. What do you say? Let me get your feedback. Could it be better and more rewarding to drive in Hørsholm-Rungsted district? I look forward to your feedback
# 3. I found out today, that I had to change my location to Odense it was previously in Copenhagen , that’s why I have not been getting requests. We go again tomorrow
# 4. Many riders in the city. People cannot properly get an hourly wage which is at least in Denmark 130. Work four hours to earn 150kr. Play time. Come on we use Shift Guard in Viborg. It can't be that 20 riders start at the same time
# 5. sunday was so bad. i waited from 16: 30 to 17:30 at peak hour and got 0 orders in the heart of copenhagen at radhuspladsen! Contacted support a couple of times and they cannot help with anything. 1 hour with 0 orders at peak hour! on top of that the waiting times were incredibly high and many times with no orders the whole day. Even taking a shift with justeat would have been better.
# 6. Got a lot of orders that was behind schedule from the get-go. And Wolt Marked was behind, hard to get in contact with the employees and a queue of couriers waiting for orders. And the attitude from “Adam” was WAY out of proportions. So not the nicest evening, and I stopped taking orders from Wolt Marked at the end of my shift. Hoping for a better day tommorrow
# 7. Unfortunately, I did not receive any Wolt delivery today, I have already done almost nothing for 3 days, I hope to have a better response tomorrow. Thanks a lot
# 8. Could you not put Brønderslev on the series of cities you can change yourself with
# 9. The language of my app now changed to danish. Please turning back to English
# 10. I find that the activity in Holbæk has gone down a lot over the last few months.
#
# === Topic 15 (134 documents) ===
# 1. Completely unacceptably poorly functioning app, again !!!
# 2. Sometimes application errors
# 3. The app is not working properly most of the time
# 4. The app was down for me
# 5. Horrid app and support. No work
# 6. The way how the app work after update is just horrible.
# 7. I don't know why but the app in general is not working so well. It gives error many times
# 8. Still error in the app
# 9. The app longed although my internet was fine
# 10. App at its absolute worst
#
# === Topic 16 (122 documents) ===
# 1. Get back to old payment method, you are stealing our money, every day the price of the tasks get lower and lower.. Tasks for 26kr?? Wtf. When you get bundle orders then we should be able to get the whole fee like before, like is supposed to be, not just the complement from first drop off. Customer does not pay 30kr for a delivery over 4.5 km.. Who keeps this money??
# 2. Still hope bundles, especially the heavy ones, will be rewarded better. Hope you share some of your profits with the couriers..
# 3. Partners have bundles and I don't have any order
# 4. The new functionality with bundled trips is too much used to send us trips that are not attractive, or from restaurants that mark the orders as clear even if they are not.
# 5. Delivered an order 18 minutes late. Just some bakery items. I was waiting around for orders for a long time, and my impression is you waited to offer the order until it could be bundled. I find this practice very wrong.
# 6. 1) The pay per order has only decreased since the new payment system. 2) bundles pays often so little that they’re not worth doing. Below 30 kr. Is too low. 3) a lot of venues marks orders as ‘ready’ without them being ready for pick up. 4) should be faster to cancel an order you have accepted but can’t pick up. Fx if you already got an order in the bag, that takes up half the space, so you accept a new one to fill out the bag, but the new takes up more than half of the space. So you can’t fit in the bag, and now you need to wait a long time for support to remove the order.
# 7. Glad you survive in a competitive market. Would like better pay for bundles. Would like to be offered tasks when they are ready, and not when I’m close to the pickup…and much more
# 8. Would be nice if we could see the both 2nd task and the first, when getting bundles. It only shows us one of the drop-off locations. So we can’t compare the two locations. What about the EU? I hope we will keep our freedom, whatever happens. When is Foodora closing? Maybe that's why Wolt is hiring more couriers again. Anyway, I hope we don't experience the same slow-down as we did earlier this year, I almost started education in desperation. Seems it’s slowing down a little, lately, order/courier ratio going down slowly. We don’t hear much from Operations Team, other than the usual reminders to go online. Other than that, everything is fine.
# 9. Seemed to run with bundle order has become less attractive than before the new reward system
# 10. About 165 kr/hr. Okayish for a Friday but what's with the bundles? It's almost not worthy taking them anymore.
#
# === Topic 17 (114 documents) ===
# 1. Would like to see how the orders are priced. Can't see how Kogle order gives 100kr+ and others give 25kr
# 2. I have lost my motivation after new rules for the price It has many times gone order against 37 kr in bonus time this weekend it is frustrating me it's new price frustrating
# 3. The prices go down and I don’t understand why the second order receive less money
# 4. Prices are very low. The Wolt Publicity is BS
# 5. return to the original system. Delivery costs are very low
# 6. Unfortunately, no with the new pricing conditions, it has become very bad, it used to be better, now you have to be near the store to be task
# 7. Two orders at no cost before accepting the order. What does your earnings look like after wage reform? Does many customers seem to get longer deliveries for less money?
# 8. Why does the system not show the fee?
# 9. Task fees have dropped too much
# 10. needs some improvement in terms of price too low price
#
# === Topic 18 (100 documents) ===
# 1. I Think Long orders should pay more. They are simply not worth taking.
# 2. It would be better if the task fee would show the net earning and the kms payment, not the gross earning as we do not receive the gross earning any more.
# 3. didn't pay for a large order ?? I wrote but. they don't understand me
# 4. Hired to many people. No orders to make the low pay per order make sense
# 5. Hi, what it s happening with the orders? from the previous update when wolt add the struer for holstebro the orders are not paid as they should and as it used to be, it s worst and wors… and it s not 5-10 kr less for each orders, it s less with 15-20 for all of themit have to be a joke right? You continue to cut the payment and think we dont see, that s not fair for us and of course we see, we see every update, everything and i m afraid in this condition im not happy at all to work and for sure is not happier for any of my colleagues as i talk with them, everyone it s searching for others jobs! It s worst and worst!
# 6. Too few orders, compensation gets lower and lower
# 7. Orders are getting paid for less, we need to work more to get paid like a few month ago.
# 8. Very little money on orders and no more multiple orders
# 9. They pay is better at foodora. Pls get back to the pay you used to give for orders.
# 10. You lowered the price of orders in February 2023. I have to place more orders and/or kilometers to earn the same as in January 2023 or last year. It is obvious that they have modified something in the algorithm variables so that orders have decreased regardless of demand or weather. With other colleagues we have compared our tasks with those of last year and we noticed the negative difference. So please, go back to the old model and stop reducing our income every year and playing with us.
#
# === Topic 19 (95 documents) ===
# 1. As soon as bonus hour stops you start giving orders
# 2. Holiday money would be fantastic
# 3. Fuck your holiday "bonuses"
# 4. 16:30 is too early to start the he bonus as there aren't enough jobs to do even 3 deliveries per hour at that time..... This makes the bonus unreachable and lowering our earnings as there are too many hopefuls and not enough ready orders!!!!! 11 orders from 17 until 20 is the realistic bonus
# 5. Good only the problem is not paying holidays money
# 6. The new nighttime bonus is absolutely atrocious and disrespectful. 10% extra is NOTHING. Maybe 30-40% would be a realistic number. Normal workplaces give 1,5x more (+50%) for night shift workers. I would really like to work at night sometimes, but this so called bonus is just not worth it. I hope you will reconsider your approach and start treating courier PARTNERS as actual partners and nog as company slaves
# 7. I don't understand the 16:30-19:30 period for the extra bonus. There are way more tasks from 19:30 to 20:00 than from 16:30 to 17:00, especially on a Friday. Saturday and Sunday might be different. Also support really dropped the ball today. 16 minutes to remove a task?! Seriously? That messed up my 13 tasks which I could have still easily done. Not being able to make an extra bonus because venues are late is one thing, but because support took 16 [sixteen] minutes to remove a task is unacceptable. That's almost sabotage.
# 8. I'm at home in a little while, no orders ??? There is no bonus there is nothing ... you took our saturday bonus ... I feel licked
# 9. On bonus days there shouldn't be tasks paying 30kr or less. Is not acceptable at all. Would be nice to implement a base fee (50kr + pick-off distance + drop off distance) on bonus days, that would motivate us riders to deliver more. Or extend it 1h+ from 17-21hs.
# 10. We need more bonus over the next few days
#
# === Topic 20 (94 documents) ===
# 1. Got pop up about some contest to win a bike mid pickup. Was annoying. I’d love to win a bike. I just want that notification when I go offline
# 2. Same bs: drive for miles and then get offered an almost ready order once you are near enough to the pick up place.
# 3. App lets me drive for miles, then offers almost ready order when I’m close to the venue Insane Miles driven
# 4. WOLT app classic, offer the late order when Courier is around 500 meters from venue. Sometimes I am ashamed to work for WOLT
# 5. App lets me drive for miles, then offers almost ready order when I’m close to the venue. ABSOLUTE JOKE!!!!!!! I hope you understand I often reject orders when the manipulation is too much.
# 6. Please please please stop the manipulation. App lets me drive for miles, then offers almost ready order when I’m close to the venue. It’s super annoying in itself but even more annoying to have just crossed a big street only to be offered an order right behind you where you just came from
# 7. App lets me drive for miles, then offers late or almost ready order when I’m close to the venue. Almost six orders like this today !!!
# 8. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Miles up by 20-30 %
# 9. That there is too too short time to read when you get you order, especially when driving a car
# 10. In my opinion we could have integration with smartwatch for confirming the orders and especially an app designed for Android auto, it would be a plus not having to touch the mobile phone while driving
#
# === Topic 21 (90 documents) ===
# 1. The payement isvery less than normal and the weather was very windy(10m/s) but the payment was less also but according to the support word they told me the info which is given to the application algorithm must increase the payment when the weather changes but this did not happen yesterday Secondly one of the support team called kristina was very unprofisionelle I was very angry and she was just replying sending me this face I do not is that what you train them for or what she was doing Third thing I hope I will not recieve any orders containing alcohol as my account is set for that cause it is a waste of time and effort to no that after reaching to the venue and then cancel the order without getting even a compensation.
# 2. I have delivered more than 2500 orders and I never had a problem, a customer can't find the order and they blame me when someone else could have taken it, since they didn't open the door for me (as happens with most orders, customers don't they open the door) and their decision without any kind of evidence against me is that I am guilty of that and they decide to take my money that I have so hard to earn, because I am not in an office with comforts like you, I am on the street dealing with people, traffic, weather). I think the arbitrary decision they have made is very unfair.
# 3. I experienced multiple times that venues told me orders were cancelled when I arrived, which meant I had to contact support on multiple occasions. Support was really good tho
# 4. If I took orders and delivered them to the client, this order is wrong, I am responsible for it, so it is not fair because it is not my fault if they gave me the wrong order.
# 5. I deliver 1 wrong order in a year and you repay by deducting me. So bad service for your employees. 0 stars and dont recommend. Trust is brokken since you dont have my back.
# 6. It is not the same support that today gets a But Laurits. Laurits is not suitable for the support, we have talked a lot together today, about an error delivery. Which I was ready for and drive back to pick up the order and get it to the right place. Where Laurits writes We have found another solution with the customer Which later turns out to be that it is me who has to pay the order. Wow where is it just a good solution
# 7. One of the support service tried to take 217 kr from my money because of restaurant mistake and I hope some supervisor from Wolt to talk to me .
# 8. My app bugged and it sent me to the wrong address on a bundle of 2 orders, after which support told me i will get deducted for the "wrongly delivered order" even after i told them i delivered everything correctly like it said in the app...Then they told me i have to deliver the mcdonalds order to the same person that i delivered the burger king order, so i did...after that they fine me 400dkk for both orders!!!!?!?!?? After that they say "oh we're very sorry we made a mistake we can't refund you so you have to wait for operations to contact you, i have filed a complaint on your behalf"...what complaint on my behalf i haven't given consent to that i wanna complain myself...i really hope someone from operations contacts me asap because these people scammed me out of my earnings and I'm outside freezing on slippery ice it's totally not fair and unprofessional...
# 9. picking up an order that is just 5 min late from Amager going into the city about 4 km should maybe take 7-8 min But smokes into a queue with road work and traffic accidents 2 km further ahead, my GPS now says that the last 3km takes about 43 minutes, writes to support if you can give my task to a scooter, and I can hand it over to him where I am, despite having been called by Wolt if I could help a car. 6-7 min and my GPS said 50 min, wrote that I would not deliver french fries and an icy order that would be 1 hour delayed, but they could not help, then I had to write they had to pull me and make sure to make the order for a moped/scooter when the order would have been over 1 hour in my car, so they drew 175 kr. Just seemed too poor that you can't make that system in case of such a thing that someone else comes and takes over, so I chose to pay $ 175 alone for the customer's sake, so he would get fresh food and stopped and drove home with a deficit instead
# 10. Vendor concerns are not being heard
#
# === Topic 22 (83 documents) ===
# 1. Payment is not transparent enough
# 2. Increase the payments!!!!
# 3. Bad payments during the week. Please return to the old model
# 4. Be transparent on payment! Prices falling like always!
# 5. Strange with drink money ??
# 6. Transparency and reward of the new payout system
# 7. No transparency!! No deductions!!
# 8. Get back to old payment system!
# 9. Transparency has become low and it doesn't seem like so much is happening in Horsens in 2023
# 10. Payments are getting worse and worse as time goes by
#
# === Topic 23 (82 documents) ===
# 1. Yes I am happy with wolt
# 2. i am happy with wolt
# 3. i am very happy with wolt
# 4. i am very happy with wolt
# 5. I love wolt and the People
# 6. im very happy with wolt
# 7. I’m very happy! I love Wolt
# 8. I'm really happy with Wolt
# 9. i am very happy with wolt
# 10. i am very happy with wolt
#
# === Topic 24 (68 documents) ===
# 1. App stops working for 5-15 minutes. Nothing fixes it. Frequent issue.
# 2. The app is working slow
# 3. The app was crashing when I was trying to send a message to support
# 4. App was slow with everything..
# 5. The app is bad at updating, and I buffering/freezing.
# 6. The software update of the app sucks. The app became slow
# 7. The recent update sucks... The app get freeze everytime
# 8. My app it's already updated, why I'm still receiving that annoying splash screen??
# 9. The app is very slow to load and make a little.
# 10. The app freezes and has to be restarted Too many delays in Non busy hours.
#
# === Topic 25 (66 documents) ===
# 1. no have orders.. i'm going home
# 2. no have orders? i go home?!!
# 3. If there are no orders i go home ?? I thought I'd work late but? No orders
# 4. no orders, I'll be home by 10 min
# 5. I'm out working I want orders??
# 6. if there won't be any orders today... I'll switch off early... if there are any orders for me I'll work late.. it depends
# 7. ???? Orders? if there are no orders I'm going home ?
# 8. no have orders?? i go home!!?
# 9. if you won't give orders I'm going home?
# 10. I'm going home??? it is OK no have orders
#
# === Topic 26 (64 documents) ===
# 1. It was an "amazing" evening with 4 orders and 285 dkk in 3 hours from 16.40 to 19.40, worse than in a quiet evening
# 2. 3 hours online,3 orders,160dkk,53 dkk per hour,very bad.
# 3. I decide for myself when and how long I want to work. If I work Friday to Sunday from 17 to 20 I am guaranteed DKK 110 per hour. If you have more orders and constantly orders are your hourly wage 150+
# 4. 90 dkk per hour gross is worse than I thought, I can't survive on this amount
# 5. disrespectful to pay a double order 32 dkk. rain and Sunday .. a disaster that you are so greedy.
# 6. Two and half hours 150dkk!!!
# 7. 40 DKK per hour is great record, so I will be very thankful if you not try improve it
# 8. 3 hours on the street, 4 orders, 260 dkk, normal status 90% of the time
# 9. This is annoying.5 hours of work,made less than 400 dkk.this isnot how u are suppose to keep people working for you
# 10. 6 hours .................. DKK 78 to laugh again

# %%
from collections import defaultdict
import random

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = 21
docs = topic_to_docs.get(topic_id, [])

# Filter documents with max length of 50 characters
filtered_docs = [doc for doc in docs if len(doc) <= 156]

if filtered_docs:
    sampled_docs = random.sample(filtered_docs, min(45, len(filtered_docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic 21 (90 documents) ===
# 1. I will be sent to orders and when I arrive at the specified place, the order is canceled and I will not be compensated
# 2. The oodren disappeared eftee 10 sec only not taking it
# 3. Could not mark items as delivered 3 times? Do I get money for waiting for Wolt support?
# 4. Canceling order is not working. Error Code: Task.Body.order_cancellation.Error.geofence
# 5. When you pick up an item to a customer, you should be allowed to deliver the item before picking up another delivery you have said yes to
# 6. Works like a charm. Just need to notify the courir when 2 orders are coming in at tye same time
# 7. I am still being penalized for notifying a work injury
# 8. Accellated automatically orders
# 9. Automatic cancel the order
# 10. Vendor concerns are not being heard
# 11. I was punished on a job and instruction that I followed from support
# 12. My order disappeared without me being informed that it had been canceled
# 13. There one who drove into my taillight while I was parked with a customer. Have taken pictures but yes:/
# 14. There should be an option to cancel an order without contacting support.
# 15. Someone stole my front light while I was picking up a delivery. Kinda annoying and I need to get another before I can work in the evening.
# 16. I spent a lot of time and energy on an order that had already been picked up that I couldn't cancel myself. I had to wait s long time for support to do it.
# 17. You gave me an order that was already picked up and did not want to give me compensation. Extremely unacceptable
# 18. I couldn't cancel the order myself, I had to cancel through support even though I had 3 cancellations left, the resturant will take 11+ minutes.
# 19. Cancel order button not working still. McDonalds Randersvej still can’t pack an order properly, drinks are not closed, bags are open.
# 20. I don’t have any problem with good manners, but when I ask support to cancel my order, just cancel my order and don’t say hello or done, it’s unnecessary
# 21. why don't you make the cancellation of orders automatic again... I write to the support.. they remove it after 10 minutes
# 22. I still can't get the "cancel the order" system to work
# 23. Today wolt deduce me 175dkk for a mistake that i tried to fix. I need to speak with a supervisor
# 24. I did not get £ 45 on order which I have handed in and support will not understand
# 25. Youtake money off from your staff even when it is not their fault
# 26. A support member ruined an order and made me loose 1hr of work ( peak hour 18h40-19h30)
# 27. One of the support service tried to take 217 kr from my money because of restaurant mistake and I hope some supervisor from Wolt to talk to me .
# 28. For one order I delivered wrongly 63kr wolt deduct me 175 kr robbery ,wolt 0 responsibility, suport 0

# %%
topic_to_docs

# %% [markdown]
# ## Zero shot classification

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

sequence_to_classify =  " ".join([word for word, _ in loaded_model2.get_topic(1)])

# Our set of potential topic labels
candidate_labels = ['earnings or income', 'waiting', 'bundle deliveries', "wolt support"]
classifier(sequence_to_classify, candidate_labels)
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use mps:0
# {'sequence': 'good happy wolt thank work day job love great flexibility',
#  'labels': ['wolt support',
#   'earnings or income',
#   'waiting',
#   'bundle deliveries'],
#  'scores': [0.6058537364006042,
#   0.2803512215614319,
#   0.09101628512144089,
#   0.022778760641813278]}

# %% [markdown]
# ## Merge topics

# %% [markdown]
# Based on the inspection of topics, it looks like the following topics can be merged
#     - topic 2 + 13 + 25 all are about not enough orders / tasks
#     - topic 0 + 23 are both about satisfaction of working with Wolt
#     - topic 8 + 15 + 24 are all about the apps functionality
#     - topic 9 + 12 + 17 + 18 + 26 are all about earnings / pay

# %% [markdown]
# Now a create a dendogram which clusters the algorithm find the closest

# %%
loaded_model2.visualize_hierarchy(custom_labels=True)

# %% [markdown]
# confirms that 15 + 8 + 24 are close to each other (app functionality)
#
# confirms 0 + 23 are close to each other and very distinct from the rest.
#
# confirms that 9 + 18 + 12 + 17 are close, but 26 is not really. However it would suggest 3 goes in as well, which after inspection looks ok. Further 22 could go in as last, but this have more with payment model to do.
#
# 2 + 13 + 15 are all in the same area of the plot, but not connected as first links.
#
# Furthermore the dendogram suggest the following topics could be merged:
# 1 (restuarant making wrong time estimate) + 4 (Mcdonalds problems (often being late)). This could make sense, but it could also make sense to keep McDonalds seperate. Senere kunne 11 så blive merged på, da det handler om steder med burger. I alt kunne disse tre topics samlet handle om arbejdet med venues.
#
# 5 + 14 giver ikke mening at merge
#
# 6 + 21 giver ikke rigtig mening, da 21 er for mudret.

# %% [markdown]
# ### Automatisk reducering + manuelt efter

# %%
# Createas a identical model called reduced_model, which is a copy of the loaded_model
# I'll use this to reduce the number of topics in the model, while keeping the original model intact
import copy

reduced_model2 = copy.deepcopy(loaded_model2)

# %%
# First I try with automatic reduction
reduced_model2.reduce_topics(documents, nr_topics="auto")

# %%
reduced_model2.get_topic_info()
# Out:
#     Topic  Count                                       Name  \
# 0      -1   4118                     -1_order_time_wolt_app
# 1       0   1064              0_ready_wait_restaurant_order
# 2       1    915                    1_good_happy_wolt_thank
# 3       2    874                   2_order_hour_pay_earning
# 4       3    671                  3_app_order_work_app work
# 5       4    435                 4_km_distance_delivery_pay
# 6       5    371            5_courier_new courier_new_order
# 7       6    331           6_support_wolt support_chat_team
# 8       7    322                   7_map_address_google_gps
# 9       8    269                       8_bag_drink_pack_cup
# 10      9    158                        9_wolt_hour_kr_work
# 11     10    146            10_task_task task_new task_time
# 12     11    138  11_wolt_wolt market_market vanløse_market
# 13     12    122           12_bundle_bundle order_order_pay
# 14     13    114         13_price_low_low price_price order
# 15     14     95       14_bonus_weekend_weekend bonus_order
# 16     15     90            15_support_order_deliver_cancel
# 17     16     83  16_payment_new payment_payment system_new
# 18     17     82        17_wolt happy_happy wolt_happy_wolt
# 19     18     66        18_home_home order_order home_order
#
#                                        Representation  \
# 0   [order, time, wolt, app, work, delivery, pay, ...
# 1   [ready, wait, restaurant, order, food, time, m...
# 2   [good, happy, wolt, thank, work, day, job, lov...
# 3   [order, hour, pay, earning, low, order order, ...
# 4   [app, order, work, app work, time, offer, dkk,...
# 5   [km, distance, delivery, pay, driver, drive, c...
# 6   [courier, new courier, new, order, order couri...
# 7   [support, wolt support, chat, team, help, bad,...
# 8   [map, address, google, gps, location, app, map...
# 9   [bag, drink, pack, cup, food, paper, spill, so...
# 10  [wolt, hour, kr, work, pay, money, day, kroner...
# 11  [task, task task, new task, time, accept task,...
# 12  [wolt, wolt market, market vanløse, market, va...
# 13  [bundle, bundle order, order, pay, task, order...
# 14  [price, low, low price, price order, order pri...
# 15  [bonus, weekend, weekend bonus, order, bonus w...
# 16  [support, order, deliver, cancel, customer, de...
# 17  [payment, new payment, payment system, new, sy...
# 18  [wolt happy, happy wolt, happy, wolt, love wol...
# 19  [home, home order, order home, order, go home,...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [I had an unacceptable experience at McDonald'...
# 2   [I'm very excited and happy to work with wolt,...
# 3   [There are not enough orders at all., There co...
# 4   [App crashes. App lets me drive for miles, the...
# 5   [You say it is 0.1km ekstra but actual distanc...
# 6   [Few orders for too many couriers, No orders!!...
# 7   [Haven't used Wolt Support, so is still uncert...
# 8   [It would be nice to be able to copy the adres...
# 9   [Please do something about the bags. Big proce...
# 10  [I remember when Wolt gave you the backpack, a...
# 11  [Too much waitig for next task, Because i alwa...
# 12  [I also want to order Wolt Market in Vanløse o...
# 13  [Why the system give bundles when there are no...
# 14  [The price is too low sometimes, I can’t see t...
# 15  [You should put a bonus for weekends 23to02am,...
# 16  [I had the order 7J5DV3, in which the app sent...
# 17  [More openness about the new payment model, Th...
# 18  [i Am very happy with wolt, i am very happy wi...
# 19  [going home.. no orders for me, I'm going home...

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = reduced_model2.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = reduced_model2.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: ready, wait, restaurant, order, food, time, minute, burger, mcdonald, mark
# Topic 1: good, happy, wolt, thank, work, day, job, love, great, work wolt
# Topic 2: order, hour, pay, earning, low, order order, bad, salary, get, time
# Topic 3: app, order, work, app work, time, offer, dkk, error, drive, mile
# Topic 4: km, distance, delivery, pay, driver, drive, car, money, payment, long
# Topic 5: courier, new courier, new, order, order courier, hour, hire, courier order, work, money
# Topic 6: support, wolt support, chat, team, help, bad, wolt, support team, good, contact
# Topic 7: map, address, google, gps, location, app, maps, wrong, google map, google maps
# Topic 8: bag, drink, pack, cup, food, paper, spill, soda, order, customer
# Topic 9: wolt, hour, kr, work, pay, money, day, kroner, low, night supplement
# Topic 10: task, task task, new task, time, accept task, accept, new, disappear, hour, receive
# Topic 11: wolt, wolt market, market vanløse, market, vanløse, danish, order, copenhagen, denmark, hour
# Topic 12: bundle, bundle order, order, pay, task, order bundle, accept, payment, new, system
# Topic 13: price, low, low price, price order, order price, order, price low, double order, double, rate
# Topic 14: bonus, weekend, weekend bonus, order, bonus weekend, bonus time, 17, time, remove, today
# Topic 15: support, order, deliver, cancel, customer, deduct, ask, tell, mistake, say
# Topic 16: payment, new payment, payment system, new, system, old payment, model, old, payment model, transparency
# Topic 17: wolt happy, happy wolt, happy, wolt, love wolt, wolt love, love, yes happy, wolt yes, thank wolt
# Topic 18: home, home order, order home, order, go home, work late, order go, go, order order, think work

# %% [markdown]
# Now there are 19 topics.
#
# From inspecting the topic representations and documents in each topic (see further down), I have made the following assessment
#
# Topic 0: Problems with restaturants (especially being late) = cooperation with venues
#
# Topic 1: Satisfaction of working with Wolt (also a few negative)
#
# Topic 2: Order and salary (two different things, but closely connected)
#
# Topic 3: App functionality
#
# Topic 4: Something about distances in relation to earnings and vehicle
#
# Topic 5: Too many couriers (and hiring new couriers), but some more express they don't care about courier or bad earnings. Too many couriers can also easily be linked to low earnings or too few orders
#
# Topic 6: Wolt support
#
# Topic 7: GPS tracking, google maps, and addresses
#
# Topic 8: Wolt bag, and how restaurant pack/seal the food
#
# Topic 9: Bad earnings
#
# Topic 10: mixed in relation to taks (too few tasks, some where task is just mentioned but about specific problems or frustrations).
#
# Topic 11: Random topics, where city names are included.
#
# Topic 12: Bundle orders
#
# Topic 13: Low prices (some about new payment model). Prices is related to earnings.
#
# Topic 14: Bonuses (either in relation to pay or schedule)
#
# Topic 15: Lidt rodet topic. Men handler bl.a. om a acceptere / annullere ordre samt unfair penalties og mangel på kompensation når der er sket fejl
#
# Topic 16: Low paypment + some comments about a new / old payment system
#
# Topic 17: Happy with Wolt
#
# Topic 18: No orders (couriers go home)
#
# --------------------------------------------
#
# The folliwing would logically make sense to merge
#
#  1+17: satisfaction with Wolt
#
#  2+5+9+13+17+18: earnings / too many couriers / orders / prices / pay

# %% [markdown]
# I inspect the documents

# %%
# Get topic assignments for each document
topics, _ = reduced_model2.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Iterate over sorted topic IDs
for topic_id in sorted(topic_to_docs.keys()):
    docs = topic_to_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))  # Randomly select up to 10 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
# Out:
# === Topic -1 (4118 documents) ===
# 1. The app works very badly. Often gets error messages when I have to enter "Items picked up". It causes i have to restart the app, which is very stressful when i'm busy
# 2. No orders. Not okay when earnings per order has gotten so shit....
# 3. Since the update of the payment, the waiting time for a task grew a lot, even in peak hours. And today I couldn’t mark my order as picked up from venue, even though my internet connection was fine. The problem was occurring for the 5 mins
# 4. Wolt application crashed
# 5. médium but no have orders?
# 6. Not enough deliveries
# 7. Hi, When I get drive orders every individual item in the order has to be marked off. For my current order there are 20 items to mark off. That is too much, and they don’t even have meaning, it’s just “parcel one”, “parcel 2”, ect… Could it be made easier ?
# 8. I took an order from a place, and when I arrived, they told me that the order was to pick in an hour from that time. If wolt allowes to the people to order on a specific time, they should write somewhere in the task so the courier can know and reject it if it’s not useful, or they should send the task to the courier when is going to be ready, not one hour before, because I lost time going to the venue and also I got no compensation for it. For that time wolt support was really slow and took 15 minutes to unassign the task. Really disappointed today
# 9. I get order from kiin kiin restaurant, when I arrived to the restaurant it was closed , I wrote to support and they said to me the restaurant is open , I told support the restaurant I closed and sent video to the support but they told me that not true . I road 2,5 km free . Always give us wrong addresses and wrong names. The support today was very bad
# 10. I took an order, the payment shows 25 crowns, but in the end I was paid 23, so in the end the payment can be lower, 23 crowns, you don't even buy a pack of toilet paper these days
#
# === Topic 0 (1064 documents) ===
# 1. I am still unhappy with MCD on Østerbrogade. Contact me on phone 42 92 81 73 if you want it elaborated.
# 2. I spilled 25 minutes at American House. When I pointed out that they can book in after that when they are in a hurry, I just got rid of the food being ready when they reported it ready. Maybe you should get a consultant to explain to them how Wolt works! I probably won't take an order from there again.
# 3. This is how it should be ALWAYS something to do and the restaurants were fast today, especially Mc Donald's
# 4. The woman in 7/11 Sjælør station is really rude and antagonist. Second time I had a bad experience with her. Tonight when I came to pick up the order. She told me to swipe before giving me the bag and ask if l have more. I did swipp before getiu the order which it's not normally this way.I told her she first needs to give me the bag and then I will swipp in front of her . She started to shout at me saying I'm not listening to her. I told her I will report her to Wolt support. She said pls do. Really an unpleasant person that looks she hate her job and people in general
# 5. It is confusing how the names of restaurants are described. E.g. Lagkagehuset is not called Silkeborg LKH I thought it was another restaurant and it took me 10 min by running around
# 6. I would like to know Why we got the orders one by one specifically when we get tow or 3 orders from same restaurant We lost waiting time when we get the orders one by one we will wait 5-10 minutes For every order Best regards for all
# 7. People working at McDonald’s Frederiksberg don’t answer when we ask for the food. And when they do, they treated me disrespectfully
# 8. DL CHICKEN should be closed they clicked rdy on 3 orders and non of them were nearly done 2x 25min 1x15min I will never deliver anything from this place sadly staff is extremely rude when you asked them why they click rdy when the food is not rdy they tell you to fuck off and they are extremely racist and am white btw....
# 9. Again the counting down when we pick up food, it’s a shit!!!!
# 10. Otto pizza Strandslosvej and jagger Strandslosvej always marking order ready when the food is not ready. This is annoying y for the couriers
#
# === Topic 1 (915 documents) ===
# 1. I would like to know why Wolt was very obsessed with adding partners all year, he doesn't care about his partners, he just wants money..
# 2. Not much happy. I am full time with wolt to earn money for family but I can't. Whenever wolt offer me for long ride. Nothing in the back and I have to use my same time to back to original position. From now I think I have to search for other job as well. I was expecting to be with you only but.....if you have anything for me. Feel free to contact.
# 3. Yeah i am very happy
# 4. For first day it is perfect
# 5. Hello I am starting again at 3rd of August, as I did for the last three years I took a little vacation (two weeks) and I am coming back with force . Thank you for your support.
# 6. i am so glad to work with wolt
# 7. Working for wolt is great!
# 8. HORRIBLE AS USUAL !!!
# 9. It very bad for the time being
# 10. For now in wolt partner is fine but the weather is sometimes is very bad but in all is work is not going be easy like that
#
# === Topic 2 (874 documents) ===
# 1. You cheat us, put wages down etc
# 2. It is under all criticism that the payment on orders is reduced again and again ..
# 3. The payouts are way too low
# 4. Pay is 30-40% less than 2 years ago.
# 5. Unfortunately extremely few orders
# 6. Almost 2 hours online 0 ORDERS, Sunday evening, it's humiliating It's been as bad for many months, very little earnings, very few orders, many kilometers traveled, in conclusion, not satisfied, it's very bad.
# 7. Since at. 11 with 2 orders?
# 8. Poco Picante at H.C.ØRSTEDSTEDSEI WHOLE DELIVERY - MUST WAIT 29 MIN ON ORDER IN BOOST PERIOD… .
# 9. It was really awful, the performance of the program and the distribution of orders. I was active for more than 10 hours today, and I moved to many places in the city center and order centers, but I got the least amount of orders.
# 10. Few orders. I need more time for the same money
#
# === Topic 3 (671 documents) ===
# 1. 12 hours 1500kr Friday busy very worst
# 2. App doesn't respond sometimes forcing me to shut it down multiple times which makes me waste time
# 3. App is not good. Each time I take an order, the order is not approved after which there is "system error". It happens almost everyday. In addition, the app does not count mile correctly. There are several times when I wasn't paid for what I should. Even when I write for support, they think the app is 100% correct.
# 4. sometimes the app doesn't work properly,has errors,delayed to response,waiting time for order is too large(more then one hour)even if the status are normal
# 5. The app is malfunctioning. Majority of the time i was getting errors when trying to accept a task. And times where the app freezes, where I had to close the app then open it again for it to run.. I got many long distance orders that where the only ones I could accept when the app was malfunctioning. And where unlucky not getting bundles on the orders that where +15-20 min late, on a busy day.......... really hope this gets fixed very soon...
# 6. I find more and more often that the order is not ready even if it is in the app or that there is just a very long wait at pickup location. There is nothing you can do as a bid than to cancel an order, and then it just goes on to another bid, not very sympathetic. I hope there will be some compensation for lost working hours
# 7. Dissatisfied. Every day paid in minor.din app doesn't work well.
# 8. Laggy app,not precise. Low wage
# 9. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Such a joke.
# 10. Problems with app on my iPhone 7
#
# === Topic 4 (435 documents) ===
# 1. Hi, The combo orders pay so less that it seems not worthy to take combo orders because a lot of time and effort has to made to collect and delivery the order. The restaurant also take our valuable time. please consider our efforts who works with cars and go for long distances with multiple orders .
# 2. Delivery don't pay much
# 3. I still can't see the distance I travelled under stats!!! It's been 3 weeks now
# 4. That Wolt cargobike should be free
# 5. The offered fare and mileage do not match the delivery details.
# 6. You run 3 km and want to Anuller Odds You get no compensation for aging is not ready and Ma n has to wait more than 30 minutes to get the oodren it is not very very far out
# 7. I’m over 1000 km today, my normal for a month. But nowhere near my normal income. Absolute disgrace.
# 8. Boring final spurt, my second last delivery was a packed delivery with my third last, the germ as being +0km which I think it must be a neighbor or similar to find out I had to drive 1.5 km extra, I then write to supporter as I expect a compensation, where after I get a hell of a lot of rules about combined delivery and everything Really a pity for you.
# 9. 50 km driven for 650 dkk. Looks like a 40-50 % increase in miles driven on a monthly basis
# 10. many orders are very cheap compared to the kilometers we have to travel
#
# === Topic 5 (371 documents) ===
# 1. There are still too many couriers on the street and I see new ones all the time, it ruins the earnings for all of us that way. Stop taking more in
# 2. They pay is so bad that couriers begin stealing the orders. Set a minimum price per order! No less than 35 kr
# 3. I went out to work .. and there is nothing .. there is an area but no orders .. what's going on .. in one hour an order ... vir you are obliged to provide us with orders ... and vir what are you doing? you release 100 couriers.. and so there is no work
# 4. Hey Wolt team, We as Wolt courier partners in Naestved city want to complain about new drivers that show up every day in the city and drop our earning income please stop accepting new drivers..
# 5. I noticed today when started being in line at 17 that's there is no bonus. I found out you changed the time due to summer clock from 18-21 instead of 17-20. When i wrote to support What is the reason we were not i formed in advance via a newsletter ( you normally update any changes or news by a newsletter) he didn't answer my question and just repeat it was changed. Then wrote you will take an appropriate actions. I would like to get an answer - why you didn't inform the couriers? You used to have an honest communication but since the new modul something changed for the worse in the attitude- less caring, less in communication.
# 6. Nearly always “quiet” even in peak hours. Wolt messages close to every day where there could be many orders, so a lot of couriers are getting to work, which means “quiet” again. The 170dkk or 200dkk whatever it is, average hourly rate is not at all true. You can easily be at work for 30min to get 40dkk or even worse, 0 orders at all.
# 7. Why there is no action about courriers that using 2 accounts in same time?? I saw a few courriers that doing this in Roskilde. Isnt it illegal?? Also unfair for us!!!! Is it hard to follow accouts location match??
# 8. It's time to raise tariffs for delivery and, accordingly, remuneration of couriers
# 9. There are too many couriers for the number of tasks in Odense. I’ve always loved this work for the past 3.5 years but this is by far the worst it’s ever been in terms of earning opportunities
# 10. many couriers, slow order fulfillment
#
# === Topic 6 (331 documents) ===
# 1. With the quick response from support team it makes task easier
# 2. To many new courriers
# 3. if the Client does not get in touch and does not respond, the support service takes a very long time to make a decision or respond to a message, which really spoils the work with your application and I and the next clients have to wait for half an hour if I have several orders with me
# 4. Wolt Support is the best in the world!
# 5. Masho, close every time the chat until you finish what you need to say!
# 6. i will be back soon on every manday, Thursday, Wednesday
# 7. Disgusting support but they're wrong if thinking that this unprovoked negative attitude touches me only. The sooner they finish, the better for all??
# 8. Good to know and I will be back next month hopefully from 17 October
# 9. Support was slow to respond, so I contacted Danish support, which I saw was now possible. They responded quickly and removed the current task. I get new order and take it. Then when I arrive at the new location, I see it's been cancelled by the original support request. I know I should have written in the original support chat, that I no longer needed help. But it's the first time I try this new support system. It really should warn you if you try to open a new support chat, that there's already a support chat open, and possibly ask if the other(s) should be closed.
# 10. Very poor response from support team, my two issues are still pending
#
# === Topic 7 (322 documents) ===
# 1. Hi. I am having a great experience. There is just one small problem. Wolt just keeps sending notifications, saying that we can't acces your device's location. I make sure I gave the permission to location.
# 2. Sometimes I can't see myself and the destination on the map simultaneously (after tapping the little blue icon in the bottom left corner). This is not ideal.
# 3. There is an issue with navigation to Google maps where it most of the time shows the wrong address, not the one stated in the order
# 4. Old app issues are back now. Thanks for that. App disappears from last used app list, throwing out of full screen in google maps. Support section hasn't been improved, but it should've been.
# 5. The map often points to the wrong building
# 6. Gps house number not precise
# 7. Route view on the app would be weird
# 8. Info about customers is good , but the map is confusing. “Google maps “ is more convenient, maybe there is a way to use it instead
# 9. The gps was.all.over the place because of the construction work on Rantzausgade and the clouds I guess
# 10. Hi, I don't understand why my location doesn't work. I try log on to another phone and it was the same situation. Then my wife open she's app everything working good and many deliveries was coming. I'm confused because I can't working. Can you check what is happening
#
# === Topic 8 (269 documents) ===
# 1. Mcd needs to get a better way of packing their drinks. They put it in a paper bag and then if it tips over it spills all over your bag. Either they need a cup with a screw on lid that is tight as a bottle or maybe use some foil under the lid (like a juice from eg. joe and the juice). We ride on all sorts of surfaces incl. cobblestone and also has to reach down to lock our bikes now and then. It can also happen with the food in other restaurants and that is almost worse since your bag smells and are hard to clean when you get home. So in general to demand a higher standard for the packaging would make the couriers happier and give the customers a better experience (by that I mean no ruined food or half portions) The map in the courier app has 2 small flaws. 1, the pickup, delivery, and courier mark disappear at the bottom (if in centered/update mode)where the order details can be swiped up. This can make it hard to guess where you are. 2, when you get really close to your target the map is to zoomed (in centered mode). It would be nice to be able to set a max zoom distance/min visible area in the settings
# 2. Rest didn’t seal container so have to get bag cleaned
# 3. McDonald's needs to have better cup holders. They're so unstable, even if I put the drinks to the back of the bag and press the meal against it to wedge it in, when I accelerate, due to the contents of the delivery bag shifting, the drink topples. The should also have better lids to insure that the drink doesn't spill
# 4. App: - Can't see drinks at menu positions - Not all "dots" with venue/customer address on cards can be seen in parcel assignments. Restaurants: - Pitato Potato marks orders ready several minutes before they actually are.
# 5. I broke food, don't know or it is my mistake or food was packed not well
# 6. Mcd cardboard mugs for soda they should sell cans to wolt
# 7. Joe and the juice spillage. Unusual for the vendor.
# 8. I picked up a piece of furniture from Babysam in Østerbro today, which was very, very heavy in two large boxes. I had to put the back seat down in my car to make room for it, and I could only carry one box at a time. It's not something we have to drive in a regular passenger car where the goods need to be lifted up in a trunk, you have to have a bag and a van for something so big and heavy! The staff also looked at it doubtfully, saying that it was the first time they had picked up something as heavy as the furniture with Wolt. Get it stopped before things go wrong, please!
# 9. Some fast food joints should start packing drinks better, it’s not a big issue, but the drinks are dripping, and the acid from the soda damages the bag, which we have to pay ourselves. Also, customers might think the drink is spilled if they see some drops running down the cups. Burger King, Carl Jr’s and a few other ones. In other countries a layer of plastic is put on the drinks. Also. It’s been pretty quiet. Please don’t hire too many couriers.
# 10. MacDonals'd soda wasting too much
#
# === Topic 9 (158 documents) ===
# 1. Strange choice of times for booster on earnings. I experience a good support and I myself am fairly satisfied. But I get tired of hearing about the many bad experiences that others have with Wolt. Wolt has become known as the blood -sucking occurrence. Pays too bad and sucks money out of small restaurants. I hear almost only badly about Wolt.
# 2. the only problem I have is that I spend a lot of hours and go to the volt every day, plus I also consume a lot of diesel and the profit on some days is very low, I can't say that the daily profit is low, but on some days it is very very low !!!!
# 3. 150 kr/hr today. Not too bad for a Thursday.
# 4. I dedicate my time full time to Wolt and I often feel that the company does not support people like me. The latest notification of bonuses for inactive people made me feel very bad because it is money that would really help me.
# 5. Impossible to make any money due to ur overhiring issues 60min no orders in peak times nah
# 6. it wasting time now i earned 1100 Kr from 11:00 to 20:25 and 112 km it's better to work Normal work i saw many new partners but i don't know how you estimated
# 7. There nothing low, I have won for the task That stand normally .......
# 8. I could not make 160 kr per hour.
# 9. I don't know why they put so many people in the company, now there is very little work for everyone
# 10. I remember when Wolt gave you the backpack, also the clothes, I remember when Wolt paid a minimum of 35 crowns per order, I remember when there was real work, when it was profitable, now it is a capitalist company exploiting the poor people who have to provide their own vehicle , go through cold wind and rain, they manage not to pay for vacations, let me tell you that ambition takes man to a dark place..
#
# === Topic 10 (146 documents) ===
# 1. Gets too little tasks
# 2. Lately the waiting time between tasks has increased and there are no more busy hours. Today we got the status “Normal” only for a few minutes.
# 3. 5 hours, 3 tasks, less than 200 DKK, pure conditions
# 4. You have too many employees for no tasks
# 5. You give me task in other zones, fuck off
# 6. In the past few days there have been a few tasks
# 7. 8 hours only 4 tasks
# 8. Accepted a task. Biked there. Task no longer there. Wasted time and effort.
# 9. I am not receiving task
# 10. I've been waiting for two hours, but the task has not arrived
#
# === Topic 11 (138 documents) ===
# 1. I also want to order Wolt Market in Vanløse ote
# 2. Too few orders. I am surprised that Wolt is advertising on social media to get more messes up to deliver food when there is not even work enough for the messes that are currently employed
# 3. I like the Danish support more then the forgrener one. I m saying that ad a foreigner. The Danes are more friendly and effective. Much Dalit
# 4. Sideechick Nørrebro.
# 5. There are too many empty hours in copenhagen; wait a lot to get some order ; that’s the unique reason to put this point on the feedback. If wolt Copenhagen is full time busy will be better for ppl who like to have this job like a full time
# 6. I don't get orders from the area i used to get before. And it's being happening from december. Now I get orders only if i come outside of my house and reach close to the central Copenhagen. not from the restaurants surounding my home.
# 7. Wow,the best work place ,the vest experience,I mean 287 kr in 4 hours of work...omg Denmark it's not ready for this
# 8. 40 kr Svanemøllen 40 kr Vesterbro This is how the hour runs And there is everything to run, but comes something? No Just cheating ..
# 9. Friday, in Aarhus it rains and there are no orders, I have been doing wolt for 2 years and I have never seen so many partners on the street
# 10. 1 order of 1.5 hours in Nykøbing Mors
#
# === Topic 12 (122 documents) ===
# 1. Some of the bundle pays are down, less than 25 kr. Please reconsider this, often short deliveries are to top floors with no elevator, and can be heavy, and the orders are also subject to delays, just like other orders…
# 2. Fuck you all and this shitty payment system and shitty bundle orders. Got tre orders at the same time but still Disney egen manage to hit over 200kr. Before you could. Also. Why the fuck do i get an order that only 100m but pays 87kr. But an order on 6+ km is only 86kr?! U idiots
# 3. Many hills that take a lot of extra time I don't feel counting in earnings versus the orders that are very close to the extradition sites
# 4. Very bad now bundles system gives less money tolk lot of rider every one unhappy
# 5. 1) The pay per order has only decreased since the new payment system. 2) bundles pays often so little that they’re not worth doing. Below 30 kr. Is too low. 3) a lot of venues marks orders as ‘ready’ without them being ready for pick up. 4) should be faster to cancel an order you have accepted but can’t pick up. Fx if you already got an order in the bag, that takes up half the space, so you accept a new one to fill out the bag, but the new takes up more than half of the space. So you can’t fit in the bag, and now you need to wait a long time for support to remove the order.
# 6. Make bundle orders worth taking!
# 7. Tonight I accepted no bundles, which I always did in the previous means of payment, since in the new payment model I can no longer see that it can answer. Of course, it is sorry for those customers who wait or receive cold food that I no longer take bundle, but the information about the new payment model is at that point quite poor
# 8. 1-bundle mode second order payment is very low. 2-there are too much couriers in small city like Roskilde. 3-Earnings decreased.
# 9. No orders for me. You shouldn't give bundles if it is quiet
# 10. The proposed Bundle Order from Menu and Cafe K I rejected was unfortunate. They should have been beaten up as 2 separate orders.
#
# === Topic 13 (114 documents) ===
# 1. Really low prices for orders.
# 2. I can’t see the price
# 3. New task fee calculation system is very bad and unfair
# 4. I don’t see the price of the tasks
# 5. We now get scammed on double orders and instead of moving these money to single orders, you have chosen to also lower those single order fees with 5-10kr as well. Not worth the hard work anymore. And double orders made the work fun before, now it makes you annoyed instead. I
# 6. the wages are low, it needs a little more improvement and the calculations are not done correctly, the orders received in double should be calculated from the point where they are received, not from the point they are given, then it would be a little better
# 7. You have been putting the prices lower and lower... Thanks a lot.
# 8. The cost per order is too low, it needs some improvement, double orders are so meaningless
# 9. Hi Support You can't join prices down the heroine. Prices are too low
# 10. New dutyfee calculation system is super unfair
#
# === Topic 14 (95 documents) ===
# 1. CHEATERS!!! FALSE PROMISES THAT BRING HOPEFULS OUT TO DELIVER ONLY TO HAVE THE ORDER AMOUNTS MANIPULATED BEFORE ACHIEVING THE TARGET NUMBER. IT'S NOT A COINCIDENCE HOW THE ORDERS STOP COMING IN SOME TIME BEFORE 8 AND COME BACK AFTER THE BONUS PERIOD. OLD TRICKS BUT NOW EVEN MORE DEVIOUS WITH THE "BONUS"
# 2. The bonus, is a fake there is no bonus. I’m completely disappointed
# 3. Holiday money would be fantastic
# 4. I don't understand the 16:30-19:30 period for the extra bonus. There are way more tasks from 19:30 to 20:00 than from 16:30 to 17:00, especially on a Friday. Saturday and Sunday might be different. Also support really dropped the ball today. 16 minutes to remove a task?! Seriously? That messed up my 13 tasks which I could have still easily done. Not being able to make an extra bonus because venues are late is one thing, but because support took 16 [sixteen] minutes to remove a task is unacceptable. That's almost sabotage.
# 5. Everything seems to go wrong this weekend with the estimates of when it would be busy and hence bonus. Anton from Wolt has to go to school again, because it seemed like the times that were not bonus was very busy, while in the bonus time there were not many deliveries. Sunday night after 8 pm in KBH things went completely wrong and it requires L strongly to evaluate how to put bonus time on. For more messes you think you are laughing and it must cost you a lot with all the orders not delivered.
# 6. You can consider put a bonus from 00to02 on weekends
# 7. Pls make so if you make over 100 oders a week you get a bonus or something like
# 8. Me and my friends will not work, because you changed the bonus at 1st January
# 9. Fuck your holiday "bonuses"
# 10. I usually make 40 dkk per order, so 15 orders give 600. Today I got 557 for 15, so 37,11. So that’s where all the bonus money is coming from? Please prove me wrong, but if I am right, this is just another really sad day with Wolt…
#
# === Topic 15 (90 documents) ===
# 1. When you pick up an item to a customer, you should be allowed to deliver the item before picking up another delivery you have said yes to
# 2. Today I had an accident with my motorcycle, where I did not suffer serious damage. but if on my motorcycle, on my cell phone. I am very annoyed by Wolt's solution of deducting 175 dk from me for not delivering the food and realizing that I am a very responsible employee. I did not like how support assisted me. I would like you to look at my case again!!!!!
# 3. I was punished on a job and instruction that I followed from support
# 4. The support is the WORST. I think I will find another job because you do everything to wear away the riders and remembee that wolt exits because of the riders. We always loose. If I deliver a wrong order, its my fault and I have to pay (not the venuen when the responsability is shared) If a venue has 30 minutes of delay, and you drove 10 minutes-2km wasting fuel and time, you loose. You dont have a compensations. You dont get nothing. And when you ask support, they seem monkeys behind a keyboard. They are fast to deduct money from your savings but when you ask something to help you, they always answer another completly different thing. Its impossible like this. I want to make a complaint and support told me that this form is a complaint. And no its not. They are liars. A good company dont have liars in their team specially when they have conctact with “providers” as we are. Wolt is sucking in all ways. Is not a good place to work specially if you are a courier. You are alone. Nobody supports or take care about you. I am guessing is anyone will read this and reach out to me. Don’t think so. I know that this is all for nothing…
# 5. negative rating from support because they withheld funds from my earnings due to alleged non-delivery. I delivered the order exactly to the address indicated in the order. I couldn’t make a mistake with the apartment, since the order indicated “stuen”, without specifying whether the apartment was on the right or left, and there was also only one “stuen” button on the intercom! my opinion is that the client decided to cheat by sending his girlfriend to receive the order (who, by the way, was already waiting for me on the landing after my call on the intercom)! I understand that the amount of 44 kr is not that big, but the very fact of fraud haunts me and you play along with it!
# 6. I went to a store and the employeer said to me oh another courier took your order so , i think some other guy took it and delivered and marked complete and now i have to take the charges of it and the other person nothing
# 7. I experienced multiple times that venues told me orders were cancelled when I arrived, which meant I had to contact support on multiple occasions. Support was really good tho
# 8. They deducted money from me for a mistake I did not do, and I was also unable to complete my work for this reason It’s not an acceptable, sorry. Why should I pay for the resturant mistake?! I received the order from the resturant after I let them control my mobile (they saw it), then I delivered it. How can I know the in package details?!
# 9. I mixed up two orders. But I was able to go pick up the order that I had delivered incorrectly and exchange them and have both orders delivered correctly within 10 or 15 minutes. But the support service just calculated a fine for me. And she didn’t give me the opportunity to do it right. Now this money is very important to me. And I think what the support team did was wrong.
# 10. Support: I got reminded that per the Service Agreement waiting times are not reimbursed. Who even asked for a compensation? An acknowledgment and some understanding would have sufficed. Great support, really App: I get a bundle (which it's great) but I get to deliver the last order - just groceries from Spar - first instead of warm food?! And it's not that was really closer either. Not a great way to take care of our customers. The warm food was therefore delivered 30 min later - probably cold by then. Not good
#
# === Topic 16 (83 documents) ===
# 1. Pias og. Payment sucks still
# 2. I would like to get more payments for order , because sometimes I work in very bad weather, extremely strong wind, rain And I don’t get normal payment for this People in 98% don’t give any tips bike sometimes breaks and this also requires spending money and time, so I would like to receive at least 20% more payment for the order
# 3. Transparency and reward of the new payout system
# 4. Bring back the old payment model’s
# 5. Strange with drink money ??
# 6. Increase the payment$ !!!!!
# 7. It's a shame how they are paying. disaster
# 8. I consider the new payment model is not completely fair because is 0 transparent.
# 9. Please Change this pay systeam
# 10. New payment model result in significantly lower payments. It’s frustrating.
#
# === Topic 17 (82 documents) ===
# 1. i am very happy with wolt
# 2. i am very happy with wolt
# 3. i am very happy with wolt
# 4. i am very happy with wolt
# 5. i am very happy with wolt
# 6. i am very happy with wolt
# 7. very happy with wolt
# 8. i am very happy with wolt
# 9. Love wolt now is better than before
# 10. I love Wolt, a thousand thanks ♡
#
# === Topic 18 (66 documents) ===
# 1. going home.. no orders for me
# 2. all day I am 400 kr... if there is no work I will go home?? today is friday but no have orders? for me
# 3. i go home no have orders
# 4. if there are no blemishes, can I go home?
# 5. if there is still no order for me, am I disconnected? and then you'll be looking for me... when everyone gets home in eight o'clock I was thinking of working late... but. if there is nothing, I will go home to the home
# 6. will they have orders or? to go home? I haven't got an order for a long time?
# 7. If no order comes to go home? There is an area no orders?
# 8. no have orders? maybe i'm go home?
# 9. waiting another 10 minutes if no orders .. going home...!!! I can't live without anything!! today is friday..
# 10. if there won't be any orders today... I'll switch off early... if there are any orders for me I'll work late.. it depends

# %%
from collections import defaultdict
import random

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = 5
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic 5 (371 documents) ===
# 1. A lot of couriers and some mistakes of distance payment
# 2. Crazy how we couriers can’t make any money nowadays. Wolt should do something about it and it’s embarrassing
# 3. It was good, however, it has become somewhat worse root how poor food delivery is accepted. Overfilling courier destroys income potential, and the company arrogant approach to the same problem
# 4. Your top priority is scamming couriers and second is delivering orders late on purpose
# 5. Hi I would like to file an official complaint against Wolt Danmark ApS for the violation of its own Employees Code of Conduct Section B, point (1), by failing to provide a fair and accurate financial report, since the company refuses to give a detailed breakdown of the task fees offered to the courier partners. The financial report must include an overview of the various alleged extra fees that the courier partner should receive, like distance-fees, weekend bonus, weather bonus, uphill-fee and so on. Until these are not provided, the courier partner has no option to check if they have received the correct compensation for each task, therefore we can not say that the financial report is fair and accurate. PS.: I am going to send this message every day to the chat support, to the email support, and I will also include it in my daily closing report, until there is change. We are partners to the company, not slaves to it, its time we get treated as such.
# 6. Bad payment. Too many couriers.
# 7. Hire us... For this money u should go and deliver yourself!
# 8. We can't make enough money because there are too many new couriers. Please find a solution to this.
# 9. Very satisfied but they have got too many courier so you don't get many tasks at the moment
# 10. Please stop hiring new couriers
# 11. A lot of couriers delivering
# 12. Your support team is 90% of the time either useless or out of touch with courier reality. They took hundreds of dkk from my earnings just based on a suspicion, just to give them back again after confronted with the truth. Evey restaurant snd courier I've talked to, is 100% dissatisfied with your support team.
# 13. Fix your demand and couriers levels. It’s a damn joke how little I’m getting orders these days
# 14. Too many couriers are working outside the the peak hours, and here is the solution: Divide all couriers into 3 groups. Only a specific group can work outside the peak hours, for a week at a time. All couriers takes part in a 3 week cycle. Evrybody can work during the peak hours.
# 15. You over work all day if you want to survive in advance there is not enough odre even though you have all the couriers enough for many some of us live by it as there is not enough jobs in Randers and they are violent and sexual harassment in Jutland workplaces Male -dominated However, in Kbh
# 16. Hi I have a question please :Number of couriers was smaller in June ?because then we had no time even for a break but now as you see ...nothing please if you can't answer can you forward it? Someone said no relation between number of couriers and number of orders which is not right of course the main reason of the quiet situation is much couriers . S The eating people in a city is almost the same . We need to know specially we the old ones to know to continue or not morning and day shift if you keep bringing new couriers
# 17. when you have enough couriers on the streets, the price of orders is ridiculous, we can't make a profit, I hope you disappear soon Wolt garbage
# 18. Hi Please I would like to send this message to the management department, Sir you are killing the job by bringing new couriers for example today from 10 to 12:30 I had only 2 tasks at Herlev and I saw another new courier believe me sir there's no tasks for more couriers why do you asking for more couriers you have enough. You are looking for new couriers and yours are looking for tasks it doesn't make sense. Thank you
# 19. Working as a courier for Wolt is everyday a little more depressing
# 20. Too many couriers and no orders

# %%
reduced_model2.visualize_hierarchy(custom_labels=True)

# %% [markdown]
# From the dendogram here, we can see that the topics are generally more distinct now, since the scores are higher before topics will be merged
#
# Confirms 1+17 make sense to merge
#
# For other topic it shows are close (2+4, 0+15) I asses their connectiveness and rate them unrelated! No merging
#
# For 2+5+9+13+16+18 which I all conlude in the very end are connected to earnings (too many couriers, to few order, too low pay, too low prices), the model places most of tem in the red area, making them somehow related.

# %% [markdown]
# Now, I manually merges these topics, as their connectiness is not technically present, but logically I rate them connected

# %%
import copy

reduced_model2_2 = copy.deepcopy(reduced_model2)

# %%
topics_to_merge = [[1, 17],
                   [2, 5, 9, 13, 16, 18]
]

reduced_model2_2.merge_topics(documents, topics_to_merge)

# %%
reduced_model2_2.get_topic_info()
# Out:
#     Topic  Count                                      Name  \
# 0      -1   4118                    -1_order_time_wolt_app
# 1       0   1666                  0_order_courier_hour_pay
# 2       1   1064             1_ready_wait_order_restaurant
# 3       2    997                    2_happy_wolt_good_work
# 4       3    671                 3_app_order_work_app work
# 5       4    435                4_km_distance_delivery_pay
# 6       5    331          5_support_wolt support_chat_team
# 7       6    322                  6_map_address_google_gps
# 8       7    269                      7_bag_drink_pack_cup
# 9       8    146            8_task_task task_time_new task
# 10      9    138  9_wolt_market_wolt market_market vanløse
# 11     10    122          10_bundle_bundle order_order_pay
# 12     11     95      11_bonus_weekend_weekend bonus_order
# 13     12     90           12_support_order_deliver_cancel
#
#                                        Representation  \
# 0   [order, time, wolt, app, work, delivery, pay, ...
# 1   [order, courier, hour, pay, new, payment, low,...
# 2   [ready, wait, order, restaurant, time, food, m...
# 3   [happy, wolt, good, work, thank, happy wolt, d...
# 4   [app, order, work, app work, time, offer, dkk,...
# 5   [km, distance, delivery, pay, driver, drive, c...
# 6   [support, wolt support, chat, team, bad, help,...
# 7   [map, address, google, gps, app, location, map...
# 8   [bag, drink, pack, cup, food, paper, order, sp...
# 9   [task, task task, time, new task, accept, acce...
# 10  [wolt, market, wolt market, market vanløse, or...
# 11  [bundle, bundle order, order, pay, task, accep...
# 12  [bonus, weekend, weekend bonus, order, bonus w...
# 13  [support, order, deliver, cancel, customer, de...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [More orders would be delicious, There are not...
# 2   [Ask Pick up places not to mark the order read...
# 3   [i am very happy with wolt, i am very happy wi...
# 4   [App crashes. App lets me drive for miles, the...
# 5   [You say it is 0.1km ekstra but actual distanc...
# 6   [Haven't used Wolt Support, so is still uncert...
# 7   [Still problems with the addressees in Google ...
# 8   [McDonalds City putting orders in big bags is ...
# 9   [I don't get as many tasks, It's Sku Slay with...
# 10  [I also want to order Wolt Market in Vanløse o...
# 11  [Why the system give bundles when there are no...
# 12  [Put a bonus for weekend 23to02am, Where is ou...
# 13  [I had the order 7J5DV3, in which the app sent...

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = reduced_model2_2.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = reduced_model2_2.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: order, courier, hour, pay, new, payment, low, earning, work, wolt
# Topic 1: ready, wait, order, restaurant, time, food, minute, burger, mcdonald, min
# Topic 2: happy, wolt, good, work, thank, happy wolt, day, wolt happy, love, job
# Topic 3: app, order, work, app work, time, offer, dkk, drive, error, task
# Topic 4: km, distance, delivery, pay, driver, drive, car, money, payment, long
# Topic 5: support, wolt support, chat, team, bad, help, wolt, support team, good, contact
# Topic 6: map, address, google, gps, app, location, maps, wrong, google map, google maps
# Topic 7: bag, drink, pack, cup, food, paper, order, spill, soda, customer
# Topic 8: task, task task, time, new task, accept, accept task, new, hour, disappear, receive
# Topic 9: wolt, market, wolt market, market vanløse, order, vanløse, danish, copenhagen, denmark, hour
# Topic 10: bundle, bundle order, order, pay, task, accept, payment, new, order bundle, system
# Topic 11: bonus, weekend, weekend bonus, order, bonus weekend, bonus time, 17, time, today, remove
# Topic 12: support, order, deliver, cancel, customer, deduct, ask, tell, mistake, time

# %% [markdown]
# Tjekker nu dokumenter i de sammensatte topics (0 og 2), for at se at det giver mening at de handler om det samme

# %%
# Get topic assignments for each document
topics, _ = reduced_model2_2.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Select only topic 2
topic_id = 12
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(25, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic 12 (90 documents) ===
# 1. Why the F do I have to ask support everytime I want to cancel an order. I have enough experience to know when I have to cancel and when not. I’ve done 550 orders this month alone, let me cancel whenever want without support please
# 2. The two layers of support you have to go through to get anything done are highly frustrating and time wasting. Also if a task is to pickup a missing item from a previous order please let us know about it. Twice today I had venues flatly tell me they had no such order only to find out after 10 minutes back and forth with support that it was for a missing item.
# 3. Please make it possible to cancel an order instead of contacting support. Unfortunately, experience a wait of +5 min at Venues. And understandingly they are busy, but who bring out is time = money
# 4. I had an Incident with an order that I got, I went to the address but the girl told me she did not order any but the address is hers, and I asked her if may be her husband and her boyfriend ordered it she was so sure no one did. One of your support team texted me As i was delivered the other order amd we had a good conversation and decided to return to the address and try one more time if not i will return it to the super market. But suddenly one of your support team his name was Mads came and " ORDERED " and even told me he is going to deduct if I didnot delivered it and he was so sure that I went to a wrong address and tried to blame me. By the way I went back to the address and tried one more but the home owner refused to open and even told me she is gonna call the police and I told him and he gave the phone number the when I called the customer said that she had made a mistake she wrote her old address which is not hers now cause she is being moved to another house. But Mads tried to be sorry after he said alot and even blame me and treathened me. But I dont accept his apologise even Told him how it cost me his attitude and make me up set and over all my precious time.
# 5. I have received errors on order today where I had not been handed the item to the customer but was still sent to the wrong customer with the wrong goods and deleted another customer delivery It is only because I am known in the area and lived there all my life that I knew where to deliver it really badly from the system and at the same time I did not get payment for one order if it was not because I had double checked it,
# 6. Support take so long to resolve a problem it looks like they never understand what the issue or how to solve it. They gave me the wrong order in the restaurant. In understand it's my fault. So they need to be fast to charge me the amount and give a straight answer right away to keep going.
# 7. Poor service that was removed for me DKK 457. Justify that I have handed in order for only wrong and it was not my problem and I have been customer service agree but she did not agree with me then she removes me without her telling me that I will remove from you 457 kr. It has asked me that I have delivered it wrong then I say to them no I have handed in it it is real customers and I have also said to them maybe they may well be that him as he works in the student Seven who was he lives the order then he writes on the bus order number wrong
# 8. One of the support service tried to take 217 kr from my money because of restaurant mistake and I hope some supervisor from Wolt to talk to me .
# 9. Very very bad support. I got an order that I accepted. When I went to the place to get my order the order got cancelled. So I waited a very long time for the support to delete the order so I could continue. On top of all I did not get compensated for the lost time or fuel I used or anything
# 10. Every time a real issue comes up, like customers not responding, wrong addresses, badly packaged food making a mess, support does nothing to help. We get no compensation. Instead it's always the same answer: "I'm sorry this happened to you, better luck next time". It's a constant reminder of how little our time and effort matters to the company.
# 11. Youtake money off from your staff even when it is not their fault
# 12. The support is the WORST. I think I will find another job because you do everything to wear away the riders and remembee that wolt exits because of the riders. We always loose. If I deliver a wrong order, its my fault and I have to pay (not the venuen when the responsability is shared) If a venue has 30 minutes of delay, and you drove 10 minutes-2km wasting fuel and time, you loose. You dont have a compensations. You dont get nothing. And when you ask support, they seem monkeys behind a keyboard. They are fast to deduct money from your savings but when you ask something to help you, they always answer another completly different thing. Its impossible like this. I want to make a complaint and support told me that this form is a complaint. And no its not. They are liars. A good company dont have liars in their team specially when they have conctact with “providers” as we are. Wolt is sucking in all ways. Is not a good place to work specially if you are a courier. You are alone. Nobody supports or take care about you. I am guessing is anyone will read this and reach out to me. Don’t think so. I know that this is all for nothing…
# 13. My account is set to do recieve only alcohol free orders today after I got an order and accept I went to the venue and picked up the order i felt there are some cans so i asked to make sure if it contain alc and surprisingly IT WAS. So the order was canceled and i did not get compensation for this distance and wasted time. And guess what this happened again and I detect that after i reached the venue and also i did not get compensation for this fault that is repeated from the application
# 14. Vendor concerns are not being heard
# 15. negative rating from support because they withheld funds from my earnings due to alleged non-delivery! The support representative promised that he would investigate with someone else and let me know the results. I will give the support a negative rating until I see these results.
# 16. I mixed up two orders. But I was able to go pick up the order that I had delivered incorrectly and exchange them and have both orders delivered correctly within 10 or 15 minutes. But the support service just calculated a fine for me. And she didn’t give me the opportunity to do it right. Now this money is very important to me. And I think what the support team did was wrong.
# 17. If I took orders and delivered them to the client, this order is wrong, I am responsible for it, so it is not fair because it is not my fault if they gave me the wrong order.
# 18. My earnings is getting cancelled because a customer is saying that they didn’t got their order. And I am 100% sure that I have delivered to right address. It’s very disappointing that the courier doesn’t have any rights.
# 19. Gastronomia Italia order 268. I arrived. Confirmed my order number is 2 6 8. They confirm and ask multiple times if it's 2 6 8. After I get it, I swipe. But they say I didn't swipe. I show them the order on my phone. They show me the order on their tablet, saying the order is 2 6 9.... I say mine is 2 6 8. They don't understand why 2 6 8 is my order, and not 2 6 9... They insist they gave me order 2 6 9, even though we agreed multiple times that I came for order 2 6 8.. I should receive compensation on behalf of their mistake.
# 20. For the Order no: 923 from Yazzy's Pita the customer claims he didn't get the right fucking Order. Even he got something else he ate it and I still got deducted an amount of 223/- DKK from my end and then the customer once again gets a fucking solution. If you had to deduct the money from me then you should have atleast asked the customer to return the Order. The customer checked the Order in front of me. He got more than be bargained for. This is the last time you did this. One more time you do this I will go public with this harrasment. You have started paying less to Wolt Couriers. No more with this bullshit.
# 21. Very sad about this situation support treated me very bad. I am stressed and sad I could not do my job properly because that . Cecile discount me 200 dk even with out ask me nothing. Hopefully some one could solve this situation fairly.
# 22. I am still being penalized for notifying a work injury
# 23. negative rating from support because they withheld funds from my earnings due to alleged non-delivery. I delivered the order exactly to the address indicated in the order. I couldn’t make a mistake with the apartment, since the order indicated “stuen”, without specifying whether the apartment was on the right or left, and there was also only one “stuen” button on the intercom! my opinion is that the client decided to cheat by sending his girlfriend to receive the order (who, by the way, was already waiting for me on the landing after my call on the intercom)! I understand that the amount of 44 kr is not that big, but the very fact of fraud haunts me and you play along with it!
# 24. I did not get £ 45 on order which I have handed in and support will not understand
# 25. There could well be a feature where you could undo an order after accepting. If, for example, there is an order in a store where they are behind with many orders

# %%
reduced_model2_2.visualize_hierarchy(custom_labels=True)

# %% [markdown]
# Topic 0 ser god ud, topic 2 ser også god ud (men nogle enkelte outliers her)

# %% [markdown]
# ### Manuel reducering

# %%
# Createas a identical model called reduced_model, which is a copy of the loaded_model
# I'll use this to reduce the number of topics in the model, while keeping the original model intact
import copy

reduced_model_manual = copy.deepcopy(loaded_model2)

# %%
topics_to_merge = [[0, 23],
                   [1, 4, 11],
                   [2, 5, 13, 25],
                   [8, 15, 24],
                   [9, 12, 17, 18, 22, 26]
]

reduced_model_manual.merge_topics(documents, topics_to_merge)

# %%
reduced_model_manual.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   4118                         -1_order_app_work_delivery
# 1       0   1073                    0_courier_hour_new courier_work
# 2       1   1064                   1_restaurant_burger_mcdonald_min
# 3       2    997                  2_happy_happy wolt_day_wolt happy
# 4       3    803                             3_pay_low_hour_payment
# 5       4    513                     4_app_app work_error_order app
# 6       5    435                        5_km_delivery_drive_payment
# 7       6    331           6_support_wolt support_chat_support team
# 8       7    322                             7_map_address_gps_maps
# 9       8    269                              8_bag_pack_food_spill
# 10      9    138        9_wolt market_market_market vanløse_vanløse
# 11     10    122        10_bundle_bundle order_payment_order bundle
# 12     11     95  11_weekend_weekend bonus_bonus weekend_bonus time
# 13     12     94            12_mile_drive mile_mile offer_let drive
# 14     13     90                  13_deliver_cancel_customer_deduct
#
#                                        Representation  \
# 0   [order, app, work, delivery, pay, hour, day, c...
# 1   [courier, hour, new courier, work, order order...
# 2   [restaurant, burger, mcdonald, min, delay, foo...
# 3   [happy, happy wolt, day, wolt happy, work wolt...
# 4   [pay, low, hour, payment, earning, work, salar...
# 5   [app, app work, error, order app, problem, res...
# 6   [km, delivery, drive, payment, bike, scooter, ...
# 7   [support, wolt support, chat, support team, su...
# 8   [map, address, gps, maps, google map, google m...
# 9   [bag, pack, food, spill, soda, paper bag, lid,...
# 10  [wolt market, market, market vanløse, vanløse,...
# 11  [bundle, bundle order, payment, order bundle, ...
# 12  [weekend, weekend bonus, bonus weekend, bonus ...
# 13  [mile, drive mile, mile offer, let drive, clos...
# 14  [deliver, cancel, customer, deduct, mistake, c...
#
#                                               KeyBERT  \
# 0   [wolt market, wolt, earn, fee, app, busy, deli...
# 1   [get order, order order, order, receive order,...
# 2   [food ready, order ready, restaurant, waiting ...
# 3   [love wolt, wolt happy, happy wolt, wolt, wolt...
# 4   [order pay, pay order, payment, payment order,...
# 5   [app work, app bad, app app, app, app buggy, a...
# 6   [distance payment, long distance, distance, co...
# 7   [wolt support, support support, support good, ...
# 8   [google map, map app, google maps, app map, ma...
# 9   [bag order, food bag, use bag, paper bag, bag ...
# 10  [market vanløse, vanløse order, vanløse ote, v...
# 11  [bundle payment, order bundle, bundle pay, pay...
# 12  [weekend bonus, saturday bonus, bonus saturday...
# 13  [venue app, order venue, venue order, app offe...
# 14  [cancel order, order cancel, deliver order, co...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [Didn't get some order, There are not many ord...
# 2   [Dear Wolt support, I would like to file anoth...
# 3   [i am very happy with wolt, i am very happy wi...
# 4   [The payment is a shameless, The payments are ...
# 5   [My app teasing therefore i have not been to w...
# 6   [The adress of one of my delivery's today was ...
# 7   [Wolt support not good.verybad, Support always...
# 8   [Sometimes wolt app doesn't redirect to accura...
# 9   [McDonalds City putting orders in big bags is ...
# 10  [I also want to order, from Wolt Market in Van...
# 11  [Why the system give bundles when there are no...
# 12  [Put a bonus for weekend 23to02am, Where is ou...
# 13  [App lets me drive for miles, then offers almo...
# 14  [I had the order 7J5DV3, in which the app sent...

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = reduced_model_manual.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = reduced_model_manual.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: courier, order, task, hour, new, new courier, time, work, order order, home
# Topic 1: ready, wait, order, restaurant, time, food, minute, burger, mcdonald, min
# Topic 2: happy, wolt, good, work, thank, happy wolt, day, wolt happy, love, job
# Topic 3: pay, low, hour, payment, earning, order, wolt, price, dkk, bad
# Topic 4: app, order, app work, work, time, error, support, task, order app, accept
# Topic 5: km, distance, delivery, pay, driver, drive, car, money, payment, long
# Topic 6: support, wolt support, chat, team, bad, help, wolt, support team, good, contact
# Topic 7: map, address, google, gps, app, location, maps, wrong, google map, google maps
# Topic 8: bag, drink, pack, cup, food, paper, order, spill, soda, customer
# Topic 9: wolt, wolt market, market, market vanløse, vanløse, order, danish, copenhagen, denmark, hour
# Topic 10: bundle, bundle order, order, pay, task, accept, payment, order bundle, new, system
# Topic 11: bonus, weekend, weekend bonus, order, bonus weekend, bonus time, 17, time, today, remove
# Topic 12: mile, drive mile, mile offer, let drive, close venue, app let, offer, offer ready, drive, order close
# Topic 13: support, order, deliver, cancel, customer, deduct, ask, tell, mistake, say

# %%
# Get topic assignments for each document
topics, _ = reduced_model_manual.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Select only topic 2
topic_id = 12
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(25, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic 12 (94 documents) ===
# 1. App lets me drive for miles, then offers almost ready order when I’m close to the venue. This time was extra special.. I literally drive 2 kilometers from Ingrid Marievej 8, Valby back towards old Valby. I go slow, but no orders. And to no great surprise, I get not one but two orders, as soon as I am back in old Valby. And both orders are late for pick up, so I find it very likely that they have been offered in the market for a minimum of four minutes before they are due for pickup. Just know that it’s very annoying to a courier, and in my case lead me to not accept the next bundle offered by the app..
# 2. Venues marking the order ready when its not ready and waiting 10-20 mins for the order,the app sucks battery like crazy and if connected to bt,lowers all volumes.
# 3. App lets me drive for miles, then offers almost ready order when I’m close to the venue. ABSOLUTE JOKE TODAY. THE LEVEL OF MANIPULATION IS BEYOND BELIEF.
# 4. In my opinion we could have integration with smartwatch for confirming the orders and especially an app designed for Android auto, it would be a plus not having to touch the mobile phone while driving
# 5. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Such a joke.
# 6. Often times the app will be slow to update my location while I'm biking. Also Restaurant Vita had an unfriendly staff at the door and Pizza Art had about 25-30min delay. Otherwise all the other venues were great.
# 7. App is assigning Long distance order and i am in cycle. Ot would have been better if i Can restrict the Delivery area myself
# 8. Have a list of someone who could be nice. 1. The Belob that you see for you accept an order it could be nice to still keep it so you still show it when you swipe up to see Contact Information / The address of the Customer Sa Star there below "Belob: XXX" 2. Make a feedback menu item in sidebar menu so when you press the burger menu SA STAR DER FEEDBACK SA when you press it then a window comes where you can write your feedback without having to log out / swipe offline. 3. Does not make sense to me that you write on and off task distance as in gore now, just keep distance it as it stood for without there Star on and off Distance Task.
# 9. App lets me drive for miles, then offers almost ready order when I’m close to the venue. I literally drive 4km, and surprise I get an order when I’m at the venue, an order that’s almost ready (1 minute) ABSOLUTE JOKE !!!!!!!!!!!!!!
# 10. The application did not work well - the location update was done at long intervals, for this reason you had to wait 4-5 minutes before you could swipe the received order -with normal and busy status, in 1 hour and 30 minutes I received 3 orders - after long periods of waiting, I received the orders ready and delayed - a second order is pending and by the time you reach the location to pick up the first one it disappears, it is pointless to be displayed until you drive 2-3 km and then disappear - I received the order for a new customer, ready and delayed, to travel to the venue 6 km, after picking up the estimated time for delivery 3 min. for 4.5 km, driving safely is a priority
# 11. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Absolute joke
# 12. It would be great if there is an option where I can restrict the delivery area or mark proffered delivery area in the map. Probably after having , you can force us to take bundle orders without rejecting
# 13. App lets me drive for miles, then offers almost ready order when I’m close to the venue Insane miles
# 14. App lets me drive for miles, then offers almost ready order when I’m close to the venue. PLEASE PLEASE change the programming of the app, so it offer us orders BEFORE we cross a big intersection, or turn a corner. It is super annoying and somewhat dangerous to have to do all these U-turns.. Also my app doesn’t really register how many miles I drive, I estimate less than 20 % is registered this month
# 15. App lets me drive for miles, then offers almost ready order when I’m close to the venue. ITS SUCH AN EXPERIENCE
# 16. I've been at work for 12 hours and I have nine races and the rest have 20 race tracks, it's something abnormal, I talked to wolt employees from the chat and they didn't help me with anything, this is not normal, I bought two phones to be always connected and for nothing, I'm the only one from this area that doesn't have orders
# 17. App lets me drive for miles, then offers almost ready order when I’m close to the venue Insane Miles driven
# 18. Drive 2 km no orders and then get offered almost ready task when I have just passed the store…
# 19. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Big joke
# 20. App lets me drive for miles, then offers order when I’m close to the venue, and as an extra bonus, the order is quite late because you wait to offer it…
# 21. App lets me drive for miles, then offers almost ready order when I’m close to the venue. PLEASE PLEASE STOP THIS MANIPULATION. IT WLL COME BACK TO YOU ONE DAY…
# 22. Today I had 3 occasions in which I waited more than 25 minutes for an order to be removed, the longest one was approximately 15 minutes the other 2 times. I also had problems with the GPS, it said that the pickup distance was less than where I was... my location was not updated in the application... and it was not a problem with my GPS... I did a huge amount of kilometers for so little money that I was able to raise. What a shame.
# 23. Today's I have some troubles because app, mix the order, and I can't deliver. Support finally help, but It takes a lot of time. And the venue had so troubles with the prepare on time. Hard day.
# 24. App lets me drive for miles, then offers almost ready order when I’m close to the venue. BIG JOKE. SSAM at Fisketorvet take more than 15 minutes to toast two buns, and it looked like the only orders they had. BIG JOKE.
# 25. Hi. 1. Some venues have almost no way to reach by car. I have parked in a parking, paid 10kr in a 300m distance. I think they must have mostly bike or if you send a car it must be much more expensive. 2. Some roads are closed and google map is bad so the time estimates and price should be different. Fx, It is 1 km away but I have to drive 6 or 7 km to reach. 3. Venues mark orders ready while I have to wait 30 minutes there and they say it is because they can see other others. Like bellisimo pizza and eat not hojbjerg.

# %% [markdown]
# ## Reduce outliers

# %% [markdown]
# ### reduce outliers for automatisk + manuel cluster reduction

# %% [markdown]
# Outliers must be reduced after topics have been merged. It cannot technically work the other way around

# %%
import copy

reduced_outlier_model2 = copy.deepcopy(reduced_model2_2)

# %% [markdown]
# I'll now look at some outliers to get an idea what proportion of outliers should be in one of the topics, and what proportion are actual outliers (noise) not belonging to any of the topics.

# %% [markdown]
# I'll now try different approaches to outlier reduction. that is techniques and thresholds

# %%
# Reduce outliers using the `embeddings` strategy
new_topics_2 = reduced_outlier_model2.reduce_outliers(documents, topics, threshold=0.7, strategy="embeddings")
# puts the outliers into one of the topics. The documents already assigfned to a topic will not be changed.

# %%
# Now we need to update the model with the new assignments of the outliers, and new topic representations are calculated
# when specifying the representation model, KEYBERT and MMR are also displayed
reduced_outlier_model2.update_topics(documents, topics = new_topics_2, vectorizer_model= vectorizer_model, representation_model=representation_model)
# Out:
# 2025-05-20 15:01:31,013 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
import copy

# Define the strategy-threshold combinations
combinations = [
    ("embeddings", 0.25),
    ("embeddings", 0.45),
    ("embeddings", 0.55),
    ("c-tf-idf", 0.02),
    ("c-tf-idf", 0.07),
    ("c-tf-idf", 0.08),
    ("distributions", 0.03),
    ("distributions", 0.08),
    ("distributions", 0.09),
]

# Store results
results = {}

# Loop through each combination
for strategy, threshold in combinations:
    print(f"Running: strategy = {strategy}, threshold = {threshold}")
    
    # Deep copy the original reduced model
    model_copy = copy.deepcopy(reduced_model2)

    # Reduce outliers using specified strategy and threshold
    new_topics = model_copy.reduce_outliers(
        documents=documents,
        topics=topics,
        strategy=strategy,
        threshold=threshold
    )

    # Update topic representations
    model_copy.update_topics(
        docs=documents,  # <-- FIXED HERE
        topics=new_topics,
        vectorizer_model=vectorizer_model,
        representation_model=representation_model
    )

    # Count number of outliers
    outlier_count = sum(1 for t in new_topics if t == -1)

    # Store results
    results[(strategy, threshold)] = {
        "model": model_copy,
        "topics": new_topics,
        "outlier_count": outlier_count
    }

# Optional: print summary of outlier counts
print("\nSummary of Outlier Counts:")
for (strategy, threshold), res in results.items():
    print(f"{strategy}, threshold={threshold}: {res['outlier_count']} outliers")

# %% [markdown]
# First run
#
# embeddings, threshold = 0.3: 302 outliers remain
#
# embeddings, threshold = 0.5: 2044 outliers remain
#
# embeddings, threshold = 0.7: 3996 outliers remain
#
#
# c-tf-idf, threshold = 0.1: 2541 outliers remain
#
# c-tf-idf, threshold = 0.2: 3956 outliers remain
#
# c-tf-idf, threshold = 0.3: 4074 outliers remain
#
# distributions, threshold = 0.1: 2007 outliers remain
#
# distributions, threshold = 0.2: 3564 outliers remain
#
# distributions, threshold = 0.3: 3984 outliers remain
#
# ------------------------------------------------------
#
# Second run
#
# embeddings, threshold = 0.35: 564 outliers remain
#
# embeddings, threshold = 0.4: 915 outliers remain
#
# embeddings, threshold = 0.45: 1443 outliers remain
#
# c-tf-idf, threshold = 0.02: 142 outliers remain
#
# c-tf-idf, threshold = 0.05: 798 outliers remain
#
# c-tf-idf, threshold = 0.08: 1795 outliers remain
#
# distributions, threshold = 0.06: 945 outliers remain
#
# distributions, threshold = 0.07: 1219 outliers remain
#
# distributions, threshold = 0.08: 1459 outliers remain
#
# ------------------------------------------------------
#
# Third run
#
# embeddings, threshold = 0.25: 151 outliers remain
#
# embeddings, threshold = 0.45: 1434 outliers remain
#
# embeddings, threshold = 0.55: 2628 outliers remain
#
# c-tf-idf, threshold = 0.02: 142 outliers remain
#
# c-tf-idf, threshold = 0.07: 1459 outliers remain
#
# c-tf-idf, threshold = 0.08: 1795 outliers remain
#
# distributions, threshold = 0.03: 310 outliers remain
#
# distributions, threshold = 0.08: 1459 outliers remain
#
# distributions, threshold = 0.09: 1720 outliers remain

# %% [markdown]
# #### Inspection of embeddings025

# %%
topics_emb_025_2 = results[("embeddings", 0.25)]["model"]
topics_emb_025_2.get_topic_info()
# Out:
#     Topic  Count                                Name  \
# 0      -1    151             -1_tax_go_battery_quiet
# 1       0   2611            0_order_courier_hour_pay
# 2       1   1527             1_ready_wait_order_time
# 3       2   1421         2_happy_wolt_good_excellent
# 4       3   1120               3_app_order_work_time
# 5       4    947          4_km_distance_delivery_pay
# 6       5    453    5_support_wolt support_chat_help
# 7       6    430            6_map_address_app_google
# 8       7    325               7_bag_drink_pack_food
# 9       8    329             8_task_work_time_accept
# 10      9    297     9_wolt_market_wolt market_order
# 11     10    160    10_bundle_order_bundle order_pay
# 12     11    216  11_bonus_weekend_weekend bonus_day
# 13     12    477   12_order_support_deliver_customer
#
#                                        Representation  \
# 0   [tax, go, battery, quiet, add, tip, come, twic...
# 1   [order, courier, hour, pay, wolt, low, payment...
# 2   [ready, wait, order, time, food, restaurant, m...
# 3   [happy, wolt, good, excellent, day, work, than...
# 4   [app, order, work, time, app work, support, ta...
# 5   [km, distance, delivery, pay, car, drive, driv...
# 6   [support, wolt support, chat, help, team, bad,...
# 7   [map, address, app, google, location, gps, map...
# 8   [bag, drink, pack, food, order, cup, restauran...
# 9   [task, work, time, accept, hour, busy, new, ac...
# 10  [wolt, market, wolt market, order, denmark, wo...
# 11  [bundle, order, bundle order, pay, task, new, ...
# 12  [bonus, weekend, weekend bonus, day, pay, tip,...
# 13  [order, support, deliver, customer, cancel, ti...
#
#                                               KeyBERT  \
# 0   [tax, pay tax, deduction, tip, pay, extra step...
# 1   [order order, order, get order, receive order,...
# 2   [food ready, restaurant, mark food, order read...
# 3   [love wolt, wolt happy, happy wolt, wolt good,...
# 4   [app app, app, app work, app crash, app let, o...
# 5   [wolt, favor wolt, fee, delivery, distance, lo...
# 6   [wolt support, support support, support good, ...
# 7   [address wolt, wrong address, google map, addr...
# 8   [bag order, paper bag, use bag, food bag, bag ...
# 9   [task, task task, add task, single task, new t...
# 10  [wolt market, order wolt, market vanløse, wolt...
# 11  [bundle payment, bundle pay, pay bundle, order...
# 12  [weekend bonus, bonus weekend, hour bonus, bon...
# 13  [cancel order, deliver order, order cancel, or...
#
#                                                   MMR  \
# 0   [tax, tip, worker right, basic worker, bike, d...
# 1   [courier, pay, low, payment, work, day, earnin...
# 2   [restaurant, burger, mcdonald, order ready, fo...
# 3   [day, happy wolt, wolt happy, excellent week, ...
# 4   [app, app work, error, delivery, hour, crash, ...
# 5   [km, delivery, drive, kr, payment, bicycle, ki...
# 6   [support, wolt support, support bad, support g...
# 7   [map, address, gps, maps, google map, google m...
# 8   [bag, food, soda, spill, paper bag, lid, mcdon...
# 9   [task, work, accept task, new task, task task,...
# 10  [market, wolt market, denmark, danish, courier...
# 11  [bundle, bundle order, accept, payment, order ...
# 12  [weekend, weekend bonus, tip, boost, earn, bon...
# 13  [order, deliver, customer, cancel, address, ac...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [More orders would be delicious, There are not...
# 2   [Ask Pick up places not to mark the order read...
# 3   [i am very happy with wolt, i am very happy wi...
# 4   [App crashes. App lets me drive for miles, the...
# 5   [You say it is 0.1km ekstra but actual distanc...
# 6   [Haven't used Wolt Support, so is still uncert...
# 7   [Still problems with the addressees in Google ...
# 8   [McDonalds City putting orders in big bags is ...
# 9   [I don't get as many tasks, It's Sku Slay with...
# 10  [I also want to order Wolt Market in Vanløse o...
# 11  [Why the system give bundles when there are no...
# 12  [Put a bonus for weekend 23to02am, Where is ou...
# 13  [I had the order 7J5DV3, in which the app sent...

# %% [markdown]
# Now I look at how the outliers were reassigned into the the topics

# %%
# Step 1: Get original topics (before outlier reduction)
topics, _ = reduced_model2_2.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Step 2: Get new topics (after outlier reduction using embedding + 0.25 threshold)

new_topics_embedding025_2 = results[("embeddings", 0.25)]["topics"]
outlier_model_embedding025_2 = results[("embeddings", 0.25)]["model"]
documents = df_combined["translated_Comment"].tolist()

# Step 1: Find reassigned outliers (originally -1, now assigned to a topic)
reassigned_outliers = [
    (i, doc, new_topic)
    for i, (doc, old_topic, new_topic) in enumerate(zip(documents, topics, new_topics_embedding025))
    if old_topic == -1 and new_topic != -1
]

# Step 2: Group reassigned outliers by new topic
topic_to_outlier_docs = defaultdict(list)
for i, doc, new_topic in reassigned_outliers:
    topic_to_outlier_docs[new_topic].append(doc)

# Step 3: Print sampled outlier docs with ORIGINAL top words (from reduced_model2)
for topic_id in sorted(topic_to_outlier_docs.keys()):
    docs = topic_to_outlier_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))

    # Get original top words from reduced_model2
    original_topic_words = reduced_model2_2.get_topic(topic_id)
    if original_topic_words:
        top_words = ", ".join([word for word, _ in original_topic_words])
    else:
        top_words = "(No original top words)"

    print(f"Reassigned Outliers → Topic {topic_id} ({len(docs)} docs) | Original top words: {top_words}")
    for j, doc in enumerate(sampled_docs):  
        print(f"{j+1}. {doc}")
    print()
# Out:
# Reassigned Outliers → Topic 0 (945 docs) | Original top words: order, courier, hour, pay, new, payment, low, earning, work, wolt
# 1. Increase the salaries or no one will work
# 2. When the weather is like this right now (storms/rain/snowy), you should raise the payment for every order by 25% to 30%. That will motivate the couriers to work on these days. Putting 3x effort than the usual on a day like this, getting vehicle spoilt, and getting paid the same is something where Wolt has failed me.
# 3. The payments given are low. Night workers should receive extra payment.
# 4. STOP INCOMING PEOPLE IN AALBORG!!! RISE THE PAYMENT
# 5. Wolt does not behave fairly. During 1.5 hours in one place, I was without an order, but the other colleagues had several orders
# 6. Whats going on with Wolt that is super dead? People don’t order anymore? Don’t think so. Maybe the competition is taking wolts place? Used to be great but now is just CRAP
# 7. The orders are very low and the amount that Volt pays is very low
# 8. Bad experience. Seems you are to keep all money for yourself. After taxes and expenses the earnings are around 50 to 60 kr per hour. Do something with second order price. Otherwise people are getting frustrated. It seems you are changing the prices according to the situation.
# 9. Not worth the hard work anymore. You keep all the money on double orders and at the same time you reduce all task fees with 5-10kr.
# 10. hey it was very poor today i was online for 8 and a half hours i took 3 orders it's a very desolate area you need to advertise a lot more
#
# Reassigned Outliers → Topic 1 (463 docs) | Original top words: ready, wait, order, restaurant, time, food, minute, burger, mcdonald, min
# 1. Sometimes it takes a long time to get deliveries
# 2. It will be very usefull if you add to notifications we got when there is an order that need to be picked, the time that order need to be picked at and when it need to be delivered! In case like when i am for example not close to centrum so i either calculate if can pick and deliver or let it to another person who is closer. So the food is hot and get cold.
# 3. KFC Rådhuspladsen was not able to handle the amount of orders they were sent in a very short while. Maybe there should be a cap of how many orders can be made within a certain timeframe. It's frustrating going to a venue only to find out they are unable to cope, and the order I'm supposed to pick up won't be ready within the foreseeable future even though it's already 35 minutes overdue. This was a special event, because of the Superbowl. But this should be looked into. After waiting in vain at the venue, I decided to decline every order from them. And it was a lot!!! No way they could handle that amount.
# 4. The original pita don't give a flying fuck about whether or not you sit and wait for 5-15 minutes, they should re evaluqte their estimates on when the food Is done
# 5. Almost all venues late. Customer not at home. Very bad friday.
# 6. Wolt market at glasvej is terrible at the moment. We are standing 10 guys for 5+ minutes without getting contact from any workers there even though there are a lot of finished bags. Only after yelling several times someone responds. My order was 35 mins late and marked ready but still it was not ready yet. This is super frustrating and you are losing valuable courier time and thereby money too. Something has to change there, either fire the responsible or let us get the bags ourselves. And then have the bags ready at the right time and only mark it ready when it is
# 7. SPIS frederiksberg is always behind the mentioned time.. always delay which waste lots of our time.
# 8. Silent notification when food is ready and no vibration
# 9. Long distances to pick up orders
# 10. I'm at home at 2 o'clock. Just one order this is fun .. Sunday? !!
#
# Reassigned Outliers → Topic 2 (424 docs) | Original top words: happy, wolt, good, work, thank, happy wolt, day, wolt happy, love, job
# 1. We work or??? I go home
# 2. Have an excellent day
# 3. Have an excellent week
# 4. Generally speaking, the partnership is good. However, there is a growing dissatisfaction among partners on earnings. Most of us do Wolt as the main source of income and the lack of pension and holiday benefits only aggravates the frustration when pays are not like what they used to be.
# 5. Have a nice day!!!!!
# 6. For every day I work for you, I become less and less worthwhile. Thanks for once again putting down the task earnings
# 7. Have an excellent day
# 8. So bad wolt has become
# 9. Thanks for yet again again shit day thanks talented shit algorithm
# 10. Is wolt dead or what
#
# Reassigned Outliers → Topic 3 (449 docs) | Original top words: app, order, work, app work, time, offer, dkk, drive, error, task
# 1. App is just slow reacting to anything
# 2. The app does not automatically update even it is turned on in app settings
# 3. When there are too many orders and couriers, the app locks or the entire network becomes unresponsive one of these two. You need to improve your network infrastructure to keep up with thr high demand. Also when there's very low demand, the orders should get paid better and the food should be discounted more in the weekday mornings. At least the breakfast and the cofee and bakery type of restaurants should receive discounts in the morning, to increase the order numbers.
# 4. App crashes multiple times and very glitchy
# 5. The app does not work so well and it often breaks down and support cannot be contacted.
# 6. The countdown at the delivery address does not often update enough and my position does not update quite often enough.
# 7. Hi I can't contact support through the app, I don't know why there's an error, I've turned off my mobile and updated the app but nothing happens
# 8. App keeps crashing like it's memory leaking
# 9. The App is working fine - everything is working fine technically... It’s a perfect set up. The only issue that I see is that life is getting so expensive everywhere in Denmark - prices go up every day - Isn’t It funny that 40-50DKK order goes down to 10-15 DKK for the driver as real money in the pocket. I think that with this tempo drivers will even will start paying so they can work - great future is coming I think :))))
# 10. App is working bad these days ,man y times you can not swipe order .
#
# Reassigned Outliers → Topic 4 (512 docs) | Original top words: km, distance, delivery, pay, driver, drive, car, money, payment, long
# 1. profits fell. there are no bonuses on weekends, the second order from the pick up is no longer paid. Riders earn less and less and we have to work more hours. We discount all the orders lost due to accidents or customer complaints without taking into account falls, shocks, blows, weather. etc The only good thing that it maintains is being able to connect when you want. the rest wolt only benefits itself and we workers matter less and less. Could you ever help the delivery men who are the ones who get cold, get wet, or hit ourselves to be able to bring the food from the restaurants to their customers. we are part of your business we are not garbage.
# 2. Would be nice to know to borders between delivery areas
# 3. Prices very cheat , working with bad weather...
# 4. Our pickup fees could be higher. It has become wildly bad after you put it down per. 01/06-23
# 5. One task with longer distance in the same condition/same day paid less than a shorter task with around the same value, we talking about food. One task with 0.75km paid 28DKK and one task with 0.64km paid 32Dkk. Support doesn't want to tell me why or acknowledge that it's an app error.
# 6. It is unfair to wait at 0 kroner for 1.30 hours during the night shift at Amager Center. Prices have already dropped. It doesn't work either. I'm curious where this situation will go. We work with our own car and our own fuel. Car tires, oil change, maintenance and fuel are not cheap things. It would be good if you calculate these costs once again and re-evaluate the prices.
# 7. Not bad It will much better when customers await you outside because somebody’s live in difficult place
# 8. 22,75 dkk for a delivery to 5th floor no elevator. A big joke in my world. I personally couldn’t treat another human being like this, but I guess we are all different…
# 9. Hi. I have got many times problems with km. sometimes even it calculates half. That’s very weird and support doesn’t help us. Thank you so much.
# 10. The distance in km between deliveries Doesn’t match the distance calculated by Google Maps or phone Kort. We usually have to drive sometimes double, and that’s sad.
#
# Reassigned Outliers → Topic 5 (122 docs) | Original top words: support, wolt support, chat, team, bad, help, wolt, support team, good, contact
# 1. Thank you with the best support
# 2. You don't give a single fuck about our feedback.
# 3. No help with fighting company partners ban from skat, even though it is in direct harm for everybody.
# 4. Support scam me for 450kr
# 5. So many times I have to face error And everytime I have to talk with customer support
# 6. You don’t answer asap
# 7. Hi They have to pay more attention to requests. I have received many requests after hours. Thanks
# 8. It didn't work to talk to support. 20 minutes waiting, an order that wasn't ready. And the option was to cancel or keep waiting. Every day you earn less money and work more hours. I think going to Just It, the competition, will be a better option if conditions don't improve.
# 9. In the middle of the task you change me the adress so far away! And lost a lot of time calling the costumer and support! Then! Ris og nuddle has change the name! Please check it!
# 10. No work, no pay, useless support
#
# Reassigned Outliers → Topic 6 (108 docs) | Original top words: map, address, google, gps, app, location, maps, wrong, google map, google maps
# 1. Customers need to write down the adress and name on the doorbell CORRECTLY
# 2. My app doesn’t show all the miles I’ve driven. Only around 60 % I estimate ( 666 km at present)… there was also trouble last month..?
# 3. Have finished taking trips to 5 and 4 floor Show it has not been written from the start has tried to explain it for support but they are for no help she wants me to write to you every time I get a walk and the full address is not on it is sick to ask me what about you just change it or ask all your customers to write the full address of or pick it up in the living room I did not agree to do
# 4. Navigation extremely slow
# 5. It would be good to have to restrict the area in the map than reciving and rejecting the orders
# 6. Kilometers count does not work in the app, that's why I don't go online
# 7. I didn't realize my area was closed. I found that out by chance after I was waiting for orders for over half an hour. It gave me an idea. Maybe you should consider doing so that you can't swipe online in an area that has closed? Otherwise, you can get a pop-up message that says that it is closed, as well as when you close the area and when you open again. It's just a suggestion. Good evening.
# 8. Navigation makes little bit problem
# 9. Incorrect short location of wolt all the time
# 10. App: my gps location 1 km off on 1 task offered. Also no price on task. “Reject task” function needs to be manually updated otherwise nothing happens.
#
# Reassigned Outliers → Topic 7 (56 docs) | Original top words: bag, drink, pack, cup, food, paper, order, spill, soda, customer
# 1. That Big dominating icon in the same color as the pickup spot that has absolutely no function….. how drunk is your UI designer?
# 2. Please make the blue bike bag available in plain black without logos.
# 3. I can’t accept pickups
# 4. When accepting order from Spar / supermarket, I want to be able to see the order content or the estimated weight / volume. The order today just showed “1 bag”. I hope this was a one off.
# 5. You remember as you have promised to remove that code on Kawasaki sushi as this has nothing to do with alcohol or tobacco to do and sushi should not have code on thanks
# 6. Menny market tarnby is a nightmare
# 7. When you deliver and accept orders, I would think it would make it much easier for the driver if you could see what the order consisted of before accepting it. For example, if I accept an order then it says what food it is so if I want to take 2 orders at once then I know if I have room for it in my bag or not. Right now it's just a rate to take 2 because you don't know if you have space
# 8. Please make the bag available in plain black without logo.
# 9. Four amigos, Mejlgade. You have to wait outside in the inner yard of the building and they only give you the order through a window, and you have to pack you bag outside, which should definetly go against a lot of health code rules and food safety, not talking about human decency
# 10. Please make available in Wolt Gear website the regular blue bike bag, same model but in plain black and without logos.
#
# Reassigned Outliers → Topic 8 (183 docs) | Original top words: task, task task, time, new task, accept, accept task, new, hour, disappear, receive
# 1. Some time stimates work really badly at pickup points but otherwise it is perfectly fine
# 2. Had mistakes several times when I had to swipe to pick up and finish
# 3. The complain i did is regading the evenings times.
# 4. Silent no vibration when task is ready
# 5. I'm going home .. no have work today ???!!
# 6. Every time an task rings it mutes the music by 50% requiering to close and re-open the music app for it to be back to normal
# 7. Shame on this job and your frustrating system
# 8. Don’t bother offering me add on tasks for 22kr they will never be accepted
# 9. One is always delayed by the schedule
# 10. There is no work ...
#
# Reassigned Outliers → Topic 9 (159 docs) | Original top words: wolt, market, wolt market, market vanløse, order, vanløse, danish, copenhagen, denmark, hour
# 1. Stop hiring people in Aalborg!!!!
# 2. Wolt we going down please check system the people going just eat or fodoora people say Peter then wolt
# 3. I want to report about the behaviour of the girls in Royal bagel. Pls take it up again with the owner. Looks he hires girls that are bored and make fun on the expense of others. I didn't take the names of the girl but it' was on evening shift today 23.8. The food was marked ready and I entered and said the order nr, the girl on fun said she doesn't have it, she as something else. The other girl gave me the order. The first one asked me : 'Hvor kommet du fra? ' i said fra Israel and pick up the order and left. Shee smiled on covert hostility and said: gør du? From the street I saw they mooning and me and laughing. Couple of months ago o reported to Nina about similar incident there . It's not ok and not proffesionel. The Muslim men in other restaurants in Valby. I live there and the venues know me:) dont behave like that. Pls jandle
# 4. Partnership itself is fine ; App is being optimized and updates regularly ; the only thing I am worried about is amount of couriers and orders. Back in time 160DKK per hour was considered as "on average" earning, now it is "up to 160 DKK". As I work in Aarhus for Wolt since 2017 I see a lot of new faces and only few "veterans".
# 5. I would like orders in a larger radius in everyday life when there are not many people here in Frederikshavn
# 6. In general, everything has been good However, Løgstørvej in Hobro is closed for passing-this means being sent out on a detour of 2-6 km (both ways) This means that a trip can be 15-20 minutes longer. And… It often results in customers lasting delayed because the app/system cannot calculate the route ID you are sent out on. Have had some acclaimed errors as support has managed lightning fast
# 7. No demand; orders cheap for long distance. 4hours of work by car for 580kr …what i should pay with this? The tax ? The gasoline or the lease? Or food for myself ?what exactly of this shift . The answer is nothing for myself … all this money will gone for someone else, but not me . INCREASE THIS PRICES .. make us work with pleasure like before in Wolt Denmark. This is absolutely non - respectable and valued job! Day by day … less and less wishes to work. I repeat few many times .. is not put billboards in hole city to make fake advertising (how u gonna earn more then 200kr/h ) . Invest in the ppl who are long with the company and especially ppl by car because without us … WOLT IS losted !
# 8. Wolt Market Glasvej is completely over.
# 9. I was exposed to mental torture even by all Wolt employees inside the Wolt Market Willemoesgade, is completely in shock
# 10. Hey Wolt I have a couple of comments that you may or may not take into consideration up to you ! Il I love using your app and the freedom that comes with it. Long distance travels are currently hard unless i have a e bike, so those deliveries are rejected, most of the times. Could you make some more articles about how we wolt partners can use the danish tax system better ? What is deductible, at swapfiets we have to pay a 200 kr extra fee if we are delivering, is there any ways to tax deduct a ebike ? Any solutions for long distances to make it more appealing? Anyways wish who ever reads this a good day ! I don't know if it's wish thinking I have
#
# Reassigned Outliers → Topic 10 (38 docs) | Original top words: bundle, bundle order, order, pay, task, accept, payment, new, order bundle, system
# 1. Meny had an idea that only will be spent 1 order access but I had 2 orders. A customer swindled me because I couldn't find the address. It is inappropriate to bundle orders from different restaurants are merged together.
# 2. Delivery generally fine, olioli was delayed with orders that delayed everything. Apple Maps very imprecise
# 3. It would be really cool if it could be made so you could see if you were on a bundle order and had to pick up two orders from the same store, because it would be much easier for everyone if you could say to the staff from the beginning of May to pick up two, rather than getting the first one, packing it, and then having to grab the staff again to get the next order
# 4. hate the new boost model
# 5. Now set the payment a little for bundles. No one is bothering to risk an order with waiting or stairs for the 5th floor for 22 kr.
# 6. Weekend was good. Still don't get how it might say "busy" (which per your definition means 'way more orders than couriers on the ground') for few hours, in an area that's packed with venues, and still not get ONE single bundle. Something doesn't make sense. You give bundles only to car/scooters or something?
# 7. When we deliver two order to the same customer or we have bundle it could be nice to click the orders and see customer details
# 8. The distance written for a bundle orders is not the write distance and the payment is not correct even the support team do not know how to handle this and they closed the chat before I got their answer or even let me explain what is wrong
# 9. System has had major issue since you change system yet its not been fixed, at this point i think it's intentional. Also bundles is really not worth it, i drive more km and getting paid less compared to before you change system, it stuns me you haven't YET made a km deduction system, at least you can do that. Benzin is not free.
# 10. Just a FYI. I get why you no longer give the full price for an add-on task but I am no longer accepting anything less than 35kr. I am tores
#
# Reassigned Outliers → Topic 11 (121 docs) | Original top words: bonus, weekend, weekend bonus, order, bonus weekend, bonus time, 17, time, today, remove
# 1. Earnings for same amount of work seems like dropping on weekdays
# 2. Another great day of getting scammed I work 1 hour more than yesterday but i earn the same thanks to your scam system
# 3. Wondering a way to commit me more. The opportunity to see expected income would help with my motivation.
# 4. Quick summary: Until 15 days ago, on weekends from 4:30 p.m. to 8:00 p.m. I was delivering between 16 and 18 orders, on Friday I delivered 5 and I disconnected because I had been unemployed for 1 hour, yesterday I made 9 and today 10, we can't even get the bonus do, it is not worth working on the weekend, more is done during the week, but that loss of the weekend has killed those of us who have Wolt as our main job, it makes us want to cry, and it makes us live with anxiety, the worst thing is that I think it will even get worse, from what I see.
# 5. 165 kr/hr on a Friday with bonus?! Not good....at all. I used to do that on a normal weekday and without bonus up to last summer. These fees need improving and with Foodora even quitting shouldn't be a problem now.
# 6. Why can't pay holiday money?
# 7. It would be great to work when there is bonus during rain..
# 8. Venues are late it's hard to make 50 dkk / hour in Friday peak hour... because you pay so little
# 9. Great support! Low boost during weekends :/ should extend boost!
# 10. I believe working in the rain is worse than weekends, and also see wolt sometimes struggles on the supply side during those conditions, hence the need for a rain bonus fee. This is just my 2 cents, but I suppose demand takes a notch up while supply does the opposite, so in that case it is really called for, from a biz perspective :) Ofc wolt makes more money when it's busy by bundling orders on fewer cp's, so wolt might not be too incentivised anymore to avoid busy ness as long as it doesn't go rougue ofc .. Just thought it'd be nice to reward the extra effort of rain riding
#
# Reassigned Outliers → Topic 12 (387 docs) | Original top words: support, order, deliver, cancel, customer, deduct, ask, tell, mistake, time
# 1. Cancel order button doesnt work, I have 4 options to choose from, but no button to cancel the order only one to contact the support
# 2. I keep getting orders that when i accept i get the message that it's not available anymore, and i accept it almost instantly
# 3. It is still a huge problem that you have to wait over 30 minutes to get the order handed out. It should be compensation for this!
# 4. Think I came to Cancel an order for about 40kr as I delivered anyway
# 5. Today work was okay, Just a problem Sometimes I go to peak order and they tell me the order is already taken. It's had happened twice today. I don't know if we can fix that problem next time. (wasting time.)
# 6. I didn't manage to write it yesterday. Pls contact the owner of Valby pizza & Shawarma hus. He told me his name is Abdul jaba. Hope he was honest. I pick up orders from there as I live in Valby . I want to note down that he had a flirting flow. I don't like it. Last year told me he wants to date with me, then his son said he is married. In the past I gave him my visitkort ads a humanitarian, i gave to some restaurants in case they have cold food, redone, not to throw it but to contact me as I fight against food waste. I keep good communication with the restaurants owner as a food courier. Yesterday he gave me chips as o looked hungry to him. This was a nice gesture. At the same time he was disrespectful and joking and degrading when I reminded him nicely to call me if he has a wrong order etc. he said "only to call you for this. Not for something else?" I find this unprofessional and disrespectful. Pls take this up with him. This behavior is not ok. BR Dalit Vilhelmsen
# 7. I have requested the termination of my partnership 2 times (first time in 2022), but I continue to receive messages as it has not being terminated. Gear has already been returned. What should I do to to make sure my request has been granted?
# 8. It happened a few times that I was presented with an order, but that it then disappeared again after a second, so I could not press yes to the one where it was then lost.
# 9. Last order from Wolt marked was too heavy and broke when customer picked it up
# 10. Hi, I think it has been complicated to contact support about problems. I was at a restaurant that marked his order ready about 15 minutes before they actually were. I wrote this for support so this could be noted in the restaurant's history as I know they are contacted if their order is often too late. When the person in support returns, they write "What can I help with". I am out and running, so I do not have the opportunity to repeat what can already be read.

# %% [markdown]
# topic 0: fits
#
# topic 1: fits mostly
#
# topic 2: fits
#
# topic 3: fits
#
# topic 4: most don't fit
#
# topic 5: 50% passer
#
# topic 6: mostly don't fit
#
# topic 7: mostly don't fit
#
# topic 8: mostly don't fit
#
# topic 9: 50% fits
#
# topic 10: 50% fits
#
# topic 11: 50% fits
#
# topic 12: 50% fits
#
# Overordnet ligner det, at der er lidt form meget støj

# %% [markdown]
# Kigger nu på de outliers der er tilbage

# %%
from collections import defaultdict
import random


# Organize documents by new topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, new_topics_embedding025_2):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = -1
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic -1 (151 documents) ===
# 1. Wolt it's a fking shit
# 2. This whole operation is a fraud, a disgrace, a circus, an infantile pipe-dream. You can have it all
# 3. The last rasturante did not give me the right
# 4. A complete DISASTER. HATING IT A BIT MORE EVERY DAY HOW RIGGED THIS IS
# 5. Slavery 21st century version
# 6. You don’t deserve us
# 7. The algorithm is really intelligent
# 8. Seems very quiet whenever I go out lately.
# 9. Pinza odense needs to get a reality check ,as I was told to stand outside in the snow blizzard ,cause his floor would get dirty otherwise
# 10. you are thieves who rob us every day
# 11. So give me something to do, it can't fit this, what are you thinking about mannnnm
# 12. In do not listen anyway
# 13. It was raining a lot, but besides it, it was perfectly
# 14. A little quiet guard
# 15. Give me something to make, it r a scandal p.t
# 16. It would be great If I get naviagtions
# 17. Like an indicator that reminds us when we need a pin code from the customer
# 18. Stop stealing my tips, you morons!
# 19. Please change the green circle for Strandvejen 5. The position is wrong. Thank you Dirk
# 20. Please add a 5 DDK tip bottom

# %% [markdown]
# Mostly noise (hard to place in a topic). However most of it are aggresive tones

# %% [markdown]
# #### Inspecting of embedding045

# %%
topics_emb_045_2 = results[("embeddings", 0.45)]["model"]
topics_emb_045_2.get_topic_info()
# Out:
#     Topic  Count                                Name  \
# 0      -1   1434             -1_work_time_wolt_money
# 1       0   2386           0_order_courier_hour_wolt
# 2       1   1387             1_ready_wait_order_time
# 3       2   1213         2_happy_wolt_good_excellent
# 4       3   1031               3_app_order_work_time
# 5       4    798          4_km_distance_delivery_pay
# 6       5    389    5_support_wolt support_team_chat
# 7       6    386            6_map_address_app_google
# 8       7    299              7_bag_drink_pack_order
# 9       8    223             8_task_time_accept_work
# 10      9    246     9_wolt_order_market_wolt market
# 11     10    147    10_bundle_order_bundle order_pay
# 12     11    157  11_bonus_weekend_weekend bonus_day
# 13     12    368     12_order_support_cancel_deliver
#
#                                        Representation  \
# 0   [work, time, wolt, money, pay, good, day, like...
# 1   [order, courier, hour, wolt, pay, low, payment...
# 2   [ready, wait, order, time, restaurant, food, m...
# 3   [happy, wolt, good, excellent, day, thank, wor...
# 4   [app, order, work, time, app work, support, ta...
# 5   [km, distance, delivery, pay, drive, car, driv...
# 6   [support, wolt support, team, chat, help, bad,...
# 7   [map, address, app, google, location, gps, map...
# 8   [bag, drink, pack, order, food, cup, restauran...
# 9   [task, time, accept, work, busy, hour, task ta...
# 10  [wolt, order, market, wolt market, denmark, wo...
# 11  [bundle, order, bundle order, pay, task, payme...
# 12  [bonus, weekend, weekend bonus, day, order, bo...
# 13  [order, support, cancel, deliver, customer, ti...
#
#                                               KeyBERT  \
# 0   [earn, work, pay, hire, salary, job, money, le...
# 1   [get order, receive order, order order, pay or...
# 2   [food ready, restaurant, order ready, delay, w...
# 3   [love wolt, wolt happy, happy wolt, wolt good,...
# 4   [app work, order app, app app, app, app let, w...
# 5   [wolt, favor wolt, fee, delivery, deliver, app...
# 6   [wolt support, support support, support good, ...
# 7   [google map, google maps, map app, wrong addre...
# 8   [bag order, food bag, paper bag, use bag, bag ...
# 9   [task come, wait task, single task, add task, ...
# 10  [wolt market, order wolt, market vanløse, wolt...
# 11  [bundle payment, bundle pay, pay bundle, order...
# 12  [weekend bonus, bonus weekend, hour bonus, bon...
# 13  [cancel order, order cancel, deliver order, or...
#
#                                                   MMR  \
# 0   [work, pay, day, hour, tax, customer, sunday, ...
# 1   [courier, wolt, low, payment, work, day, earni...
# 2   [restaurant, mcdonald, min, order ready, food ...
# 3   [day, happy wolt, wolt happy, excellent day, e...
# 4   [app, app work, error, delivery, crash, app le...
# 5   [km, delivery, driver, kr, payment, bicycle, k...
# 6   [support, wolt support, chat, support good, su...
# 7   [map, address, app, gps, maps, google map, goo...
# 8   [bag, pack, soda, spill, paper bag, lid, mcdon...
# 9   [busy, task task, accept task, new task, time ...
# 10  [wolt market, denmark, danish, courier, market...
# 11  [bundle, order, bundle order, payment, accept,...
# 12  [weekend, weekend bonus, boost, pay, bonus wee...
# 13  [order, cancel, deliver, customer, accept, can...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [More orders would be delicious, There are not...
# 2   [Ask Pick up places not to mark the order read...
# 3   [i am very happy with wolt, i am very happy wi...
# 4   [App crashes. App lets me drive for miles, the...
# 5   [You say it is 0.1km ekstra but actual distanc...
# 6   [Haven't used Wolt Support, so is still uncert...
# 7   [Still problems with the addressees in Google ...
# 8   [McDonalds City putting orders in big bags is ...
# 9   [I don't get as many tasks, It's Sku Slay with...
# 10  [I also want to order Wolt Market in Vanløse o...
# 11  [Why the system give bundles when there are no...
# 12  [Put a bonus for weekend 23to02am, Where is ou...
# 13  [I had the order 7J5DV3, in which the app sent...

# %%
# Step 1: Get original topics (before outlier reduction)
topics, _ = reduced_model2_2.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Step 2: Get new topics (after outlier reduction using embedding + 0.25 threshold)
new_topics_embedding045_2 = results[("embeddings", 0.45)]["topics"]

# Step 1: Find reassigned outliers (originally -1, now assigned to a topic)
reassigned_outliers = [
    (i, doc, new_topic)
    for i, (doc, old_topic, new_topic) in enumerate(zip(documents, topics, new_topics_embedding045))
    if old_topic == -1 and new_topic != -1
]

# Step 2: Group reassigned outliers by new topic
topic_to_outlier_docs = defaultdict(list)
for i, doc, new_topic in reassigned_outliers:
    topic_to_outlier_docs[new_topic].append(doc)

# Step 3: Print sampled outlier docs with ORIGINAL top words (from reduced_model2)
for topic_id in sorted(topic_to_outlier_docs.keys()):
    docs = topic_to_outlier_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))

    # Get original top words from reduced_model2
    original_topic_words = reduced_model2_2.get_topic(topic_id)
    if original_topic_words:
        top_words = ", ".join([word for word, _ in original_topic_words])
    else:
        top_words = "(No original top words)"

    print(f"Reassigned Outliers → Topic {topic_id} ({len(docs)} docs) | Original top words: {top_words}")
    for j, doc in enumerate(sampled_docs):  
        print(f"{j+1}. {doc}")
    print()
# Out:
# Reassigned Outliers → Topic 0 (720 docs) | Original top words: order, courier, hour, pay, new, payment, low, earning, work, wolt
# 1. This is not a complaint, but I would like to draw your attention to the behavior of the Volt Market Soborg employees. Firstly, they are in no hurry to give orders to the couriers, sometimes pretending that they simply do not notice the couriers, that they are standing and waiting for their orders. And secondly, they give orders with such an air as if they are doing someone a favor. Frankly speaking, on some shifts you don’t even want to take orders there because of such behavior of the staff. I hope that you will help them to respect the couriers a little, since this is your structure and you have a direct influence on them.
# 2. Wolt needs to do something about the venues who mark the order as ready and it's not ready. We loose time going to the venue, expecting the order is ready. When we get there they say it's not ready and that we need to wait 10 or 15+ min until it's ready. This makes us riders loose time and energy. And of course money. It's not fair for us riders. Venues who exceed the time for the order should be penalized in some way. Because it's us riders who at the end of the day end up loosing nad being penalized (for being on time to pick up the order? ) I hope Wolt resolves this issue as soon as possible, because it's very frustrating. And affects our income very bad
# 3. Who take orders over 60-75 kr ??? Only special "curiers" like Roxana ???
# 4. I don't know if it's the app or to meny currier/drivers. But the last week I worked from 11 to around 13:30 o'clock with so few orders that I actually lost money on gas and time on it. Just take today's peak time 1 hour and 34 minutes and got only 1 order on 40kr drove the whole city so meny times. There most be a solution on this matter.
# 5. Delayed orders wayy to much
# 6. no have orders. ? from 11 ? would they have ordered or? to take a day off
# 7. We need hourly pay or better pay per order in odense
# 8. Wolt market took 20min+
# 9. Bad pay for the deliveries I had and bad connections. Taking several orders at once was actually worse than taking just one at a time. I will have to be more careful with the orders i accept from now on because some of them are really really really not worth the effort
# 10. 3 and half hours online,2 orders,110 dkk!!!!! it can be worse than that, probably yes
#
# Reassigned Outliers → Topic 1 (323 docs) | Original top words: ready, wait, order, restaurant, time, food, minute, burger, mcdonald, min
# 1. Would be neat were venues to provide somewhat accurate "order ready"-time....
# 2. Long distances to pick up orders
# 3. It is very very difficult to collect 3 deliveries from three restaurants within the city of Aalborg because as a car driver we can’t go in all the streets. So it is time to rethink the policy of combine order from different restaurants as it is time consuming and too much stress for car drivers. Instead it is better to collect 2-3 orders from same restaurant and delivery different locations in the similar direction or a little bit deviating direction. We can’t earn that much the way we are working hard and taking all the risk on the road. There are lot of options to be more efficient.
# 4. The delivery times were a bit short sometimes.
# 5. I experience more disrespect from the venue to the couriers. Even today a teenager shouted to me because I arrived 27 minutes late of the order. (When I received the order it was 23 minutes late already.) so they wanted to close, it’s too much bad and insulting such atmosphere. Strøg Shawarma. It’s really bad and insulting for good and educated people like us.
# 6. When the customer has chosen contact-free delivery, it says in app that I need to wait until the customer opens the door, but some customers don't know that the courier needs to wait for them to open the door, so sometimes (not so often though) it takes a long time for that to happen. Maybe it could be made clearer to the customers?
# 7. I got an order from Riviera bar it was already late when I when to pick up the order I was told to wait 15 minutes, so I did but after 15 minutes I asked for order they told me I had to wait 20 minutes, so I canceled the order and waisted my time for nothing
# 8. Grow pop thai to Kathrine. The food was over 20 min. delayed so I took the order off. Let it move on to those who work with the restaurants.
# 9. No notification when venue marks food ready
# 10. Today it happened to me several times, arriving to venues to pick up orders marked as ready and find out that they were still several minutes to go. So not ready. I understand by the pattern that this may have come from you. If unfortunately this is like that, let me tell you that this is not good. It’s not good to put my time and the planning I do in terms of the type of orders I want to accept at someone else’s disposal. Please correct this and try to be accurate in the the you mark the orders. Thanks in advance.
#
# Reassigned Outliers → Topic 2 (216 docs) | Original top words: happy, wolt, good, work, thank, happy wolt, day, wolt happy, love, job
# 1. Really happy with the customer support
# 2. I'm really happy, and really enjoy the job. The only thing I've been thinking about is why the customer should give gratuity before they got the food.
# 3. In its entirety, Wolt is pretty good, you have just become fiercely stingy
# 4. Have an excellent week
# 5. Have an excellent week
# 6. Very friendly customer service!
# 7. Wolt is the Best..!!
# 8. Have a nice week!!!!!!!
# 9. Have an excellent weekend
# 10. Have an excellent day
#
# Reassigned Outliers → Topic 3 (360 docs) | Original top words: app, order, work, app work, time, offer, dkk, drive, error, task
# 1. App was unstable, slow and clumsy.
# 2. I am using the app with new payment method and I am satisfied. I am delivering with car.
# 3. I cannot anymore i have try few times to work today but is disaster!!! What kind of app you have and what kind of IT SUPPORT ? 1.st of all the rate prices … is absolutely bad JOKE FOR us to work 5km per 50kr ?!?!? 2. Now when appear on the display some order is error all the time we cannot take it . After when we reject something appear on the display 10 times more … very very disappointed to start work today!
# 4. App crashes for 5+ minutes at a time. Nothing fixes it.
# 5. The app works terribly. Cutting our salaries was not nice. I don’t like when the volume goes down when receiving a task. On the other hand, I think it’s better that wolt pays our taxes now. There have been more orders this month. I hope it remains the same.
# 6. App keeps going down when I connect support
# 7. The app didn't work from first Bot needed to be updated and after that fine
# 8. Wolt has become extremely stingy, Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you have set our starting fee down from 45,- to 35,- earlier it was a bird spacing of 450 meters when the reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km, can give 24,- as it is a delivery close to the previous one and not as before, both order from start to finish. Personally I reject all order to less than 35,- That is, even one of 34.95,- will be rejected I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped and it can be clearly felt how busy it has become. Many orders are thrown out and made up to 3 times I have experienced, as us cures who are left can not reach and pick up in time as you replace/pay. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !! It will probably not last long until I do the same
# 9. App is not showing prices paid for the job. So I don’t have the ability to choose what tasks to accept or not.
# 10. The app is far to a good app. It is blocking and not connecting always.
#
# Reassigned Outliers → Topic 4 (363 docs) | Original top words: km, distance, delivery, pay, driver, drive, car, money, payment, long
# 1. Long distance to pickup. Not many orders to choose
# 2. For Norebreo we should send only bikers and scooterists guys because of the closed Norebrogade it' not worth it to deliver by car 'cause the app is calculating the route but she doesn't knows that we need to go arround that entyre street to reach to the customer unfortunately... please take it in consideration...!!! Thx very much...!!!
# 3. Same pattern as always..kates 2 km without orders then get an almost clear order on the route I have just run, ie an order that must have been offered long ..
# 4. Well. Been having a nice abusing day and it's sooo nice to go to work with this shitty payment! Order 8.3 km for 110kr... apparently ive had to accept the buttplugging and listen to my podcast. Thanks wolt operation team for the shitty payment ideas... I honestly believe operations team thought it was a good idea without even testing their shit...
# 5. Works good enough but there is too little payment for a long trip. Car drive more in km. A long trip response to 2 short trips. Less km. and less time but payment is the same for a short trip. The other thing regarding App, which shows default graphic statistics for busyness that shows on the app when you start the app. It must show how many turns are currently time. Otherwise I'm happy.
# 6. Missing the old scheme where one could choose Fixed Paid 3 hours and earned out of 500 meters
# 7. It is unfair to wait at 0 kroner for 1.30 hours during the night shift at Amager Center. Prices have already dropped. It doesn't work either. I'm curious where this situation will go. We work with our own car and our own fuel. Car tires, oil change, maintenance and fuel are not cheap things. It would be good if you calculate these costs once again and re-evaluate the prices.
# 8. Verry bad experience today from first delivery I drive 10 km to get 35 dk and wolt suport makking fun out of my problem
# 9. The distance calculation is not done correctly and this is always annoying and the support staff sometimes don't give the correct answer, I think they just want to finish conversation.
# 10. It came to my attention that the miles were calculated incorrectly. I have almost always driven more than the kilometers paid.
#
# Reassigned Outliers → Topic 5 (58 docs) | Original top words: support, wolt support, chat, team, bad, help, wolt, support team, good, contact
# 1. Bad support and wages
# 2. You are paying less every month. Support really sucks, nobody take care about the riders. Support only are smart to take money from your savings, in other situations they look stupid and seem that you are chating with a bot. Also noboy see this feedback. I never had a reply. So why you do it?
# 3. Support its worst everydays. Today i waste 1 hour because i had another location (i dont kniw why) and i asked a lot of times because i didn't have orders and anyones checked. I'm super hungry
# 4. Order marked as ready, waiting time for over 20 min in peak hours :( bad support. Get told that there is just nothing to do practice
# 5. Thank you so much for your support and help Goodnight
# 6. Great help from support
# 7. Slow support, your navigation fucked me up
# 8. You have the best system it runs smoothly everytime, no problems whatsoever, I dont think you have change anything, and your support is also the best they always have a solution for everything, you should give them a raise especially the ones i have been in contact with today
# 9. It's a bit unfortunate that the system reports unknown errors when you can see for yourself what the error is, and support also says they don't know about the error
# 10. Support thank you so much,
#
# Reassigned Outliers → Topic 6 (64 docs) | Original top words: map, address, google, gps, app, location, maps, wrong, google map, google maps
# 1. Another order that only shows up when you are close to the pick up place and have run about one kilometer before. Have you programmed the algorithm for it?
# 2. I was face problem with my last delivery I was not able to swipe the address .
# 3. Your cards are always mega misleading about where the food should be delivered, there should be built -in GPS It's a worse mess to have a GPS on another app simultaneously.
# 4. Today, I put the wrong food due to the google map error and contactless customer, but after the support messaged me, I went back and corrected it, but I was fined, and this was a bad experience for me.
# 5. Please make it possible to copy the address as well because sometimes Google maps inputs the wrong one
# 6. I'm not sure if my last delivery, to a Louise Black, actually went through. After delivering, it kept giving me errors when I tried to slide the "Delivered!" bar. Then it just suddenly went back to map.
# 7. Either I am not aware how it is done but lack of navigation in the app is cumbersome.
# 8. I think there was a bug, saw it 2 times. I believe when the app shows the customer's location before pick-up, and there is another order that can be picked up right after, the app will show the wrong customer's location (it shows the second one) until I decline the second order after confirming the pick up of the first one.
# 9. The kilometer counter does not work inside the app, in addition I have requested my km numbers through the app and still nothing received.
# 10. At the beginning the app had lags: didnt show the the client on the map, cracked(log out) several times
#
# Reassigned Outliers → Topic 7 (30 docs) | Original top words: bag, drink, pack, cup, food, paper, order, spill, soda, customer
# 1. MENY Packed the goods very badly
# 2. I got an order I couldn’t fit in my bag
# 3. This one guy at Papa Cucina is very demeaning towards couriers, asking us to wait outside even when it is pouring, i do not intend to pick up there any longer at least.
# 4. Over some time I’ve noticed some room for improvement for McDonald’s. First, the cups are not sealed good enough. Often the soft drinks spill in the bag, eventhough i try to drive carefully (bike), and make the inside of the bag wet and sticky. Secondly, often (not always) the staff don’t seem to pay attention to Wolt couriers. Often eventhough the order is ready, they don’t reach out to me when I enter the restaurant and go to the counter. I know they are busy but when i stand in front of the counter with my big blue bag, they should pay attention at least within a minute or two. I don’t want to disturb their work, but sometimes I have to call across the counter after many minutes without them realizing I’m here.
# 5. Macdonalds packing of coffee very poor.
# 6. Good morning, I would like to raise a concern regarding supermarket orders, such as Spar, for instance. Most of the time, these orders are quite heavy, and as a delivery driver, I have no way of knowing what the order contains, as the description does not provide any details about the contents. I can only find out the order's contents when I arrive at the restaurant and the staff hands it over to me. It wouldn't be fair to request that I reject the order at that moment because it would mean wasting a lot of time, including the time it took to get to the supermarket and the time spent waiting for a new order. Last night, I had to carry 10 bottles of oil from SPAR, in addition to an existing order in my backpack, and carrying all of this on my back is not healthy. It would be beneficial to find a solution to prevent this from happening. As a delivery driver, the only solution I can think of is to stop accepting such orders, but I don't believe that's the best option for everyone.
# 7. Pizzatime (my last delivery) wasn't wrapped properly so JRG had to go home and clean my bag
# 8. Eat Now Højbjerg has pizzas wider than our bags. Bruh
# 9. Can you explain McDonald railway station that many of us Wolt Budde has attached our bags on our bikes scooters and cars, There is only one particular employee who in the McDonald railway station who refuses to hand out the order before hair out and pick up his attached bag and it takes time, there is a box -made of 8 steps from the counter where you get the food for your bike where you get the order in the bag. It is only this one employee that does it and it is only this one McDonald it happens by. Please explain the manager who both order gets cold and it is frustrating to have driven all the way there and then not get the order.
# 10. It is completely unacceptable that I should stand for 15 minutes in rain just to cancel an order so I could drive on with an order I already had in my bag completely unacceptable
#
# Reassigned Outliers → Topic 8 (77 docs) | Original top words: task, task task, time, new task, accept, accept task, new, hour, disappear, receive
# 1. More than 2 hours nothing
# 2. Shame on this job and your frustrating system
# 3. Hard work but no reward because of your new system where you steal all the double order money. Not mentioning the 5DKK drop on all task fees. Good luck on busy mode this Winther.
# 4. I waited many times today but I didn’t get a task for me to deliver. Hope it will get better going forward. Please look into this. I will be online again tomorrow. Thanks
# 5. Going offline due to your support employee Hector, I do not bother every time he does things slowly, he does it almost intentionally otherwise he just dont dare not to his job But that's why I go offline now
# 6. Task fees go down and down...
# 7. I really love this work, but the price of tasks has now become so low that it makes it impossible to continue with you, a shame you have become so fucking greedy !!!
# 8. Whar is this?!?!? This is not job
# 9. No work? maybe it's time to go on vacation?
# 10. I have always to wait even in busy time
#
# Reassigned Outliers → Topic 9 (108 docs) | Original top words: wolt, market, wolt market, market vanløse, order, vanløse, danish, copenhagen, denmark, hour
# 1. Not enough orders , people are just not ordering it's quiet all the time, there's too much people driving in Aarhus, we can barely pay our rent and make for bread.
# 2. No demand; orders cheap for long distance. 4hours of work by car for 580kr …what i should pay with this? The tax ? The gasoline or the lease? Or food for myself ?what exactly of this shift . The answer is nothing for myself … all this money will gone for someone else, but not me . INCREASE THIS PRICES .. make us work with pleasure like before in Wolt Denmark. This is absolutely non - respectable and valued job! Day by day … less and less wishes to work. I repeat few many times .. is not put billboards in hole city to make fake advertising (how u gonna earn more then 200kr/h ) . Invest in the ppl who are long with the company and especially ppl by car because without us … WOLT IS losted !
# 3. Am tired of your lies and your lower intelligent collaborative partners who refuse to do their job It may not be true that I have to wait for a trip from Burger King Nørreport which is reported clear but because they do not care about Wolt, the trip is just even if it is packed and the bid is ready it does not become Correcting it up and doing something. By saying that it is the best day to deliver but has been out for almost 5 hours and earned £ 800 where is the best day so I should have earned as much as last year but no is just paid what you always do fucking ridiculous
# 4. There are too little orders, too little money because there is too. A little orders I drive back and forth but I only get money for it is the worst. I have gasoline consumption, car wear, but still I serve difficult enough more than other "light" jobs in Denmark. Stop being greedy and taking prices down or getting customers so I can work for the same salary as now or better. I sit and do nothing more than I work, almost. Under 150kr per hour for the most part. in advertising for 160kr per hour. lies.
# 5. (Continuation of my previous message as I sent it a bit too early)… The kind of discrimination faced by us Wolt couriers in Mc Donalds in Hillerød is unacceptable and almost criminal by law. I hope you can align with them a more appropriate way to treat the couriers and to not down-prioritizing our food, so it’s always late for our customers. Further more please pay attention to Wolt couriers that are stealing food from the restaurants and take the necessary actions to stop it from happening continuously, so that the better behaved Wolt couriers can have a better collaboration with the restaurants. Thanks in advance!
# 6. A complete disappointment should not even be given a score, they make fun of us in the face, the rates are a pittance and they are getting lower and lower and they don't care more than just filling the company's pocket because of us who are the ones who do the hard work in this harsh and cold Danish winter, there is no benefit for us, we feel exploited and not valued, a disaster
# 7. Recently I can't get sufficient orders at Aarhus. Long time have been waiting for receive an order. Payment should be increased. For 8/10 hours working I can make only 500-700. I think I shouldn't depend on this delivery job....
# 8. Wolt Support told me there are so -called hot spots, so even though the app said there was an odre soon, never came one, but next time, I'm down at Stengade in Helsingør, which is a hotspot;) Thanks to the support and pretty misleading of the app to say there was an odre soon
# 9. Risk of confusion: At Vesterbro are two Oli Oli Business, one on Istedgade and one on Sønder Boulevard. I was wrong today and maybe you can give them a name by the way? Today it was called "Oli Oli Vesterbro", but there they both are located, and the pick up cursor is relatively largely compared to how close the two cafes are on each other, so you can easily be mistaken in the heat of the fight
# 10. So nobody is reading the messages her and nobody is interested in cases of discrimination and racism from support agents against couriers. It is difficult to accept that this happens even in Denmark ,:))
#
# Reassigned Outliers → Topic 10 (25 docs) | Original top words: bundle, bundle order, order, pay, task, accept, payment, new, order bundle, system
# 1. It would be really cool if it could be made so you could see if you were on a bundle order and had to pick up two orders from the same store, because it would be much easier for everyone if you could say to the staff from the beginning of May to pick up two, rather than getting the first one, packing it, and then having to grab the staff again to get the next order
# 2. The new pay system is unfavorable and unreasonable to couriers. This is especially with services provided by couriers during bundle deliveries…in my opinion that’s not fair …we should get our full fee for services whether bundle or single delivery.
# 3. I can’t see the weight of order when I receive them in bundles.
# 4. Delivery generally fine, olioli was delayed with orders that delayed everything. Apple Maps very imprecise
# 5. Hi Wolt Support, I wanted to share some feedback and a suggestion that could really improve the experience for couriers like me. It would be great if the app could show us the order items before we accept the delivery. That way, if my bag is almost full and the order is small, I can accept it. But if it’s a larger order, I can leave it for another Wolt courier with more space (or someone with a car). Also, I want to say a big thank you for finally adding the “decline delivery” feature after accidentally accepting an order. I’ve been waiting for that for a long time, and it’s much appreciated! Thanks for considering this suggestion, and keep up the great work! Best regards, Samuele
# 6. The prices are very low specifically for long distances and bundle
# 7. Time waste. Too much emphasis on bundles. That's why a lot of orders were late(bad for customers). Because of this couriers weren't getting orders in a fluid manner. Spending periods without an order just to get bundles out of the blue. Revert back. This is bad for couriers and customers!!! It will come to Wolt as the company if things don't improve
# 8. Free delivery for the customers, less payment for couriers. I am working so hard, but at the end I'm just tired and nothing more. Orders in bundle coming 4-5 in a row and they don't give me nothing. Why i should take them? Now everything I so expensive and you guys paying less and less for more work than before. You gonna loose many of the couriers and when you don't have enough to pick up the orders you gonna start loosing customers too. Nobody what his food 30 min and more delayed food.
# 9. I got a survey earlier today where I said I felt the payment was fine. However on busy days like today, and snowy weather, where you're held up in ultra slow traffic, the tasks could pay better. Especially the bundles fees, as arriving to the venues and customers take extra long time in these weather conditions. Otherwise all is good!
# 10. Get back to old payment method! It's more clear! Now we don't know, you just se the price that you like for the tasks, really unfair. Km deduction!!!! It doesn't worth it anymore to deliver over 3km. We have to pay 100% of our expenses and the prices are super low. Let the bundles be the full price as before! 35kr for a bundle task over 4km??? When we actually have to drive 1-2-3 km from first drop of to the second??? This is insane
#
# Reassigned Outliers → Topic 11 (62 docs) | Original top words: bonus, weekend, weekend bonus, order, bonus weekend, bonus time, 17, time, today, remove
# 1. Boost should be start from 18:00 pm to 21:00 pm. There is no use of boost in between 17:00 to 18:00 pm as the day time increases than before. People usually start their dinner after 18:00 pm. You must take action. Very low amount of order in between 17-18 pm . We have observed for last few days. Take consideration the issue so that we can make the most use of it. Good for both
# 2. I suggest you pay more hours bonus on weekends and when the weather is really bad like yesterday in Copenhagen.
# 3. Hey guys, I hope you be a bit more careful with the bonuses, on x amount of orders, when you’re uncertain how busy the evening actually will be. I stoppes today after just two orders, when i had planned to drive the whole rushhour, as the streets were yet again packed with drivers waiting for tasks.
# 4. Very week day , considering that it's pay weekend ,before the amount earned was double
# 5. It is thrilled that the extra money does not work when you pick up 15:59 and it starts at 16, so you have to wait to accept instead of taking it.
# 6. Very dissapointed in the folks alerting about “high order weekend” there’s no activity at all…
# 7. Fees are still pretty bad. 162 per hour on a Sunday where everyone is back from vacation AND with bonus on. I used to do that on a normal weekday up to last summer. Something needs to change here.
# 8. Night time should have bonus pay. Like it is now it's ridiculous
# 9. Been told there was boost on all orders and later only between 17-20, an later on I ask again there should be 15%. But I can't calculate any boost compare to yesterday or this afternoon ! Dear wolt this have been the worst snowstorm in Denmark for 13 years, we risk our cars and life out on these ice roads. All support massages should be honest, and we should at least get the 20% boost at night on weekends, as we used to for years!
# 10. I still have not received my payment for the 1-15, that’s the only reason I’m not giving 5 stars
#
# Reassigned Outliers → Topic 12 (278 docs) | Original top words: support, order, deliver, cancel, customer, deduct, ask, tell, mistake, time
# 1. Tell me what happened from 19:45 to 20:05 I didn’t receive any order You should compensate me about it there were orders outside and support didn’t help me
# 2. Took a long time to detect that I had finished the orders
# 3. Can't you do so that you should not receive orders below 65kr for example?
# 4. I got a bad experience with a customer who was unhappy and shouted and slammed doors after me
# 5. I got logged out while going into the city actively looking for deliveries, but since my phone is in my pocket I was unaware and I don’t know how many potential orders I have missed because of this
# 6. Hello, I had bad experience not only today, also few times before when I show up to pick up a order in the venue, order is already stolen from another courier. What they do they ask for the order, pick up it and they don't swipe to start delivery, they cancel the order, but they already stole the food. So when I show up and ask for the order in the venue they say "is already picked". I always tell the workers in the venues to ask the courier to show them how they swipe before they leave. And I think is very easy for you to find out who is doing this, you have the courier in your system and to punish him.
# 7. Please fix the application, every day we have to receive a delivery and we go to the restaurant and that delivery has already been delivered, but of course Wolt is never to blame, it is always us, and of course we drive kilometers for nothing, because no one pays us, The excuse is always the same. Since you don't want to pay for your mistake, fix the application, thank you
# 8. Time estimate was off by 1hour, then missed another order in queue because support was too slow to cancel the late one
# 9. Did not receive yet the payment for 1-15 June. It is already 25 June.
# 10. Cancel order button doesnt work, I have 4 options to choose from, but no button to cancel the order only one to contact the support

# %% [markdown]
# topic 0: 50% fits
#
# topic 1: mostly fits
#
# topic 2: fits
#
# topic 3: fits
#
# topic 4: mostly fits
#
# topic 5: fits
#
# topic 6: 50% fits
#
# topic 7: 50% fits
#
# topic 8: mostly don't fit
#
# topic 9: mostly don't fit
#
# topic 10: fits
#
# topic 11: mostly fits
#
# topic 12: mostly don't fit

# %% [markdown]
# Kigger nu på de outliers der er tilbage

# %%
from collections import defaultdict
import random


# Organize documents by new topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, new_topics_embedding045):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = -1
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic -1 (1434 documents) ===
# 1. All good, except for Mc Kastrup. They are without exception, always between 7-10 min backwards. Apology we are so busy they have such a disrespect to us cures
# 2. Hi It's seemed distances are longer than which are indicated in the tasks. There's no difference between first floor and fourth floor . In my opinion it should be added cost for each sale on destination , because of used energy and time for climbing the stairs . Thanks
# 3. Have an excellent Sunday
# 4. Add ratings to each venue after task 1-5 stars. To get the venues to become better. Best rated venue get diplomas to hang in restaurant
# 5. Stop asking for feedback repeatedly!
# 6. No extra boost this Saturday due to Monday "free day" ..... come on Wolt!!!! Is that the best way to motivate us to jump on the road??!!??
# 7. It is a scam, it is not worth putting in physical effort for this company.
# 8. There's not registered km drive ... Is there an error?
# 9. Make option in settings for rider to be able to choose pickup radius.
# 10. If I stand online, there is no order ???
# 11. Original pita always late even when not busy
# 12. Lorteeeeeeee algoritme
# 13. Forgot to mark as delivered
# 14. I thought it deeply ridiculous that it is clear that you can wait mamge minutes for again things? Jers Sport isn't quite with being time? Rasturants are mega bad for liver on time
# 15. There should be more to do out of peak hours.
# 16. you are dirty toilets, the algorithm is stealing from us, it is not compatible with us, I will file a complaint everywhere
# 17. Add reject system of order
# 18. One day there is a lot of work and the next nothing, that's how it is wolt, all the time, inefficient, opportunistic, basic, they only think about themselves and do not pay vacations.
# 19. All week earming per hour was meh but on Sunday was really good. Hoping it was not a one-time thing.
# 20. Its all good, but I wish the app on iOS didn’t lower my volume while listening to audio .

# %% [markdown]
# Nearly 50% could actually fit in a topic

# %% [markdown]
# #### Inspecting of embedding055

# %%
topics_emb_055_2 = results[("embeddings", 0.55)]["model"]
topics_emb_055_2.get_topic_info()
# Out:
#     Topic  Count                                  Name  \
# 0      -1   2628               -1_order_work_time_wolt
# 1       0   2072              0_order_courier_hour_pay
# 2       1   1273               1_ready_wait_order_time
# 3       2   1024                2_happy_wolt_good_work
# 4       3    924                 3_app_order_work_time
# 5       4    634          4_km_distance_delivery_drive
# 6       5    364      5_support_wolt support_team_chat
# 7       6    351              6_map_address_app_google
# 8       7    283                 7_bag_drink_pack_food
# 9       8    178          8_task_time_accept_task task
# 10      9    206           9_wolt_order_denmark_market
# 11     10    140      10_bundle_order_bundle order_pay
# 12     11    128  11_bonus_weekend_weekend bonus_order
# 13     12    259       12_order_support_deliver_cancel
#
#                                        Representation  \
# 0   [order, work, time, wolt, excellent, day, hour...
# 1   [order, courier, hour, pay, wolt, low, payment...
# 2   [ready, wait, order, time, food, restaurant, m...
# 3   [happy, wolt, good, work, happy wolt, thank, d...
# 4   [app, order, work, time, app work, support, ta...
# 5   [km, distance, delivery, drive, pay, order, dr...
# 6   [support, wolt support, team, chat, bad, help,...
# 7   [map, address, app, google, gps, location, map...
# 8   [bag, drink, pack, food, order, cup, soda, pap...
# 9   [task, time, accept, task task, second, new, n...
# 10  [wolt, order, denmark, market, wolt market, wo...
# 11  [bundle, order, bundle order, pay, task, payme...
# 12  [bonus, weekend, weekend bonus, order, day, bo...
# 13  [order, support, deliver, cancel, customer, ti...
#
#                                               KeyBERT  \
# 0   [order, deliver, wolt, delivery, earn, work, b...
# 1   [order, get order, order order, receive order,...
# 2   [food ready, order ready, delay, waiting time,...
# 3   [love wolt, wolt happy, happy wolt, wolt, wolt...
# 4   [app app, app, app work, fix app, problem app,...
# 5   [distance payment, wolt, fee, favor wolt, dist...
# 6   [wolt support, support wolt, support support, ...
# 7   [google map, google maps, map app, wrong addre...
# 8   [bag order, food bag, paper bag, use bag, bag ...
# 9   [task come, task, task task, wait task, new ta...
# 10  [market vanløse, vanløse, order wolt, wolt mar...
# 11  [bundle payment, bundle pay, pay bundle, order...
# 12  [weekend bonus, saturday bonus, friday bonus, ...
# 13  [cancel order, order cancel, deliver order, or...
#
#                                                   MMR  \
# 0   [order, work, day, hour, pay, delivery, custom...
# 1   [courier, hour, wolt, payment, work, earning, ...
# 2   [restaurant, burger, mcdonald, order ready, fo...
# 3   [happy, happy wolt, day, wolt happy, work wolt...
# 4   [app work, error, hour, app let, drive mile, o...
# 5   [km, delivery, drive, payment, kr, bike, app, ...
# 6   [support, wolt support, chat, support team, su...
# 7   [map, address, gps, maps, google map, google m...
# 8   [bag, pack, soda, spill, paper bag, lid, mcdon...
# 9   [task task, new task, accept task, time task, ...
# 10  [denmark, wolt market, danish, market vanløse,...
# 11  [bundle, bundle order, payment, order bundle, ...
# 12  [weekend, weekend bonus, bonus weekend, hour, ...
# 13  [order, deliver, cancel, customer, compensatio...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [More orders would be delicious, There are not...
# 2   [Ask Pick up places not to mark the order read...
# 3   [i am very happy with wolt, i am very happy wi...
# 4   [App crashes. App lets me drive for miles, the...
# 5   [You say it is 0.1km ekstra but actual distanc...
# 6   [Haven't used Wolt Support, so is still uncert...
# 7   [Still problems with the addressees in Google ...
# 8   [McDonalds City putting orders in big bags is ...
# 9   [I don't get as many tasks, It's Sku Slay with...
# 10  [I also want to order Wolt Market in Vanløse o...
# 11  [Why the system give bundles when there are no...
# 12  [Put a bonus for weekend 23to02am, Where is ou...
# 13  [I had the order 7J5DV3, in which the app sent...

# %%
# Step 1: Get original topics (before outlier reduction)
topics, _ = reduced_model2_2.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Step 2: Get new topics (after outlier reduction using embedding + 0.25 threshold)
new_topics_embedding055_2 = results[("embeddings", 0.55)]["topics"]

# Step 1: Find reassigned outliers (originally -1, now assigned to a topic)
reassigned_outliers = [
    (i, doc, new_topic)
    for i, (doc, old_topic, new_topic) in enumerate(zip(documents, topics, new_topics_embedding055))
    if old_topic == -1 and new_topic != -1
]

# Step 2: Group reassigned outliers by new topic
topic_to_outlier_docs = defaultdict(list)
for i, doc, new_topic in reassigned_outliers:
    topic_to_outlier_docs[new_topic].append(doc)

# Step 3: Print sampled outlier docs with ORIGINAL top words (from reduced_model2)
for topic_id in sorted(topic_to_outlier_docs.keys()):
    docs = topic_to_outlier_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))

    # Get original top words from reduced_model2
    original_topic_words = reduced_model2_2.get_topic(topic_id)
    if original_topic_words:
        top_words = ", ".join([word for word, _ in original_topic_words])
    else:
        top_words = "(No original top words)"

    print(f"Reassigned Outliers → Topic {topic_id} ({len(docs)} docs) | Original top words: {top_words}")
    for j, doc in enumerate(sampled_docs):  
        print(f"{j+1}. {doc}")
    print()
# Out:
# Reassigned Outliers → Topic 0 (406 docs) | Original top words: order, courier, hour, pay, new, payment, low, earning, work, wolt
# 1. Instead of sending 56 messages about "super busy weekend" could try paying more. It's a shame how little are paying per order, day after day a little less.
# 2. Got my first 2 deliveries ever today, it was impeccable. However I didn't get any other orders after that for an hour
# 3. 1 every 45 min? MAX 90kr!? In the hour .. Are you serious? People are being sent, why are you slowed down? You literally run KBH round ends with 1-35kr! ? Fair distribution? The r destination, yesterday 35-120 kr lunch time! Is that good? Want to work for 35 kr/ or whatever get entered in the system per hour process is running on? Be honest. It r total disappointment and bad. This one yesterday 15/2 Kl- 9-230 kr 10-35kr. ??? 11- 50kr+ 80kr. ??? 12-1/100+45! ??? 13-125 + 45kr +45 (215)
# 4. It is a shame how much you're paying us for orders on days when there is rain and wind.
# 5. Very bad experience today 2 people get same order support doesn’t help and waste 1 hour and in peak hours you said 25% extra but nothing was added
# 6. Im not happy at all , we dont get orders to make money and the support somethimes they just dont care and they close the conversation without to give You an answer or to help You ...
# 7. One order, maximum 2 per hour and 200dkk after 3 hours on the street is not ok, the application works strangely for distributing orders.
# 8. Couriers should be notify which floor the order is going to. Today I had all the orders in the 4th floor and I am not paid for that. I should be able to decide if I tak the task knowing the whole complexity of it
# 9. If is busy, why don't give orders???
# 10. Very bad experience, lots of orders of 20-30 kr, from there I also pay taxes and from there I also have other expenses, I work for nothing
#
# Reassigned Outliers → Topic 1 (209 docs) | Original top words: ready, wait, order, restaurant, time, food, minute, burger, mcdonald, min
# 1. Macdonald Norreport is never asking courrier for numbers and we waste time waiting when the food is ready
# 2. I had to wait for half an hour over time on aji sushi and this is not the first time they have been very delayed. A little tired of siding and wasting my drive time because the restaurant can't fit the estimated time that is just about.
# 3. Fresh Burger in Vejle never has a ready order even when there is no traffic, it just waits until the delivery person arrives and only then starts preparing the food Vejle
# 4. Late venues. E.g. Hubb kitchen marks orders as “ready” and end up 21 minutes late. Implement rainy weather bonus please!
# 5. The customers need please write down the address correctly otherwise is difficult for us to find it and delayed us doing the deliveries and next customer complain so please. Mack Donalds need more staff on weekend they take 15 or until 30 minutes to give us the order.
# 6. Today it happened to me several times, arriving to venues to pick up orders marked as ready and find out that they were still several minutes to go. So not ready. I understand by the pattern that this may have come from you. If unfortunately this is like that, let me tell you that this is not good. It’s not good to put my time and the planning I do in terms of the type of orders I want to accept at someone else’s disposal. Please correct this and try to be accurate in the the you mark the orders. Thanks in advance.
# 7. About half an hour delay at Frankies in spite of having marked the order ready
# 8. Huge waiting time at the venues. This is the first time im writing a feedback after the shift. It was just so bad, wasted around 30min just on waiting during the whole working time…
# 9. The waiting time between orders is way too high even between 17-20:00
# 10. I am tired of that I can't see the customers address after I accepted. Some times I am at McDonald's and waiting 5 minutes, in that time it would be nice to prepare the delivery
#
# Reassigned Outliers → Topic 2 (27 docs) | Original top words: happy, wolt, good, work, thank, happy wolt, day, wolt happy, love, job
# 1. i am very happy with wolt wolt is the best app
# 2. Very happy but hope to improve the app more
# 3. i am very happy with wolt this is the best
# 4. Really happy with the customer support
# 5. wolt is the best i am happy with this
# 6. Thanks . Wolt is the best
# 7. Happy New Year ALL at the Wolt Team
# 8. i am very happy with woltwilt us the best app
# 9. i am very happy with wolt wolt is the best App
# 10. Lovely people and good service
#
# Reassigned Outliers → Topic 3 (253 docs) | Original top words: app, order, work, app work, time, offer, dkk, drive, error, task
# 1. Lots of times app doesn’t show distance and price before accepting a task.
# 2. Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you have set our starting fee down from 45,- to 35,- earlier it was a bird spacing of 450 meters when the reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km, can give 24,- as it is a delivery close to the previous one and not as before, both order from start to finish. Personally I reject all order to less than 35,- That is, even one of 34.95,- will be rejected I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped and it can be clearly felt how busy it has become. Many orders are thrown out and made up to 3 times I have experienced, as us cures who are left can not reach and pick up in time as you replace/pay. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !! It will probably not last long until I do the same
# 3. Once again the app is offering a good, far distance task and doesn't let you accept it. It is extremely frustrating. Please fix it.
# 4. The app sometimes asks if I want to log off or stay on ??? !!! But unfortunately too little to make
# 5. Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you have set our starting fee down from 45,- to 35,- earlier it was a bird spacing of 450 meters when the reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km, can give 24,- as it is a delivery close to the previous one and not as before, both order from start to finish. Personally I reject all order to less than 35,- That is, even one of 34.95,- will be rejected I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped and it can be clearly felt how busy it has become. Many orders are thrown out and made up to 3 times I have experienced, as us cures who are left can not reach and pick up in time as you replace/pay. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !! It will probably not last long until I do the same
# 6. several places where the app led us, but at this time, for about a month, this street is closed. But the app doesn't know that.
# 7. Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you put our starting fee down from 45,- to 35,- earlier it was a bird spacing, such as praying at Islands Brygge, birds distance of 450 meters above the water when reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km can give 21.50,- as it is a delivery close to the previous one and not as before, both order from start to finish. Which is some hell of a swine, personally I reject all orders for less than 40,- That is, even one of 39.95,- will be rejected I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped and it can be clearly felt how busy it has become. Many orders are thrown out and made up to 3 times I have experienced, as us cures who are left can not reach and pick up in time as you replace/pay. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !!
# 8. The stores really rarely have the order ready when it says it is ready on the app
# 9. Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you put our starting fee down from 45,- to 35,- earlier it was a bird spacing, such as praying at Islands Brygge, birds distance of 450 meters above the water when reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km can give 21.50,- as it is a delivery close to the previous one and not as before, both order from start to finish. Which is some hell of a swine, personally I reject all orders for less than 40,- That is, even one of 39.95,- will be rejected I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped and it can be clearly felt how busy it has become. Many orders are thrown out and made up to 3 times I have experienced, as us cures who are left can not reach and pick up in time as you replace/pay. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !!
# 10. App is working bad these days ,man y times you can not swipe order .
#
# Reassigned Outliers → Topic 4 (199 docs) | Original top words: km, distance, delivery, pay, driver, drive, car, money, payment, long
# 1. Hello with you "Wolt" You talk about listening to us cures and fairly done the app. First you have set our starting fee down from 45,- to 35,- earlier it was a bird spacing of 450 meters when the reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells you that you have listened to us where we were paid per piece for distance. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km can give 31,- as it is a delivery close to the previous PS. I'm super disappointed with your behavior toward us
# 2. Extremely low money for that busy evening and after payday in DK ! Stop to make joke with us . We who actually move this company …. respect do you know how much cost 1 tire of the car in dk ? I have to work 3 days in wolt to change just 1 flat tire of my car ! You thing that’s fairly and good job . I like to be flexible but last months looks like im forced to stop. Because instead of earning money i pay by myself to do it and mantein a car
# 3. Unfortunately, the fares for some routes are so low that even if you arrive at the address right away, it's not worth carrying a heavy load up 5 floors for, say, 20 kronor.
# 4. There much to do, one had to collect .. 3x35kr/ hour or 4x35 .. 85kr-140 per hour !! 7 hours drive under 900kr where you made 1900-2200kr! Monday is Mini Sunday! You can see the opportunity to reach more, you press it to be removed/taken then you have to have a longer period of time because you had to not. No bundle or long or anything. One becomes completely physically, mentally, financially smashed, why? Constant 35s every 15-20 min? When driving a whole way apart in vain trip and spending time, be better reward!
# 5. Every day they pay us less, your app is wrong and it costs us money because it bother us and they calculate distances incorrectly.
# 6. It is a shame that you pay 26kr for an order when it is rainy and windy. I hope the system return to the old one when the payments were fare.
# 7. 35-130/hour 1-2 drops/ hour The country full of order you had to do anything! 15/2 Kl- 9-230 kr 10-35kr. ??? 11- 50kr+ 80kr. ??? 12-1/100+45! ??? 13-125 + 45kr +45 (215) And end ... Over 6 hours of none stop driving totally in vain BGA something in the background that happens. There was a lot to do and you had to do and it typically every 10,11,12.13 time for everyday life. So Is it good? Normal? Justice? 35kr!? So fine maybe, 1 hour where is it completely dead, why when time and order is busy and much to make you drive even less? Bundles are prohibited by hand, whether it is short or long distance? It's really scary that driver/ set to run on. 35! Thank you so much
# 8. The flexibility is really what sets Wolt apart from my other jobs, it's great to be able to have some flexibility with my schedule while studying. I very much enjoy the exercise I get from it as well. Things to improve would be some sort of guarentee or payment when delays happen which are out of our control as couriers. We can report delays which I was told punishes the venues, but It happens often enough that it doesn't seem to discourage the behavior. Since I'm biking I could imagine people on scooters who are faster are affected by this even more. Also the distance bonus isn't really worth it, I've started denying orders that are far cause it makes the 180-200per hour impossible, as one it's far and I can complete multiple orders in that time and you get sent out of city center, and you won't get any orders before you get close to the center again, wasting even more time earnings wise. All in all I'm happy, but it could be better
# 9. Perfrom once again why you put it in busy when there aren't very many trips and those who are paying do not understand how this company can run around when you underpay your "partners"
# 10. Had to drive 2.5 km in vain and the order wasted. It was 25 pizzas as a bid for bicycle/scooter yes I do not have room for :( no compensation practice
#
# Reassigned Outliers → Topic 5 (33 docs) | Original top words: support, wolt support, chat, team, bad, help, wolt, support team, good, contact
# 1. Support thank you so much
# 2. hello Thank you for all support team
# 3. Support its worst everydays. Today i waste 1 hour because i had another location (i dont kniw why) and i asked a lot of times because i didn't have orders and anyones checked. I'm super hungry
# 4. Thank you so much SUPPORT.
# 5. System is scamming and support is useless
# 6. I can’t go online, and the support is very slow
# 7. Thanks for the good support,
# 8. Really happy with customer support
# 9. Thank you so much SUPPORT
# 10. Support thank you so much
#
# Reassigned Outliers → Topic 6 (29 docs) | Original top words: map, address, google, gps, app, location, maps, wrong, google map, google maps
# 1. Kilometers count does not work in the app. It is very inconvenient
# 2. It is indescribably unbearable that I cannot see my kilometers of numbers inside the app, it does not write it as it usually is, that's only why I go offline. Otherwise I had run all day but not when I can't see it
# 3. My kilometers of numbers do not show under statistics in my app, so I go offline and do not run until the problem is resolved. Although it takes days if I do not drive until I can see km numbers in the app
# 4. Would be very helpful to have the option to be allowed to copy the address in order to make it faster and to avoid mistakes when entering the address in Google Maps
# 5. Please make it possible to copy the address as well because sometimes Google maps inputs the wrong one
# 6. It does not detect miles in the app
# 7. Hi, sometimes the customer's address is written incorrectly and we can't find it. Customer should be able to send his location please
# 8. Your app is incredibly bad it does not detect that you run on the card so on the map I stand still even though I am in reality I move I MOSEMeter do not pigeon in addition so the link you send that you have to fill to your kitchen it does not answer in all in all an incredibly bad experience
# 9. I was face problem with my last delivery I was not able to swipe the address .
# 10. 5 second countdown before starting delivery is unnecessary and a bit of a hassle tbh. The location is often entered incorrectly, into apple maps when pressing the GPS button in the wolt app.
#
# Reassigned Outliers → Topic 7 (14 docs) | Original top words: bag, drink, pack, cup, food, paper, order, spill, soda, customer
# 1. hello It is necessary to say two things here. 1- On rainy and cold days and after sunset the stated prices for delivery do not differ from hot summer days, which is very problematic considering that under heavy rain, the delivery work is really difficult, especially with a motorcycle that is directly exposed to the rain and we spray water from the side of the cars, it will be very difficult so we have to reject some orders. 2- Burger King Vanløse has a problem with the beverage package, and almost all orders including the drinks have waste or leaks that need to be warned because it is us who are questioned when the food is delivered.
# 2. Can you explain McDonald railway station that many of us Wolt Budde has attached our bags on our bikes scooters and cars, There is only one particular employee who in the McDonald railway station who refuses to hand out the order before hair out and pick up his attached bag and it takes time, there is a box -made of 8 steps from the counter where you get the food for your bike where you get the order in the bag. It is only this one employee that does it and it is only this one McDonald it happens by. Please explain the manager who both order gets cold and it is frustrating to have driven all the way there and then not get the order.
# 3. Ift. The app. It could be nice if you could see all the orders you have to pick up from the same restaurant at once, so you don't have to take one in the bag first, swipe picked up (maybe even on the way out the door), and only then find out that you have to pick up one more.
# 4. One of the venues declined to give the food argumento g that th rules say I must go show with my bag. It the second time, it is the chain MAX burgers
# 5. I got an order I couldn’t fit in my bag
# 6. Restaurant Halifax forgot to give me a lemon soda in one of their orders today. Burger King gave me a wrong order and told me that they could not see my order number in their system. Only thing I could correct was the beverage, as I could see it was wrong compared to the order in the app, which I pointed out. Generally I cannot always, as a courier, check the food, because often times it’s placed in a sealed food bag by the restaurant. So out of respect for the customers, I don’t break the seal to check what’s inside. So I have to trust the restaurant staff when receiving an order. I would recommend Wolt to make the restaurants either always tape the receipt of the food content on the bags or hand the receipt over to the courier to be sure the food is correct. There are many young service employees in this area who works in restaurants, and they are not always that observant and precise with the orders. Would be great if you could encourage them to double check the orders and consistently use receipts on the bags. Because it’s us as couriers that has to deal with upset customers when we drive a far distance to deliver a wrong order. Thanks in advance for understanding.
# 7. The Coca Cola from McDonald's was not sealed and it was spilled all over and the customer couldn't enjoy his drink. There was also a lot of waiting time on some places to pick up the orders but it's okay. Besides that it was good.
# 8. The one that restaurant Ristorante da Alfredo! Here the employees are mega arrogant and smart and talking down to us Wolt employees! In addition, they refuse to give a bag with which the customers have paid for! It's just not okay and should be articulated in front of the restaurant
# 9. Macdonalds packing of coffee very poor.
# 10. app throws orders with a certain distance and when u get the order at the venue that distance significantly increases. That’s no bueno. Regarding Venues. Burger King guys don’t put any tape to secure the sodas, therefore as much as u try to be careful, u end up with the bag full of soda everywhere. Would be awesome if they start securing that. Customer support is awesome as always. Orders have decreased a lot tho…what’s up?
#
# Reassigned Outliers → Topic 8 (32 docs) | Original top words: task, task task, time, new task, accept, accept task, new, hour, disappear, receive
# 1. I went to pick up the task from Stefanos and a new, very youg guy told me to step back because i am to close to the bar where it was the food. I really felt bad, no maniers and i used to picked up task from them since i started colaboration with Wolt. P.S I showed him the phone at the entrance , i told him the task number, i had my wolt bag with me.
# 2. Why is there no work and orders? I think i'm going to work late .. But I'm getting bored and .. sure AKP will continue like this, I turn off
# 3. Rather often I experience that the earning for accepting a task is not shown
# 4. Please add the task fee to the display after the task is accepted so can see it while waiting
# 5. After 23,00 good tasks support venue . From 15,00 until 23,00 very bad one order takes more than an hour with support to solve the problem
# 6. Absolutely shitty day in terms of work.......wrong distribution of tasks!!
# 7. Earn not good. wolt don't have task.too much people.waiting long time for task.
# 8. I went online thinking ,because it's busy demand ,the task rewards are going to be higher ,but they were lower (5-10Dkk) on average ,even though I made more money during normal demand while having small orders. It's raining currently,but the task rewards are low It is difficult to get motivated to work when it's busy and the help is needed ,but task rewards are lower than during normal demand :/ hope you understand
# 9. Please stop setting me offline, I was waiting for tasks
# 10. Hestitant to go back online because I’m worried whether there’ll be enough to do… lately there’s been a lot of waiting between tasks even when the status is “busy”
#
# Reassigned Outliers → Topic 9 (68 docs) | Original top words: wolt, market, wolt market, market vanløse, order, vanløse, danish, copenhagen, denmark, hour
# 1. To many couriers, to few orders, why does this happen in Aarhus constantly?
# 2. To say that they are the worst companies in Denmark is an understatement, the payment system is becoming increasingly disgusting, I don't understand how they can continue to operate as if nothing happened in Denmark, a disaster in every way!!
# 3. It's not so much work for the time in Aarhus It's far too many employees ￼ One does not get as many orders ￼
# 4. Hello, I work in the Vestegnen Vallensbæk and ishøj , where customer orders are fewer compared to other places; for instance, we receive two or three offers per hour. It is crucial for me to contribute to wolt's success, and I'm pleased with my role in this group. While I'm generally satisfied, I've observed a recent decrease in the number of fare offers. I kindly request a reconsideration of the fare amount to boost activity and engagement in this area, benefiting both the employees and your company. Im waiting for your response. Thanks in advance and best regards
# 5. 7/11 Sjælør Boulevard had not started the order, which is not optimal when they write that I have to wait outside until the order is marked. The last time I was there, they forgot to mark it ready, so it reduces my goodwill to follow the directions of waiting outside.
# 6. So bath .. Nothing Calls from Distance, Driving Around and Nothing Even There Is Something .. And Just Waste Time and Suddenly and Delayed Order .. Why Did Not Send from The Beginning ?? There Was Pick Up's In The Drop Area and Other Areas .. No Ofc (Drive Around and Waiting The Car Wont Start) BREEEEMSE? For what? From Brøndbyøster to Zoo nothing suddenly from Valby in -15 min .. So stupid. Where does it call from a distance .. 10 km on the way back .. Then again and again .. Besides evening was so strange and provocative .. 1 after 1st .. or to distant places, Søborg, Husum, Fields, they turn half hour ahead and half hour Nothing back .. And 1000 km for 80 kr. .. or 25 kr turn .. To collect too plane off no .. Or constant Sv .. Where the bridge is blocked and Vasbygade is on road work and must not turn.
# 7. Not enough orders , people are just not ordering it's quiet all the time, there's too much people driving in Aarhus, we can barely pay our rent and make for bread.
# 8. No demand; orders cheap for long distance. 4hours of work by car for 580kr …what i should pay with this? The tax ? The gasoline or the lease? Or food for myself ?what exactly of this shift . The answer is nothing for myself … all this money will gone for someone else, but not me . INCREASE THIS PRICES .. make us work with pleasure like before in Wolt Denmark. This is absolutely non - respectable and valued job! Day by day … less and less wishes to work. I repeat few many times .. is not put billboards in hole city to make fake advertising (how u gonna earn more then 200kr/h ) . Invest in the ppl who are long with the company and especially ppl by car because without us … WOLT IS losted !
# 9. 0-1 orders per hour... would you work for 50kf per hour in Copenhagen?
# 10. I will order too. From the Wolt Market in Vanløse
#
# Reassigned Outliers → Topic 10 (18 docs) | Original top words: bundle, bundle order, order, pay, task, accept, payment, new, order bundle, system
# 1. Time waste. Too much emphasis on bundles. That's why a lot of orders were late(bad for customers). Because of this couriers weren't getting orders in a fluid manner. Spending periods without an order just to get bundles out of the blue. Revert back. This is bad for couriers and customers!!! It will come to Wolt as the company if things don't improve
# 2. The new pay system is unfavorable and unreasonable to couriers. This is especially with services provided by couriers during bundle deliveries…in my opinion that’s not fair …we should get our full fee for services whether bundle or single delivery.
# 3. No orders enough. But wolt gives bundles to some couriers
# 4. Please please look at bundle pay, it’s not only about distance. I’ve written this before and I know you probably don’t care, but just know the matter has been brought to your attention many times… also when doing bundles/ triples. Sometimes you deliver one of the orders and get offered a new one, while you still have orders to deliver. BUT THE APP LOOKS LIKE ALL YOUR DELIVERIES HAVE BEEN MADE. This sometimes confuses me so I reject the new orders offered..
# 5. 29kr for most of the task in a super windy and rainy day, busy and all orders delayed.. Bundles of course even less.. What do you expect? How much more are you gonna push the prices down? Until nobody works anymore?
# 6. I can’t see the weight of order when I receive them in bundles.
# 7. 1. There is a bug in the software. When you pick up a supermarket/wolt market delivery, sometimes you can only swipe to complete the pick-up task, if the checkbox(s) of some of the bags are unchecked. If I checked them all, I can't complete the task. 2. The prices of the tasks are too low. There is no account of the waiting time at wolt market, you should be able to get an estimate of the waiting time. I got 36 dkk for a second order from wolt that had to wait 15 minutes and took me 10 minutes to deliver...too little! I am not taking more bundled order unless they are ready at the assignment.
# 8. Get back to old payment method! It's more clear! Now we don't know, you just se the price that you like for the tasks, really unfair. Km deduction!!!! It doesn't worth it anymore to deliver over 3km. We have to pay 100% of our expenses and the prices are super low. Let the bundles be the full price as before! 35kr for a bundle task over 4km??? When we actually have to drive 1-2-3 km from first drop of to the second??? This is insane
# 9. I got a survey earlier today where I said I felt the payment was fine. However on busy days like today, and snowy weather, where you're held up in ultra slow traffic, the tasks could pay better. Especially the bundles fees, as arriving to the venues and customers take extra long time in these weather conditions. Otherwise all is good!
# 10. The prices are very low specifically for long distances and bundle
#
# Reassigned Outliers → Topic 11 (33 docs) | Original top words: bonus, weekend, weekend bonus, order, bonus weekend, bonus time, 17, time, today, remove
# 1. Maybe you should consider giving incentives to workers that work after 12 mid night in Thursday to Sunday
# 2. Today's bonus hours and decreasing the prices during the day and every day reduce the motivation to work. Many wolt employees complain and feel uncomfortable about this, I think you need to do something about this issue as soon as possible...
# 3. Orders get less and less payments, for example, if during day delivery orders coasts 40-50-60kr, in 'Weekend boost' the same - so doesn't have sense of this 'Weekend Boost'.
# 4. I feel disrespected and humiliated. Your payment structure is not transparent. Our task fee appears less and less week to week, now the weekend bonus also seems to disappear. There are only 2 hours each day with enough order for a fair hourly wage. It is not enough for us to compensate the other horribly quiet hours. Of course since you employ a large fleet it still puts a fair income to the company’s pocket. My hourly wage is about 30-50 dkk lower. Even the weekends are bad. Care about your couriers or this business will fail
# 5. Fees are still pretty bad. 162 per hour on a Sunday where everyone is back from vacation AND with bonus on. I used to do that on a normal weekday up to last summer. Something needs to change here.
# 6. I can’t tell when it’s “peak hours”… 34 kr for an order which is 1,5 km in “bonus time”.. shame
# 7. also thanks for the boost.. which im unable to earn even that small one of 7 orders during 2-2.5h . thats disgusting..
# 8. It raihed all day where is the bonus for bad weather
# 9. I suggest you pay more hours bonus on weekends and when the weather is really bad like yesterday in Copenhagen.
# 10. It’s good. Restaurants who are often delayed should adjust their estimates so we don’t have to wait, if this is not already being done. Everyone’s going online at 17:00 in the weekends now lol, I’m earning more outside of the bonus hours. Don’t start more new couriers, this Sunday was really slow between 17-20, while we’re only 1 week into April month. When is it time for a pay rise? Pay has decreased per task since 2022, although inflation has been high. I was even told by support that we would not receive less than 35DKK per task.. All other groups in Denmark receive yearly pay increases. Why does everyone else get more money, but not us Wolt Courier Partners? Not even the smallest adjustment.
#
# Reassigned Outliers → Topic 12 (169 docs) | Original top words: support, order, deliver, cancel, customer, deduct, ask, tell, mistake, time
# 1. Today i have one order from McDonald's ringstedgade but its already late 31 minutes when I go inside that girl ask me we have to remake I just come out side and cancel the order but that girl come out side asked me your food is ready I ask him I can not take this order its already cancelled. She asked me come inside and pick up the order. I tell him you can not force me I have to pick up order its totally up to me I don't want .its very simple I don't want any conversation with you if you have any issues just write wolt sopurt. And I go again ofter some time picked up another order she asked me what's you name I asked him we are not allowed any conversation if any issues write wolt spourt. Just give my order.its very simple .
# 2. I am missing payment for order HEG has delivered They did not come under my tasks yesterday Oh today…
# 3. I have been suspended for an order even though I have neither picked up or delivered the order. It is about order number 896, the task was canceled before I managed to pick it up. I took the task to start with but wrote to you again that you have to cancel it and it was. So I didn't pick it up from the restaurant. When I wrote yes to one of your colleagues on message then it had gone strong and I read wrong. You can contact the restaurant and hear them if I picked up the order or not. I only picked up two orders from there and they were delivered to the customers.
# 4. I had issue with my last order . I accepted the order and went from osterbo to åboulevard to collect it - 10min . When i was there around 19:00 food was already marked ready . I went to the empty restraubt and they inform me customer order it to be done after 19:30 . I chatted to the support and you can see how the conversation went . They didnt want to compensate me athough it was obvoius a mistake either from the venue or wolt app . I made the picture in the restraunt and in their app it was saying 19:30 although they marked it ready at 19:00 . When i delivered it customer confirm that he request after 19:30 . So i refuse to agree i cannot be compensated for losing 30min in front of venue for a order that they refuse to make before . If it was a busy day i agree to wait few minutes more but today its mistake in the app because of which i lost over 30min. Please take a look at this case and treat your employes the correct way.
# 5. Weather very bad.some order too much late and some body take my order.donot give me compensation.who give me gas and waiting money.
# 6. I log out even if order is left. Just sin your reach is so small. Your customers can just be pouted. And why can't I just take an order and go instead of waiting 10 minutes without doing anything, just to take a No.2 order for under 30kr.
# 7. Very bad support i waited 1 hour and the order canceled for system fail i said make new one and I took only 35 1 hour 35 krone perfect deal
# 8. Fine but 1 of my first 3 deliveries did not include payment?
# 9. I don't understand my last order #191 from Many. I received+14 minutes and I had to drive 3 km. The venue was delayed and I picked it up -10. It is a long long time
# 10. I had new orders disappear after only a few seconds before I could accept them on multiple occasions. Please fix this

# %% [markdown]
# topic 0: fits
#
# topic 1: fits
#
# topic 2: fits
#
# topic 3: mostly fits
#
# topic 4: mostly don't fit
#
# topic 5: fits
#
# topic 6: mostly don't fit
#
# topic 7: 50% fits
#
# topic 8: mostly don't fit
#
# topic 9: mostly fit.
#
# topic 10: fits
#
# topic 11: fits
#
# topic 12: 50% fit

# %%
from collections import defaultdict
import random


# Organize documents by new topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, new_topics_embedding055):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = -1
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic -1 (2628 documents) ===
# 1. Would be smart with a feature where you could choose restaurants from which you did not want to have orders from. Are you will and get extremely many from places I can't get to or park.
# 2. Annoying with no reject button in bundle mode. Just got spammed with McDonald’s yesterday. And had to wait like 1-2 min x +10 times.
# 3. People are super happy to have food delivered and other delivered directly to the door. I feel I help some through a busy everyday life and make life a little more festive for others.
# 4. Customers will have to understand that the green location marking is what we Wolt Bude is running for. It is very important that it is precise and put precisely on their front door
# 5. Things are very slow in my area.
# 6. The code required from customers is annoying and a waste of time! Almost gona quit working due to its effects!
# 7. Have an excellent week
# 8. Same problem as last time
# 9. Very thin on orders today, it didn't exactly feel like "peak hours"
# 10. More bad customers who can't open the door properly or write bad descriptions of how to get to them.
# 11. Wasted 30min of my time and do not answer my messages.
# 12. Please don’t give me any more this feedback prompts
# 13. Crashing many times. Makes the whole phone unstable.
# 14. To wait 20 min at Wolt Market Iken Okay
# 15. Have an excellent weekend
# 16. Hello, please do not accept new members. The order is too small
# 17. Decline button no reaction 50% of the times Support reply messages don’t appear
# 18. No job offers for 40 min!!!!!
# 19. Aren't we supposed to be compensated when we're willing to wait on remakes. The task was marked ready but i was told to wait 10min for a remake. And now having problems with support for a compensation
# 20. To many curriers on street

# %% [markdown]
# Some are noise, but some could be fitted into topics

# %% [markdown]
# #### Inspecting of embedding050

# %%
outlier_model_embedding025_2 = copy.deepcopy(reduced_model2_2)

# %%
# Reduce outliers using the `embeddings` strategy
new_topics_embedding05_2 = model_copy.reduce_outliers(documents, topics, threshold=0.5, strategy="embeddings")
# puts the outliers into one of the topics. The documents already assigfned to a topic will not be changed. 
# Now we need to update the model with the new assignments of the outliers, and new topic representations are calculated
# when specifying the representation model, KEYBERT and MMR are also displayed
outlier_model_embedding025_2.update_topics(documents, topics = new_topics_embedding05_2, vectorizer_model= vectorizer_model, representation_model=representation_model)
# Out:
# 2025-05-21 10:25:55,132 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
#model_copy = results[("embeddings", 0.25)]["model"]
outlier_model_embedding025.get_topic_info()
# Out:
#     Topic  Count                                Name  \
# 0      -1   2044             -1_work_time_wolt_order
# 1       0   2237            0_order_courier_hour_pay
# 2       1   1331             1_ready_wait_order_time
# 3       2   1093               2_happy_wolt_good_day
# 4       3    991               3_app_order_work_time
# 5       4    717        4_km_distance_delivery_drive
# 6       5    372    5_support_wolt support_team_chat
# 7       6    365            6_map_address_app_google
# 8       7    290               7_bag_drink_pack_food
# 9       8    198        8_task_time_accept_task task
# 10      9    225         9_wolt_order_denmark_market
# 11     10    145    10_bundle_order_bundle order_pay
# 12     11    136  11_bonus_weekend_weekend bonus_day
# 13     12    320     12_order_support_cancel_deliver
#
#                                        Representation  \
# 0   [work, time, wolt, order, excellent, hour, mon...
# 1   [order, courier, hour, pay, wolt, low, payment...
# 2   [ready, wait, order, time, food, restaurant, m...
# 3   [happy, wolt, good, day, happy wolt, work, tha...
# 4   [app, order, work, time, app work, support, ta...
# 5   [km, distance, delivery, drive, pay, car, orde...
# 6   [support, wolt support, team, chat, bad, help,...
# 7   [map, address, app, google, gps, location, map...
# 8   [bag, drink, pack, food, order, cup, soda, pap...
# 9   [task, time, accept, task task, hour, new, sec...
# 10  [wolt, order, denmark, market, wolt market, wo...
# 11  [bundle, order, bundle order, pay, task, payme...
# 12  [bonus, weekend, weekend bonus, day, order, bo...
# 13  [order, support, cancel, deliver, customer, ti...
#
#                                               KeyBERT  \
# 0   [week excellent, excellent week, weekend excel...
# 1   [order order, get order, order, order low, rec...
# 2   [food ready, order ready, minute order, time r...
# 3   [love wolt, wolt happy, happy wolt, wolt, wolt...
# 4   [app app, app work, app, fix app, app crash, a...
# 5   [distance payment, wolt, favor wolt, fee, deli...
# 6   [wolt support, support wolt, support support, ...
# 7   [google map, google maps, map app, app map, co...
# 8   [bag order, paper bag, use bag, food bag, bag ...
# 9   [task, task task, wait task, task come, get ta...
# 10  [market vanløse, order wolt, wolt market, vanl...
# 11  [bundle payment, pay bundle, bundle pay, payme...
# 12  [weekend bonus, saturday bonus, friday bonus, ...
# 13  [cancel order, order cancel, deliver order, or...
#
#                                                   MMR  \
# 0   [work, hour, money, day, pay, customer, delive...
# 1   [courier, hour, low, payment, work, earning, d...
# 2   [restaurant, mcdonald, min, order ready, food ...
# 3   [happy, day, happy wolt, wolt happy, work wolt...
# 4   [app work, error, delivery, app let, drive mil...
# 5   [km, delivery, drive, kr, payment, bike, kilom...
# 6   [support, wolt support, chat, support good, su...
# 7   [map, address, app, gps, maps, google map, goo...
# 8   [bag, pack, soda, spill, paper bag, lid, mcdon...
# 9   [task, task task, new task, accept task, busy,...
# 10  [denmark, wolt market, danish, market vanløse,...
# 11  [bundle, bundle order, payment, order bundle, ...
# 12  [weekend, weekend bonus, bonus weekend, pay, h...
# 13  [order, cancel, deliver, customer, cancel orde...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [More orders would be delicious, There are not...
# 2   [Ask Pick up places not to mark the order read...
# 3   [i am very happy with wolt, i am very happy wi...
# 4   [App crashes. App lets me drive for miles, the...
# 5   [You say it is 0.1km ekstra but actual distanc...
# 6   [Haven't used Wolt Support, so is still uncert...
# 7   [Still problems with the addressees in Google ...
# 8   [McDonalds City putting orders in big bags is ...
# 9   [I don't get as many tasks, It's Sku Slay with...
# 10  [I also want to order Wolt Market in Vanløse o...
# 11  [Why the system give bundles when there are no...
# 12  [Put a bonus for weekend 23to02am, Where is ou...
# 13  [I had the order 7J5DV3, in which the app sent...

# %%
# Step 1: Get original topics (before outlier reduction)
topics, _ = reduced_model2_2.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Step 2: Get new topics (after outlier reduction using embedding + 0.25 threshold)


# Step 1: Find reassigned outliers (originally -1, now assigned to a topic)
reassigned_outliers = [
    (i, doc, new_topic)
    for i, (doc, old_topic, new_topic) in enumerate(zip(documents, topics, new_topics_embedding05_2))
    if old_topic == -1 and new_topic != -1
]

# Step 2: Group reassigned outliers by new topic
topic_to_outlier_docs = defaultdict(list)
for i, doc, new_topic in reassigned_outliers:
    topic_to_outlier_docs[new_topic].append(doc)

# Step 3: Print sampled outlier docs with ORIGINAL top words (from reduced_model2)
for topic_id in sorted(topic_to_outlier_docs.keys()):
    docs = topic_to_outlier_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))

    # Get original top words from reduced_model2
    original_topic_words = reduced_model2_2.get_topic(topic_id)
    if original_topic_words:
        top_words = ", ".join([word for word, _ in original_topic_words])
    else:
        top_words = "(No original top words)"

    print(f"Reassigned Outliers → Topic {topic_id} ({len(docs)} docs) | Original top words: {top_words}")
    for j, doc in enumerate(sampled_docs):  
        print(f"{j+1}. {doc}")
    print()
# Out:
# Reassigned Outliers → Topic 0 (571 docs) | Original top words: order, courier, hour, pay, new, payment, low, earning, work, wolt
# 1. how can you take orders that disappear in a second,
# 2. The payment is lower than March
# 3. Way to few deliveries
# 4. normal?????? but no have orders what happened
# 5. The order estimates are surreal. Today, between 11.45 and 13.15 not even an order??? It's very strange...
# 6. I don't get orders in peak hours and distance is still not correct on many orders
# 7. No respect. You pay the orders even lower every day. I will go out deliver when you start respecting and paying decent amount
# 8. Is it possible to pay more money on orders because we are using petrol ( benzine) to deliver the food . Otherwise very happy….
# 9. No orders for an hour. Previous hour paid a lot below acceptable rate, best locations
# 10. Hello, I'm based in Vestegnen Vallensbæk and Ishøj, handling customer orders where we receive two or three offers per hour. I'm dedicated to contributing to Wolt's success and value my role in this group. Although generally satisfied, I've noticed a recent decline in fare offers. I kindly request a reconsideration of the fare amount to enhance activity and engagement in this area, benefiting both employees and the company. Looking forward to your response. Thanks in advance and best regards.
#
# Reassigned Outliers → Topic 1 (267 docs) | Original top words: ready, wait, order, restaurant, time, food, minute, burger, mcdonald, min
# 1. Really happy about everything related to Wolt and most partners. However there is a general problem with some of the larger and smaller restaurants pushing the “order is ready”, while in reality we end up waiting 5-15 minutes for the order. Especially Hubbs Kitchen, both Frederiksberg and Nordvestare some of the biggest ones in this. As couriers we miss out reaching boost goals, when we are kept waiting, two Hubbs orders can destroy the tarvet of reaching 12 orders before 20.00.
# 2. A lot of time wasted. 5 minutes delayed. I started 16:30 and I did one order
# 3. Lack orders, Long rides between Pick ups, bones Århus 15 min late
# 4. Huge waiting time at the venues. This is the first time im writing a feedback after the shift. It was just so bad, wasted around 30min just on waiting during the whole working time…
# 5. Hello. Mc Donald's harbor always delays orders. Will have to wait so far for an order. It does not pay to wait half an hour for 30-40 kr We are talking to my colleagues and they experience the same problem.
# 6. No notification when the food is ready
# 7. Waited 20 min for order at Wolt marked
# 8. These McDonald's Østerbro guys should mark food as "Ready" when it's actually ready. They do it instead when they're preparing it and I got the order like 5 min after it was marked as ready. I don't get this.
# 9. Jagger Vanløse always mark the food ready but it’s not. At Brøndby Mc Donalds I’m waited 20 min for the food and i needed to unassign the task, no copensation.
# 10. Put in KFC Rødovre is very bad the food is ready and I say Order No. But still I have to wait and it is a specific co -work and this is not the first time she does it
#
# Reassigned Outliers → Topic 2 (96 docs) | Original top words: happy, wolt, good, work, thank, happy wolt, day, wolt happy, love, job
# 1. Have an excellent day
# 2. I’m done with Wolt after 3 years this company went down like shit and it’s dying because of the problems you created
# 3. Have an excellent day
# 4. Very happy going online again after a mild back injury. But unfortunately on duty I hit a pot hole on the road the broke my rear wheel with all the heavy load I had on my cargo bike. I was forced to end my duty because I couldn't use my transport vehicle
# 5. Have an excellent day
# 6. Glad I could take a summer vacation while there was quiet (according to my colleagues). Looking forward to getting started again
# 7. Have an excellent day
# 8. wolt is the best i am happy with wolt
# 9. Have an excellent day
# 10. Have an excellent week. Wish you the best.
#
# Reassigned Outliers → Topic 3 (320 docs) | Original top words: app, order, work, app work, time, offer, dkk, drive, error, task
# 1. Could't contact the support due to app bug, it was unavailable today.
# 2. App !! loses connection
# 3. The application completed a task without me being close to the address, it must be a bug in the system or something. Please check how could this be possible. It caused a delay for the customer to receive the food, and if the support person does not contact me I would have not been able to deliver the task.
# 4. I sometimes find that the app's calculations are not all time correct, I hope soon you find a solution. Besides this I am satisfied.
# 5. The app crashes too often and must restart tel to be able to order received or handed in and my mobile is brand new and fully updated and otherwise 5G
# 6. Had to kill the app several times
# 7. It crashes pretty often. And it's the only app that even crashes my whole o
# 8. There were some problems in between when I had to press delivered that it didn't mind completing it, so I had to restart it a few times.
# 9. The pay should be higher, the App works fine, some bugs but fine.
# 10. The app failed big and the support was not to be obtained, in the sense that I could not be allowed to write to the support.
#
# Reassigned Outliers → Topic 4 (282 docs) | Original top words: km, distance, delivery, pay, driver, drive, car, money, payment, long
# 1. I got less per kilometer than usual ￼
# 2. Low payment. Weekend boost is not enough pay. Customer should go down to pick up their food. Most of the buildings doesn't have elevator and apartments are missing customer's name and apartment's number
# 3. Hello I still observe that as an available courier in the area of Ørestads I bearly get any orders from Mcdonalds Field's or KFC Field's, seeing that priority is given especially to cars coming from far away. Just consider that for the reasonable share of orders I should receive as a constant available courier of the area, distance payment could be saved from your side, for the orders I could reasonably receive from such places. But the algorithm prefers to pay distance 90% of the time, as I have long observed. This issue I have observed it since september of last year, here in Ørestads. Please, check if you may, my history of tasks performed until such date and you will see that as a constant available courier of Ørestads, my history of orders was full of Mcdonald's Fields (the most) and KFC Field's, Shawarma Ørestads aswell....but not now. Just don't overlook the distance payment you were saving on such orders by being assigned to regular couriers of the area like my case, and that for some reason related to the algorithm (I guess) is not the case now, and only cars coming from further distance do get priority. As an example, I could literally be next to or inside such restaurants waiting for orders for 1 hour or more (not exagerating) watching how car drivers especially come and go with orders, ignoring my availability. It is simply something not coherent from the algorithm in my opinion, and it would mainly be beneficial for Wolt in order to pay less distance fees, by the algorithm not skipping available couriers in the area Sincerely, Juan
# 4. The operations team are absolute idiots... Ive got two order for the same building. The first order paid 121kr for 3.7km. And the second one paid 74kr for 4km. The had the same amount of weight and it was in the same building. Both before peak hours. Great job idiots!
# 5. I need my kilometers please Why you Wolt don’t send it ?
# 6. Everything is okay just I believe pay rate is way less as one has to use his car petrol and all expenses. Rest is all good
# 7. Same pattern as always..kates 2 km without orders then get an almost clear order on the route I have just run, ie an order that must have been offered long ..
# 8. Horrible rates for night shift and long distance. I'd love to deliver, but fx 100dkk for 12,5km is way too little Saw many orders like this
# 9. Hi, I would like to thank you and come up with a suggestion for those who work by car, if possible, suggest a route that they can receive an order in Berksht.
# 10. Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you put our starting fee down from 45,- to 35,- earlier it was a bird spacing, such as praying at Islands Brygge, birds distance of 450 meters above the water when reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km can give 21.50,- as it is a delivery close to the previous one and not as before, both order from start to finish. Which is some hell of a swine, personally I reject all orders for less than 35,- That is, even one of 34.95,- will be rejected I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped and it can be clearly felt how busy it has become. Many orders are thrown out and made up to 3 times have je Experienced, as us Kure who is left I can reach and pick up in time as you replace/pay. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !!
#
# Reassigned Outliers → Topic 5 (41 docs) | Original top words: support, wolt support, chat, team, bad, help, wolt, support team, good, contact
# 1. Thanks. thanks support
# 2. Quite bad support with 40 kr per hour
# 3. Support thank you so much
# 4. You are paying less every month. Support really sucks, nobody take care about the riders. Support only are smart to take money from your savings, in other situations they look stupid and seem that you are chating with a bot. Also noboy see this feedback. I never had a reply. So why you do it?
# 5. Support thank you so much
# 6. When will you fix this scam system??? Support is supporting the scam not me
# 7. Thanks for the help for support - you are the best!
# 8. It didn't work to talk to support. 20 minutes waiting, an order that wasn't ready. And the option was to cancel or keep waiting. Every day you earn less money and work more hours. I think going to Just It, the competition, will be a better option if conditions don't improve.
# 9. No work, no pay, useless support
# 10. Thanks for the good support,
#
# Reassigned Outliers → Topic 6 (43 docs) | Original top words: map, address, google, gps, app, location, maps, wrong, google map, google maps
# 1. I'm not sure if my last delivery, to a Louise Black, actually went through. After delivering, it kept giving me errors when I tried to slide the "Delivered!" bar. Then it just suddenly went back to map.
# 2. My kilometers of numbers do not show under statistics in my app, so I go offline and do not run until the problem is resolved. Although it takes days if I do not drive until I can see km numbers in the app
# 3. Today, I put the wrong food due to the google map error and contactless customer, but after the support messaged me, I went back and corrected it, but I was fined, and this was a bad experience for me.
# 4. 5 second countdown before starting delivery is unnecessary and a bit of a hassle tbh. The location is often entered incorrectly, into apple maps when pressing the GPS button in the wolt app.
# 5. Your cards are always mega misleading about where the food should be delivered, there should be built -in GPS It's a worse mess to have a GPS on another app simultaneously.
# 6. App: my gps location 1 km off on 1 task offered. Also no price on task. “Reject task” function needs to be manually updated otherwise nothing happens.
# 7. Hi the app doesn’t always my mean everyday show distance on and off km ? Please look at it for stats km
# 8. At the beginning the app had lags: didnt show the the client on the map, cracked(log out) several times
# 9. Hi, sometimes the customer's address is written incorrectly and we can't find it. Customer should be able to send his location please
# 10. My app doesn’t show all the miles I’ve driven. Only around 60 % I estimate ( 666 km at present)… there was also trouble last month..?
#
# Reassigned Outliers → Topic 7 (21 docs) | Original top words: bag, drink, pack, cup, food, paper, order, spill, soda, customer
# 1. hello It is necessary to say two things here. 1- On rainy and cold days and after sunset the stated prices for delivery do not differ from hot summer days, which is very problematic considering that under heavy rain, the delivery work is really difficult, especially with a motorcycle that is directly exposed to the rain and we spray water from the side of the cars, it will be very difficult so we have to reject some orders. 2- Burger King Vanløse has a problem with the beverage package, and almost all orders including the drinks have waste or leaks that need to be warned because it is us who are questioned when the food is delivered.
# 2. When you deliver and accept orders, I would think it would make it much easier for the driver if you could see what the order consisted of before accepting it. For example, if I accept an order then it says what food it is so if I want to take 2 orders at once then I know if I have room for it in my bag or not. Right now it's just a rate to take 2 because you don't know if you have space
# 3. You are so irresponsible with your workers. You have to be respect. You send people to pick up food from Wolt market and you know that everyone can come to do that, but of course a bike or motorcycle can't do dlthat, it has to be a car because is too many bags. Last time I went to pick it up I went down with mi bike, I tried to cancel the task and you told me it was too late. So please be respectful with workers. We are humans.
# 4. Multi-deliverys to big for the bag, and to little payment, you have to improve things
# 5. Can you explain McDonald railway station that many of us Wolt Budde has attached our bags on our bikes scooters and cars, There is only one particular employee who in the McDonald railway station who refuses to hand out the order before hair out and pick up his attached bag and it takes time, there is a box -made of 8 steps from the counter where you get the food for your bike where you get the order in the bag. It is only this one employee that does it and it is only this one McDonald it happens by. Please explain the manager who both order gets cold and it is frustrating to have driven all the way there and then not get the order.
# 6. The Coca Cola from McDonald's was not sealed and it was spilled all over and the customer couldn't enjoy his drink. There was also a lot of waiting time on some places to pick up the orders but it's okay. Besides that it was good.
# 7. Ift. The app. It could be nice if you could see all the orders you have to pick up from the same restaurant at once, so you don't have to take one in the bag first, swipe picked up (maybe even on the way out the door), and only then find out that you have to pick up one more.
# 8. Over some time I’ve noticed some room for improvement for McDonald’s. First, the cups are not sealed good enough. Often the soft drinks spill in the bag, eventhough i try to drive carefully (bike), and make the inside of the bag wet and sticky. Secondly, often (not always) the staff don’t seem to pay attention to Wolt couriers. Often eventhough the order is ready, they don’t reach out to me when I enter the restaurant and go to the counter. I know they are busy but when i stand in front of the counter with my big blue bag, they should pay attention at least within a minute or two. I don’t want to disturb their work, but sometimes I have to call across the counter after many minutes without them realizing I’m here.
# 9. Eat Now Højbjerg has pizzas wider than our bags. Bruh
# 10. I got an order I couldn’t fit in my bag
#
# Reassigned Outliers → Topic 8 (52 docs) | Original top words: task, task task, time, new task, accept, accept task, new, hour, disappear, receive
# 1. Still fond of work but seems the amount of effective work one has has fallen too much
# 2. I waited many times today but I didn’t get a task for me to deliver. Hope it will get better going forward. Please look into this. I will be online again tomorrow. Thanks
# 3. Went offline because of too few tasks
# 4. Please add the task fee to the display after the task is accepted so can see it while waiting
# 5. Please stop setting me offline, I was waiting for tasks
# 6. Lack of tasks and low price.
# 7. Same bs: You have programmed the algorithm to wait with offering tasks until one is around 500 meter away from the venue, probably only when order level is quiet/order is not too late…
# 8. I slipped to work again.. and still nothing I'll go home with a cigar-nosed peck... if there's no work, there's no point in going around empty-handed
# 9. Waited almost half an hour online on high demand and got no tasks. Maybe im a bit to far from city center but idk
# 10. Times are far too small It is impossible to get on time it takes longer than you put it. You just have to do something about it in advance thanks didn't
#
# Reassigned Outliers → Topic 9 (87 docs) | Original top words: wolt, market, wolt market, market vanløse, order, vanløse, danish, copenhagen, denmark, hour
# 1. However, I would like to file a formal complaint about the Wolt staff in the Wolt Market Willemoesgade. They are extremely hard in their tone and it is as if they have formed their own little click, they shout and almost stand 3-4 people at once and shout one in your head when you are up there and pick up orders. It is a direct unpleasant environment and only the English -speaking ladies are in there is the problem. I reject the decided order up there from because of the unpleasant mood you meet as soon as you come in the door, it is primarily in the evening they are there. It destroys your entire work ethic when you come in and meet these women. I would like to be taken seriously here as their shouting and extremely condescending saying to me as cure commandments is simply under all criticism. Especially a blonde and one that is shown from India or something. We are some messes that are extremely tired of it but now I write the message as the other messages cannot write properly English or Danish. Would you not want to help us with those who work in the Wolt Market Willemoesgade in Aarhus. It's not a good situtation that is up there and it ruins our daily lives.
# 2. No demand; orders cheap for long distance. 4hours of work by car for 580kr …what i should pay with this? The tax ? The gasoline or the lease? Or food for myself ?what exactly of this shift . The answer is nothing for myself … all this money will gone for someone else, but not me . INCREASE THIS PRICES .. make us work with pleasure like before in Wolt Denmark. This is absolutely non - respectable and valued job! Day by day … less and less wishes to work. I repeat few many times .. is not put billboards in hole city to make fake advertising (how u gonna earn more then 200kr/h ) . Invest in the ppl who are long with the company and especially ppl by car because without us … WOLT IS losted !
# 3. I wonder why Wolt Viborg has become completely quiet even in Peek Hours there are half hours where nothing happens? This is how it has become within the last week or more? If I look at Silkeborg, Herning, Holstebro then there is busy or normal. Now not answer that I can just drive to Holstebro? Turn of more than 100km return. Another thing that wonders me, today I started at 5:29 pm at DK Pizza and Grill Viborg and I stood alone Wolt man with 5 men with Foodora bags and got orders, then pizza the man asks a foodora man if the order he should have is a wolt order ??? What's going on ?? Greetings Henrik
# 4. Why are you asking for feedback?! You setted up the algorithm to lower the payment per task until it became almost not motivating anymore to work with wolt. You are continuing to push the so called VARIABLE METHOD OF PAYMENT which is absurd and actually is a tricky way to lower the income for us and higher it for you. I couldn't believe it here in Denmark the sistem allow you to play around with those who do the work, instead to appreciate it and pay always better... We feel like real slaves...
# 5. Thank you for a shit day again today 3 days pull there is not a person there and tell me why block me from Wolt Market in Vanløse Tell me why why
# 6. Am tired of your lies and your lower intelligent collaborative partners who refuse to do their job It may not be true that I have to wait for a trip from Burger King Nørreport which is reported clear but because they do not care about Wolt, the trip is just even if it is packed and the bid is ready it does not become Correcting it up and doing something. By saying that it is the best day to deliver but has been out for almost 5 hours and earned £ 800 where is the best day so I should have earned as much as last year but no is just paid what you always do fucking ridiculous
# 7. (Continuation of my previous message as I sent it a bit too early)… The kind of discrimination faced by us Wolt couriers in Mc Donalds in Hillerød is unacceptable and almost criminal by law. I hope you can align with them a more appropriate way to treat the couriers and to not down-prioritizing our food, so it’s always late for our customers. Further more please pay attention to Wolt couriers that are stealing food from the restaurants and take the necessary actions to stop it from happening continuously, so that the better behaved Wolt couriers can have a better collaboration with the restaurants. Thanks in advance!
# 8. The restaurants in Holbæk start preparing after we courier arrives to pickup. This resolved in later delivery, bad costumer satisfaction and loss of money and time for the individual courier
# 9. Task fees for any kind of orders from Stenløse is not fair with the offers it's so far from Frederikssund and we will come back to city again it's 36km in total so please pay attention that's why we decline orders from Stenløse Thanks
# 10. Burger King in Vanløse is simply having to get more at work - they can never follow
#
# Reassigned Outliers → Topic 10 (23 docs) | Original top words: bundle, bundle order, order, pay, task, accept, payment, new, order bundle, system
# 1. Time waste. Too much emphasis on bundles. That's why a lot of orders were late(bad for customers). Because of this couriers weren't getting orders in a fluid manner. Spending periods without an order just to get bundles out of the blue. Revert back. This is bad for couriers and customers!!! It will come to Wolt as the company if things don't improve
# 2. When we deliver two order to the same customer or we have bundle it could be nice to click the orders and see customer details
# 3. Hi Wolt Support, I wanted to share some feedback and a suggestion that could really improve the experience for couriers like me. It would be great if the app could show us the order items before we accept the delivery. That way, if my bag is almost full and the order is small, I can accept it. But if it’s a larger order, I can leave it for another Wolt courier with more space (or someone with a car). Also, I want to say a big thank you for finally adding the “decline delivery” feature after accidentally accepting an order. I’ve been waiting for that for a long time, and it’s much appreciated! Thanks for considering this suggestion, and keep up the great work! Best regards, Samuele
# 4. Now set the payment a little for bundles. No one is bothering to risk an order with waiting or stairs for the 5th floor for 22 kr.
# 5. Wasted 18 min waiting for order at Yieast, what do I get from waiting, company pays fine to Wolt but what about courier. Made more earnings not taking premade bundle tasks than if I accepted them
# 6. Meny had an idea that only will be spent 1 order access but I had 2 orders. A customer swindled me because I couldn't find the address. It is inappropriate to bundle orders from different restaurants are merged together.
# 7. Free delivery for the customers, less payment for couriers. I am working so hard, but at the end I'm just tired and nothing more. Orders in bundle coming 4-5 in a row and they don't give me nothing. Why i should take them? Now everything I so expensive and you guys paying less and less for more work than before. You gonna loose many of the couriers and when you don't have enough to pick up the orders you gonna start loosing customers too. Nobody what his food 30 min and more delayed food.
# 8. Get back to old payment method! It's more clear! Now we don't know, you just se the price that you like for the tasks, really unfair. Km deduction!!!! It doesn't worth it anymore to deliver over 3km. We have to pay 100% of our expenses and the prices are super low. Let the bundles be the full price as before! 35kr for a bundle task over 4km??? When we actually have to drive 1-2-3 km from first drop of to the second??? This is insane
# 9. Please please look at bundle pay, it’s not only about distance. I’ve written this before and I know you probably don’t care, but just know the matter has been brought to your attention many times… also when doing bundles/ triples. Sometimes you deliver one of the orders and get offered a new one, while you still have orders to deliver. BUT THE APP LOOKS LIKE ALL YOUR DELIVERIES HAVE BEEN MADE. This sometimes confuses me so I reject the new orders offered..
# 10. I got a survey earlier today where I said I felt the payment was fine. However on busy days like today, and snowy weather, where you're held up in ultra slow traffic, the tasks could pay better. Especially the bundles fees, as arriving to the venues and customers take extra long time in these weather conditions. Otherwise all is good!
#
# Reassigned Outliers → Topic 11 (41 docs) | Original top words: bonus, weekend, weekend bonus, order, bonus weekend, bonus time, 17, time, today, remove
# 1. The new nighttime bonus is absolutely atrocious and disrespectful. 10% extra is NOTHING. Maybe 30-40% would be a realistic number. Normal workplaces give 1,5x more (+50%) for night shift workers. I would really like to work at night sometimes, but this so called bonus is just not worth it. I hope you will reconsider your approach and start treating courier PARTNERS as actual partners and not as company slaves
# 2. Today was a very disappointed day, first you put the booster from 25 to 20% and try to sale a ideia of a mistake, typo, come on, we are not stupid. After this I made 25 deliveries and was supposed to be the big day bla bla bla, and with 25 deliveries I made not so different if I compare with 31/12, when I made 26 deliveries more the 1.300, today with 25 I made less than 1.300! For me we were cheated! Very disappointed and sad about.
# 3. Really ridiculous in putting boost on Friday between 18.00 and 20.00 when absolutely nothing happens !! Have dear 3 trips during that period and it was! Uses a lot of gasoline to lie down and run around by order. It's really bad style
# 4. It raihed all day where is the bonus for bad weather
# 5. Overall, I'm happy with my collaboration with Wolt, but there's one problem. The new courier registered using my referral number and made 30 deliveries in 30 days, starting with the first delivery. But I still haven't received the 1000 CZK referral bonus that I was entitled to. On July 22, I contacted Wolt support to find out why I was not credited with the referral bonus, but I still have not received an answer to my question. So for now I give the Wolt app 2 stars.
# 6. You have to give more wages and give holiday money
# 7. wolt is a crap company, during the bonus you don't get any orders, fuck you
# 8. I suggest you pay more hours bonus on weekends and when the weather is really bad like yesterday in Copenhagen.
# 9. How can I have made less money than in everyday life despite more order and weekend bonus ?????
# 10. When is raining you should pay more or bonus otherwise we can't get wet and the delivery won't be able and all the food will stay in restaurants. Thinks about it. Thanks
#
# Reassigned Outliers → Topic 12 (230 docs) | Original top words: support, order, deliver, cancel, customer, deduct, ask, tell, mistake, time
# 1. I was very happy in the past. But since the issues the operational team keep continue to flub with not including the VAT to my salary for 2 times. Each time i sent the form and still it repeated again, and especially that i don't have a direct communication channel to them and it gas to be via the support- so I'm not happy. I sk pls that someone from the operational team contact me at 29900570 or send me an email to dalitv@gmail.com telling me when they will sent a new invoice with the added fee plus to see this trouble doesn't appears again . Thanks alot
# 2. Says unknown error when you have to complete a delivery it takes long.
# 3. Unfair and unacceptable task payments. Please do something about it. It’s starting to be not worth the time and effort under the weather’s circumstances. Thank you
# 4. I have been suspended for an order even though I have neither picked up or delivered the order. It is about order number 896, the task was canceled before I managed to pick it up. I took the task to start with but wrote to you again that you have to cancel it and it was. So I didn't pick it up from the restaurant. When I wrote yes to one of your colleagues on message then it had gone strong and I read wrong. You can contact the restaurant and hear them if I picked up the order or not. I only picked up two orders from there and they were delivered to the customers.
# 5. Very bad support i waited 1 hour and the order canceled for system fail i said make new one and I took only 35 1 hour 35 krone perfect deal
# 6. So bad i go to restaurant and the order cancel it’s not my fault and it’s not pay for me i think we think we must look for another company better because wolt company became bad treatment of her employees thanks for everything
# 7. Hi, I think it has been complicated to contact support about problems. I was at a restaurant that marked his order ready about 15 minutes before they actually were. I wrote this for support so this could be noted in the restaurant's history as I know they are contacted if their order is often too late. When the person in support returns, they write "What can I help with". I am out and running, so I do not have the opportunity to repeat what can already be read.
# 8. wolt is designed to steal from us, couriers, yesterday I worked all day for wolt and at the last order the location where I picked up gave me the wrong order, I know it's within my competence to check but many locations don't even give a receipt , the order was worth 37 crowns and they stopped me 230 for around six delivered work orders
# 9. Even though i delivered the food which was partly wasted, im still being fully charged. I think couriers that work hard and are sincere, Shouldn't be charged for their mistake - it can happen to anybody
# 10. Arrived to pick up the order and the order was already taken. Support contacts the venue and got them to do the order again, only that they didn't agree cause they remade it twice so what was handled by support on the phone? Nothing. I then got the task removed and at least got 35 kr for it. Only it's bonus hours and should be around 50 but support tells me bonus is not really a thing, which it's not true cause I can clearly see I get around 45 instead of 35 on weekends so bonus is definitely still a thing. So I wasted over 40 minutes for....35 kr. I'm sorry but no. Very bad support. Not okay.

# %% [markdown]
# topic 0: fits
#
# topic 1: fits mostly
#
# topic 2: fits
#
# topic 3: fits
#
# topic 4: most don't fit
#
# topic 5: 50% passer
#
# topic 6: mostly don't fit
#
# topic 7: mostly don't fit
#
# topic 8: mostly don't fit
#
# topic 9: 50% fits
#
# topic 10: 50% fits
#
# topic 11: 50% fits
#
# topic 12: 50% fits
#
# Overordnet ligner det, at der er lidt form meget støj

# %%
from collections import defaultdict
import random


# Organize documents by new topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, new_topics_embedding025_2):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = -1
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")

# %%
 
from octis.evaluation_metrics.coherence_metrics import Coherence
coherence_model = Coherence(texts=tokens_for_coherence, # reference corpus. Here it's all documents in the dataset
                            topk=10, #specifies the number of top words to consider for NPMI calculation
                            measure="c_npmi")
npmi_score = coherence_model.score({"topics": topic_words_target_model}) # average

# Calculate Topic Diversity
# the topic_diversity command was defned before the loop. This is not a standard command, so I defined how it works earlier.
diversity_score = topic_diversity(topics = topic_words_target_model, topk=10)

# Calculate Topic Quality by multiplying NPMI score and Topic Diversity
topic_quality = npmi_score * diversity_score
# Out:
# /Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide

# %%
for i, topic in enumerate(topic_words_target_model):
    score = coherence_model.score({"topics": [topic]})
    print(f"Topic {i}: NPMI = {score}")
# Out:
# Topic 0: NPMI = -0.009005572304378559
# Topic 1: NPMI = 0.1402920801882038
# Topic 2: NPMI = 0.04223354805439683
# Topic 3: NPMI = 0.02140121370663232
# Topic 4: NPMI = -0.04580471063209176
# Topic 5: NPMI = -0.15760481957677328
# Topic 6: NPMI = 0.17599019618695694
# Topic 7: NPMI = 0.026913872987460865
# Topic 8: NPMI = 0.07887086558831503
# Topic 9: NPMI = 0.08594379337345763
# Topic 10: NPMI = -0.12377918713783191
# Topic 11: NPMI = 0.04619751059702082
# Topic 12: NPMI = 0.05604190803107952
# Topic 13: NPMI = -0.5272028101349079
# Topic 14: NPMI = -0.05510848210649167
# Topic 15: NPMI = -0.19818362204376036
# Topic 16: NPMI = -0.46947643980528525
# /Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning:
#
# invalid value encountered in scalar divide
# Topic 17: NPMI = nan
# Topic 18: NPMI = -0.6001775191780095

# %% [markdown]
# ### redcution of outliers for manuel cluster reduction

# %%
import copy

# Define the strategy-threshold combinations
combinations = [
    #("embeddings", 0.36),
    #("embeddings", 0.37),
    #("embeddings", 0.38),
    #("embeddings", 0.39),
    #("embeddings", 0.40),
    #("embeddings", 0.41),
    ("c-tf-idf", 0.075),
    ("c-tf-idf", 0.08),
    ("c-tf-idf", 0.085),
    ("c-tf-idf", 0.09),

    #("distributions", 0.09),
    #("distributions", 0.095),
    #("distributions", 0.10),
]

# Store results
results_c_tf_idf = {}

# Loop through each combination
for strategy, threshold in combinations:
    print(f"Running: strategy = {strategy}, threshold = {threshold}")
    
    # Deep copy the original reduced model
    model_copy = copy.deepcopy(reduced_model_manual)

    # Reduce outliers using specified strategy and threshold
    new_topics = model_copy.reduce_outliers(
        documents=documents,
        topics=topics,
        strategy=strategy,
        threshold=threshold
    )

    # Update topic representations
    model_copy.update_topics(
        docs=documents,  # <-- FIXED HERE
        topics=new_topics,
        vectorizer_model=vectorizer_model,
        #representation_model=representation_model
    )

    # Count number of outliers
    outlier_count = sum(1 for t in new_topics if t == -1)

    # Store results
    results_c_tf_idf[(strategy, threshold)] = {
        "model": model_copy,
        "topics": new_topics,
        "outlier_count": outlier_count
    }

# Optional: print summary of outlier counts
print("\nSummary of Outlier Counts:")
for (strategy, threshold), res in results_c_tf_idf.items():
    print(f"{strategy}, threshold={threshold}: {res['outlier_count']} outliers")
# Out:
# Running: strategy = c-tf-idf, threshold = 0.075
# 2025-05-25 19:17:37,952 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# Running: strategy = c-tf-idf, threshold = 0.08
# 2025-05-25 19:18:46,462 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# Running: strategy = c-tf-idf, threshold = 0.085
# 2025-05-25 19:19:54,395 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# Running: strategy = c-tf-idf, threshold = 0.09
# 2025-05-25 19:21:02,257 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.
# Summary of Outlier Counts:
# c-tf-idf, threshold=0.075: 1587 outliers
# c-tf-idf, threshold=0.08: 1758 outliers
# c-tf-idf, threshold=0.085: 1945 outliers
# c-tf-idf, threshold=0.09: 2122 outliers

# %% [markdown]
# First run
#
# - embeddings, threshold=0.4: 2415 outliers
#
# - embeddings, threshold=0.45: 3172 outliers
#
# - embeddings, threshold=0.5: 3682 outliers
# - c-tf-idf, threshold=0.07: 1406 outliers
# - c-tf-idf, threshold=0.08: 1758 outliers
# - c-tf-idf, threshold=0.09: 2122 outliers
# - distributions, threshold=0.08: 1401 outliers
# - distributions, threshold=0.09: 1657 outliers
# - distributions, threshold=0.1: 1943 outliers
#
# ------------------------------------------------------
#
# Second run
#
# - embeddings, threshold=0.25: 457 outliers
#
# - embeddings, threshold=0.3: 955 outliers
# - embeddings, threshold=0.35: 1627 outliers
# - c-tf-idf, threshold=0.075: 1587 outliers
# - c-tf-idf, threshold=0.08: 1758 outliers
# - c-tf-idf, threshold=0.085: 1945 outliers
# - distributions, threshold=0.09: 1657 outliers
# - distributions, threshold=0.095: 1819 outliers
# - distributions, threshold=0.1: 1943 outliers
#
# ------------------------------------------------------
#
# third run
# - Summary of Outlier Counts:
#
# - embeddings, threshold=0.36: 1772 outliers
#
# - embeddings, threshold=0.37: 1928 outliers
# - embeddings, threshold=0.38: 2111 outliers
# - embeddings, threshold=0.39: 2260 outliers
# - embeddings, threshold=0.4: 2415 outliers
# - embeddings, threshold=0.41: 2583 outliers

# %% [markdown]
# #### Inspection of embeddings 0,35

# %%
# Step 1: Get original topics (before outlier reduction)
topics, _ = reduced_model_manual.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Step 2: Get new topics (after outlier reduction using embedding + 0.25 threshold)
topics_emb_035_manual = results[("embeddings", 0.4)]["topics"]

# Step 1: Find reassigned outliers (originally -1, now assigned to a topic)
reassigned_outliers = [
    (i, doc, new_topic)
    for i, (doc, old_topic, new_topic) in enumerate(zip(documents, topics, topics_emb_035_manual))
    if old_topic == -1 and new_topic != -1
]

# Step 2: Group reassigned outliers by new topic
topic_to_outlier_docs = defaultdict(list)
for i, doc, new_topic in reassigned_outliers:
    topic_to_outlier_docs[new_topic].append(doc)

# Step 3: Print sampled outlier docs with ORIGINAL top words (from reduced_model2)
for topic_id in sorted(topic_to_outlier_docs.keys()):
    docs = topic_to_outlier_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))

    # Get original top words from reduced_model_manual
    original_topic_words = reduced_model_manual.get_topic(topic_id)
    if original_topic_words:
        top_words = ", ".join([word for word, _ in original_topic_words])
    else:
        top_words = "(No original top words)"

    print(f"Reassigned Outliers → Topic {topic_id} ({len(docs)} docs) | Original top words: {top_words}")
    for j, doc in enumerate(sampled_docs):  
        print(f"{j+1}. {doc}")
    print()
# Out:
# Reassigned Outliers → Topic 0 (700 docs) | Original top words: courier, hour, new courier, work, order order, order courier, day, hire, earning, courier order
# 1. I would like to arrange for delivery.
# 2. Yesterday I had an order from Wolt Market and there was 6 bags and for that it would be needed 2 couriers. I was waiting for over 15 min to be ready and then decided to ask them about it because is not really usual to be that late. For my surprise they told me that only one of the couriers get the notification that is ready which for me make no sense. Could you please inform that to the IT team so that can be fixed otherwise the customer will receive an order within 10min and the rest who knows when?
# 3. I took an order that was almost an hour late, i get there and am told that somebody took the order already. Support tells mr i can wait for a remake. I wait for a remake and deliver it. This ordeal takes 30minutes on top of delivering - but according to your guidelines ( as i am told by the support ) this is not worthy of a compensation. So this tells me, that next time there is a problem with an order, abandon it instantly so i can use my time to actually work and deliver normal orders, and let you deal with the customer. Absolutely horrible , especially with the overly cheery attitude claiming they care but in reality couldnt care less about couriers
# 4. Meny is not marking heavily orders as heavy and unfortunately they started once first after 5 minutes asking to pack the back - therefore I was delayed. The staff there seems to be unmotivated as they had to call even the person who has to pack for Wolt. And they said that they start the task always first when the driver is there - which is of course not the fact. Guess it was the todays staff and a friendly reminder helps
# 5. Are we going to work? I am waiting for my orders
# 6. Hi, I had an experience tonight that was a bit strange. I accepted a task that was going from the center of Aarhus to Hasselager, the distance was 10km, I received the opportunity to take another order. The next order would first be ready for pickup in 20 minutes, it had to be delivered to the same road, but gave only 30 kr. When an extra order is going on a very long trip, but you only get so little paid, then there is very little to reject the order. If I had been offered 70 kr, I would like to expect the time and Wolt would save the money they now have to pay another bid to deliver the food.
# 7. Medium but no orders ???
# 8. Everyday there happens "ukendt fejl", which makes order can not be closed normally, and it also wastes time.
# 9. Uniform tasks and no price and kilometers informed by the orders
# 10. Especially when you are on a bike, it is really nice to be able to see the content, and thus also the size, of the orders you are on your way to pick up. Therefore, it does not seem quite optimal that you have removed the overview of the content of the orders from the Wolt Market. They are often quite large and heavy to cycle with. Now you really do not have the opportunity to see the order until it is handed over to one. Before, you could assess the size of the order and possibly get it canceled, without having to run in vain.
#
# Reassigned Outliers → Topic 1 (74 docs) | Original top words: restaurant, burger, mcdonald, min, delay, food ready, order ready, burger king, mcdonalds, mc
# 1. Too many restaurants not prepared with the food. I wasted a lot of time just waiting. The orders I get in the app are located places inaccessible by car, even though I’m registered as a car deliver partner. Also the orders I get offered were all already late, and the customers are not happy about it.
# 2. Burger concept is always preparing the food when we arrive and show the order It’s wasting our time And the food is also marked ready Also Macdonalds Frederikberg Workers almost always let the curriers wait long time on the window when the food is ready and they let us wait for nothing Instead having someone there always to hand over the food to the curriers They look on us tapping on the window and simply ignoring us Yesterday the food was ready And one of the workers told me that it’s not ready when it’s in front of him And he let me wait on purpose And he told me we are busy here And you need to wait Why I need to wait when the customer is waiting for their food
# 3. McDonald's is hopelessly behind constantly (Slagelse)
# 4. The Jenin restaurant had a real rude staff
# 5. Still not receiving a notification when the food is marked ready
# 6. McDonalds Risskov marks Food as ready but it s not
# 7. essan thai food always marks order as ready when timers runs out, even if they didnt even start wirh order. burger king tends to also mark food as ready even though it is not
# 8. McDo Valby doesn’t give out the food, though it’s there, already getting For 20 mins, 4 times today at the very least..
# 9. Still long waiting time in Macdonald Valby til they give the food after it is ready
# 10. I am tired of that I can't see the customers address after I accepted. Some times I am at McDonald's and waiting 5 minutes, in that time it would be nice to prepare the delivery
#
# Reassigned Outliers → Topic 2 (108 docs) | Original top words: happy, happy wolt, day, wolt happy, work wolt, thank wolt, wolt good, happy work, love wolt, satisfied
# 1. Have an excellent day
# 2. Have an excellent week
# 3. Have an excellent day
# 4. Thanks for 12 hours of work for the money I spent today
# 5. Have an excellent day
# 6. Have an excellent week
# 7. Have an excellent week
# 8. Have an excellent day
# 9. Have an amazing day .
# 10. Have an excellent day
#
# Reassigned Outliers → Topic 3 (258 docs) | Original top words: pay, low, hour, payment, earning, work, salary, kr, wage, earn
# 1. Perfect independent work. Sweet and nice employee in office. But now it is time that pay rises a little more When all things got expensive in society.
# 2. Yes thanks with a pre -shown amount, correct, but we also want details. So if not in advance, then when our task is made Nobody is Perfect, nor Wolt. Now we do not have the opportunity to join in and keep track of as there is nothing and keep track of I've always been very fond of Wolt but this is totally wrong As 5 km = 100,- + 35,- = 135,- but I got 76,- It is equally valid if you have moved from bird's eye view to normal distance as we lose a great deal of payment instead And never have we experienced less than 35,- Now suddenly an order is popping up, with an income 31.50 so you think it may be an advantage for us cures, but I don't think that
# 3. Every day we earn less and we have to work more hours. once think of the delivery guys
# 4. There is little money
# 5. Orders get less and less payments, for example, if during day delivery orders coasts 40-50-60kr, in 'Weekend boost' the same - so doesn't have sense of this 'Weekend Boost'.
# 6. not a lot of action on my first shift ended up with an hourly wage og 60-70 kroner
# 7. The payment is too low
# 8. Pay way less than before
# 9. I can't see my money Get my piece
# 10. You didnt pay me when you had to. The wages are way too low.
#
# Reassigned Outliers → Topic 4 (281 docs) | Original top words: app, app work, error, order app, problem, restart, bug, time app, error app, accept order
# 1. The app didn't work from first Bot needed to be updated and after that fine
# 2. The app could well help with the directions
# 3. Some time app not responding properly.
# 4. App still drains battery like crazy and nobody is a big fan of the combined orders or multiple orders
# 5. The app does not automatically update even it is turned on in app settings
# 6. This app is very bad for making money
# 7. The app is slow and clumsy, even on a fully updated and fast phone. The worker at Fontaenen Grillbar is very impatient. If he sees you checking the phone for 30 seconds to figure out a route to delivery, he hurries you over and over.
# 8. App have been closing by itself, usually fixed by closing the app manually and opening it again
# 9. You just cost me over 2000kr because your clammy app didn't work yesterday for 3 hours. My phone was silent because your clumsy app couldn't log me out because your clumsy app didn't work. The next morning I couldn't hear my phone called so I missed my brother's driving test. Many thanks for that.
# 10. Congratulations on ruining the app completely. Only fake food ready and no control of logistics. Worst long !!!
#
# Reassigned Outliers → Topic 5 (17 docs) | Original top words: km, delivery, drive, payment, bike, scooter, trip, kilometer, long distance, ride
# 1. I need my kilometers please Why you Wolt don’t send it ?
# 2. Had to drive 2.5 km in vain and the order wasted. It was 25 pizzas as a bid for bicycle/scooter yes I do not have room for :( no compensation practice
# 3. The payments are soooo bad. I rather want to walk every single of my orders. I honestly put it on bike and only take orders less then 1.5km
# 4. Ways many long shot orders.. I'm not a car or a moto I just have a mountain bike!
# 5. If you send me order with 4 km to pick up so doesn't work for me
# 6. Seems good enough the price for the long trips is low, 145 kr for a 30 km drive in the weekend boost. Usually gets 55-65 for 3-4 km. So the long trips are to take piss on his courier. Get it fixed
# 7. Verry bad experience today from first delivery I drive 10 km to get 35 dk and wolt suport makking fun out of my problem
# 8. Kilometers don't work
# 9. 3.4 km 48 kr?!!???? First time 2 ,4 km 50 kr
# 10. Less time to pickup than the trip
#
# Reassigned Outliers → Topic 6 (50 docs) | Original top words: support, wolt support, chat, support team, support good, support bad, support support, support help, people support, support today
# 1. Good help from support
# 2. Very annoyed for the support. I lost my 45 minutes for one delivery which was previously delivered 2 hours before. Shop didn’t know anything about the order also support take my 45 minutes.
# 3. Thank you with the best support
# 4. Quite bad support with 40 kr per hour
# 5. Thank you so much SUPPORT
# 6. Bad support and shops
# 7. hello Thank you for all support team
# 8. Still getting scammed and support is denying it
# 9. Really happy with customer support
# 10. Thank you so much SUPPORT.
#
# Reassigned Outliers → Topic 7 (6 docs) | Original top words: map, address, gps, maps, google map, google maps, wolt app, wrong address, route, street
# 1. Customer had indicated address incorrect
# 2. Hi, sometimes the customer's address is written incorrectly and we can't find it. Customer should be able to send his location please
# 3. Would be very helpful to have the option to be allowed to copy the address in order to make it faster and to avoid mistakes when entering the address in Google Maps
# 4. Today, I put the wrong food due to the google map error and contactless customer, but after the support messaged me, I went back and corrected it, but I was fined, and this was a bad experience for me.
# 5. Please make it possible to copy the address as well because sometimes Google maps inputs the wrong one
# 6. Like to add shops and restaurants in your map so you can drive against these if you do not have order self only those who are in Wolt and the ones you can order from
#
# Reassigned Outliers → Topic 8 (1 docs) | Original top words: bag, pack, food, spill, soda, paper bag, lid, leak, packaging, mcdonald
# 1. Please make the bag available in plain black without logo.
#
# Reassigned Outliers → Topic 9 (74 docs) | Original top words: wolt market, market, market vanløse, vanløse, danish, copenhagen, denmark, courier, order wolt, hillerød
# 1. Not enough orders , people are just not ordering it's quiet all the time, there's too much people driving in Aarhus, we can barely pay our rent and make for bread.
# 2. The cannibalising from your side, the Wolt platform, was just toooo much today!!! Every order was like 40-80 minutes late - stop it please, it's awful to work under these conditions, the customers are receiving their orders way too late, and you are pushing the limits beyond sanity. No wonder we get the reputation 'Kolt' = cold in Danish, because the food will be cold when it arrives. Restaurants also did way too much cannibalising today, marking orders ready, having like 8 or more couriers waiting, but not enough staff to serve us, so we have to wait way too long, and the food will be cold. It's awful to work under these conditions.
# 3. 0-1 orders per hour... would you work for 50kf per hour in Copenhagen?
# 4. Low prices ! Long distance, some big orders more then 25kg from wolt market and more then 6km distance is cost 80kr? Others appear on my display 5km for 50kr? Come on ! Till when the wolt company gonna make a bad joke with us especially we who are with the cars? You think i can pay my gasoline, insurance and manteining the car woth this low prices ? I invite all owners to come and drive on the street of Copenhagen!!! It’s seems like if you like to drive by car wolt and be like a full time job ; you will be of the poorest ppl in Denmark! I hope one day this government really gonna catch good this company and pay everything by the low ! You cannot work in Saturday and Sunday; even in the evenings without additional pay! This is not exist in the country with the most expensive tax in the world! Let’s see if this company gonna close like other deliveries markets or will invest in the most important ppl” We who are on the streets! No wishes to work with this prices , i will never recommend to drive wolt to the friends , since few months ago ; day by day is going worse and worse
# 5. We have to go too many bids in Sønderborg, which goes beyond all of us. There are not enough orders and earnings are included. In general, Wolt is a great concept and works impeccable! Support also makes it great!
# 6. Lies upon lies, Wolt is a damn scam, they are not transparent, they play with us, they modify the payments all the time. Wolt is the biggest trash in Denmark...
# 7. Definitely day by day is getting worse and worse paid WOLT! I don’t know is the idea from the menagment to go in Denmark this company; but for sure is not in better . No wishes , no fairly rules at all. How is possible in super busy time to appear on our display order with distance 5km for 50-60dkk?!?! Sure ? That’s the 2023 fairly delivery payment in the most expensive TAX country in the world? What about the gasoline ? What about the ppl with expensive tax and car insurance! And yes you need this ppl a lot , because no one scooter or bike will run 10km for some orders ! Pls a little of respectable work… if you still there is someone who cares for the riders in this company…. RIDERS … the people who move all in WOLT they are worst paid and no any benefits!!!
# 8. Wolt Market nordvest is a mess. It seems that the employees have a competition to see who packs the order the slowest. Get more people, or efficient ones please!
# 9. Unfortunately wolt is no longer the same as before when there were many orders, now there are many partners who pay less money every day, they always manage to not pay for vacations by telling you that you are their partner, they should be ashamed of how they abuse their partners who suffer from cold and rainevery day, you will all receive what you deserve, without a doubt it is the worst job in Denmark.
# 10. Task fees go down and down,even when foodora has left denmark and wolt has more customers....
#
# Reassigned Outliers → Topic 10 (14 docs) | Original top words: bundle, bundle order, payment, order bundle, bundle task, bundle pay, reject, courier, delivery, accept bundle
# 1. The prices are very low specifically for long distances and bundle
# 2. No orders enough. But wolt gives bundles to some couriers
# 3. In shock over the Wolt bundle ambush
# 4. It would be really cool if it could be made so you could see if you were on a bundle order and had to pick up two orders from the same store, because it would be much easier for everyone if you could say to the staff from the beginning of May to pick up two, rather than getting the first one, packing it, and then having to grab the staff again to get the next order
# 5. Weekend was good. Still don't get how it might say "busy" (which per your definition means 'way more orders than couriers on the ground') for few hours, in an area that's packed with venues, and still not get ONE single bundle. Something doesn't make sense. You give bundles only to car/scooters or something?
# 6. Time waste. Too much emphasis on bundles. That's why a lot of orders were late(bad for customers). Because of this couriers weren't getting orders in a fluid manner. Spending periods without an order just to get bundles out of the blue. Revert back. This is bad for couriers and customers!!! It will come to Wolt as the company if things don't improve
# 7. I am so disappointed with your new pricing model. I drove 4km for 35kr because you are not allowed to make money on bundles anymore.
# 8. Wolt's/doordash new motto is "Reject the Bundles".
# 9. Please please look at bundle pay, it’s not only about distance. I’ve written this before and I know you probably don’t care, but just know the matter has been brought to your attention many times… also when doing bundles/ triples. Sometimes you deliver one of the orders and get offered a new one, while you still have orders to deliver. BUT THE APP LOOKS LIKE ALL YOUR DELIVERIES HAVE BEEN MADE. This sometimes confuses me so I reject the new orders offered..
# 10. The distance written for a bundle orders is not the write distance and the payment is not correct even the support team do not know how to handle this and they closed the chat before I got their answer or even let me explain what is wrong
#
# Reassigned Outliers → Topic 11 (45 docs) | Original top words: weekend, weekend bonus, bonus weekend, bonus time, earn, 17:00, saturday, bonus bonus, bonus day, extra bonus
# 1. Have an excellent weekend
# 2. I find it extremely unfair you offered the 500 kr bonus for 40 tasks only to some couriers. Guess no point in delivering extra this weekend then
# 3. Pay us the promised extreme weather bonus
# 4. Have a great weekend
# 5. Have an excellent weekend
# 6. Have an excellent weekend
# 7. Rainy day and no extra bonus? No thank you, we want increased earnings, not decreased!
# 8. I suggest you pay more hours bonus on weekends and when the weather is really bad like yesterday in Copenhagen.
# 9. Have an excellent weekend
# 10. Have an excellent weekend
#
# Reassigned Outliers → Topic 12 (5 docs) | Original top words: mile, drive mile, mile offer, let drive, close venue, order close, joke app, venue app, delivery, distance
# 1. I get order from kiin kiin restaurant, when I arrived to the restaurant it was closed , I wrote to support and they said to me the restaurant is open , I told support the restaurant I closed and sent video to the support but they told me that not true . I road 2,5 km free . Always give us wrong addresses and wrong names. The support today was very bad
# 2. your mileage calculations are wrong
# 3. The app hasn't counted mile 29/10 and 30/10?
# 4. Really bad mile counts doesn't work in the app, it feels like you don't take us courier seriously when nothing about the problem!
# 5. We would like holiday money and mile money
#
# Reassigned Outliers → Topic 13 (70 docs) | Original top words: deliver, cancel, customer, deduct, mistake, compensation, cancel order, delivery, deliver order, order cancel
# 1. Complain about 11 november, i had a problem with my delivery: The address was wrong, it was the backdoor of the hotel, and I find on the door the address of the main door. At the reception they reject me because the address was different and they don t have a name of the customer. I call the customer but they didn t answer me. I was outside with 2 packages, their one was like 10kg and started to rain, heavy rain... and i put the package inside the box again. I contacted the support but with all the water and the time i lose 40 minutes. Later the support give me a correct number, a third one. And they confirm that the hotel was correct. So I lose time, energy and make problems with 2 deliveries. I just want to ask you to do two things. Make a blacklist and check the number of the customers or force them to put the name of the hotel and the relative name of the booking in that hotel. So if the customer is from an hotel I can easily pass the reception with correct data. And the customer after 3 hours, while I was sleeping they call me. So i would like to propose a black list for the hotel and these couple of customers. The hotel was Axel guldsmeden hotels, they have 2 address front and back door. They weren t collaborative. Even if I show them the address of the backdoor they insist that the name of the customer was the hotel, another place. Secondly the customer, i don t care if they were tired or lazy, they used the wrong name in the hotel, they didn t give me the name pf the hotel, they give me the backdoor, the phone was wrong. And they call me during the night. I SPENT 1 hour in the night, under rain for some banana and idk. So please make a black list or make a procedure to force the customer to don t be retarded. Next time I will spend 10 or 15 minuts after this I will consider lose the delivery. No one pay me if I get sick or If the customer don t answer. I am trying to be professional but I don t like to lose my energy and time. So I repeat put the hotel on a black list because they werent collaborative. If they were more open I can save 20 minutes and avoid to stay under a heavy rain with an heavy bag.
# 2. It would be nice if there were more options when "Dina" asks you when you intend to deliver again. I'm on a three week vacation so none of the options apply to me. So I had to pick one that wasn't correct.
# 3. I had an incident, the order that I was transporting in which the soup was not tightly closed. it just spilled and the support said it was my fault. But I don’t see my fault here and I want you to return my money that was written off for this order. Since I think this is the restaurant's mistake..
# 4. Today there was a delay in responding to my question about the customer's address, and an amount was unjustly deducted from me.
# 5. I could deliver without problem.Thank you for your help. Mvh Mahendran.
# 6. Cancel task only works with manual update Drive for miles and then get offered almost ready order once you are near the venue:-(
# 7. I'm angry because yesterday you offered me 35 crowns for an order, 4 km 300 and you said it was 500 km, I took screenshots and you told me that to the restaurant it was 400 meters and to the restaurant it was 3 km according to Google maps. and from the restaurant to the customer it was a kilometer 300 and you say it was a kilometer all according to Google maps. and it was a single order not combined because I had placed my last order at 7:19 p.m. At that time I had no order, I was shopping at the supermarket to go home.
# 8. Please consider the following points 1-please add 10kr tips for each floor if the elevator is not available in the building 2-Please ask the customer to write guidelines in English and be available to respond until delivered 3-Make full task money for the attached task 4-please add cancellation fee task for partner 5-Increase boost time until 9pm from 4pm on weekend and during week from 5 to 8pm 6-Pleae give 30% extre during night time to delivery partner 5-Please ask to the venue make sure ready order according to timely otherwise charges fine and pay to delivery partner
# 9. You don't give me deliveries
# 10. Think I came to Cancel an order for about 40kr as I delivered anyway

# %%
from collections import defaultdict
import random


# Organize documents by new topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics_emb_035_manual):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = -1
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic -1 (1627 documents) ===
# 1. I could not be allowed to accept but well reject. Tried turning off my phone but teasing me. Trying again tomorrow, unfortunately, has no more time right now :(
# 2. Today was a very disappointed day, first you put the booster from 25 to 20% and try to sale a ideia of a mistake, typo, come on, we are not stupid. After this I made 25 deliveries and was supposed to be the big day bla bla bla, and with 25 deliveries I made not so different if I compare with 31/12, when I made 26 deliveries more the 1.300, today with 25 I made less than 1.300! For me we were cheated! Very disappointed and sad about.
# 3. Ah why this keep showing
# 4. It was my first guard today Seems it went wellited
# 5. Boost should be start from 18:00 pm to 21:00 pm. There is no use of boost in between 17:00 to 18:00 pm as the day time increases than before. People usually start their dinner after 18:00 pm. You must take action. Very low amount of order in between 17-18 pm . We have observed for last few days. Take consideration the issue so that we can make the most use of it. Good for both
# 6. Why didn't you say that lowered the base price of the order to 30 kr? is that more transparency? Every time worst...
# 7. Is satisfied. However, it seems that there is very little to do in Fredericia compared to other cities. The features that are added to a really nice one too. But it could also be interesting to hear when new features are coming and what these could be ..? E.g. Opportunity to get gratuity after the order is completed, and the opportunity to see how many couriers are online in its area.
# 8. Freezing Old man looking for work
# 9. There is a question: Why is the tax on tips reduced? The tax deduction has been done before for tips, and tips are clean money, and you decrease tax from it again!!!! ,
# 10. Add ratings to each venue after task 1-5 stars. To get the venues to become better. Best rated venue get diplomas to hang in restaurant
# 11. Not so much and do right now, but that summer
# 12. Fuck this job, I've been more (3) hours I worked only 80DD it's fucking shit man
# 13. Would be great if restaurants could stop using open drink containers, better with cans/bottles. One surprising bump while delivering on bike and it's all over the place. Perhaps you could also do a differentiation between using a normal bike and an electrical one, then times would be more accurate and the expectations from customers would be more realistic - I couldn't possibly compete with my motorized bike colleagues in terms of speed.
# 14. Why this message is coming again and again
# 15. Nothing works - it's for laughs
# 16. We need more money for walking to 5th or 6th floor apartment with no elevator.!
# 17. You may want to make in the app that you get a tone when the message that you have not been active in the 30 min through message sound and not media sound.
# 18. Would be very nice to make the app compatible with CarPlay/Android Auto.It would help us a lot
# 19. Everything works fine but there are not enough orders. It is super hard not look to another working options!
# 20. Let costumerw add tip AFTER delivery!!! Current system makes no sense

# %% [markdown]
# #### Inspection of c-tf-idf 0,085

# %%
from collections import defaultdict
import random

# Step 2: Get new topics (after outlier reduction using embedding + 0.25 threshold)
topics_c_tf_idf_0085_manual = results_c_tf_idf[("c-tf-idf", 0.085)]["topics"]

# Step 1: Find reassigned outliers (originally -1, now assigned to a topic)
reassigned_outliers = [
    (i, doc, new_topic)
    for i, (doc, old_topic, new_topic) in enumerate(zip(documents, topics, topics_c_tf_idf_0085_manual))
    if old_topic == -1 and new_topic != -1
]

# Step 2: Group reassigned outliers by new topic
topic_to_outlier_docs = defaultdict(list)
for i, doc, new_topic in reassigned_outliers:
    topic_to_outlier_docs[new_topic].append(doc)

# Step 3: Print sampled outlier docs with ORIGINAL top words (from reduced_model2)
for topic_id in sorted(topic_to_outlier_docs.keys()):
    docs = topic_to_outlier_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))

    # Get original top words from reduced_model_manual
    original_topic_words = reduced_model_manual.get_topic(topic_id)
    if original_topic_words:
        top_words = ", ".join([word for word, _ in original_topic_words])
    else:
        top_words = "(No original top words)"

    print(f"Reassigned Outliers → Topic {topic_id} ({len(docs)} docs) | Original top words: {top_words}")
    for j, doc in enumerate(sampled_docs):  
        print(f"{j+1}. {doc}")
    print()
# Out:
# Reassigned Outliers → Topic 0 (242 docs) | Original top words: courier, order, task, hour, new, new courier, time, work, order order, home
# 1. Busy time without orders
# 2. I don't know if it's the app or to meny currier/drivers. But the last week I worked from 11 to around 13:30 o'clock with so few orders that I actually lost money on gas and time on it. Just take today's peak time 1 hour and 34 minutes and got only 1 order on 40kr drove the whole city so meny times. There most be a solution on this matter.
# 3. Absolutely all is good just with 2 things I’m not happy. 1. Waiting time with the restaurants - they don’t care about the couriers and let us wait sometimes more then 20min for 1 order , then this is absolutely loosing time and nobody pay us for that. 2. The busy time is just 17-20h if you’re not able to work at that time in general you will not earn money from Wolt
# 4. No enough orders. A lot of new partners
# 5. no work no order what's going on?
# 6. A lot of new partners. I don't have orders
# 7. From 18 to 19 is according to you peak hours but I didn't receive any orders, how is that peak hours
# 8. You need to change your tariff when you offer extra task to your route due to the extra waiting time on order # 2 I will earn more per hour by only taking an order of times due to the waiting time on the orders
# 9. where are these orders??
# 10. Can it really fit that no orders will be run through in Odense at 19:15 on a Saturday? It is teeming with Wolt Bude bored. While you can contact if feedback is to be given regarding demand versus the number of bids you have taken in. Ever since you have expanded the area in January It has been more limited and almost impossible to make money unless you only bother to work 2 hours 17: 30-19: 30. Demand is briefly reaching the "normal". Before, it was "busy" in between 17-20 but now it is "quiet" most of the time. Hope you will look at whether you have not hired too many after the area expansion in January which has destroyed the flow.
#
# Reassigned Outliers → Topic 1 (376 docs) | Original top words: ready, wait, order, restaurant, time, food, minute, burger, mcdonald, min
# 1. Aloha Bowl must have tuned their time estimate. They were so 15 min behind and they were the last time I was there. So just bump their time up a bit so you don't wait too long maybe?
# 2. The customers need please write down the address correctly otherwise is difficult for us to find it and delayed us doing the deliveries and next customer complain so please. Mack Donalds need more staff on weekend they take 15 or until 30 minutes to give us the order.
# 3. KFC Rådhuspladsen was not able to handle the amount of orders they were sent in a very short while. Maybe there should be a cap of how many orders can be made within a certain timeframe. It's frustrating going to a venue only to find out they are unable to cope, and the order I'm supposed to pick up won't be ready within the foreseeable future even though it's already 35 minutes overdue. This was a special event, because of the Superbowl. But this should be looked into. After waiting in vain at the venue, I decided to decline every order from them. And it was a lot!!! No way they could handle that amount.
# 4. Today it happened to me several times, arriving to venues to pick up orders marked as ready and find out that they were still several minutes to go. So not ready. I understand by the pattern that this may have come from you. If unfortunately this is like that, let me tell you that this is not good. It’s not good to put my time and the planning I do in terms of the type of orders I want to accept at someone else’s disposal. Please correct this and try to be accurate in the the you mark the orders. Thanks in advance.
# 5. The Wolt business at the Landmark had waiting times of up to 45 minutes. Unsatisfactory when they better than anyone else must know how nuisance it is for us Bud. Must be able to do better! :-)
# 6. I got an order from Riviera bar it was already late when I when to pick up the order I was told to wait 15 minutes, so I did but after 15 minutes I asked for order they told me I had to wait 20 minutes, so I canceled the order and waisted my time for nothing
# 7. I had to wait for half an hour over time on aji sushi and this is not the first time they have been very delayed. A little tired of siding and wasting my drive time because the restaurant can't fit the estimated time that is just about.
# 8. Everything goes ok and happy but when you pick up food from MacDonald, the wait is very long
# 9. Staff at Otto Frederiksberg gave bad estimate and took no responsibility for the 15 minute delay they caused to my customers
# 10. No vibration or sound when food is ready no longer pushing to Apple Watch
#
# Reassigned Outliers → Topic 2 (209 docs) | Original top words: happy, wolt, good, work, thank, happy wolt, day, wolt happy, love, job
# 1. wolt is the best i like sooo much
# 2. Have a excellent day and I wish all of you a great Holly week.
# 3. One day there is a lot of work and the next nothing, that's how it is wolt, all the time, inefficient, opportunistic, basic, they only think about themselves and do not pay vacations.
# 4. I'm happy with wolt, but sometimes we get long orders for cheap prices , thanks wolt
# 5. Have an excellent day . Wish you the best.
# 6. Some times is hard but in all is work for me is good
# 7. I am getting the hang of it being my first day to deliver to customers. It was a good experience. Thank you for this opportunity.
# 8. The last delivery of the year from Mc Donald's Slagelse is delivered to the customer Happy New Year!
# 9. Have an excellent day
# 10. Another great day of getting scammed I work 1 hour more than yesterday but i earn the same thanks to your scam system
#
# Reassigned Outliers → Topic 3 (317 docs) | Original top words: pay, low, hour, payment, earning, order, wolt, price, dkk, bad
# 1. Haven't been paid yet even though it says I was paid on 4
# 2. No have order and price .......
# 3. Less money and more work time
# 4. Do something about this extremely low demand
# 5. Not received paid wages
# 6. When the weather is like this right now (storms/rain/snowy), you should raise the payment for every order by 25% to 30%. That will motivate the couriers to work on these days. Putting 3x effort than the usual on a day like this, getting vehicle spoilt, and getting paid the same is something where Wolt has failed me.
# 7. Stop cutting our payment!!!!!!!!!!!
# 8. No orders for an hour. Previous hour paid a lot below acceptable rate, best locations
# 9. Not even in a rainy day you pay a decent price for the tasks.
# 10. Payment is Getting low everyday
#
# Reassigned Outliers → Topic 4 (293 docs) | Original top words: app, order, app work, work, time, error, support, task, order app, accept
# 1. App keeps crashing like it's memory leaking
# 2. I sometimes had trouble receiving orders. It gave “unknown error”
# 3. Sometimes app unknown problem when swiping an order
# 4. Still don't understand why the app turns down music or anything else that plays over the phone
# 5. Wolt app turns down the volume of other apps… please fix it (on iPhone)
# 6. App crashed so I had to login again. Really weird
# 7. I cant call costummers. Because the app tries to call Hungarian numbers. When I have to wait for the order to get redy I am not paid. This can be quite some time, and WOLT has to means to change that.
# 8. The app currently reports many errors, when picking up and handing over. It results in lost orders and waste time at the customer. And then we are several who miss an overview of whether more orders should be picked up from the same restaurant or before the first delivery.
# 9. It crashes pretty often. And it's the only app that even crashes my whole o
# 10. The app turns down my headphones and only up again when I shut it down
#
# Reassigned Outliers → Topic 5 (222 docs) | Original top words: km, distance, delivery, pay, driver, drive, car, money, payment, long
# 1. In Hobro, Løgstørvej is blocked for transit - it causes a somewhat longer drive around (both ways). I have experienced trips that were 8 km and not 3 km as app 'estimated Otherwise everything fine
# 2. Not like the old system of double oodre for the same money or the distances
# 3. Bad calculations on distance payment,it looks like a tricks to reduce the payment.Apps shows one and when start to deliver then it shows another
# 4. Seems good enough the price for the long trips is low, 145 kr for a 30 km drive in the weekend boost. Usually gets 55-65 for 3-4 km. So the long trips are to take piss on his courier. Get it fixed
# 5. Cheap orders, long distance
# 6. I work with a car and the price of gasoline is high. Unfortunately, with the prices you pay, it is not profitable for me. Half of the income is taxed and the rest is used on gasoline and car depreciation, and practically there is nothing left for me. It is actually very difficult and dangerous to work with a bicycle and motorcycle in rain and snow.
# 7. The new system was not good for us car driver I ask you to find a solution to this situation. In the past, it was clearer what money we would make math in km. It's unclear right now.We waste fuel and pay high taxes. We work day and night and there must be a satisfactory yield.
# 8. Km count does not work can not see how much I have run
# 9. If it is activated as a car ride, namely by bike. But is by car forward over
# 10. Hi, I had an experience tonight that was a bit strange. I accepted a task that was going from the center of Aarhus to Hasselager, the distance was 10km, I received the opportunity to take another order. The next order would first be ready for pickup in 20 minutes, it had to be delivered to the same road, but gave only 30 kr. When an extra order is going on a very long trip, but you only get so little paid, then there is very little to reject the order. If I had been offered 70 kr, I would like to expect the time and Wolt would save the money they now have to pay another bid to deliver the food.
#
# Reassigned Outliers → Topic 6 (118 docs) | Original top words: support, wolt support, chat, team, bad, help, wolt, support team, good, contact
# 1. Thank you so much for your support and help Goodnight
# 2. Customer support is not good
# 3. hello Thank you for all support team
# 4. The app failed big and the support was not to be obtained, in the sense that I could not be allowed to write to the support.
# 5. 2 and a half hrs, no order.....support sucks
# 6. Contacted Wolt Support Today because 36 kr for an order over 24 kg to be delivered on 4 floor without a lift is simply too little ... just get copy paste answer back ...
# 7. Wolt Support told me there are so -called hot spots, so even though the app said there was an odre soon, never came one, but next time, I'm down at Stengade in Helsingør, which is a hotspot;) Thanks to the support and pretty misleading of the app to say there was an odre soon
# 8. Thanks. thanks support
# 9. Disgusting thieves in support
# 10. Great app, great support overall great.
#
# Reassigned Outliers → Topic 7 (61 docs) | Original top words: map, address, google, gps, app, location, maps, wrong, google map, google maps
# 1. one of the restaurants address was incorrect and waste my time
# 2. We need new customers and wolt logo on the doors of each building. And is it possible to show our location and other 10 wolt workers locations, so we are not many at one place.
# 3. Not all stores were in the exact location as shown on the map.
# 4. At the beginning the app had lags: didnt show the the client on the map, cracked(log out) several times
# 5. Add possibility to copy Client address
# 6. I would like to say that the app crashed in two occasions. It sent me to a different address twice, two kilometers away from the real address I suppose to do the delivery. In both occasions the app wasn't able to give me back the real address so I had to figure out for myself how to get to the real place. Otherwise when this happens you lose battery on your electric scooter and time of course. Thank you
# 7. App location and swiping when picked up or delivered food is not working good enough...
# 8. However, I would like to think that when you have more orders at once that you can see the addresses on all of them
# 9. Will be nice to add copy to client and restaurant address
# 10. Incidental Address Specification On First Order. But Google also marked it inaccurate ... Otherwise everything ok
#
# Reassigned Outliers → Topic 8 (45 docs) | Original top words: bag, drink, pack, cup, food, paper, order, spill, soda, customer
# 1. One of the venues declined to give the food argumento g that th rules say I must go show with my bag. It the second time, it is the chain MAX burgers
# 2. Wrap house vesterbro did mis behave with me. Normally I respect the wolt law for example at the venue before take foods bag from the venue I have to show the order number to the manager or supervisor. This restaurant u have showed the order number from my mobile. The lady was shouting with me and said why you are showing me , look a food bag from that table and go. So this is not a good manner from a manager. As soon as possible I have cancelled the order and notified to the support centre. I did mind it and she was shouting, if I wanted I can do shout, but I did patience and notified your support centre. So if you take actions or communicate with them I will be grateful to you. Thanks
# 3. I got an order I couldn’t fit in my bag
# 4. I think the app is great. I would like an option to just push orders back into the line instead of outright refusing to do it. Just a preference really as I often refuse when I can't have a third order in the bag.
# 5. Can you explain McDonald railway station that many of us Wolt Budde has attached our bags on our bikes scooters and cars, There is only one particular employee who in the McDonald railway station who refuses to hand out the order before hair out and pick up his attached bag and it takes time, there is a box -made of 8 steps from the counter where you get the food for your bike where you get the order in the bag. It is only this one employee that does it and it is only this one McDonald it happens by. Please explain the manager who both order gets cold and it is frustrating to have driven all the way there and then not get the order.
# 6. Multi-deliverys to big for the bag, and to little payment, you have to improve things
# 7. When accepting order from Spar / supermarket, I want to be able to see the order content or the estimated weight / volume. The order today just showed “1 bag”. I hope this was a one off.
# 8. Never experienced anything as slowly as Carls ... all their bonner were red. They were three in the kitchen, and two in service. I do not understand at all how it is possible. I was at Carls for an hour for three order !! Also, they are so bad at packing their bags. It flows over with both food and soda. I am not coming to st take more order from there there is only error, every eternal only time
# 9. hello It is necessary to say two things here. 1- On rainy and cold days and after sunset the stated prices for delivery do not differ from hot summer days, which is very problematic considering that under heavy rain, the delivery work is really difficult, especially with a motorcycle that is directly exposed to the rain and we spray water from the side of the cars, it will be very difficult so we have to reject some orders. 2- Burger King Vanløse has a problem with the beverage package, and almost all orders including the drinks have waste or leaks that need to be warned because it is us who are questioned when the food is delivered.
# 10. Too long waiting times. Especially the Wolt Market. At the same time the orders were both so large that I could barely get a seat in my bag
#
# Reassigned Outliers → Topic 9 (78 docs) | Original top words: wolt, wolt market, market, market vanløse, vanløse, order, danish, copenhagen, denmark, hour
# 1. Wolt Market nordvest is a mess. It seems that the employees have a competition to see who packs the order the slowest. Get more people, or efficient ones please!
# 2. Please Open my app to Wolt Market
# 3. Please Open my app to Wolt Market hop
# 4. Very few orders. It's too many Wolt Bude. There is a lack of weight on orders from Wolt Market
# 5. Wolt, where is orders ?????
# 6. Unprofessional support, lack of information, does not pay no amount due to an error. Although I have the goods and can be handed over to the Wolt Market again.
# 7. Wolt market nordvest realt needs a manager. It’s a very chaotic
# 8. Wolt Market Bådehavnsgade seemed understaffed. Customer mentioned that she had been waiting for 1.5 hours
# 9. PLEASE OPEN MY APP TO WOLT MARKET Because
# 10. Too little order for the time of many Wolt Employees
#
# Reassigned Outliers → Topic 10 (33 docs) | Original top words: bundle, bundle order, order, pay, task, accept, payment, order bundle, new, system
# 1. When we deliver two order to the same customer or we have bundle it could be nice to click the orders and see customer details
# 2. Two things Some venues keep forgetting the extra soda. Also, when I want to stop working I have to hear that annoying ringing sound and wait 60 seconds. When those seconds are over I tried to go offline, but I immediately got another task. (In bundle )
# 3. Hope to see the overall pay go up and bundle fee being increased and bonus pay reintroduced fully. In short, I want the old Wolt back, and our American friends from Doordash can find some (Mexican) immigrants to exploit, but not in Denmark
# 4. Heads up: Had a delivery from Burger King Rådhuspladsen to cbs near Forum. Price just under 30 kr. While it was a bundle, I find the price too low: the customer had asked to have the order delivered to the 5th floor… apparently there is an elevator in the building, but one needs a special card to ride the elevator..So as it is a tall building, getting to the fifth floor, is quite hard.. if all the students/customers start asking for 5th floor delivery for that price, I will stay away from those orders..
# 5. In shock over the Wolt bundle ambush
# 6. The prices are very low specifically for long distances and bundle
# 7. System has had major issue since you change system yet its not been fixed, at this point i think it's intentional. Also bundles is really not worth it, i drive more km and getting paid less compared to before you change system, it stuns me you haven't YET made a km deduction system, at least you can do that. Benzin is not free.
# 8. I can’t see the weight of order when I receive them in bundles.
# 9. My guess is the algorithm is a primitive ai, a master manipulator, that waits to offer orders when it’s in your favor, and conversely pushes orders that are in your favor. Just so you know it’s quite stressful to navigate in traffic, and run to the fifth floor and then also try and figure out, if you should accept a bundle or a triple order, even though it seems you are saving Wolt some 10-20 percent compared to normal prices…
# 10. I got a survey earlier today where I said I felt the payment was fine. However on busy days like today, and snowy weather, where you're held up in ultra slow traffic, the tasks could pay better. Especially the bundles fees, as arriving to the venues and customers take extra long time in these weather conditions. Otherwise all is good!
#
# Reassigned Outliers → Topic 11 (75 docs) | Original top words: bonus, weekend, weekend bonus, order, bonus weekend, bonus time, 17, time, today, remove
# 1. Have a nice weekend!!!!
# 2. Hey guys, I hope you be a bit more careful with the bonuses, on x amount of orders, when you’re uncertain how busy the evening actually will be. I stoppes today after just two orders, when i had planned to drive the whole rushhour, as the streets were yet again packed with drivers waiting for tasks.
# 3. Have an excellent weekend
# 4. First time I delivered in 2 months. I was hoping fees got better but....160 per hour on a Friday (and with weekend bonus)?! This is not good. So in 2 months no change
# 5. Have an excellent weekend
# 6. Yet another task fee drop recorded today bringing single order low down to 39kr inkl. weekend bonus. Not worth it
# 7. Have an excellent weekend
# 8. Have an excellent weekend
# 9. Have an excellent weekend
# 10. Fees are still pretty bad. 162 per hour on a Sunday where everyone is back from vacation AND with bonus on. I used to do that on a normal weekday up to last summer. Something needs to change here.
#
# Reassigned Outliers → Topic 12 (30 docs) | Original top words: mile, drive mile, mile offer, let drive, close venue, app let, offer, offer ready, drive, order close
# 1. Offers late orders when i am close to Pick up after i have driven Long
# 2. So I drive around 1 km no orders, no problem because order level is “quiet”, but then when I am around 500 meters from a venue I get offered an order that is already 6 minutes late for pickup. I’m sorry but I don’t see how this could be random, I’ve seen similar scenarios many times before. So pathetic.
# 3. Very few orders, bad orders and lots of miles driving. Very bad day
# 4. Very poor amount offered
# 5. My app doesn’t show all the miles I’ve driven. Only around 60 % I estimate ( 666 km at present)… there was also trouble last month..?
# 6. Order level quiet, yet I drive around with no orders only to get offered ready or late orders once I am near the place of pick up ??!
# 7. Some venues were quite late
# 8. Kilometers count in the app under statistics do not work. It's a big problem for me that I can't see driving miles daily. It makes me drive less than I can
# 9. Often get orders that are close to having to be picked up, but only after driving a longer stretch without orders. Is it due to the pick up place or programs in the algorithm to wait to offer the order….? Hope really in comments on this
# 10. Kilomet the counter does not work in the app In addition, I have requested driving miles with you but nothing received yet
#
# Reassigned Outliers → Topic 13 (74 docs) | Original top words: support, order, deliver, cancel, customer, deduct, ask, tell, mistake, say
# 1. Very annoyed for the support. I lost my 45 minutes for one delivery which was previously delivered 2 hours before. Shop didn’t know anything about the order also support take my 45 minutes.
# 2. I had a terrible night with support tonight because a mistake by one of them caused the food to not reach the customer.I asked him to confirm that I got the food from the restaurant because I was unable to do so, but instead he confirmed that I delivered the food to the customer.
# 3. Less orders to deliver
# 4. That was a little delay to response today. (For canceling order)
# 5. When you deliver and accept orders, I would think it would make it much easier for the driver if you could see what the order consisted of before accepting it. For example, if I accept an order then it says what food it is so if I want to take 2 orders at once then I know if I have room for it in my bag or not. Right now it's just a rate to take 2 because you don't know if you have space
# 6. I couldn't cancel an order if it already was picked from the restaurant
# 7. Hello, I had a bad experience with the 'supporter 'Anachi'. Pls look at our chat. 1. She waxs first impolite by calling me with unfriendly vibes, not saying her name while I'm biking( delivering bundle of 4 orders ) telling me to answer her msg. Obviously I didn't see it as I was biking to the customers. 2. All her way of communicating was make wrong , insisting again & again that I marked the order as delivered and didn't pay attention that I did. If I got it to deliver -i would just bike to the customer to deliver it. I'm very much in present time and read all the data in the tasks i get. After I picked up from Doner King I instantly got an order from Del nono. 3. I asked her how long she works on Wolt and you she didn't want to answer. If she would worked enough she would know that the system can do flubs. She chose to blame the courier and it's not ok. I work 4 years in Wolt. I'm 99.9,% sure she is not danish. As the Danish supporters are kind friendly and have caring attitude to the couriers. She would also know that a courier can get an order as part of a bundle and then doesn't get in the app to deliver it , he would call support and told they don't see it in the system. So the system can make a mistake and could be that what happened on that case -a mistake of the system. Even if the drop off is very short distance , from experience -the app won't let me to swipe it as delivered after bust picking it up. I find herway of communicating an unpleasant one. Pls make sure to have foreign supporters that really give a supportive attitude to the courier ad it's give not a good PR to Wolt BR Dalit
# 8. Wolt sended same order to 2 partners, when i got to the venue they said that the order is already on the way to the customer
# 9. I have been suspended for an order even though I have neither picked up or delivered the order. It is about order number 896, the task was canceled before I managed to pick it up. I took the task to start with but wrote to you again that you have to cancel it and it was. So I didn't pick it up from the restaurant. When I wrote yes to one of your colleagues on message then it had gone strong and I read wrong. You can contact the restaurant and hear them if I picked up the order or not. I only picked up two orders from there and they were delivered to the customers.
# 10. Not many orders, plus there should be an option. Where the customer can give gratuity after and while one's orders are/have been delivered. This

# %%
from collections import defaultdict
import random


# Organize documents by new topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics_c_tf_idf_0085_manual):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = -1
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic -1 (1945 documents) ===
# 1. I can not go online for some weeks
# 2. Too much spam messaging
# 3. Being offered too many trips where I can't keep legally with my car.
# 4. Last 3 weeks get less assignments.
# 5. Too little money compared to how much gasoline has been used
# 6. Slavery 21st century version
# 7. We can’t get any order. You hired a kot of people so we can’t earn money anymore. Area demand always quiet. Please fix this problem
# 8. I get few orders despite good demand. It's like I've been blacklisted. It's just not clear why.
# 9. Can you please explain to me why I deserve to be scammed so much
# 10. one customer's adress was shown not where it was by ~100m. This caused the delivery to be a bit slower
# 11. Burger King does not get delivery under the hot lamp, and then you have to bring your bike or scooter in. enough to be sure that Wolt is blamed for cold items
# 12. Still trying to figure out how to earn enough. Maybe an ebike is necessary...
# 13. I have requested the termination of my partnership 2 times (first time in 2022), but I continue to receive messages as it has not being terminated. Gear has already been returned. What should I do to to make sure my request has been granted?
# 14. Hello There is many drivers are using accounts for someone else and works illegally so I suggest to put the account owner picture on the system so the restaurant can see who's coming and will deliver. Thank you
# 15. I got scammed once again today
# 16. Gimme my 35kr compensation!!!!!
# 17. You hired too many people in Frederikshavn and now there’s not so many orders available. I have been with Volt in Frederikshavn from the beginning but now is difficult to earn money.
# 18. Hej Freezing and bored Old man looking for work
# 19. Can you make it possible to set a limit on what order you want to receive? Eg no order under 60kr
# 20. Have an excellent week

# %% [markdown]
# #### Inspection of distribution 0,9

# %%
from collections import defaultdict
import random

# Step 2: Get new topics (after outlier reduction using embedding + 0.25 threshold)
topics_distribution009_manual = results[("distributions", 0.1)]["topics"]

# Step 1: Find reassigned outliers (originally -1, now assigned to a topic)
reassigned_outliers = [
    (i, doc, new_topic)
    for i, (doc, old_topic, new_topic) in enumerate(zip(documents, topics, topics_distribution009_manual))
    if old_topic == -1 and new_topic != -1
]

# Step 2: Group reassigned outliers by new topic
topic_to_outlier_docs = defaultdict(list)
for i, doc, new_topic in reassigned_outliers:
    topic_to_outlier_docs[new_topic].append(doc)

# Step 3: Print sampled outlier docs with ORIGINAL top words (from reduced_model2)
for topic_id in sorted(topic_to_outlier_docs.keys()):
    docs = topic_to_outlier_docs[topic_id]
    sampled_docs = random.sample(docs, min(10, len(docs)))

    # Get original top words from reduced_model_manual
    original_topic_words = reduced_model_manual.get_topic(topic_id)
    if original_topic_words:
        top_words = ", ".join([word for word, _ in original_topic_words])
    else:
        top_words = "(No original top words)"

    print(f"Reassigned Outliers → Topic {topic_id} ({len(docs)} docs) | Original top words: {top_words}")
    for j, doc in enumerate(sampled_docs):  
        print(f"{j+1}. {doc}")
    print()
# Out:
# Reassigned Outliers → Topic 0 (230 docs) | Original top words: courier, hour, new courier, work, order order, order courier, day, hire, earning, courier order
# 1. Everything went wrong :-( Many illum gave my order to the other courier, another restaurant very delayed and seemed nothing wrong about it. Wolt courier should be able to give restaurants reviews
# 2. Couriers should be notify which floor the order is going to. Today I had all the orders in the 4th floor and I am not paid for that. I should be able to decide if I tak the task knowing the whole complexity of it
# 3. I don't know if it's the app or to meny currier/drivers. But the last week I worked from 11 to around 13:30 o'clock with so few orders that I actually lost money on gas and time on it. Just take today's peak time 1 hour and 34 minutes and got only 1 order on 40kr drove the whole city so meny times. There most be a solution on this matter.
# 4. Slightly higher fees for us driving a car would be nice. I get all too often tasks that need to be delivered far out. So I don't get new tasks until I'm back. It is not worthwhile to take those tasks.
# 5. High demand but no orders or orders delayed
# 6. No have order ????2 hours
# 7. 0-1 orders per hour... would you work for 50kf per hour in Copenhagen?
# 8. Had an hour of waiting to get an order while you said there was normal delivery demand. When I then went offline and online I got orders right away
# 9. It's incomprehensible how the application works, to wait 2 hours for an order 100 m from a location and to see other couriers picking up orders, it's frustrating. I forgot, it's from the algorithms
# 10. I only get money four kilometers run. So how can it be you give me 3 orders at once when I don't get all 3 orders at once? I waited 16 minutes, ie 0 km/h, ie 0 kr/h, on 3 orders. Your system doesn't work. Fix it. You still owe me 2000kr 3 days ago due to your app's instability.
#
# Reassigned Outliers → Topic 1 (366 docs) | Original top words: restaurant, burger, mcdonald, min, delay, food ready, order ready, burger king, mcdonalds, mc
# 1. Sensu Sushi had the order marked as ready, but it was not ready. I was there waiting for more than 15 minutes, that is unacceptable. Other than that, all was good and smooth.
# 2. Hi Wolt, I usually give 5 stars every time to Wolt, but unfortunately this time I only give one star. That's because yesterday I've had a trip from Burger King to Christian X's Alle 35. I'm 1000000000% sure the number on your app was 35, suddenly the number was changed to 34, which was the real number. I've been driving 300 m too far and I've spent 15 minutes of my time finding an address that doesn't exist. Your customer service was incomprehensible and did not give me a compensation. I have thus decided not to take more orders from Burger King in Lyngby. When I have to make an extra effort, it must be appreciated by Wolt, as a partnership is about giving and taking, and not just taking (Wolt).
# 3. Some of the orders were very behind, between 12-15 min. Customers were not very happy (those who waited longer than they should). I did my best, but is out of us as delivery if the restaurant is behind. I got few order which pick up time was already delayed by the time I accepted it.
# 4. Today was really busy. I like that… there was sometimes a little problem on getting the orders when I was in the same restaurant I got an order then the app get me to deliver and then go back to the same restaurant to pick up another order. The easy was to pick up everything in one time and then deliver. But in general was a good day! Thanks to the support and Happy St. Valentines
# 5. Hi Wolt I write as I notice that an order ordered at Wolt has not been delivered or picked up by a courier when you have returned to the Rasstuan. My idea with the problem as a solution is to get the tasks popped up after. 2-3 minutes again if the food has not been picked up by another curl. We find that we received a task from Burger King at 3 o'clock at night approx. We drive out to Burger King and Burger King was closed at the time. An addition to the app could be smart if you have more orders on the trip that you can sort who you first run out to the direction on the road. (Unless it's hot food so it's first priority) I was thinking about whether you could raise delivery the price a little? For example, to drive about 15 minutes away and get approx. 80 kr but nothing to drive back to the next task Hope my message made sense if not then ask finally
# 6. It is very very difficult to collect 3 deliveries from three restaurants within the city of Aalborg because as a car driver we can’t go in all the streets. So it is time to rethink the policy of combine order from different restaurants as it is time consuming and too much stress for car drivers. Instead it is better to collect 2-3 orders from same restaurant and delivery different locations in the similar direction or a little bit deviating direction. We can’t earn that much the way we are working hard and taking all the risk on the road. There are lot of options to be more efficient.
# 7. The app currently reports many errors, when picking up and handing over. It results in lost orders and waste time at the customer. And then we are several who miss an overview of whether more orders should be picked up from the same restaurant or before the first delivery.
# 8. No orders and the order at original pita was 20 minutes late
# 9. I got an order from Riviera bar it was already late when I when to pick up the order I was told to wait 15 minutes, so I did but after 15 minutes I asked for order they told me I had to wait 20 minutes, so I canceled the order and waisted my time for nothing
# 10. Jagger Lyngby had very long wait and bad customer service
#
# Reassigned Outliers → Topic 2 (182 docs) | Original top words: happy, happy wolt, day, wolt happy, work wolt, thank wolt, wolt good, happy work, love wolt, satisfied
# 1. i am very happy with wolt this is the best
# 2. Seems it is really good and I am very happy with the job. The only thing I wonder is that the customer has no opportunity to give gratuity after you have delivered the order. In this way, the customer can also have the opportunity to see who he/she gives gratuity to.
# 3. Right now I am not happy with Wolt because the earnings are too low After closing foodoora all the employees came to wolt and it’s impossible to live with those earnings. Since this is the only job I have it’s very difficult for me to survive with those earnings I hope it will be better otherwise I have to find another job mad soon as possible
# 4. I’m earming way less than i used to the same day og the week and time of day where i feel like i had the same amount to do. Good day
# 5. I would like to work more
# 6. Have an excellent day . Wish you the best.
# 7. i am very happy with wolt wolt is the best app
# 8. What you gonna do whit this payment? ... Now im working same..for even not 15.000 after taxes..! This company and this job is a joke... u loat half of the couriers at 1 june..and u will lose them all easy by easy .. because u dont care...and u will nrver do... Until the day when wolt its gonna be rejected from Denmark...or when taxes will force u to hires us...! And pay our rights and benefits! ... U do everything is possible to run from hiring us and pay us legally and as supposed to be! ... I will have to say goodbye to you!
# 9. You should be ashamed of you..it is crazy this ... I've gone from loving this work, to hate it as the plague, ... so many thanks for that
# 10. Im happy that i can make money and do it on my own hours. But the waiting time when on medium and even on high demand is absurd at times
#
# Reassigned Outliers → Topic 3 (251 docs) | Original top words: pay, low, hour, payment, earning, work, salary, kr, wage, earn
# 1. Discriminative low payment and negative treatment without reason is so bad in Denmark
# 2. it's raining, high demand,very long waiting time,few order and low earning,3hours online,300 dkk,it's not good
# 3. Saturday evening, almost 3 hours online, 3 orders, 200dkk with boost "a wonderful evening", I'm very "happy"
# 4. Low pay, large delay from restaurant, no compensation
# 5. Payments for curriers are every time lower
# 6. I think the earnings per package are low. The weekend wage must be for the whole week
# 7. It's a shame that you pay an order 23kr with this cold and wind. And the payment for the rest of the orders are a joke.
# 8. Working is annoying for you. Believe me, sometimes I have to, otherwise I won't even mention the name of your company. Worse day by day, bad program, low money, bad service
# 9. Last friday I worked from 6pm to 8pm. 250 kr?! That's 125 kr per hour. Lowest ever. What's going on with the fees since about last October ?!
# 10. There are too little orders, too little money because there is too. A little orders I drive back and forth but I only get money for it is the worst. I have gasoline consumption, car wear, but still I serve difficult enough more than other "light" jobs in Denmark. Stop being greedy and taking prices down or getting customers so I can work for the same salary as now or better. I sit and do nothing more than I work, almost. Under 150kr per hour for the most part. in advertising for 160kr per hour. lies.
#
# Reassigned Outliers → Topic 4 (318 docs) | Original top words: app, app work, error, order app, problem, restart, bug, time app, error app, accept order
# 1. I had issue with my last order . I accepted the order and went from osterbo to åboulevard to collect it - 10min . When i was there around 19:00 food was already marked ready . I went to the empty restraubt and they inform me customer order it to be done after 19:30 . I chatted to the support and you can see how the conversation went . They didnt want to compensate me athough it was obvoius a mistake either from the venue or wolt app . I made the picture in the restraunt and in their app it was saying 19:30 although they marked it ready at 19:00 . When i delivered it customer confirm that he request after 19:30 . So i refuse to agree i cannot be compensated for losing 30min in front of venue for a order that they refuse to make before . If it was a busy day i agree to wait few minutes more but today its mistake in the app because of which i lost over 30min. Please take a look at this case and treat your employes the correct way.
# 2. I think there was a bug, saw it 2 times. I believe when the app shows the customer's location before pick-up, and there is another order that can be picked up right after, the app will show the wrong customer's location (it shows the second one) until I decline the second order after confirming the pick up of the first one.
# 3. The new system doesn't work the app finally said the right km we make but the payment is less, all the promotion about the new system make it simple for us the earnings and how to get what we had asked for so long, a way to accurate more the route, but was smoke because many courier we don't understands the new pricing model and to get the accuracy for the route it cost us almost 20kr or 30kr per task just to see on the app what we knew that we drive more km than what we get pay, just that now we get even less pay. I hope we can have better conditions soon. And the wolt support, they have not fault on all this but the handle our insecurity and frustration on this situation but they have no answers for our questions and they don't give help as they did with the last model
# 4. The app could use a little more guidance for new Woltbude. When I'm new, it all took a little longer.
# 5. Please please look at bundle pay, it’s not only about distance. I’ve written this before and I know you probably don’t care, but just know the matter has been brought to your attention many times… also when doing bundles/ triples. Sometimes you deliver one of the orders and get offered a new one, while you still have orders to deliver. BUT THE APP LOOKS LIKE ALL YOUR DELIVERIES HAVE BEEN MADE. This sometimes confuses me so I reject the new orders offered..
# 6. The app has been a DISASTER these last 3 days. It stops working for 5 to 15 minutes at a time. It did so like 5 times. It stops you from contacting support, confirming deliveries, reading addresses. No amount of restarting the phone or the app helps. I have the app fully updated. This is extremely annoying. Is anyone gonna pay me for all the lost time???
# 7. There are problems with KM registration in the app right now. This is probably changing.
# 8. The app gets worse and worse, hears the same from other Wolt Bude .. it hangs and won't accept swipes
# 9. Earnings are not related to how long it takes to perform the task. There are too many things that the app doesn't take into account.
# 10. Congratulations on the upgrade of the app. It has made it much much better than before. Really good work !!
#
# Reassigned Outliers → Topic 5 (178 docs) | Original top words: km, delivery, drive, payment, bike, scooter, trip, kilometer, long distance, ride
# 1. Pick up distance should increase and amount also. Thanks. Because it is not worth it to go for long distance deliveries .
# 2. Horrible rates for night shift and long distance. I'd love to deliver, but fx 100dkk for 12,5km is way too little Saw many orders like this
# 3. Things are changing in worse. Every time you change something is bad for us drivers. More work and less money. Distances that were payed 90 kr now are paying 60-65 kr…taxes are 46 %, benzine is 10%, fines and road tax and insurance is 10%, the rent and food is up to 20%. And no holiday money for us and nothing that employee people have . Change something for the people that deliver with their own car!!!!! We work 11 hours to get 1500 kr and after paying everything we have nothing left!!!!!!
# 4. I like to have more deliveries!
# 5. I think the timeframe from you receives the order compared to the distance it’s not realistic and quiet impossible. If I take an order from my home and have to pick up the order 4,3km away the time estimate is 9 minutes, and that’s impossible on your bike . And 3km to the customer witch is 3,5 away, for 96,-kr and in 25 minutes to deliver.
# 6. The payment is not good l Make to much km now and l not Make the Money wich l Make forat time l need to stai more Horus and Work many Horus and l dont Make the money wich l Make first , YOU promis beter Buț is not beter for us is beter FOR Wolt now ,example before l Make 100 km FOR 1000 kr now l Make 200 km and l dont Make 1000 kr and l Work many Horus in confrontation with first sorry but is not good is not fair for us , all my friends and my family he is disappointed
# 7. Car orders, big orders , and long distance orders should be only for cars. Food always remains good and hot, for the customer’s satisfaction, and has customers requirements
# 8. Any chance wolt increase pickup & drop off distance price per order & any plane for benefit for employees like other company I. Denmark ..???
# 9. Ways many long shot orders.. I'm not a car or a moto I just have a mountain bike!
# 10. It is a lose-lose situation when I get a delivery late, I’m driving a car and I can’t turn around as I want to get a delivery behind my location.
#
# Reassigned Outliers → Topic 6 (192 docs) | Original top words: support, wolt support, chat, support team, support good, support bad, support support, support help, people support, support today
# 1. App was hanging UP, problem with ending order. Loosing time to restart Phone. No connection to support without restrting Phone
# 2. Support thank you so much
# 3. Why is it no longer possible to simply click 'Remove Order' and then it will be removed shortly? McDonald's Frederiksberg appeared really rude to us cures this evening. We were several couriers standing with orders that were marked ready, but the staff ignored us totally! They see us but don't service us? We stood and waited for a very, very long time, and in the end we go in and ask if they are not kind to take Wolt orders, and in addition he answers he comes over in a little while. But they just continued in the same track of handling orders in the store, and only after a long time does he come over, maybe because we went in to ask again. They tell us nothing about when they will service us or how long it will take before we get our orders handed out - they just keep the hatch closed. It is rude and not at all okay. At times, it seems that they are waiting for a lot of orders to accumulate and that there are a lot of cures outside before they start responding to orders already marked ready. It is an unpleasant situation for us cures because we are going to wait for far too long and without anyone giving us information about what is happening. Wolt Support was very slow to respond and respond to messages today and there was virtually no help to pick up. It's the worst support I can remember for a very long time.
# 4. Support doesn't understand much. Salary is miserable. Positive: Freedom
# 5. Of course can't be more with those roma thieves in support:)))
# 6. System is scamming and support is useless
# 7. Hi, I think it has been complicated to contact support about problems. I was at a restaurant that marked his order ready about 15 minutes before they actually were. I wrote this for support so this could be noted in the restaurant's history as I know they are contacted if their order is often too late. When the person in support returns, they write "What can I help with". I am out and running, so I do not have the opportunity to repeat what can already be read.
# 8. Slow support, your navigation fucked me up
# 9. At first then it says Bones, then I drive to Bones after I accept the order so when I stand there there is pasta diem, the system changed the place the moment I swipe, now I stand mega far away from Pastsvdiem, and write it to the support then I just get star smiley and laugh from support
# 10. Bad support and wages
#
# Reassigned Outliers → Topic 7 (73 docs) | Original top words: map, address, gps, maps, google map, google maps, wolt app, wrong address, route, street
# 1. I would be very happy if i be able to copy the costume and restaurant addresses
# 2. Today, I put the wrong food due to the google map error and contactless customer, but after the support messaged me, I went back and corrected it, but I was fined, and this was a bad experience for me.
# 3. Many times the app says the task is 300 meters distance to pick it up and when you accept and put google maps it's more than double distance. The third pick up from the same place always wants to pay 20 Kroners even if the distance of delivery is more than 1 kilometer it's just funny to not say disrespectful. Thank you
# 4. I got order but the address was shown wrong on the map, which can be misleading for us courier because usually we watch the map when taking an order. I have taken the sceenshots too.
# 5. Wolt should atop blocking the "accwpt order button" with review requests for the staff. That is a forced sabotage. Also, Wolt should consider that if an order needs to be delivered in areas of the city that are very far away from hotspots, the order needs to be paid double. If I go 3-4 kilometers in the outskirts of the city to deliver food where there are barely any restaurants I then need to also return back to the areas that have restaurants but I find myself biking many kilometers back to thr hotspot areas on my own wasted energy and with no pay. Wolt needs to acknowledge hotspots on the map abd integrate them in the app itself and calibrate the payment of orders based on how far away from hotspots a courier gets sent.
# 6. You keep writing that I am offline when I am actually heading out to an address with the food. I'm on maps when I get those messages from you. I can't understand what's wrong ...... I can understand, I go offline when I haven't been given a task for over an hour ...... but while I work and drive doesn't make sense ..... ???
# 7. App functionality is good enough, with the exception of the collaboration with the world's best guide program, Google Maps. There is Wolt App Extrem bad for the collaboration. Constantly I have to look up the address on my own Google Maps and everything is perfect. The other thing is Wolt would improve the collaboration with us Kure, who has already made Wolt for billions. Instead, Wolt has taken the ass on us cures, blistering over now we also get distance payment for and pick up. I have always been praised for my main bill and have come to the conclusion that we get 5 kr, per km to pick up. Minimum payment is gone, weekend bonus is gone. Since I have had an order out to the bottom of Ørestad before the change I have got 135,- now with the new system I have got 97.50. Whether it is an improvement is in great mistakes. Can mention, I've talked to many cures showing huge dissatisfaction with the new payment system. You dare not even show details of payment, which we got in the old system. So expect a lot of resistance from us cures soon, it is despite us who have made Wolt for a billion business, so appreciate it before it's too late
# 8. Would be very helpful to have the option to be allowed to copy the address in order to make it faster and to avoid mistakes when entering the address in Google Maps
# 9. Will be nice to add copy to client and restaurant address
# 10. Those signs over the pick up and drop off location are very confusing. Having two green dots instead of one is really weird and confusing
#
# Reassigned Outliers → Topic 8 (62 docs) | Original top words: bag, pack, food, spill, soda, paper bag, lid, leak, packaging, mcdonald
# 1. McDonald’s City has become really slow now that they double bag orders.
# 2. I would greatly appreciate if the Carls Jr venue would make it possible to see every item that needs to be picked up. So there wouldn’t be any issues like a missed drink or anything like that. It makes it possible for me to check over the items and in any case mention it to the worker and correct the order if needed.
# 3. Please make available in Wolt Gear website the regular blue bike bag, same model but in plain black and without logos.
# 4. Why is it only me who has uniform on and bag with ?? PS We represent the Wolt as an employer. Seems to check up on it.
# 5. I have to pay for order 725 or 726 185 Dkk at night time??? For some food i did return to Burger Palace? I did nt want the food but i could keep it if i knew i had to pay… Is like this Wolt treat me as courier after many years i work, plus at night time? I have to pay for some food i did return to the restaurant because the guy from the restaurant gave me the wrong bag??? The restaurant should pay, not me!
# 6. It is completely unacceptable that I should stand for 15 minutes in rain just to cancel an order so I could drive on with an order I already had in my bag completely unacceptable
# 7. Four amigos, Mejlgade. You have to wait outside in the inner yard of the building and they only give you the order through a window, and you have to pack you bag outside, which should definetly go against a lot of health code rules and food safety, not talking about human decency
# 8. Incomprehensible payment Today I picked up 2 pieces. Order in Wolt Market Søborg. The order that filled at least I only got DKK 33 and was on 4 very heavy bags and was going on the 2nd floor. The order I got DKK 79 filled less and weighed less. I do not understand the very extreme difference in the payment. I think this is how it is an extra order so it gives almost nothing compared to the hassle. That's why I often reject it. You must be able to do better. See photos
# 9. I experienced being beaten twice in the back today by an employee of IKI Sushi Nordre Frihavnsgade - it was a man. I was bent down over my bag to open it when I was struck out of my back out of the blue, it seemed like I was beating the knots. I look up and see him just walk past me and I ask "What's Up" but he doesn't answer and just goes on. I look up at the girls behind the counter, which tells me that "I shouldn't take care of it - that's how he is just sometimes"! So they have seen what happened. I am a little in shock and deep, deeply amazed as I get no explanation from him. I think any of the girls say it has something to do with the door. Their door does not close properly in behind one because it gets stuck in their mat which is not level, but it may not be near to be a valid reason to hit me hard in the back twice with the knots without being prepared for it in any way. I now hurt the muscle around my shoulder blade, and stopped working today because it hurt. I use that muscle a lot when driving a car when I lift the bag up stairs, etc. - I use it a lot at work. My question now is what you want to do? Want to have a really serious talk with Iki Sushi Nordre Frihavnsgade, and the person who struck me, or what's going to happen from here? Are they going to pay for my physical and medical treatment due to the pain I have in the muscle now that reduces my ability to work or what's going to happen? Please answer me via the app or at info@eknowhouse.dk.
# 10. I wonder why Wolt Viborg has become completely quiet even in Peek Hours there are half hours where nothing happens? This is how it has become within the last week or more? If I look at Silkeborg, Herning, Holstebro then there is busy or normal. Now not answer that I can just drive to Holstebro? Turn of more than 100km return. Another thing that wonders me, today I started at 5:29 pm at DK Pizza and Grill Viborg and I stood alone Wolt man with 5 men with Foodora bags and got orders, then pizza the man asks a foodora man if the order he should have is a wolt order ??? What's going on ?? Greetings Henrik
#
# Reassigned Outliers → Topic 9 (88 docs) | Original top words: wolt market, market, market vanløse, vanløse, danish, copenhagen, denmark, courier, order wolt, hillerød
# 1. no orders... what about the wolt
# 2. Please write a new message about the conditions of Wolt Market orders, many of my colleagues and I did not even understand the message.
# 3. Busy, busy, busy but not orders. WHY WOLT????
# 4. Wolt market took 20min+
# 5. I was exposed to mental torture even by all Wolt employees inside the Wolt Market Willemoesgade, is completely in shock
# 6. 15 min delay in peak time from Wolt Market Landmaerket is not acceptable
# 7. Wolt market too slow
# 8. Wolt market takes very long to get deliveries ready
# 9. Wolt Market vanlosene
# 10. Worst first day at a job, the foreign girls working up in Willemoesgade Gade Wolt Market are the most rude and small gifted people. Considering to quit already here on my first day as a wolt bid. I have never in my life seen so provocative people in a workplace !!!!
#
# Reassigned Outliers → Topic 10 (42 docs) | Original top words: bundle, bundle order, payment, order bundle, bundle task, bundle pay, reject, courier, delivery, accept bundle
# 1. The new pay system is unfavorable and unreasonable to couriers. This is especially with services provided by couriers during bundle deliveries…in my opinion that’s not fair …we should get our full fee for services whether bundle or single delivery.
# 2. Rain is a Big problem for this Industry. Many of ur partners will not dare to go to Word bc of the high risk. Even if u give extra fee it will still not compensate if they get sick or enjure. Im one of the crazy partners who does not get effected my this weather. Well to be honest im just Human eventually i will get enjure or sick. I alrdy Solved this problem. Simple math everyone can understand. 1+1=2 and 2+2= 4. 1 car. 2 partners = 2 bundles = 4 happy costumers. 1 car. 2 accounts link together. Will serve 4 costumers if ur alghorythen is set to it. Dont worry m8 here is the trick. We are going to put ur sale trick into good use in the right way. 1st put a warning sign in ur app. Foreksample: Due to weather comdition the orders will be in motion every one hour to avoid trafick orders so we can deliver fresh food in ur home Thank you for understanding Wolt we care If u have something better go for it. This is just a good brainstorm strategy. Think of the Big picture. Ur giving safety for ur partners at thesame time serving the people everybody wins in this strategy. Also parking Bills is pain in the ass so how do we avoid? I got one idea. We pay ahead. This is mandotory everyone that has a car need to pinch in and pay some amount of fee to avoid Big Bills. Remember this strategy must be only use when the weather is rly bad. Otherwise normal day for everyone. Thank you for ur time and I hope that u can see the good thing in the long run. Cheers and
# 3. Annoying with no reject button in bundle mode. Just got spammed with McDonald’s yesterday. And had to wait like 1-2 min x +10 times.
# 4. 50- 90 kr / 30-40 min.. when it's 140-200 kr. From 16 to 02. Dropping, doesn't give the ready pick up 20 m next to me no sending from the next area with waiting time.. only only to make it slower and reduced the earning. Double pick up to same costumer fra same venue sending 3 kurere on it so cleaver, only and only to reduce the earning and lose time and extra km. Dropping NEVER call for the next.. need to increase the free drive back and around 3 city for get one.. then its remember! Exactly same lost time after dropping! Taking a ready adding 15 min as bundle after driving 10 min around then 15-20 min max speed dropping.. calculate it.. and se the results! Then suddenly there is 10 matches ready on the way! Wtf are you doing.. why ? Its on purpose to make the driving Hour for 100-150 kr!! And 60% of the time for free! + Saving to drive Half prices on Drops... + Freezing!! All venue explode why then? 20 - 25 min of each hour must be destroyed.. resultat -700 to 1500 kr each day.. 150% driving and time 30-50% earning.. Be professional with manners, you crying for 35 kr when the stupid system make an error and sending keeps sending 10 kurere to the same pick.. and refuse to pay for any kind of a futile trip, and doesn't send a pic up from distance to save couple of øre, and trying the best to saving by loading on a bundle and pay 20% of the real price when many times the km price being 5 kr! And many things.. and all of this not enough adding freezing? 2-3 drops? Seriously? Are you proud of all this exploitation?
# 5. Get back to old payment method! It's more clear! Now we don't know, you just se the price that you like for the tasks, really unfair. Km deduction!!!! It doesn't worth it anymore to deliver over 3km. We have to pay 100% of our expenses and the prices are super low. Let the bundles be the full price as before! 35kr for a bundle task over 4km??? When we actually have to drive 1-2-3 km from first drop of to the second??? This is insane
# 6. No orders enough. But wolt gives bundles to some couriers
# 7. Hej, I have to stop working due to the weather. My el bike hot gucked up from the snow and the speed button doesn't function. I put when I started boiled water and then it was ok. When I picked up the food at Shweik shuarma. I asked for hot water to handle it. Okan the owner was late in 10 min with the food. After 1 min when I was outi came inside again and asked for hot water, I explained him regarding the ice on my bike and thdt o can't bike. He was rude and said the food is going to be cold and why I come back. I ask you pls to call him and give him peace of your mind. This was really not concederate of him. The order was very warm when I delivered it and also was second on a bundle line. I font think I will pick up orders from him again. The guy was late with prespsring the food and complains when I ask for an help so can ride to deliver the food BR Dalit
# 8. My guess is the algorithm is a primitive ai, a master manipulator, that waits to offer orders when it’s in your favor, and conversely pushes orders that are in your favor. Just so you know it’s quite stressful to navigate in traffic, and run to the fifth floor and then also try and figure out, if you should accept a bundle or a triple order, even though it seems you are saving Wolt some 10-20 percent compared to normal prices…
# 9. It is very unfortunate how the algorithm significantly continues to keep bicycle drivers "out of the equation" in remote areas where there's a McDonalds, like Kastrup or Ørestads. Tonight I have tried to deliver at McDonald's Kastrup since 11'30 in the night until now 2'30. I have only been assigned one order, while car drivers were coming and going with bundles included, as I have been waiting literally inside of the restaurant watching all that time. It is very difficult to assume that all the orders were only suitable for car drivers, unless we admit that the algorithm has developed a remarkable incoherence upon bicycle drivers availability in the mentioned remote areas where there's a McDonalds. I don't know how much Wolt considers such undeniable car-drivers priority in those areas to be long-term efficient at all, when in reality it will lead to the opposite, for many overlooked reasons. It does not make sense at all to skip a courier that is reasonably available in a place where there's a constant flow of tasks like McDonald's. It does not make sense either to assume that all the orders in such a long time-frame were only suitable for car-drivers. It would be easier to win the lottery under the same premises.
# 10. Wasted 18 min waiting for order at Yieast, what do I get from waiting, company pays fine to Wolt but what about courier. Made more earnings not taking premade bundle tasks than if I accepted them
#
# Reassigned Outliers → Topic 11 (90 docs) | Original top words: weekend, weekend bonus, bonus weekend, bonus time, earn, 17:00, saturday, bonus bonus, bonus day, extra bonus
# 1. Dear Operations Team As a courier since 2019, this is one of the first times I decide to leave a comment. Your ongoing updates seem to be harming more than benefitting car couriers. We have more expenses than bikes and scooters (having done bike method for two years), and our speed and order size capacity are higher (more in long distance). Therefore, having analyzed this update I conclude to see a decrease of about 20% to 30% in earnings while delivering. Please try to make an incentive for us, and I am not even mentioning the weekend bonus (deleted). I do not participate in protests nor I expected so many changes, just make a fee adjust according to each type of group. Counting “real routes” and pickup distances do not give any meaning when the outcome is a lower return per kilometer made. Please find this message as an encouragement to make real focus on real issues, and to make the game fair to play, for each of the couriers.
# 2. Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you put our starting fee down from 45,- to 35,- earlier it was a bird spacing, such as praying at Islands Brygge, birds distance of 450 meters above the water when reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km can give 21.50,- as it is a delivery close to the previous one and not as before, both order from start to finish. Which is some hell of a swine, personally I reject all orders for less than 40,- That is, even one of 39.95,- will be rejected I was offered 26,- for and picking up an order on Sunday in bonus time, +15,- in bonus, = 11,- kr for the order itself? I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !!
# 3. Have an excellent weekend
# 4. The bonus doesn't make up for the speed decrease in the snow, still no transparency but likely the only reason it was busy is that there are no drivers, whereas busy normally means you can expect you le orders and short routes as supply and demand kicks in, here it was just very low supply and the routes offered were mostly really bad 4km+ which is exacerbated by the road conditions making those even less worth it than normal. That's not even considering it being cold. I'd love to drive but if it doesn't make sense economically while also being in rougher terring what are we as couriers to do
# 5. I am waiting a delayed order, payment 35kr in bonus time after 25minutes without order. Very sad work with Wolt lastly
# 6. 1000 kr per day -tax-benzin=nothing gud (without bonus )we drive only to make millions wolt and for us 0000000000000000.
# 7. You overtired and you took most of foodora drivers in as well we can't even make 50kr an hiur due to this so thank you as for rates they are lower as well bonuses don't work half the times as well 50kr 2 7km with a weekend bonus sure...
# 8. Have an excellent weekend
# 9. Hey guys, I hope you be a bit more careful with the bonuses, on x amount of orders, when you’re uncertain how busy the evening actually will be. I stoppes today after just two orders, when i had planned to drive the whole rushhour, as the streets were yet again packed with drivers waiting for tasks.
# 10. I find it extremely unfair you offered the 500 kr bonus for 40 tasks only to some couriers. Guess no point in delivering extra this weekend then
#
# Reassigned Outliers → Topic 12 (47 docs) | Original top words: mile, drive mile, mile offer, let drive, close venue, order close, joke app, venue app, delivery, distance
# 1. Let's keep wolt as it is now . Let's gooooo
# 2. Something Strange happen when I slide for Pick up an order then while I was driving there the order dissapear
# 3. Same pattern, you drive miles without an order and suddenly when you are close to a pick up place you are offered an order that is close to being ready/ ie it must have been offered long…
# 4. App fubar. And so many miles extra since your last attack on the pay system ….
# 5. Everyday there happens "ukendt fejl", which makes order can not be closed normally, and it also wastes time.
# 6. So I drive around 1 km no orders, no problem because order level is “quiet”, but then when I am around 500 meters from a venue I get offered an order that is already 6 minutes late for pickup. I’m sorry but I don’t see how this could be random, I’ve seen similar scenarios many times before. So pathetic.
# 7. The application works very badly. If you reject an order, why does he offer it to you again 20 more times? We waste time and it harms both us and you.
# 8. Kilomet the counter does not work in the app In addition, I have requested driving miles with you but nothing received yet
# 9. Better to give the closest delivery first Isted for the longest to drive back to someone you actually drove past.
# 10. Occasionally it doesnt allow me to swipe for both pick up and drop off and accepting order, ut after closing and reopening it works most of those times worh a few still not
#
# Reassigned Outliers → Topic 13 (56 docs) | Original top words: deliver, cancel, customer, deduct, mistake, compensation, cancel order, delivery, deliver order, order cancel
# 1. Restaurant canceled order but it did not show up in the app as canceled. I mistakenly marked the order as picked up to try to get rid of it, so support was not able to cancel it afterwards, even though I didn’t get the order from the restaurant. Then I was forced to drive to the destination of the delivery to mark the order as delivered, even though it wasn’t, so I could get it off my list at go on with other tasks.
# 2. I was in Kasai sushi got the restaurant doing a mistake with my order and I didn’t getting paid for arriving
# 3. 15 minutes to cancel one order, because one of your guys from support was playing on me... What an idiot!
# 4. Difficult to see whether I had enough time for double deliveries, causing some orders to be delivered way too late.
# 5. Non responsive support. Delayed restaurants and restaurant’s delivering wrong orders to wrong couriers
# 6. I was supposed to take one order at 18:40 and deliver it at 18:35, so time estimation was totally bad
# 7. Today, I had to cancel an order after traveling a long way because the venue said it will take too long. It would be great if the Wolt could improve order preparation estimates or consider a compensation. Thanks.
# 8. I'm not sure if my last delivery, to a Louise Black, actually went through. After delivering, it kept giving me errors when I tried to slide the "Delivered!" bar. Then it just suddenly went back to map.
# 9. I can't swipe my order to be delivered
# 10. It would be nice to be able to choose which order to prioritise when you’re delivering multiple orders. It would also be nice to be able to see where I have to deliver an order in between 2 pickups in case the next order is 10+ min later. Otherwise we can run into some trouble with the venues worrying about the food becoming cold

# %%
from collections import defaultdict
import random


# Organize documents by new topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics_distribution009_manual):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = -1
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic -1 (1657 documents) ===
# 1. Ang. It released Memo last Friday that it is expected to be busy in KBH on Sunday night. This did not really turn out to be true, despite many customers returning home from vacation. I had also thought it would be busy, but it just shows how hard it is to predict demand. I hope you are doing an internal evaluation on this announcement, because you can next rely on a future announcement from you about great demand?
# 2. Macdonald Bellarup wasted more than 20 mints
# 3. Streeet namesare to smalll. Count not swipe "delivered" 2out of5 times..
# 4. Not so much and do right now, but that summer
# 5. Have an excellent Sunday
# 6. Every day I earn less, a scam!!
# 7. Almost no order. Sometimes you earn 200kr per hour - other times a maximum of 100.
# 8. It is thrilled that the extra money does not work when you pick up 15:59 and it starts at 16, so you have to wait to accept instead of taking it.
# 9. City gave me a free pizza :)
# 10. The job became so much frustrating and worthless that makes me feel you’re using us only for your benefit
# 11. The driving is extremly dangerous and weather is -10° freezing. Yet we get paid less then usual, instead of a boost. That's lead to less carriers at work, and meny orders are -50 minutes and up, some will not get out to the costumer. Please consider a small boost, for the big effort to deliver in this harsh weather conditions. Some people in my area are still snowed in and hungry, and meny won't risk get injured or smashing the car, because the roads are snowed / frozen.
# 12. Impossible to make money. It’s really quiet
# 13. Salary has unfortunately become bad
# 14. Repeatedly that I cannot announce an order picked up or in delivered.
# 15. Yet another ridiculous day with wolt
# 16. Another excellent way to make money
# 17. Please hire people who pay taxes, at least occasionally, and who have more cognitive capacities than a common invertebrate.
# 18. All week earming per hour was meh but on Sunday was really good. Hoping it was not a one-time thing.
# 19. No bugs,everything is perfect
# 20. Add heatmap to get last star

# %% [markdown]
# ### Update the topic model for outliers reduction

# %%
import copy

reduced_outlier_model_manual = copy.deepcopy(reduced_model_manual)

# %%
reduced_outlier_model_manual.update_topics(documents, topics = topics_c_tf_idf_0085_manual, vectorizer_model= vectorizer_model)
# Out:
# 2025-05-25 19:26:09,107 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
reduced_outlier_model_manual.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   1945                        -1_order_delivery_time_work
# 1       0   1315                          0_order_courier_hour_task
# 2       1   1440                            1_ready_wait_order_time
# 3       2   1206                             2_happy_wolt_good_work
# 4       3   1120                             3_low_pay_payment_hour
# 5       4    806                          4_app_time_app work_order
# 6       5    657                       5_km_distance_delivery_drive
# 7       6    449                   6_support_wolt support_help_chat
# 8       7    383                      7_address_map_google_location
# 9       8    314                              8_bag_drink_food_pack
# 10      9    216               9_wolt market_market_wolt_order wolt
# 11     10    155                   10_bundle_order_bundle order_pay
# 12     11    170  11_bonus_weekend_excellent weekend_weekend exc...
# 13     12    124                     12_mile_offer_drive_drive mile
# 14     13    164                    13_order_deliver_support_cancel
#
#                                        Representation  \
# 0   [order, delivery, time, work, wolt, excellent,...
# 1   [order, courier, hour, task, time, new, work, ...
# 2   [ready, wait, order, time, food, minute, resta...
# 3   [happy, wolt, good, work, day, thank, happy wo...
# 4   [low, pay, payment, hour, price, order, work, ...
# 5   [app, time, app work, order, work, error, supp...
# 6   [km, distance, delivery, drive, pay, car, driv...
# 7   [support, wolt support, help, chat, bad, team,...
# 8   [address, map, google, location, app, gps, map...
# 9   [bag, drink, food, pack, order, cup, soda, pap...
# 10  [wolt market, market, wolt, order wolt, order,...
# 11  [bundle, order, bundle order, pay, task, payme...
# 12  [bonus, weekend, excellent weekend, weekend ex...
# 13  [mile, offer, drive, drive mile, order close, ...
# 14  [order, deliver, support, cancel, customer, ca...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [Didn't get some order, There are not many ord...
# 2   [Dear Wolt support, I would like to file anoth...
# 3   [i am very happy with wolt, i am very happy wi...
# 4   [The payment is a shameless, The payments are ...
# 5   [My app teasing therefore i have not been to w...
# 6   [The adress of one of my delivery's today was ...
# 7   [Wolt support not good.verybad, Support always...
# 8   [Sometimes wolt app doesn't redirect to accura...
# 9   [McDonalds City putting orders in big bags is ...
# 10  [I also want to order, from Wolt Market in Van...
# 11  [Why the system give bundles when there are no...
# 12  [Put a bonus for weekend 23to02am, Where is ou...
# 13  [App lets me drive for miles, then offers almo...
# 14  [I had the order 7J5DV3, in which the app sent...

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = reduced_outlier_model_manual.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = reduced_outlier_model_manual.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: order, courier, hour, task, time, new, work, 2, order order, receive
# Topic 1: ready, wait, order, time, food, minute, restaurant, burger, mark, mcdonald
# Topic 2: happy, wolt, good, work, day, thank, happy wolt, job, love, wolt happy
# Topic 3: low, pay, payment, hour, price, order, work, bad, earning, wolt
# Topic 4: app, time, app work, order, work, error, support, task, accept, wolt
# Topic 5: km, distance, delivery, drive, pay, car, driver, order, long, wolt
# Topic 6: support, wolt support, help, chat, bad, team, wolt, contact, support bad, support team
# Topic 7: address, map, google, location, app, gps, maps, wrong, google map, google maps
# Topic 8: bag, drink, food, pack, order, cup, soda, paper, spill, restaurant
# Topic 9: wolt market, market, wolt, order wolt, order, market vanløse, vanløse, danish, copenhagen, hour
# Topic 10: bundle, order, bundle order, pay, task, payment, system, new, order bundle, accept
# Topic 11: bonus, weekend, excellent weekend, weekend excellent, weekend bonus, excellent, order, bonus weekend, day, bonus time
# Topic 12: mile, offer, drive, drive mile, order close, offer ready, mile offer, close venue, app let, let drive
# Topic 13: order, deliver, support, cancel, customer, cancel order, tell, ask, pick, wrong

# %% [markdown]
# ## Fine tune topic representations

# %%
import copy

reduced_outlier_model_manual_topics = copy.deepcopy(reduced_outlier_model_manual)

# %%
keybert_model = KeyBERTInspired()
mmr_model = MaximalMarginalRelevance(diversity=0.4) #0.2 is used in the book.

representation_model = {
    "Main": mmr_model,
    "KeyBERT": keybert_model,
    
}

# %%
reduced_outlier_model_manual_topics.update_topics(documents, topics = topics_c_tf_idf_0085_manual, vectorizer_model= vectorizer_model, representation_model=representation_model)
# Out:
# 2025-05-25 19:45:14,496 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
reduced_outlier_model_manual_topics.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   1945                       -1_work_customer_deliver_day
# 1       0   1315                    0_hour_work_order order_receive
# 2       1   1440                       1_order_minute_mark_mcdonald
# 3       2   1206                        2_happy_work_day_happy wolt
# 4       3   1120                               3_low_hour_work_wolt
# 5       4    806                     4_app work_work_error_delivery
# 6       5    657                        5_delivery_drive_kr_payment
# 7       6    449           6_support_wolt support_chat_support team
# 8       7    383                     7_location_gps_google map_copy
# 9       8    314                            8_pack_order_soda_spill
# 10      9    216         9_wolt market_order_market vanløse_denmark
# 11     10    155                  10_bundle_payment_order bundle_km
# 12     11    170  11_weekend excellent_weekend bonus_bonus weeke...
# 13     12    124   12_drive mile_order close_mile offer_close venue
# 14     13    164              13_deliver_customer_cancel order_pick
#
#                                        Representation  \
# 0   [work, customer, deliver, day, hour, bad, busy...
# 1   [hour, work, order order, receive, new courier...
# 2   [order, minute, mark, mcdonald, food ready, de...
# 3   [happy, work, day, happy wolt, wolt happy, wor...
# 4   [low, hour, work, wolt, dkk, system, earn, lik...
# 5   [app work, work, error, delivery, restart, ord...
# 6   [delivery, drive, kr, payment, work, bicycle, ...
# 7   [support, wolt support, chat, support team, su...
# 8   [location, gps, google map, copy, wrong addres...
# 9   [pack, order, soda, spill, customer, paper bag...
# 10  [wolt market, order, market vanløse, denmark, ...
# 11  [bundle, payment, order bundle, km, bundle tas...
# 12  [weekend excellent, weekend bonus, bonus weeke...
# 13  [drive mile, order close, mile offer, close ve...
# 14  [deliver, customer, cancel order, pick, mistak...
#
#                                               KeyBERT  \
# 0   [week excellent, excellent week, excellent sun...
# 1   [get order, order order, order, wait order, re...
# 2   [food ready, order ready, delay, restaurant, m...
# 3   [love wolt, wolt happy, happy wolt, wolt, wolt...
# 4   [low payment, low pay, order pay, payment, pay...
# 5   [app work, fix app, app app, app, problem app,...
# 6   [wolt, favor wolt, hello wolt, fee, fairly app...
# 7   [wolt support, support wolt, support bad, supp...
# 8   [address wrong, wrong address, incorrect addre...
# 9   [paper bag, bag order, use bag, pack bag, food...
# 10  [wolt market, market vanløse, order wolt, mark...
# 11  [bundle payment, bundle pay, pay bundle, order...
# 12  [weekend bonus, friday bonus, bonus weekend, d...
# 13  [venue app, order venue, venue order, mile app...
# 14  [cancel order, deliver order, order cancel, or...
#
#                                                   MMR  \
# 0   [delivery, work, customer, deliver, day, hour,...
# 1   [courier, hour, work, order order, new courier...
# 2   [minute, restaurant, burger, mcdonald, order r...
# 3   [happy, day, happy wolt, wolt happy, excellent...
# 4   [low, pay, payment, hour, work, earning, salar...
# 5   [app, app work, error, crash, fix, restart, or...
# 6   [km, delivery, drive, pay, kr, payment, app, b...
# 7   [support, wolt support, chat, support bad, sup...
# 8   [address, map, app, gps, maps, google map, goo...
# 9   [bag, pack, soda, spill, paper bag, lid, mcdon...
# 10  [wolt market, market, order wolt, market vanlø...
# 11  [bundle, bundle order, payment, order bundle, ...
# 12  [weekend, excellent weekend, weekend excellent...
# 13  [mile, drive mile, order close, mile offer, cl...
# 14  [deliver, cancel, customer, cancel order, mist...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [Didn't get some order, There are not many ord...
# 2   [Dear Wolt support, I would like to file anoth...
# 3   [i am very happy with wolt, i am very happy wi...
# 4   [The payment is a shameless, The payments are ...
# 5   [My app teasing therefore i have not been to w...
# 6   [The adress of one of my delivery's today was ...
# 7   [Wolt support not good.verybad, Support always...
# 8   [Sometimes wolt app doesn't redirect to accura...
# 9   [McDonalds City putting orders in big bags is ...
# 10  [I also want to order, from Wolt Market in Van...
# 11  [Why the system give bundles when there are no...
# 12  [Put a bonus for weekend 23to02am, Where is ou...
# 13  [App lets me drive for miles, then offers almo...
# 14  [I had the order 7J5DV3, in which the app sent...

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = reduced_outlier_model_manual_topics.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = reduced_outlier_model_manual_topics.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: hour, work, order order, receive, new courier, wolt, order courier, today, people, lot
# Topic 1: order, minute, mark, mcdonald, food ready, delay, late, burger king, 5, waste
# Topic 2: happy, work, day, happy wolt, wolt happy, work wolt, day excellent, today, team, happy work
# Topic 3: low, hour, work, wolt, dkk, system, earn, like, wage, pay order
# Topic 4: app work, work, error, delivery, restart, order app, bug, try, app crash, km
# Topic 5: delivery, drive, kr, payment, work, bicycle, long distance, trip, kilometer, app favor
# Topic 6: support, wolt support, chat, support team, support good, support help, contact support, thank support, support support, message
# Topic 7: location, gps, google map, copy, wrong address, wolt app, problem, copy address, house, card
# Topic 8: pack, order, soda, spill, customer, paper bag, lid, mcdonald, seal, packaging
# Topic 9: wolt market, order, market vanløse, denmark, courier, ote, delivery, today, app wolt, employee
# Topic 10: bundle, payment, order bundle, km, bundle task, courier, bundle pay, reject, extra, delivery
# Topic 11: weekend excellent, weekend bonus, bonus weekend, day, task, bad, 50kr, deliver, 17:00, earn
# Topic 12: drive mile, order close, mile offer, close venue, app let, joke app, delivery, venue app, km, minute
# Topic 13: deliver, customer, cancel order, pick, mistake, say, contact, venue, compensation, deduct

# %% [markdown]
# ## Save / Load the final model

# %%
reduced_outlier_model_manual_topics.save("reduced_outlier_model_manual_topics")
# Out:
# 2025-05-25 19:59:31,420 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %%
from bertopic import BERTopic

model = BERTopic.load("reduced_outlier_model_manual_topics")

# %% [markdown]
# ## Inspect final model

# %%
reduced_outlier_model_manual_topics.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   1945                       -1_work_customer_deliver_day
# 1       0   1315                    0_hour_work_order order_receive
# 2       1   1440                       1_order_minute_mark_mcdonald
# 3       2   1206                        2_happy_work_day_happy wolt
# 4       3   1120                               3_low_hour_work_wolt
# 5       4    806                     4_app work_work_error_delivery
# 6       5    657                        5_delivery_drive_kr_payment
# 7       6    449           6_support_wolt support_chat_support team
# 8       7    383                     7_location_gps_google map_copy
# 9       8    314                            8_pack_order_soda_spill
# 10      9    216         9_wolt market_order_market vanløse_denmark
# 11     10    155                  10_bundle_payment_order bundle_km
# 12     11    170  11_weekend excellent_weekend bonus_bonus weeke...
# 13     12    124   12_drive mile_order close_mile offer_close venue
# 14     13    164              13_deliver_customer_cancel order_pick
#
#                                        Representation  \
# 0   [work, customer, deliver, day, hour, bad, busy...
# 1   [hour, work, order order, receive, new courier...
# 2   [order, minute, mark, mcdonald, food ready, de...
# 3   [happy, work, day, happy wolt, wolt happy, wor...
# 4   [low, hour, work, wolt, dkk, system, earn, lik...
# 5   [app work, work, error, delivery, restart, ord...
# 6   [delivery, drive, kr, payment, work, bicycle, ...
# 7   [support, wolt support, chat, support team, su...
# 8   [location, gps, google map, copy, wrong addres...
# 9   [pack, order, soda, spill, customer, paper bag...
# 10  [wolt market, order, market vanløse, denmark, ...
# 11  [bundle, payment, order bundle, km, bundle tas...
# 12  [weekend excellent, weekend bonus, bonus weeke...
# 13  [drive mile, order close, mile offer, close ve...
# 14  [deliver, customer, cancel order, pick, mistak...
#
#                                               KeyBERT  \
# 0   [week excellent, excellent week, excellent sun...
# 1   [get order, order order, order, wait order, re...
# 2   [food ready, order ready, delay, restaurant, m...
# 3   [love wolt, wolt happy, happy wolt, wolt, wolt...
# 4   [low payment, low pay, order pay, payment, pay...
# 5   [app work, fix app, app app, app, problem app,...
# 6   [wolt, favor wolt, hello wolt, fee, fairly app...
# 7   [wolt support, support wolt, support bad, supp...
# 8   [address wrong, wrong address, incorrect addre...
# 9   [paper bag, bag order, use bag, pack bag, food...
# 10  [wolt market, market vanløse, order wolt, mark...
# 11  [bundle payment, bundle pay, pay bundle, order...
# 12  [weekend bonus, friday bonus, bonus weekend, d...
# 13  [venue app, order venue, venue order, mile app...
# 14  [cancel order, deliver order, order cancel, or...
#
#                                                   MMR  \
# 0   [delivery, work, customer, deliver, day, hour,...
# 1   [courier, hour, work, order order, new courier...
# 2   [minute, restaurant, burger, mcdonald, order r...
# 3   [happy, day, happy wolt, wolt happy, excellent...
# 4   [low, pay, payment, hour, work, earning, salar...
# 5   [app, app work, error, crash, fix, restart, or...
# 6   [km, delivery, drive, pay, kr, payment, app, b...
# 7   [support, wolt support, chat, support bad, sup...
# 8   [address, map, app, gps, maps, google map, goo...
# 9   [bag, pack, soda, spill, paper bag, lid, mcdon...
# 10  [wolt market, market, order wolt, market vanlø...
# 11  [bundle, bundle order, payment, order bundle, ...
# 12  [weekend, excellent weekend, weekend excellent...
# 13  [mile, drive mile, order close, mile offer, cl...
# 14  [deliver, cancel, customer, cancel order, mist...
#
#                                   Representative_Docs
# 0   [Hello with you "Wolt" I will start by mention...
# 1   [Didn't get some order, There are not many ord...
# 2   [Dear Wolt support, I would like to file anoth...
# 3   [i am very happy with wolt, i am very happy wi...
# 4   [The payment is a shameless, The payments are ...
# 5   [My app teasing therefore i have not been to w...
# 6   [The adress of one of my delivery's today was ...
# 7   [Wolt support not good.verybad, Support always...
# 8   [Sometimes wolt app doesn't redirect to accura...
# 9   [McDonalds City putting orders in big bags is ...
# 10  [I also want to order, from Wolt Market in Van...
# 11  [Why the system give bundles when there are no...
# 12  [Put a bonus for weekend 23to02am, Where is ou...
# 13  [App lets me drive for miles, then offers almo...
# 14  [I had the order 7J5DV3, in which the app sent...

# %%
# Display top 10 word representations for each topic (excluding outlier topic -1)
topic_info = reduced_outlier_model_manual_topics.get_topic_info()
for topic_id in topic_info.Topic:
    if topic_id != -1:
        words = reduced_outlier_model_manual_topics.get_topic(topic_id)
        if words:
            top_words = [word for word, _ in words[:10]]
            print(f"Topic {topic_id}: {', '.join(top_words)}")
# Out:
# Topic 0: hour, work, order order, receive, new courier, wolt, order courier, today, people, lot
# Topic 1: order, minute, mark, mcdonald, food ready, delay, late, burger king, 5, waste
# Topic 2: happy, work, day, happy wolt, wolt happy, work wolt, day excellent, today, team, happy work
# Topic 3: low, hour, work, wolt, dkk, system, earn, like, wage, pay order
# Topic 4: app work, work, error, delivery, restart, order app, bug, try, app crash, km
# Topic 5: delivery, drive, kr, payment, work, bicycle, long distance, trip, kilometer, app favor
# Topic 6: support, wolt support, chat, support team, support good, support help, contact support, thank support, support support, message
# Topic 7: location, gps, google map, copy, wrong address, wolt app, problem, copy address, house, card
# Topic 8: pack, order, soda, spill, customer, paper bag, lid, mcdonald, seal, packaging
# Topic 9: wolt market, order, market vanløse, denmark, courier, ote, delivery, today, app wolt, employee
# Topic 10: bundle, payment, order bundle, km, bundle task, courier, bundle pay, reject, extra, delivery
# Topic 11: weekend excellent, weekend bonus, bonus weekend, day, task, bad, 50kr, deliver, 17:00, earn
# Topic 12: drive mile, order close, mile offer, close venue, app let, joke app, delivery, venue app, km, minute
# Topic 13: deliver, customer, cancel order, pick, mistake, say, contact, venue, compensation, deduct

# %%
# Get topic assignments for each document
topics2, _ = reduced_outlier_model_manual_topics.transform(df_combined["translated_Comment"].tolist())

# %%
from collections import defaultdict
import random

# Organize documents by their assigned topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics2):
    topic_to_docs[topic].append(doc)

# Iterate over sorted topic IDs
for topic_id in sorted(topic_to_docs.keys()):
    docs = topic_to_docs[topic_id]
    
    # Filter to only include feedback with length ≤ 150
    short_docs = [doc for doc in docs if len(doc) <= 400000]
    sampled_docs = random.sample(short_docs, min(20, len(short_docs)))  # Randomly select up to 10 docs
    
    print(f"\n -- Topic {topic_id} -- ")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
# Out:
#  -- Topic -1 --
# 1. Fist shift was ok not as busy as i expected
# 2. After the update, the app works very poorly
# 3. No money. Working for nothing
# 4. Nothing works in appropriate condition. App doesn't see the real distance between me and restaurants. DDS in all it's "beauty"
# 5. Hello with you "Wolt" I will start by mentioning that I have been very happy with my time at Wolt and proud to tell how well we serve, as today is called how well we used to and earn, because that time is over. You talk about listening to us cures and fairly done the app. First you put our starting fee down from 45,- to 35,- earlier it was a bird spacing, such as praying at Islands Brygge, birds distance of 450 meters above the water when reality was 2 km. Ñu has once again fixed the app in favor of Wolt and not us who have made you rich. In the video on YouTube, the guy tells us that you have listened to us, but that is not entirely correct or you have misunderstood something. Now you have again changed the app in favor of Wolt, so a delivery that is in fact 5 km can give 21.50,- as it is a delivery close to the previous one and not as before, both order from start to finish. Which is some hell of a swine, personally I reject all orders for less than 40,- That is, even one of 39.95,- will be rejected I was offered 26,- for and picking up an order on Sunday in bonus time, +15,- in bonus, = 11,- kr for the order itself? I am super disappointed with your behavior against us. There are also a large number of colleagues who have stopped. 100% even owed "Wolt" Presence never gives good results. Give and it comes back, stingy and you get smack. !!
# 6. It could be nice to have a raise in our salary
# 7. Feels great rejecting your -25min double order scams to be honest.
# 8. The pay is to low to cover the cost of the job and the car
# 9. An interface tutorial would go a loooong way
# 10. Decline button no reaction 50% of the times Support reply messages don’t appear
# 11. Almost no deliveries
# 12. Hi wolt partner, It seems as if the prices are pressed down a little further than it’s possible for us to maintain our living cost plus the car expenses! We hope that you will consider the inflation as well as all the increases living standard in DK
# 13. Frankie's is always disrespectful of our role. They just lie abut the orders being ready, the estimated waiting times and they avoid us every time we walk in
# 14. The bonus doesn't make up for the speed decrease in the snow, still no transparency but likely the only reason it was busy is that there are no drivers, whereas busy normally means you can expect you le orders and short routes as supply and demand kicks in, here it was just very low supply and the routes offered were mostly really bad 4km+ which is exacerbated by the road conditions making those even less worth it than normal. That's not even considering it being cold. I'd love to drive but if it doesn't make sense economically while also being in rougher terring what are we as couriers to do
# 15. Support thank you so much,
# 16. Great help from support
# 17. The algorithm is really intelligent
# 18. How can I have made less money than in everyday life despite more order and weekend bonus ?????
# 19. I'm there was a mixup with some orders. I got to different supporter in the same mistake and it toke very long time to explain number two supporter what happened. If we can have the same supporter we will spare surporters Time and the currier's time
# 20. Continue to ask for the same documents
#
#  -- Topic 0 --
# 1. Few orders. I need more time for the same money
# 2. Too many couriers are working outside the the peak hours, and here is the solution: Divide all couriers into 3 groups. Only a specific group can work outside the peak hours, for a week at a time. All couriers takes part in a 3 week cycle. Evrybody can work during the peak hours.
# 3. Im happy ii need more order
# 4. Horrible for car couriers, barely worth the time
# 5. I have seen some couriers who make more than 200 kr per hour ,and I have experienced today a hourly payment under 100 kr per hour,it's wolt have a list with favourite couriers?!How it's that possible?
# 6. Not a single task in one hour. Pathetic...
# 7. There are not enough orders
# 8. Online at noon and got only one trip of 1 1/2 hours
# 9. No orders in peak hours
# 10. What did I do to receive a single order after 9?
# 11. Too few orders or too many bends.
# 12. As always. No it wasn’t a good day. Screw you operations team for screwing the car delivery over. You suck at your job
# 13. More orders and less messages
# 14. Whenever I complete a task and receive a new one the new task disappears after 1 second. I don’t even have time to read it… McDonald’s Fisketorvet… It feels like they are not taking Wolt seriously at all. The food is often delayed and we get ignored completely.
# 15. No order has sided and waited for over 30 min and it's nicely comet just to side down
# 16. No orders!!! If it is one order is in delay, so very sad!!
# 17. Is already full of.couriers in the streets and is still winter. Stop please opening accounts, the earnings are super low
# 18. It's not fair to the customers and to the courier partners. Distance is just not real only for flying cars max... For example, if you are a customer, you can see distance fees.. 1.9 km... as a courier, you get the a 1.9 km distance fee even though from the pick up point you have to drive or bike almost the double. It's the deception of the customer and your courier partner. And it's illegal.
# 19. You have hired too many new couriers, I struggle to make a decent earning even though I work far more than the peak hours
# 20. 5 hours, 3 tasks, less than 200 DKK, pure conditions
#
#  -- Topic 1 --
# 1. The delivery to Lundkjærvej was faulty. Both customer and restaurant were surprised that I arrived 15-30 minutes premature in both places. This even though the restaurant was about to have the food ready in the app. I used approx. 15 minutes to wait in the restaurant due to the flawed info in the app. I would like to see compensation as 34kr does not cover that work effort. Otherwise fine :)
# 2. Mc Donald is ignoring couriers. I ve been waiting for 20 minutes after they marked order ready. There are underage children working and they dont give a damn about us waiting there. Every single wolt courier hates mc donald. Please contact them and tell them to change their approach to us and to their responsibilities.. Thank you.
# 3. Is really tired of McDonald's Kongensgade always waiting even if the food is packed and ready for delivery. In addition, it also writes as clear when it is not. Earlier today I waited 40 min. on an order and I asked several times after it. However, this is only Kongensgade and not Storegade, which delivered it immediately.
# 4. Some employees at Macdonalds Havnen in Næstved are extremely rude and disrespectful in their tone and does not seem to have respect for Wolt drivers at all. No importance of our time and self-respect. They treat us like some stupid children…Wolt should take up this matter with the owner soonest. It is your duty to protect us against such rude behavior, disrespect and undue waiting time.....
# 5. Im reporting separtly to in the chat about a very bad experience with the owner of 'Burgers & Bagels"
# 6. Mc donalds Roskilde kobenhavnvej selfish personal you have to ask 10 times to get you totally ready pack Burger King Roskilde never ready pack but they mark all time ready and you wait minimum 8-12 minutes
# 7. Burger King continues to take over half an hour to prepare orders, REGARDLESS of what time of day it is.
# 8. Often it says that the order should be clear but it is not, so you end up standing somewhat longer in the restaurant one expected.
# 9. Otro pizza gothasvej waiter was not nice
# 10. I had an order at McDonald’s that didn’t come in on their system, so I waited 10 minutes before asking if they had it. And when they said it was coming… which it wasn’t. So I waited 5 more minutes and asked again. They then figured out that they didn’t have it. And made it for me. Thankfully everything was worked out in the end. But this did make me 20 minutes late for both of my orders which in turn frustrated my customers…
# 11. I am online for delivery and waiting in front of mcdonald's outlet for 1 hour. But i have not received a single order, but so many wolt partners are coming to pick up the order. Wolt is spoiled my hour by not providing order
# 12. The restaurants should compensate for waiting time
# 13. Boom burger marked the order ready, yet still made me wait almost 10 mins. At the end she handed me a bag, that had been left untouched during my wait, meaning the order was actually “ready” on time
# 14. Some of employees at macdonalds havnen in naestved are rude with wolt drivers, with no respect for wolt drivers and no regard to wolt drivers' time....I have been highlighting this from very long time but it appears that wolt does not care either..
# 15. Shitty Restaurant Grillen Burger.
# 16. Should again wait 20 minutes for an order at Fresh Burgerbar Vejle. So it is almost every time in time
# 17. Long waiting time pasta diem
# 18. La Qualita Birkerød is always too late with the food. Usually wait 5-10 min.
# 19. Problems with spar and mcd Valby
# 20. McDonald's is late as always, I'm refusing to take orders from them from now on as they completely messed up my good flow. Also there was a problem with the app where multiple guys got the same order.
#
#  -- Topic 2 --
# 1. Bad Services, bad conversation, totally bad,bad
# 2. Very free just right to get started but is happy to further
# 3. Oscar was super cute and helpful
# 4. I enjoy my first time wolt delivering
# 5. Not too bad also today.
# 6. May God make you happy, Lord of the worlds, for your hard work
# 7. Great and simple system
# 8. At all nothing to make all day Really bad day
# 9. Very satisfied .. fat work .. Sunshine
# 10. i am very happy with wolt
# 11. Great people and pleasure serving with honour
# 12. i am so glad to work with wolt
# 13. Awesome! I recommend it!
# 14. wolt is the best working place.
# 15. Good morning people me going to sleep now Long kiss good night
# 16. I am very happy! I love this job!
# 17. Thanks for the lovely night with wolt
# 18. i am vary happy with wolt
# 19. i am very happy with wolt
# 20. company that deceives people, I will remember when the bad weather comes
#
#  -- Topic 3 --
# 1. Pay is to low guys. Think we all agree. (Workers )
# 2. 700 kr 10 hours with great sistem "random"
# 3. I think Wolt is the only company in the world that prefers to lose money, prestige and clients rather than pay its partners/employees better.
# 4. increasingly low rates and little support help
# 5. Prices for orders are very low
# 6. Wonder well known expected hourly wage before i start
# 7. Would like better pay like fodora
# 8. Don’t force us to work on fixed hourly wage, this will destroy everything.
# 9. 30% reduced payment + less orders = Shitty Job
# 10. Prices are very low. The Wolt Publicity is BS
# 11. I made 600 dkk for 10h of working was very bad day... another people got orders but from 20 00 until 22 00 I didn't get any.. or maybe just one
# 12. Payment per orders are a totaly dezaster
# 13. if earnings per task were higher, it would be great. otherwise all good, but the earnings could improve
# 14. Falling wages and tasks
# 15. Earnings have dropped alot in the last 3 months, the new system is bad, and i don't like it. I hope you will return to the old system, because was better.
# 16. In my first 2 years I have been very fond of Wolt. But now that has changed. I am very disappointed with Wolt's poor treatment of the cure. How we can now suddenly get 21 kroner for an order. When I started with you, it was my 45,- for an order and payment for full distance for all orders. This is just a warning to you, you are going to burn you over your nearness
# 17. Get back to the previous payment model
# 18. the first hour of work I made 40 kroner from which I pay taxes and I deduct petrol, you are rubbish
# 19. Too few orders, compensation gets lower and lower
# 20. An exploitative company that does not bear responsibility for anything ! Fuck Wolt!
#
#  -- Topic 4 --
# 1. Has just been cheated to take an order ... when the app didn't work
# 2. The Lagkagehuset did not control the orders and took eternity to hand over the order. There is a lot of layers at the app when there are more than two orders active at a time.
# 3. ADD profile pictures
# 4. I have tried a couple of times now to lose an order because the app says there was a mistake .... it is still close to £ 200 I've lost
# 5. In the last days there ar a lot of issues with the app to costumers
# 6. The app keeps reporting errors
# 7. The app is really slow sometimes
# 8. App is working bad,same order is coming arleast 30 Times after rejecting again again same order.Also order is coming from 2 to 3 kilometeres .regards
# 9. The app kept giving me an error all throughout the evening, that it couldn't start tasks or accept orders. Most of the time it still started the task though, but it was quite frustrating.
# 10. App version don't work.
# 11. You have to fix that app, waisting my time and money with daily errors an-mass, today I almost went home after my first order, just in frustration, it's not good enough, steals my profit, and have done so for a long time. No dispensation for the trouble either.
# 12. For an error on the app, customer support deducted the price of an order from me
# 13. Today was not a good day Many times I tried to check out and it didn't work, I restarted the system and I couldn't log in to the app anymore
# 14. It is not app functionality, but would write a complaint about the new system in relation to tax payment, my complaint is not so much in changing the system, but that you only give 1 month's notice to the new system being used, which for me personally fucker quite my plans, compared to how much I would have worked, you could at least have given 3 months notice.
# 15. Had a couple of problems with the App today. I had a Jaegger order in my bag. Some how the order was completed even though I didn't swipe to complete it. Same with a McDonald's order shortly after. Was the only time it happened. Just a bit of weirdness today but other than that the app worked fine
# 16. The app is stalling too many times
# 17. The app doesn't seem to work properly.
# 18. Isn't it always that the app allows you to write to the customer? Why not?
# 19. App fails. Are there fewer orders?
# 20. I don’t know how wolt is so special to make the app every day badly I reject the same order 30 times
#
#  -- Topic 5 --
# 1. Still really happy to be a Wolt bid! It would be good if Wolt pointed out that tuned scooters, bikes, etc. may expose others in traffic to danger and make the bid liable in case of accidents. I have seen several people running too strong on 30 mopeds and div. Electric vehicles ...
# 2. From bad to worse, more and more people are taking advantage of us, I see rates getting lower, vehicles depreciating, driving twice as many kilometers as before, it really is a scam
# 3. So far my miles look to increase around 20-25 %. That’s 200-250 km extra a month. I will let you know how it ends.
# 4. Why is the estimate graph not showing?
# 5. How long should wait the riders to be valued?!?! Why WOLT think if there is a low paid will success? I’m so disappointed at all . This night it was not bikes on the streets of cph. We with the cars make all works and wolt need us . How ? How the menagment think we will pay our expenses with 50kr x 5km?!?! Really I cannot understand where going this company it’s seems like mazocism. You pay for remakes and this night im sure for too many foods undelivered. But don’t boost the prices with minimum 50% . How the menagment of this company think to mantain serous ppl for long period in the company?!? In the country with most expensive life and taxes in the world ?!? Really? I’m turned off without any wishes and ambition to follow . Since when im starting in the winter wolt going worse and worse . How is possible to offer price 50kr x5km distance and -120min delayed?!?!?! In super busy and raining day !!! I’m tired to write and write to support and never happens something in better. May be I will leave this company like too many riders after stop the CVR partnership.
# 6. After I got 1 order and then almost 2 hours waiting time in cold weather got nothing, there is order is for bike not for car and far-away?
# 7. For low payments per delivery in the past
# 8. Too few trips because there are too many buddies otherwise the amount per order too little i think,
# 9. So my miles look they are increasing some 20 %, but I am sure it is the same for you, so please let me offer my condolences. I know you must be struggling with your health and social life. But don’t give up, spring is just around the corner!
# 10. I drive a 45km scooter, when app is set to scooter it calculates on bike road which can be a lot shorter at times than on car roads.
# 11. Pay us fairly according to REAL distance as you promised. Some tasks are horribly underpaid
# 12. Cars are taking most of the orders nowadays so there’s less job for bikes and scooters wich really sucks
# 13. Immediately I think it is good. I would suggest that you take more consideration for the payment of car driver as we have many expenses. Gasoline is very expensive and we drive many kilos of meters, even when you drive many kilos of meters, the car loses a lot in value, and when you drive so much you also have to change oil and brakes a little more often. So my opinion is that the car driver can get something more for the trips. And if you work at night, I think it should also give a little extra. But otherwise I think it is good and you do well in relation to support etc
# 14. Update distance payment,you are grabbing maximum of my distance payment just only showing your rules and regulation Most of the time you lies,you show a distance in time of picking order and we get another distance when we go to deliver.This is not fair.It is not professional.
# 15. Why is that salary per. Delivery got worse?
# 16. When is it arranged with the kilometer counter inside the app, it is very important it is to count kilometers you drive on trips!
# 17. Overhiring foodora drivers so we barely make anythint
# 18. Not enough work for the amount of delivery drivers in my city. Currently barely even meet the goal given by you of 150 kr. an hour
# 19. With a car I earn better with long distances. If the system has a 0.5 km deopoff distance and a 3.9 km one and I am with a car it is very stupid from the system to offer me te 0.5 km first and only offer me the 3.9 km one after I did not accept the 0.5 km one. Very very stupid. And it keeps doing that routinely on other days too.
# 20. Not enough offers for work - And VERY now salary for Long distance
#
#  -- Topic 6 --
# 1. Support is very friendly ording, however, I would like it so that I can go offline myself without trouble supporting it
# 2. Support told me they will get back to me in a moment, like 6 hours ago and still nobody reached out to me.
# 3. Nothing good for those negative support who are treating me in so disgusting way.
# 4. Supports closing the chat so fast cant ask them second question
# 5. Now I have some strange lenguage on my aplication in support part
# 6. How is possible so negative people to exist in support and to pay 30 kr per hour
# 7. Some support refuse to transfer us when we need to speak with a support from Copenhagen. Like Zura. I had a problem today and I asked her to transfer me directly to Copenhagen and she told me she can t do this and every support will do the same like her. That s not normal. When I have a very serious case I talk with someone from Copenhagen. After all I should wait so long for the support to answer me.
# 8. Why does support say hello and claim they have solved the task and close the conversation? When they did nothing other than let me go!
# 9. Support don't understanding
# 10. Best routine best support today.I turn where I start I like it .thanks
# 11. It’s 50/50 You never know what really going to happen. You always have to verify all informations. The instant chat is not working. Juli wrote to me because she chooses card B for my paiement. I need CARD A to be choosed but I can’t reply to her message. The application automatically redirect my messages to another assistant. It’s really frustrating and time consuming
# 12. Support is not good. Aalborg burger king is too much slow. And the price of delivery getting low. I am getting less orders. The order combo system is very bad. I loved the previous version of the wolt.
# 13. Connection issues with wolt server I could open youtube and load videos so the problem lies with you
# 14. It says I'm delivering in car. Support doesn't work
# 15. Wolt support loss my time.
# 16. Had an accident due to spotting a loose dog and breaking at the wrong time. Great support, very understanding
# 17. I'm taking a break. I'll be back in an hour
# 18. Support is very deficient helping us
# 19. Can't get in touch with you
# 20. Why wolt support is very bad?
#
#  -- Topic 7 --
# 1. The adress on google had the wrong number. Every time. All day. Right street, two numbers or so off
# 2. Cannot copy address from wolt
# 3. my location seems to be a very rough estimate which makes finding the destination sometimes a bit difficult
# 4. Today, navigation has only led me to the wrong address. I don't bother working because it doesn't bother to work
# 5. I often find that the address that is copied over to Google Maps is changing and is therefore wrong in Google Maps, which is not appropriate
# 6. It would be a good idea to add order area borders to built-in map
# 7. The addresses are not properly picked as destination in Google Maps navigation, after pressing the map icon from the Wolt app.
# 8. Some times gps take wrong direction. For example, the directon es number 5, and gps give us to number 7
# 9. I have some problem with my app and maps. When I'm going around town, it makes it like I'm on a bike. I have updated maps, it is for car. And it must be in the Wolt app as it informs the customer that I am there in 36 minutes for a trip that takes 6 minutes by car via the highway. I also have screendump of this. Furthermore, when I start delivery, and there is H P Hansens Gade in the app and I press the Maps icon in the right corner, it has changed address to something else, so I am wrong guided around the city. Now I often have to the keybaftess myself
# 10. The app shows incorrect addresses every now and then
# 11. The GPS was a bit off today.
# 12. Some adresses were misleading
# 13. I have some observation: 1. Sometimes not indicate actual address in Google map. Suppose House no 20 it should be indicate 20. But it sometimes show 10 -20 like that. 2.Another issues sometimes restaurant food not ready 5-20 min waiting when wolt should add Money for waiting. ( MacDonald is big example) 3. Distance kilometres is not accurate sometimes also show example 67kk but paid 52dkk. This is not complaint. 4. Pick time I accept a order so far from restaurant. There is no restaurant there so need again come back otherwise no order so like this area should add money. So this is not complaint. Just my observation.
# 14. Map put a pin WAY OFF actuall address of dropoff. Had me confused and made me deliver to customer late.
# 15. Krak's card might be great if possible. There you can see all house numbers, but if it is not technically possible, it will probably go anyway
# 16. GPS position in the app is working very slowly and it refreshes once every 1 minute. On the map there should be borders of your chosen area.
# 17. I keep getting a location tracking error message, and I’m only having this issue on the Wolt app
# 18. map don't working good
# 19. It's generally very good in every aspect, but I really do wish my map icon would be an arrow, so that I could more easily tell which direction I'm facing.
# 20. Strange that it often fails to take the address over into Maps. Approx. 1 to 2 times out of 10. Thinking it must be able to fixz
#
#  -- Topic 8 --
# 1. Kashmir place packed the order poorly. Sauce went all over the place. The paper bag literally melted away (they should use plastic) and my bag was full of sauce. Sauce started to leak out of the bag. An utter MESS. Had to go offline and go home to clean the bag. A weekend day of work pretty much ruined. Not good. It's actually not the first time indian places packed their food poorly. They need better containers for their saucy food. And they should put it in a plastic bag in case of the containers breaking.
# 2. Riders need to use the bag
# 3. Pls tell Thai wok in Vigerslev alle to close hermetically the food boxes. The sauce went out and dirt the nylon bag and my gear :(
# 4. Burger King soda glasses are not sealing the drink and it leaks to the bag.
# 5. The Wolt Bags are very good. Keeps the temperatures on the goods well, etc.
# 6. You really need to chance something about picking up from Wolt market in terms of the size/weight of the orders. First, some of the orders are really heavy for a bike-courier. But it’s hard to tell when we can only see how many bags there order entails. Secondly, it seems odd that we get paid the same wether it just a light order or two heavy bags. So please look into this
# 7. Joe & The Juice gives us coffee in cups with a hole in the lid that they have not covered. There is not much bump in the road until there is coffee throughout the bag/bag.
# 8. MC. D and Burger King simply have to learn to wrap their bags properly. Tape is so weak…
# 9. Halifax Burger handed me the drink without any holder and in a glass that wasn’t delivery-ready. Because of that, I took more time to arrive at customer’s house and the food was not delivered in the ideal condition. I did the best I could.
# 10. I would like to complain about Frankies Østerbro. They demand that you take your bag in when you pick up, which means they demand that you remove your bag from the bike with buckles and all, which takes a very long time and is very difficult for the courier. There are no other restaurants in KBH that demand the same from couriers. I also think of people of motorcycles to run their entire setup because Frankies makes this demand.
# 11. I forgot to come with feedback after my guard so here it is. I once again had 2 bad experiences with packaging that were not close. This provides an extremely bad experience for the customer. As a bid, this is clearly what I see as the biggest problem and I would advise you to go in and make demands on the restaurants regarding the packaging. You could even make your own packaging that the restaurants can buy. It is alpha-omega that all containers are hamitically closed and can withstand tilt or even stand upside down if it ends like that. If it makes the packaging more expensive then it is good that there is a statutory charge and the restaurants can even make a mortgage system so that customers can come back with the packaging and get money back (when they have to pick up food Aha, win win). Of course, it will require the packaging to be reusable, but it is just positive for the environment and the business.
# 12. I have a OnePlus 6T and often freeze the screen so I will have to restart the app if I want to open the directions. But my biggest complaint is that we offer to transport open drinks (for example from McDonald's and Carl's Jr.) because it is impossible to transport it, without any of the content ending in the bag
# 13. Wolt should monitor whether couriers use their bags at pickups and dropoffs, because let me tell you, 80% of them don’t, which goes against our contract and against basic health code regulations. It would be a shame if the DVFA found out that the company allows its employees to commit health code violations
# 14. It was not clear that what I was going to deliver was a menu, which is why I only got the drink. Instead of contacting me, sent in a new bid, nor did it tell me about this why I drove 2.5 km extra back to the restaurant without any use
# 15. Yesterday one heavy bag, wasnt marked as heavy from MENY, and it was more than 10kg.
# 16. There needs to be better monitoring on grocery orders and different pricing based on size and weight.
# 17. Maybe add more details to order info, so we can help the venues remembering everything, especially drinks. Would benefit Wolt, causing less problems with missing items.
# 18. Drinks are not visible on orders in app where they used to be
# 19. Restaurants are really bad at communicating when the order will be ready and packing the orders up nicely. They give you the food randomly without a bag that the customer has paid for. If you ask for a bag the staff gets annoyed. Specially Halifax at Fredrikborgsgade today, they kept delaying the order while the restaurant was almost empty, and packing up “their own food that they where taking home” very unprofessional.
# 20. App: - Can't see drinks at menu positions - Not all "dots" with venue/customer address on cards can be seen in parcel assignments. Restaurants: - Sataya was 30 min delayed with an order
#
#  -- Topic 9 --
# 1. Many riders in the city. People cannot properly get an hourly wage which is at least in Denmark 130. Work four hours to earn 150kr. Play time. Come on we use Shift Guard in Viborg. It can't be that 20 riders start at the same time
# 2. Not enough to do in Helsingør area
# 3. I want to do delivery’s in Ishøj but I never get any orders here even on weekends whereas I have seen people standing beside me getting orders continuously here. It is not same when I go to Copenhagen but going Copenhagen everytime is not possible as it is a little far from my home.
# 4. Too little information and then we lack that you write things in Danish to Danes It is not everyone who is strong in English
# 5. No customers compared to Wolt Partners. No need to announce that many orders will be coming on a specific day, because then more Wolt Cure Partners = “quiet” even in weekends Peek Hours.
# 6. Overall very good experience, to get more orders maybe Wolt can operate with more restaurants should be a + ,is a very nice city with a lot of them .
# 7. Hope for communication from Wolt that you look at how Wolt Bude can avoid having to mark "parcels" when picking up Wolt Drive orders.
# 8. Wolt is very good idea to deliver food and goods.
# 9. Complete and utter shitshow. 4 hours to do 10 orders, easy, right? Only there wasn’t 10 orders to do in that time, in Copenhagen. Hopefully you will compensate
# 10. Could you come with your message in Danish You are in Denmark
# 11. I'd like to know where foFor in block me from Wolt Market in Vanløse
# 12. Something change happened in wolt algorithm. I am getting long distance order and I am in cycle
# 13. Seems like places like Burger King were understaffed tonight, and didn't prioritize Wolt orders. The support from Wolt was, however, exemplary! Fast and effective. Thanks!
# 14. All the restaurants was really super today A very quiet shift today, I am afraid that Hjørring have got to many Wolt partners...
# 15. Why always the same cures get order always from Wolt Market in Vanløse
# 16. Thank you for a shit day 12 hours at work Only 6 order allle shit Bulgarian people earned soooo a lot of money in front of Wolt Market in Vanløse Me Short man Looking at them and sitting 12 hours in the car so you tell me I will not give order from WOLT Market in Vanløse Then I have to sit at home
# 17. I am new to wolt but the experience is not good. If you have enough delivery partners, you should refuse to get new ones. This is how some other comanies do, like "Just Eat". Too many partners and low njmber of task. That is so bad.
# 18. All msgs from The support for nothing! There is no high demand- friday night … Wolt is not good job opportunity in Copenhagen anymore
# 19. I'm tired of going out to work and there are no orders and they keep adding partners because it suits Wolt, I hate all of you, you are the scum of Denmark, you should leave the country
# 20. It's a great help in meeting the cost of living in Denmark
#
#  -- Topic 10 --
# 1. Tonight I accepted no bundles, which I always did in the previous means of payment, since in the new payment model I can no longer see that it can answer. Of course, it is sorry for those customers who wait or receive cold food that I no longer take bundle, but the information about the new payment model is at that point quite poor
# 2. Bundle orders should be compensated as the full distance. We can earn more that way. Getting bundles for 20-30kr is an insult for us couriers. Specially on bonus days. We use to make money on weekends, now I only make a very small difference. It's not different from a weekday. Wolt is growing, higher earnings, more customers. Give us riders a fair part of this growth. We are staying the same financially and task are paying less everyday. :(
# 3. Many hills that take a lot of extra time I don't feel counting in earnings versus the orders that are very close to the extradition sites
# 4. Very unhappy.. decreased the price per km. bundle order calculate from drop of not from shop. Worst management ever.
# 5. Seems Bundle should be paid better, it is my impression that you clearly take the greatest profit on bundle orders. Can't immediately see that heavy orders are paid better, nor, for example, the 5th floor without a lift?
# 6. We want old system, stop forcing bundle orders down our throat when you made bundle orders alot less rewarding. Stop calling us Partners when we get zero information about anything
# 7. Partners have bundles and I don't have any order
# 8. Bring back base fees. And compensate properly for bundles because customer still pays the fee
# 9. The number of orders I reject is incredible because of how poorly u are paying for the orders. following this way u will break the system.. especially the bundles. Too greedy.
# 10. Every day I earn less.. nobody cares about us. The bundles aren't a good business for the couriers. There are few orders
# 11. The bundle task is not worthy the new pricing model fail with this too
# 12. Many bundles or "planned routes" with very low revenue. Like 3 tasks for 75kr Or 3 tasks for 97kr This brings no values it is just lots of time waist with a very low return for us. For a planned route to work, it must bring us some cash for the time being on it, which 75kr for 3 tasks doesn't bring, and neither is anything that's less than 130kr. In pick time isn't worth a planned route i rather do 3 for 50kr than a planned route of 3 orders with 120kr even if i need to wait for those 3 tasks of 50kr maybe the same time like i would have been on the planned order
# 13. Seemed to run with bundle order has become less attractive than before the new reward system
# 14. Bundled tasks pay really bad, if we dont take them and you give someone else higher pay for same task why not pay us higher.
# 15. Pay full distance for bundle orders!!!!!
# 16. Confusion over orders when there are three in a bundle. I had three people standing in front of a hotel today waiting for different things and I have to trust people’s names are what they say they are etc. I also canceled the third pick up as it was awkward I didn’t know how big and heavy it was going to be as I usually avoid pickups from wolt market, and it was in the wrong direction before going to my drop off. I already had KFC and McDonalfs orders. This left one poor lady standing there confused waiting for her giffler and I assured her someone else was coming with the order. The thing is that bundles are basically just the same orders but all at once and the routing especially in the middle of town on a Friday evening when people are cycling drunk going through red lights etc mean riders WILL cancel orders.
# 17. Bundles pay way too little atm, you can often make more money by driving single orders, by going back and forth from the restaurant. Too many chatbots too.
# 18. Bundle orders is a scam
# 19. Bundle-deliveries is needed
# 20. No hollyday payment, bundles are too low 35KR
#
#  -- Topic 11 --
# 1. I didn't feel the change with the 50% boost per order. It was like a normal weekend bonus time . I had to decline a lot of Macdonald Valby Langgade - as too long waiting time and the waiting area is very small full with couriers. Have an Happy New Year
# 2. Holiday money would be fantastic
# 3. Very disappointed in the bonus system as I have had orders before until the places I have been today where the amount has been pretty much the same .. had probably hoped to get some money in today ..
# 4. I didn't received a bonus today. The #425 order from Wolt Landemærket it was heavy and with many many items inside. Why is not considered a large order?
# 5. Everything seems to go wrong this weekend with the estimates of when it would be busy and hence bonus. Anton from Wolt has to go to school again, because it seemed like the times that were not bonus was very busy, while in the bonus time there were not many deliveries. Sunday night after 8 pm in KBH things went completely wrong and it requires L strongly to evaluate how to put bonus time on. For more messes you think you are laughing and it must cost you a lot with all the orders not delivered.
# 6. You can stay 30minutes without orders in "normal" amount of orders in bonus time
# 7. Consider it necessary to modify the weekend bonus schedules. From 5pm to 7pm there are very few orders
# 8. Think we should get bonus paid these holidays ;) i guess you all get that in the offices.
# 9. Don’t you get no benefits, such as perks or discounts, some coupons or anything?
# 10. As soon as bonus hour stops you start giving orders
# 11. I don't understand why I get the notification of the 16:30-19:30 extra bonus only at 17:26. I could have easily done the 11 tasks. I did more in fact but by 20:00 It's not my phone cause I got the notification of the usual fri-sun 17-20 bonus way earlier than 17 as I usually do just fine. This other notification arrived too late.
# 12. Less and less money for orders, no more weekend bonus.
# 13. Honestly, did not feel like a bonus/high earnings day, but rather just a usual weekend.
# 14. Where is the bonus?? You finally removed it!! Thanks a lot, prices going down all the time and now this..
# 15. Good only the problem is not paying holidays money
# 16. I do not understand that when there is bonus time, how can it be you can get an order that gives a mere DKK 30.50 ???
# 17. First you changed the new year bonus from 25% to 20% and told everyone it was a mistake that you wrote 25% from the beginning. You don’t make the same mistake two-three times. I’m sorry but I don’t buy it. And then you promised 50% between 16-20 but we didn’t get it. We delivered the same amount of orders as usual and made the same amount of money in the same time. When we compare the amount we earned on one delivery today and on other days it is almost the same… I’m very disappointed with this. How are we supposed to believe you when you straight up lie to us? I do not trust you anymore and I for sure won’t deliver on the 1st of January again if this is how you do it… Three years ago I worked on the 1st of January for you and made 2250 in six hours. That’s double the amount that I made today …
# 18. I have not get the bonus for 50 deliveries at the beginning of June. I communicated it but haven't got answer.
# 19. This app is so bad, I can't believe wolt really paid dev to make and check it. Venus like Mcdonald and Burgerking are fully with stupid people that are not capable to take care of orders, not even capable to talk to you. They prefer to leave you wait for 15 minutes even if the order already done ,I see the order , the order can see me too but between us might be a retard who don't even know why he is working in burger king . Maybe I'm a little too mean, or maybe not. Take it with break mother×××××. If I would made the app, I would add the bonuses separately. So in a rainy day or bad weather when you get bonus, to be able to see it separately in another box or next to your income. So you can really see what bonus you get and therefore people won't text 100000000 messages to wolt support asking why there is no bonus on top . Many things can be improved in order to earn more as wolt company and also wolt worker, but in the end I'm just a simple courier who is kinda sad that I'm going down instead of up, especially because all my experience.
# 20. The new nighttime bonus is absolutely atrocious and disrespectful. 10% extra is NOTHING. Maybe 30-40% would be a realistic number. Normal workplaces give 1,5x more (+50%) for night shift workers. I would really like to work at night sometimes, but this so called bonus is just not worth it. I hope you will reconsider your approach and start treating courier PARTNERS as actual partners and nog as company slaves
#
#  -- Topic 12 --
# 1. App is assigning Long distance order and i am in cycle. Ot would have been better if i Can restrict the Delivery area myself
# 2. App lets me drive for miles, then offers almost ready order when I’m close to the venue Disaster stats: Miles driven increased 20-30 % absurd.
# 3. All good. It would be great if application have feature to restrict distance to venues and customer..
# 4. I had an hour and a half with no deliveries. Called support to hear if there was anything wrong with my app or if there was anything wrong with software but he said that everything was fine and I just had to drive around the city but I have never experienced that there were no tasks taking so you must just look at the time if there was something wrong with the system itself I have only got an order that I hand in and then I have completed the guard.
# 5. App lets me drive for miles, then offers late or almost ready order when I’m close to the venue. Almost six orders like this today !!!
# 6. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Please understand that I often reject orders when I feel manipulated by “the algorithm”…
# 7. Drive for miles and suddenly when you are near a venue an order pops up…
# 8. it seems like a nice job so far :) Only problem I have is some technical issues with sliding the buttons during an order due to my phone being a bit slow. And deliveries showing up as having to be collected in negative amounts of minutes. But I'm sure it all works out in the end, and is maybe just due to a lack of couriers?
# 9. App lets me drive for miles, then offers almost ready order when I’m close to the venue. PLEASE PLEASE change the programming of the app, so it offer us orders BEFORE we cross a big intersection, or turn a corner. It is super annoying and somewhat dangerous to have to do all these U-turns.. Also my app doesn’t really register how many miles I drive, I estimate less than 20 % is registered this month
# 10. App lets me drive for miles, then offers almost ready order when I’m close to the venue. ABSOLUTE JOKE !!!!!
# 11. It was really a flop today. You wrote to me this morning: "Calling all Couriers in Frederiksværk" - that was busy, so you encouraged us cures to meet. I drive 10 km. Out and home, after sitting approx. 1 hour in Frederiksværk without a single order, so I drove home again. It was good enough practice. Do not understand in missing people when neither stopped nor normal on the app. There was nothing at all. Would like to ask for a feedback from you on this. Sincerely, Tonny
# 12. Obviously Miles driven to earn money are massively increased. App lets me drive for miles, then offers almost ready order when I’m close to the venue. And how can order level be medium, when there are no orders for 20 minutes ? Please provide better info on availability of orders
# 13. App lets me drive for miles, then offers almost ready order when I’m close to the venue. Absolute joke
# 14. App lets me drive for miles, then offers almost ready order when I’m close to the venue. HAVE YOU NO SHAME ?
# 15. The app is a joke. I drive 2 kilometers with no orders, order level normal and then get offered a late order once I am right next to the pick up. I worry for your future, if this poor performance continues
# 16. App lets me drive for miles, then offers almost ready order when I’m close to the venue. JUST AN ABSOLUTE JOKE. DONT YOU HAVE ANY SELF RESPECT?
# 17. App lets me drive for miles, then offers almost ready order when I’m close to the venue. I literally drive 4km, and surprise I get an order when I’m at the venue, an order that’s almost ready (1 minute) ABSOLUTE JOKE !!!!!!!!!!!!!!
# 18. App lets me drive for miles, then offers almost ready order when I’m close to the venue. 7/9 last orders offered late !!!!!!!!!!!!!!!!
# 19. I haven't gotten any deliveries although it is fast I can't reach to the support through the app
# 20. The application did not work well - the location update was done at long intervals, for this reason you had to wait 4-5 minutes before you could swipe the received order -with normal and busy status, in 1 hour and 30 minutes I received 3 orders - after long periods of waiting, I received the orders ready and delayed - a second order is pending and by the time you reach the location to pick up the first one it disappears, it is pointless to be displayed until you drive 2-3 km and then disappear - I received the order for a new customer, ready and delayed, to travel to the venue 6 km, after picking up the estimated time for delivery 3 min. for 4.5 km, driving safely is a priority
#
#  -- Topic 13 --
# 1. Support take so long to resolve a problem it looks like they never understand what the issue or how to solve it. They gave me the wrong order in the restaurant. In understand it's my fault. So they need to be fast to charge me the amount and give a straight answer right away to keep going.
# 2. For one order I delivered wrongly 63kr wolt deduct me 175 kr robbery ,wolt 0 responsibility, suport 0
# 3. I am charged with some of 90 kroner for a restaurant that has a little boy behind the box that does not hear the difference from orders 896 and 892. It is not my problem, it should be an insurance case as all parties are people and can make mistakes. One must not have a smaller year behind the box, that is what happens, again not my problem, but this illegal act should not cost me. I am so frustrated with this that I have gone offline because of it, it may not be true that I have been at work 1 full hour to get 30 kr which is based on someone else's mistake. The supporter who made this decision has for some reason no logical sense, which is worrying as they are between the lead between us and the customers. She asked me to hand over the food to the customer even though it was not the right order, where after she asked if I could drive it to the restaurant and pick up the right orders like that about 3-4 min after she wrote I had to hand in. After this I had written that it was too late when she said she will have to deduct full amount from as both parties are responsible for this error. Which I don't think was the case here if the staff of the restaurant gives me the order where the staff directly look at the number and still manage to give me the wrong order is not my mistake. I've never seen anything like it. I hope you get control of your staff This is not okay. I think it is rude to send a bid for an hour of work without pay. Good evening hope you get control of your policies (not to support illegalities as children behind the box)
# 4. Gastronomia Italia order 268. I arrived. Confirmed my order number is 2 6 8. They confirm and ask multiple times if it's 2 6 8. After I get it, I swipe. But they say I didn't swipe. I show them the order on my phone. They show me the order on their tablet, saying the order is 2 6 9.... I say mine is 2 6 8. They don't understand why 2 6 8 is my order, and not 2 6 9... They insist they gave me order 2 6 9, even though we agreed multiple times that I came for order 2 6 8.. I should receive compensation on behalf of their mistake.
# 5. I had a case where I was not able to pick up the items because another courier already tool them, and I wrote to support and had the order made and I delivered it. My complaint is I lost 25 minutes of time to a mistake someone else made and did not get compensated for it, I would like to ask for this to be changed, cause I lost out on an entire orders worth of time
# 6. Automatic cancel the order
# 7. The two layers of support you have to go through to get anything done are highly frustrating and time wasting. Also if a task is to pickup a missing item from a previous order please let us know about it. Twice today I had venues flatly tell me they had no such order only to find out after 10 minutes back and forth with support that it was for a missing item.
# 8. About order number 929 from WEDO: When I come to Wedo to pick up the order the employee from Wedo tells me that order is taken from another !! I jumped twice but she refuses to give that order to me selfom I have shown to her my mobile where on the Wolt App stands that it is me who should get that order. I suns that someone has got that order
# 9. If I took orders and delivered them to the client, this order is wrong, I am responsible for it, so it is not fair because it is not my fault if they gave me the wrong order.
# 10. My app bugged and it sent me to the wrong address on a bundle of 2 orders, after which support told me i will get deducted for the "wrongly delivered order" even after i told them i delivered everything correctly like it said in the app...Then they told me i have to deliver the mcdonalds order to the same person that i delivered the burger king order, so i did...after that they fine me 400dkk for both orders!!!!?!?!?? After that they say "oh we're very sorry we made a mistake we can't refund you so you have to wait for operations to contact you, i have filed a complaint on your behalf"...what complaint on my behalf i haven't given consent to that i wanna complain myself...i really hope someone from operations contacts me asap because these people scammed me out of my earnings and I'm outside freezing on slippery ice it's totally not fair and unprofessional...
# 11. Vendor concerns are not being heard
# 12. A worker from support team deducted me unfairly on a wolt app fault that I got confirmation on from Macdonalds and another support worker. She seems to not care and still toke my payment, that's why I removed order and got offline
# 13. Why the F do I have to ask support everytime I want to cancel an order. I have enough experience to know when I have to cancel and when not. I’ve done 550 orders this month alone, let me cancel whenever want without support please
# 14. A support member deducted 145 kr from my pay, because of a spill. He said it was procedure, but I don’t know any workplace that deducts the pay of its employees due to spills. It happens. I would like my money returned please, as I earned that.
# 15. Canceling order is not working. Error Code: Task.Body.order_cancellation.Error.geofence
# 16. Poor service that was removed for me DKK 457. Justify that I have handed in order for only wrong and it was not my problem and I have been customer service agree but she did not agree with me then she removes me without her telling me that I will remove from you 457 kr. It has asked me that I have delivered it wrong then I say to them no I have handed in it it is real customers and I have also said to them maybe they may well be that him as he works in the student Seven who was he lives the order then he writes on the bus order number wrong
# 17. My order disappeared without me being informed that it had been canceled
# 18. You gave me an order that was already picked up and did not want to give me compensation. Extremely unacceptable
# 19. Please make it possible to cancel an order instead of contacting support. Unfortunately, experience a wait of +5 min at Venues. And understandingly they are busy, but who bring out is time = money
# 20. There one who drove into my taillight while I was parked with a customer. Have taken pictures but yes:/

# %% [markdown]
# # Model 3

# %%
from bertopic import BERTopic

loaded_model_3 = BERTopic.load("simple_model3")
print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %%
loaded_model_3.get_topic_info()
# Out:
#     Topic  Count                                          Name  \
# 0      -1   4111                        -1_order_time_wolt_app
# 1       0    868                        0_good_happy_wolt_work
# 2       1    633                 1_order_order order_hour_home
# 3       2    624                  2_distance_km_delivery_drive
# 4       3    452                  3_payment_earning_pay_salary
# 5       4    380                  4_restaurant_ready_food_wait
# 6       5    374               5_courier_new courier_new_order
# 7       6    354                 6_map_address_google_location
# 8       7    307               7_mcdonald_wait_mcdonalds_order
# 9       8    274      8_support_wolt support_team_support team
# 10      9    248             9_wolt_market_wolt market_denmark
# 11     10    233                 10_app_app work_work_time app
# 12     11    215                        11_low_order_price_pay
# 13     12    201                  12_app_order_order app_error
# 14     13    183     13_burger_king_burger king_burger concept
# 15     14    143             14_task_task task_new task_accept
# 16     15    131              15_bundle_bundle order_order_pay
# 17     16    104                         16_drink_bag_cup_soda
# 18     17    104  17_bonus_weekend_weekend bonus_bonus weekend
# 19     18     95            18_wolt_pay_night supplement_money
# 20     19     81                 19_support_deliver_order_tell
# 21     20     79           20_wolt happy_happy wolt_happy_wolt
# 22     21     75              21_dkk_hour_dkk hour_hour online
# 23     22     69       22_mile_mile offer_drive mile_let drive
# 24     23     65               23_system_new_new system_update
# 25     24     61               24_bag_heavy_wolt market_market
#
#                                        Representation  \
# 0   [order, time, wolt, app, work, delivery, custo...
# 1   [good, happy, wolt, work, thank, day, love, jo...
# 2   [order, order order, hour, home, wait, home or...
# 3   [distance, km, delivery, drive, pay, long, car...
# 4   [payment, earning, pay, salary, money, low, wa...
# 5   [restaurant, ready, food, wait, time, food rea...
# 6   [courier, new courier, new, order, order couri...
# 7   [map, address, google, location, gps, app, map...
# 8   [mcdonald, wait, mcdonalds, order, ready, minu...
# 9   [support, wolt support, team, support team, ba...
# 10  [wolt, market, wolt market, denmark, order, ma...
# 11  [app, app work, work, time app, update, freeze...
# 12  [low, order, price, pay, pay order, payment, p...
# 13  [app, order, order app, error, accept, get, ti...
# 14  [burger, king, burger king, burger concept, co...
# 15  [task, task task, new task, accept, accept tas...
# 16  [bundle, bundle order, order, pay, task, order...
# 17  [drink, bag, cup, soda, spill, lid, pack, mcdo...
# 18  [bonus, weekend, weekend bonus, bonus weekend,...
# 19  [wolt, pay, night supplement, money, remember,...
# 20  [support, deliver, order, tell, mistake, deduc...
# 21  [wolt happy, happy wolt, happy, wolt, love wol...
# 22  [dkk, hour, dkk hour, hour online, online, 3 h...
# 23  [mile, mile offer, drive mile, let drive, clos...
# 24  [system, new, new system, update, new update, ...
# 25  [bag, heavy, wolt market, market, break, wolt,...
#
#                                   Representative_Docs
# 0   [The world's bad wolt guard. It requires a lit...
# 1   [wolt is the best i am happy with wolt, I am v...
# 2   [if there are no orders, I'll be off in a whil...
# 3   [Where is the delivery’s ?!, Deliveries should...
# 4   [The earning are less than before, The payment...
# 5   [Much behind at last restaurant, Orders coming...
# 6   [No orders and to much couriers…, few orders t...
# 7   [Addresses were misleading, Please make it pos...
# 8   [15-20 minute wait at McDonald's, Very long wa...
# 9   [Haven't used Wolt Support, so is still uncert...
# 10  [Wolt Market vanlosene, Wolt Market vanlosene,...
# 11  [The app was down for me, MOST RIGGED MANIPULA...
# 12  [Prices of the orders are very low, The price ...
# 13  [Uphill…. Began as courier 5 months ago (it ma...
# 14  [Burger King and The Burger Concept is almost ...
# 15  [I didn't get any task, Too much waitig for ne...
# 16  [Why the system give bundles when there are no...
# 17  [I really think it's slavish that places like ...
# 18  [Put a bonus weekend 00to02am, Where is our we...
# 19  [I remember when Wolt gave you the backpack, a...
# 20  [I had the order 7J5DV3, in which the app sent...
# 21  [i am very happy with wolt, i am very happy wi...
# 22  [It is disastrous, yesterday after 7 hours on ...
# 23  [App lets me drive for miles, then offers almo...
# 24  [I Just Want to Give feedback for New System t...
# 25  [I can’t work without bag, because bag was sto...

# %% [markdown]
# # Model with zero-shot

# %%
from bertopic import BERTopic
import pandas as pd
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
import spacy
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.model_selection import ParameterGrid
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance
from octis.evaluation_metrics.coherence_metrics import Coherence
from umap import UMAP
from hdbscan import HDBSCAN
import spacy
from tqdm import tqdm

# Your documents
documents = df_combined["translated_Comment"].tolist()

# Your zero-shot topic list
zeroshot_topic_list = [
    "Flexibility in work hours and when to go online",
    "Earnings and pay including bonuses",
    "Planning your time",
    "experience and satisfaction with completing jobs or tasks",
    "Interactions with customers",
    "Interactions and chat with Wolt support team",
    "Interactions with venues or restaurants",
    "Techlogical issues or bugs with the app",
    "Communication",
    "Gear, equipment, bag, clothes, cup,",
    "Safety"
]

# Embedding model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
#Compute embeddings
#embeddings = embedding_model.encode(documents, show_progress_bar=True)

# Prepare Tokenizer model
# Load spaCy English model
nlp = spacy.load("en_core_web_sm")
nlp.max_length = 1520000

# Define custom tokenizer function with lemmatization for topic representations
def spacy_tokenizer(doc):
    spacy_doc = nlp(doc)
    # Lemmatize, lowercase, remove stopwords & punctuation
    return [token.lemma_.lower() for token in spacy_doc if not token.is_stop and not token.is_punct] #

base_vectorizer = CountVectorizer(tokenizer=spacy_tokenizer, min_df=5) # remove words that appear in less than 5 documents
base_vectorizer.fit(documents) # fit the vectorizer to the documents, to find the vocabulary for topic representations
filtered_vocab = set(base_vectorizer.get_feature_names_out()) # # get the vocabulary of the filtered vectorizer

def filtered_tokenizer(doc): # Now create a custom tokenizer that only keeps words in the filtered vocabulary, which will be passed to the CountVectorizer for topic representations
    tokens = spacy_tokenizer(doc)
    return [t for t in tokens if t in filtered_vocab]

# Create CountVectorizer with custom tokenizer
vectorizer_model = CountVectorizer(tokenizer=filtered_tokenizer, # use the custom tokenizer
                                   #stop_words="english", # already done in the tokenizer, but countvectorizer might have other stop words
                                   lowercase = False, # lowercase is already done in the tokenizer
                                   #min_df = 1, #  Excludes words that appear in only one document.
                                   ngram_range=(1, 2)) # consider topic representations that are made up of one or two words

def coherence_tokenizer(doc): # The tokenizer for the coherence score. This is a standard tokenizer that does not filter out words, but lemmatizes and lowercases them.
    spacy_doc = nlp(doc)
    return [
        token.lemma_.lower()
        for token in spacy_doc
        if not token.is_punct  # keep stopwords as I want to calculate the coherence score based on all words
    ]

tokens_for_coherence = [coherence_tokenizer(doc) for doc in documents] 


# Fine-tune representations 
#keybert_model = KeyBERTInspired()
#mmr_model = MaximalMarginalRelevance(diversity=0.2) #0.2 is used in the book.

#representation_model = {
    #"KeyBERT": keybert_model,
    #"MMR": mmr_model
#}


# Function to calculate Topic Diversity as the proportion of unique words across all top-k topic words (PUW)
def topic_diversity(topics, topk):
    all_words = [word for topic in topics for word in topic[:topk]]
    unique_words = set(all_words)
    return len(unique_words) / len(all_words)


# Results storage. A list that sores the coherence and diversty score of each model
results = []
# A list which saves all the models, so each model can be easily retrieved by typing its corresponding parameters
saved_models = {}  


# Loop through models 1 to 10
for i in tqdm(range(1, 11)):
    # Load existing saved model
    loaded_model = BERTopic.load(f"simple_model{i}")

    umap_params = loaded_model.umap_model.get_params()
    hdbscan_params = loaded_model.hdbscan_model.get_params()

    # Re-initialize the model with zero-shot topic modeling enabled
    # Note: We must create a new BERTopic instance with the same saved parameters plus zero-shot params
    topic_model = BERTopic(
        embedding_model=embedding_model,
        umap_model = UMAP(**umap_params),
        hdbscan_model = HDBSCAN(**hdbscan_params),
        vectorizer_model=vectorizer_model,
        zeroshot_topic_list=zeroshot_topic_list,
        zeroshot_min_similarity=0.5,
        top_n_words=10,
    )

    # Optionally, if you want to keep the original fitted topics and just add zero-shot, you might try:
    # topic_model.topics_, topic_model.probs_ = loaded_model.topics_, loaded_model.probs_

    # Fit or transform documents
    topics, probs = topic_model.fit_transform(documents)


    # Get top `top_n_words` words per topic (excluding outlier topic -1)
    topic_words = [] #an empty list that will be used to store the top words of every topic found for each model. So a list (topics) of lists (top words for each topic).
    
    for topic in topic_model.get_topic_freq().Topic: # grabs the topics from the topic_model
        if topic != -1: #skips the outlier topic -1
            topic_content = topic_model.get_topic(topic) #get the top words and scores for the topics.
            if isinstance(topic_content, list) and len(topic_content) > 0: # checks if the topic_content (top words) is a list and has more than 0 elements. To check if there actually is extracted topic words
                if isinstance(topic_content[0], tuple) and len(topic_content[0]) == 2: # checks if the first element of topic_content is a tuple and has two elements (word and score)
                    words = [word for word, _ in topic_content[:topic_model.top_n_words]] #if so, it extracts the words (but not the scores) in a variable called "words"
                else:
                    words = topic_content[:topic_model.top_n_words] #if there is only top words but no scores, extracts the top words in a variabkle called "words"
                topic_words.append(words) #append the topic words (defined in the variable "words") to the topic_words list for the model.

    if topic_words:
        
        # Calculate NPMI
        coherence_model = Coherence(texts=tokens_for_coherence, # reference corpus. Here it's all documents in the dataset
                                    topk=10, #specifies the number of top words to consider for NPMI calculation
                                    measure="c_npmi")
        npmi_score = coherence_model.score({"topics": topic_words}) # average

        # Calculate Topic Diversity
            # the topic_diversity command was defned before the loop. This is not a standard command, so I defined how it works earlier.
        diversity_score = topic_diversity(topics=topic_words, topk=10)

        # Calculate Topic Quality by multiplying NPMI score and Topic Diversity
        topic_quality = npmi_score * diversity_score 

        # Print the number of topics
        num_topics = len(topic_words) #number of topics is the length of the topic_words list
        num_outliers = sum(1 for topic in topics if topic == -1) #number of outliers is the number of topics that are equal to -1
        print(f"Number of Topics: {num_topics} | TC: {npmi_score:.3f} | TD: {diversity_score:.3f} | TQ: {topic_quality:.3f} | num_outliers: {num_outliers}") #4f = 4 decimals 


    # Save the updated model with zero-shot topics included
    topic_model.save(f"simple_model{i}_zeroshot")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 12:51:02,969 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 30 | TC: 0.072 | TD: 0.703 | TQ: 0.051 | num_outliers: 3716
#  10%|█         | 1/10 [02:04<18:37, 124.20s/it]/Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 12:52:44,849 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 32 | TC: 0.089 | TD: 0.725 | TQ: 0.065 | num_outliers: 4063
#  20%|██        | 2/10 [03:46<14:49, 111.13s/it]/Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 12:54:27,678 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 32 | TC: 0.087 | TD: 0.716 | TQ: 0.062 | num_outliers: 4046
#  30%|███       | 3/10 [05:28<12:30, 107.24s/it]/Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 12:56:10,021 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 33 | TC: 0.087 | TD: 0.718 | TQ: 0.062 | num_outliers: 3877
#  40%|████      | 4/10 [07:11<10:32, 105.38s/it]/Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 12:57:52,702 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 31 | TC: 0.079 | TD: 0.713 | TQ: 0.056 | num_outliers: 3898
#  50%|█████     | 5/10 [08:54<08:42, 104.44s/it]/Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 12:59:35,912 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 35 | TC: 0.088 | TD: 0.731 | TQ: 0.064 | num_outliers: 4345
#  60%|██████    | 6/10 [10:38<06:57, 104.48s/it]/Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 13:01:20,453 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 30 | TC: 0.081 | TD: 0.703 | TQ: 0.057 | num_outliers: 3811
#  70%|███████   | 7/10 [12:23<05:13, 104.61s/it]/Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 13:03:06,408 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 28 | TC: 0.086 | TD: 0.689 | TQ: 0.059 | num_outliers: 3882
#  80%|████████  | 8/10 [14:09<03:30, 105.14s/it]/Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 13:04:58,193 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 31 | TC: 0.088 | TD: 0.723 | TQ: 0.063 | num_outliers: 4126
#  90%|█████████ | 9/10 [16:02<01:47, 107.53s/it]/Users/jonashermansen/Library/Caches/pypoetry/virtualenvs/bertopic-evaluation-30RDbgio-py3.9/lib/python3.9/site-packages/scipy/sparse/_index.py:145: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#
# 2025-05-21 13:06:27,480 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
# Number of Topics: 10 | TC: 0.061 | TD: 0.810 | TQ: 0.050 | num_outliers: 64
# 100%|██████████| 10/10 [17:32<00:00, 105.28s/it]

# %%
from bertopic import BERTopic

# Load the saved model
simple_model1_zeroshot = BERTopic.load("simple_model1_zeroshot")

# Get topic information (frequency, topic ID, etc.)
simple_model1_zeroshot.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   3716                            -1_order_time_wolt_work
# 1       0     11    Flexibility in work hours and when to go online
# 2       1     22                 Earnings and pay including bonuses
# 3       2      3  experience and satisfaction with completing jo...
# 4       3      4                        Interactions with customers
# 5       4     74       Interactions and chat with Wolt support team
# 6       5     34            Interactions with venues or restaurants
# 7       6    329            Techlogical issues or bugs with the app
# 8       7      1                Gear, equipment, bag, clothes, cup,
# 9       8    152              8_task_task task_new task_accept task
# 10      9    343                           9_map_address_google_gps
# 11     10     90                10_happy wolt_wolt happy_happy_wolt
# 12     11    129                   11_bundle_bundle order_order_pay
# 13     12    369                   12_courier_new courier_new_order
# 14     13    882                           13_good_happy_thank_wolt
# 15     14    316                         14_support_system_new_chat
# 16     15    538                            15_app_order_drive_time
# 17     16    119              16_wolt_pay_night supplement_remember
# 18     17    163       17_denmark_danish_market vanløse_wolt market
# 19     18     75                   18_dkk_hour_dkk hour_hour online
# 20     19     88       19_bonus_weekend_weekend bonus_bonus weekend
# 21     20    794                           20_payment_pay_low_price
# 22     21    167             21_delivery_deliver_rate_delivery rate
# 23     22    273                     22_km_distance_drive_kilometer
# 24     23    112                      23_support_order_deliver_tell
# 25     24    223                              24_bag_drink_cup_pack
# 26     25    180          25_burger_king_burger king_burger concept
# 27     26    345                   26_mcdonald_wait_mcdonalds_order
# 28     27    387                      27_ready_restaurant_food_wait
# 29     28    219                               28_hour_order_wait_1
# 30     29    306               29_order_home_order order_home order
#
#                                        Representation  \
# 0   [order, time, wolt, work, delivery, customer, ...
# 1   [online, flexible, hour, flexibility, earn mon...
# 2   [earning, bonus, earning hour, earning increas...
# 3   [happy like, satisfy happy, job satisfy, verry...
# 4   [customer, wonder, donalds, store, wonder eye,...
# 5   [wolt support, wolt, support, work wolt, team,...
# 6   [venue, restaurant, venue mark, ready, mark, o...
# 7   [app, app work, work, crash, error, app crash,...
# 8   [buy gear, sadly buy, sadly, gear, buy, , , , , ]
# 9   [task, task task, new task, accept task, accep...
# 10  [map, address, google, gps, location, maps, ap...
# 11  [happy wolt, wolt happy, happy, wolt, love wol...
# 12  [bundle, bundle order, order, pay, task, syste...
# 13  [courier, new courier, new, order, order couri...
# 14  [good, happy, thank, wolt, work, day, job, lov...
# 15  [support, system, new, chat, help, bad, suppor...
# 16  [app, order, drive, time, app let, mile, mile ...
# 17  [wolt, pay, night supplement, remember, supple...
# 18  [denmark, danish, market vanløse, wolt market,...
# 19  [dkk, hour, dkk hour, hour online, online, 3 h...
# 20  [bonus, weekend, weekend bonus, bonus weekend,...
# 21  [payment, pay, low, price, money, salary, hour...
# 22  [delivery, deliver, rate, delivery rate, money...
# 23  [km, distance, drive, kilometer, pay, calculat...
# 24  [support, order, deliver, tell, customer, mist...
# 25  [bag, drink, cup, pack, spill, soda, paper, fo...
# 26  [burger, king, burger king, burger concept, co...
# 27  [mcdonald, wait, mcdonalds, order, ready, minu...
# 28  [ready, restaurant, food, wait, time, food rea...
# 29  [hour, order, wait, 1, hour order, 2, order ho...
# 30  [order, home, order order, home order, order h...
#
#                                   Representative_Docs
# 0   [50- 90 kr / 30-40 min.. when it's 140-200 kr....
# 1   [I am very happy with wolt and I like to go on...
# 2   [Okay-ish earnings per hour, Earnings per hour...
# 3   [Satisfied with everything, I am happy, but I ...
# 4   [Very friendly customer service!, I love the n...
# 5   [Wolt support very very very bad.too much bad ...
# 6   [app throws orders with a certain distance and...
# 7   [The app is working very bad, The app is worki...
# 8          [Sadly that you have to buy gear yourself]
# 9   [It's Sku Slay with Tasks, Because i always ge...
# 10  [Please don’t pley maps, Keeps giving me the w...
# 11  [i am very happy with wolt, i am very happy wi...
# 12  [Why the system give bundles when there are no...
# 13  [Either there are too few orders or too many c...
# 14  [wolt is the best i am happy with wolt, Thanks...
# 15  [Support was slow to respond, so I contacted D...
# 16  [App lets me drive for miles, then offers almo...
# 17  [I remember when Wolt gave you the backpack, a...
# 18  [I also want to order from Wolt Market in Vanl...
# 19  [Almost 2 hours online, 2 orders, 110 dkk, 3 h...
# 20  [Put a bonus weekend 00to02am, Where is our we...
# 21  [The gains seems low :(, The payments are a pi...
# 22  [Almost no deliveries, Deliveries should be mo...
# 23  [You say it is 0.1km ekstra but actual distanc...
# 24  [I had the order 7J5DV3, in which the app sent...
# 25  [Please do something about the bags. Big proce...
# 26  [Burger King and The Burger Concept is almost ...
# 27  [Very long wait for McDonald's even if the ord...
# 28  [Please ask restaurant to mark food as ready o...
# 29  [no orders? in 1 hour one order, only 1 order ...
# 30  [i go home no have orders, ???? Orders? if the...

# %%
topics = simple_model1_zeroshot.topics_
documents = df_combined["translated_Comment"].tolist()  # if this was the original list

# %%
from collections import defaultdict
import random

# Organize documents by new topic
topic_to_docs = defaultdict(list)
for doc, topic in zip(documents, topics):
    topic_to_docs[topic].append(doc)

# Select only topic 5
topic_id = 0
docs = topic_to_docs.get(topic_id, [])

if docs:
    sampled_docs = random.sample(docs, min(20, len(docs)))  # Randomly select up to 20 docs
    print(f"\n=== Topic {topic_id} ({len(docs)} documents) ===")
    for i, doc in enumerate(sampled_docs):
        print(f"{i+1}. {doc}")
else:
    print(f"No documents found for Topic {topic_id}.")
# Out:
# === Topic 0 (11 documents) ===
# 1. I think it's great that I can be self -employed and I can go online or offline whenever I want. Also I earn money to cycle around and deliver
# 2. Super nice that you are so flexible with working hours. I couldn't wish for a better job
# 3. Very flexible workplace
# 4. Flexible working hours
# 5. The flexibility is absolutely great. I can work when I want. No more stress about thinking about the child.
# 6. I can log in and work when I have time.
# 7. I worked 12 13 hours as online on of my friend worked 5 6 hours as online but we earn same money. Do you distribute fairly?
# 8. Time flexibility is important, and we can have all the hours we want.
# 9. I consider that the freedom of hours that we can work is important.
# 10. I am very happy with wolt and I like to go online every day since this is the only job I have right now and I would like to have more orders during the time I am online
# 11. I stay online long time but have a few tasks only with long distanses

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
import spacy
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.model_selection import ParameterGrid
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance
from octis.evaluation_metrics.coherence_metrics import Coherence
from umap import UMAP
from hdbscan import HDBSCAN
import spacy

# Load your data
#df = pd.read_csv('~/Library/Mobile Documents/com~apple~CloudDocs/UNI-kopi 2/Kandidat/virtual_environments/data/short.csv')
#documents = df["translated_Comment"].tolist() # Convert to list of strings


# Define the hyperparameter grid
param_grid = {
    # BERTOPIC parameters
    #"min_topic_size": [50,70,90], # Minimum size of a topic. Should be higher than min_cluster_size
    #"top_n_words": [10],
    #"nr_topics": ["none","auto"], # None means no reduction

    #UMAP parameters
    "n_components": [2], # Number of dimensions to reduce to
    "n_neighbors": [15], # Number of neighbors to consider for UMAP 

    #HDBSCAN parameters
    "min_cluster_size": [30,50,70,90,110,130,150], # Min cluster size for HDBSCAN # Min cluster size for HDBSCAN. 
    #"min_samples": [70] # Minimum number of samples in a cluster
}
#Create all possible combinations of the hyperparameter grid
grid = list(ParameterGrid(param_grid))


# Filter: only keep combinations where min_cluster_size <= min_topic_size
#valid_grid = [
   # params for params in grid
    #if params["min_samples"] <= params["min_cluster_size"]
#]

# Total number combinations. Used later in the print statement to show progress
#total = len(valid_grid)

total = len(grid)


# Embedding model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
#Compute embeddings
#embeddings = embedding_model.encode(documents, show_progress_bar=True)



# Prepare Tokenizer model
# Load spaCy English model
nlp = spacy.load("en_core_web_sm")
nlp.max_length = 1520000

# Define custom tokenizer function with lemmatization for topic representations
def spacy_tokenizer(doc):
    spacy_doc = nlp(doc)
    # Lemmatize, lowercase, remove stopwords & punctuation
    return [token.lemma_.lower() for token in spacy_doc if not token.is_stop and not token.is_punct] #

base_vectorizer = CountVectorizer(tokenizer=spacy_tokenizer, min_df=5) # remove words that appear in less than 5 documents
base_vectorizer.fit(documents) # fit the vectorizer to the documents, to find the vocabulary for topic representations
filtered_vocab = set(base_vectorizer.get_feature_names_out()) # # get the vocabulary of the filtered vectorizer

def filtered_tokenizer(doc): # Now create a custom tokenizer that only keeps words in the filtered vocabulary, which will be passed to the CountVectorizer for topic representations
    tokens = spacy_tokenizer(doc)
    return [t for t in tokens if t in filtered_vocab]

# Create CountVectorizer with custom tokenizer
vectorizer_model = CountVectorizer(tokenizer=filtered_tokenizer, # use the custom tokenizer
                                   #stop_words="english", # already done in the tokenizer, but countvectorizer might have other stop words
                                   lowercase = False, # lowercase is already done in the tokenizer
                                   min_df = 1, #  Excludes words that appear in only one document.
                                   ngram_range=(1, 2)) # consider topic representations that are made up of one or two words

def coherence_tokenizer(doc): # The tokenizer for the coherence score. This is a standard tokenizer that does not filter out words, but lemmatizes and lowercases them.
    spacy_doc = nlp(doc)
    return [
        token.lemma_.lower()
        for token in spacy_doc
        if not token.is_punct  # keep stopwords as I want to calculate the coherence score based on all words
    ]

tokens_for_coherence = [coherence_tokenizer(doc) for doc in documents] 


# Fine-tune representations 
#keybert_model = KeyBERTInspired()
#mmr_model = MaximalMarginalRelevance(diversity=0.2) #0.2 is used in the book.

#representation_model = {
    #"KeyBERT": keybert_model,
    #"MMR": mmr_model
#}


# Function to calculate Topic Diversity as the proportion of unique words across all top-k topic words (PUW)
def topic_diversity(topics, topk):
    all_words = [word for topic in topics for word in topic[:topk]]
    unique_words = set(all_words)
    return len(unique_words) / len(all_words)


# Defintions to later being able to track best model. 
best_model = None #no best model from the start
best_score = -1 # the first model with a score better than -1 will the current best. Just a placeholder make npmi_score > best_score work.
best_params = None #no best parameters from the start


# Results storage. A list that sores the coherence and diversty score of each model
results = []
# A list which saves all the models, so each model can be easily retrieved by typing its corresponding parameters
saved_models = {}  



#### THE LOOP ####
# Grid search
for i, params in enumerate(grid, 1):#change to valid_grid as the parameter grid to iterate over if min_topic_size is used
    print(f"[{i}/{total}] Running with params: {params}") #print the current parameter combination being evaluated for each iteration 

    # UMAP
    umap_model = UMAP(n_neighbors=params["n_neighbors"],
                      n_components=params["n_components"], 
                      min_dist=0.0, 
                      metric='cosine', 
                      random_state=42)

    # HDBSCAN  
    hdbscan_model = HDBSCAN(min_cluster_size=params["min_cluster_size"], 
                            #min_samples=params["min_samples"], 
                            metric='euclidean', 
                            cluster_selection_method='eom',
                            prediction_data=True
                            )

    # BERTopic model
    topic_model = BERTopic(
        #nr_topics=params["nr_topics"],
        #min_topic_size=params["min_topic_size"]
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        #representation_model=representation_model,
        vectorizer_model=vectorizer_model, #this makes some models not able to calculate NPMI
        #ctfidf_model=ctfidf_model,
        top_n_words=10,   
    )

    # Fit model
    topics, _ = topic_model.fit_transform(documents, embeddings)

    # Save meach model in the Saved_models list
    param_key = tuple(sorted(params.items()))  # extracting the parameters for the each model and creates a unique key for every model combination
    saved_models[param_key] = topic_model # save the each model in the saved_models list by its unique key 


    # Get top `top_n_words` words per topic (excluding outlier topic -1)
    topic_words = [] #an empty list that will be used to store the top words of every topic found for each model. So a list (topics) of lists (top words for each topic).
    
    for topic in topic_model.get_topic_freq().Topic: # grabs the topics from the topic_model
        if topic != -1: #skips the outlier topic -1
            topic_content = topic_model.get_topic(topic) #get the top words and scores for the topics.
            if isinstance(topic_content, list) and len(topic_content) > 0: # checks if the topic_content (top words) is a list and has more than 0 elements. To check if there actually is extracted topic words
                if isinstance(topic_content[0], tuple) and len(topic_content[0]) == 2: # checks if the first element of topic_content is a tuple and has two elements (word and score)
                    words = [word for word, _ in topic_content[:topic_model.top_n_words]] #if so, it extracts the words (but not the scores) in a variable called "words"
                else:
                    words = topic_content[:topic_model.top_n_words] #if there is only top words but no scores, extracts the top words in a variabkle called "words"
                topic_words.append(words) #append the topic words (defined in the variable "words") to the topic_words list for the model.

    if topic_words:
        
        # Calculate NPMI
        coherence_model = Coherence(texts=tokens_for_coherence, # reference corpus. Here it's all documents in the dataset
                                    topk=10, #specifies the number of top words to consider for NPMI calculation
                                    measure="c_npmi")
        npmi_score = coherence_model.score({"topics": topic_words}) # average

        # Calculate Topic Diversity
            # the topic_diversity command was defned before the loop. This is not a standard command, so I defined how it works earlier.
        diversity_score = topic_diversity(topics=topic_words, topk=10)

        # Calculate Topic Quality by multiplying NPMI score and Topic Diversity
        topic_quality = npmi_score * diversity_score 


        # Print the number of topics
        num_topics = len(topic_words) #number of topics is the length of the topic_words list
        num_outliers = sum(1 for topic in topics if topic == -1) #number of outliers is the number of topics that are equal to -1
        print(f"Number of Topics: {num_topics} | TC: {npmi_score:.3f} | TD: {diversity_score:.3f} | TQ: {topic_quality:.3f} | num_outliers: {num_outliers}") #4f = 4 decimals 

        # Track best model
        if npmi_score > best_score:
            best_score = npmi_score
            best_model = topic_model
            best_params = params

        # store the params, npmi, diversy, and num_topcis for each model in the results list
        results.append({
            "params": params,
            "num_topics": num_topics,
            "npmi_score": npmi_score,
            "topic_diversity": diversity_score,
            "topic_quality": topic_quality,
            "num_outliers": num_outliers
        })

    else:
        print("No valid topics were generated.")

#####

import csv

# Save the all the models' information to a CSV file

model_info = [] # an empty list to store model information. This is the dataframe that will be saved in the CSV file in the end 

# Loop through the models saved from the loop above and save the information to the model_info dataframe
for param_key, model in saved_models.items(): #activates a loop that goes through all the models (identified by their unique key).
    # Convert the tuple of params back to a dictionary (a formal step)
    params_dict = dict(param_key)
    
    # Get topic information
    #topics_freq = model.get_topic_freq() #retrives the number of topics and documents in each topic
    #num_topics = len(topics_freq[topics_freq.Topic != -1]) #retrives the number of topics (length) and exlcudes the outlier topic -1
    
    ## Get performance metrics if available
    # Matches the models with parameters saved in the loop with the parameters of models saved in the CVS file
    matching_result = next((r for r in results if all(r["params"][k] == v for k, v in params_dict.items())), None)
    
    if matching_result: 
        num_topics =matching_result.get("num_topics", 0) #extract the number of topics for the models
        num_outliers = matching_result.get("num_outliers", 0) #extract the number of outliers for the models
        npmi_score = matching_result.get("npmi_score", 0) #extract the NPMI score for the models
        diversity_score = matching_result.get("topic_diversity", 0) #extract the topic diversity score for the models
        topic_quality = matching_result.get("topic_quality", 0) #extract the topic quality score for the models
        
        model_info.append({  #assigns the number of topics and scores to the differnt models in the model_info list. This is the dataframe that will be saved in the CSV file.
            **params_dict,  
            "num_topics": num_topics,
            "npmi_score": npmi_score,
            "topic_diversity": diversity_score,
            "topic_quality": topic_quality,
            "num_outliers" : num_outliers   
        })

# Now we retrived all the information to the model_info dataframe, 
# Saves it to CSV file
with open('min_cluster_size', 'w', newline='') as csvfile:
    fieldnames = list(model_info[0].keys()) if model_info else []
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    for info in model_info:
        writer.writerow(info)


# Sort the results by NPMI score in descending order
top_20_npmi = sorted(results, key=lambda x: x["npmi_score"], reverse=True)[:10]

# Sort the results by Topic Diversity score in descending order
top_20_diversity = sorted(results, key=lambda x: x["topic_diversity"], reverse=True)[:10]

# Sort the results by both NPMI and Topic Diversity score in descending order
top_20_quality = sorted(results, key=lambda x: (x["topic_quality"]), reverse=True)[:10]

# Print the top 20 based on NPMI
print("\nTop 20 Best Performing Models (Based on NPMI):\n")
for i, result in enumerate(top_20_npmi, start=1):
    print(f"Rank {i}: num_topics: {result['num_topics']} | {result['params']} | TC: {result['npmi_score']:.3f} | TD: {result['topic_diversity']:.3f} | TQ: {result['topic_quality']:.3f} | num_outliers: {result['num_outliers']})")

# Print the top 20 based on Topic Diversity
print("\nTop 20 Best Performing Models (Based on Topic Diversity):\n")
for i, result in enumerate(top_20_diversity, start=1):
    print(f"Rank {i}: num_topics: {result['num_topics']} | {result['params']} | TC: {result['npmi_score']:.3f} | TD: {result['topic_diversity']:.3f} | TQ: {result['topic_quality']:.3f} | num_outliers: {result['num_outliers']})")

# Print the top 20 based on topic quality
print("\nTop 20 Best Performing Models (Based on topic quality):\n")
for i, result in enumerate(top_20_quality, start=1):
    print(f"Rank {i}: num_topics: {result['num_topics']} | {result['params']} | TC: {result['npmi_score']:.3f} | TD: {result['topic_diversity']:.3f} | TQ: {result['topic_quality']:.3f} | num_outliers: {result['num_outliers']})")
# Out:
# [1/7] Running with params: {'min_cluster_size': 30, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 63 | TC: 0.063 | TD: 0.735 | TQ: 0.046 | num_outliers: 3378
# [2/7] Running with params: {'min_cluster_size': 50, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 38 | TC: 0.059 | TD: 0.682 | TQ: 0.040 | num_outliers: 3848
# [3/7] Running with params: {'min_cluster_size': 70, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 26 | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059
# [4/7] Running with params: {'min_cluster_size': 90, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 18 | TC: 0.065 | TD: 0.683 | TQ: 0.044 | num_outliers: 4458
# [5/7] Running with params: {'min_cluster_size': 110, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 15 | TC: 0.064 | TD: 0.680 | TQ: 0.043 | num_outliers: 4448
# [6/7] Running with params: {'min_cluster_size': 130, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 10 | TC: 0.055 | TD: 0.690 | TQ: 0.038 | num_outliers: 3780
# [7/7] Running with params: {'min_cluster_size': 150, 'n_components': 2, 'n_neighbors': 15}
# Number of Topics: 7 | TC: 0.058 | TD: 0.743 | TQ: 0.043 | num_outliers: 3201
#
# Top 20 Best Performing Models (Based on NPMI):
#
# Rank 1: num_topics: 26 | {'min_cluster_size': 70, 'n_components': 2, 'n_neighbors': 15} | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059)
# Rank 2: num_topics: 18 | {'min_cluster_size': 90, 'n_components': 2, 'n_neighbors': 15} | TC: 0.065 | TD: 0.683 | TQ: 0.044 | num_outliers: 4458)
# Rank 3: num_topics: 15 | {'min_cluster_size': 110, 'n_components': 2, 'n_neighbors': 15} | TC: 0.064 | TD: 0.680 | TQ: 0.043 | num_outliers: 4448)
# Rank 4: num_topics: 63 | {'min_cluster_size': 30, 'n_components': 2, 'n_neighbors': 15} | TC: 0.063 | TD: 0.735 | TQ: 0.046 | num_outliers: 3378)
# Rank 5: num_topics: 38 | {'min_cluster_size': 50, 'n_components': 2, 'n_neighbors': 15} | TC: 0.059 | TD: 0.682 | TQ: 0.040 | num_outliers: 3848)
# Rank 6: num_topics: 7 | {'min_cluster_size': 150, 'n_components': 2, 'n_neighbors': 15} | TC: 0.058 | TD: 0.743 | TQ: 0.043 | num_outliers: 3201)
# Rank 7: num_topics: 10 | {'min_cluster_size': 130, 'n_components': 2, 'n_neighbors': 15} | TC: 0.055 | TD: 0.690 | TQ: 0.038 | num_outliers: 3780)
#
# Top 20 Best Performing Models (Based on Topic Diversity):
#
# Rank 1: num_topics: 7 | {'min_cluster_size': 150, 'n_components': 2, 'n_neighbors': 15} | TC: 0.058 | TD: 0.743 | TQ: 0.043 | num_outliers: 3201)
# Rank 2: num_topics: 63 | {'min_cluster_size': 30, 'n_components': 2, 'n_neighbors': 15} | TC: 0.063 | TD: 0.735 | TQ: 0.046 | num_outliers: 3378)
# Rank 3: num_topics: 10 | {'min_cluster_size': 130, 'n_components': 2, 'n_neighbors': 15} | TC: 0.055 | TD: 0.690 | TQ: 0.038 | num_outliers: 3780)
# Rank 4: num_topics: 26 | {'min_cluster_size': 70, 'n_components': 2, 'n_neighbors': 15} | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059)
# Rank 5: num_topics: 18 | {'min_cluster_size': 90, 'n_components': 2, 'n_neighbors': 15} | TC: 0.065 | TD: 0.683 | TQ: 0.044 | num_outliers: 4458)
# Rank 6: num_topics: 38 | {'min_cluster_size': 50, 'n_components': 2, 'n_neighbors': 15} | TC: 0.059 | TD: 0.682 | TQ: 0.040 | num_outliers: 3848)
# Rank 7: num_topics: 15 | {'min_cluster_size': 110, 'n_components': 2, 'n_neighbors': 15} | TC: 0.064 | TD: 0.680 | TQ: 0.043 | num_outliers: 4448)
#
# Top 20 Best Performing Models (Based on topic quality):
#
# Rank 1: num_topics: 26 | {'min_cluster_size': 70, 'n_components': 2, 'n_neighbors': 15} | TC: 0.100 | TD: 0.688 | TQ: 0.069 | num_outliers: 4059)
# Rank 2: num_topics: 63 | {'min_cluster_size': 30, 'n_components': 2, 'n_neighbors': 15} | TC: 0.063 | TD: 0.735 | TQ: 0.046 | num_outliers: 3378)
# Rank 3: num_topics: 18 | {'min_cluster_size': 90, 'n_components': 2, 'n_neighbors': 15} | TC: 0.065 | TD: 0.683 | TQ: 0.044 | num_outliers: 4458)
# Rank 4: num_topics: 15 | {'min_cluster_size': 110, 'n_components': 2, 'n_neighbors': 15} | TC: 0.064 | TD: 0.680 | TQ: 0.043 | num_outliers: 4448)
# Rank 5: num_topics: 7 | {'min_cluster_size': 150, 'n_components': 2, 'n_neighbors': 15} | TC: 0.058 | TD: 0.743 | TQ: 0.043 | num_outliers: 3201)
# Rank 6: num_topics: 38 | {'min_cluster_size': 50, 'n_components': 2, 'n_neighbors': 15} | TC: 0.059 | TD: 0.682 | TQ: 0.040 | num_outliers: 3848)
# Rank 7: num_topics: 10 | {'min_cluster_size': 130, 'n_components': 2, 'n_neighbors': 15} | TC: 0.055 | TD: 0.690 | TQ: 0.038 | num_outliers: 3780)
